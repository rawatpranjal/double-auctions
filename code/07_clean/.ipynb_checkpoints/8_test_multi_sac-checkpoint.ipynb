# %%
#from setup import *
##from agents import *
#from env import *
gamereinforcers, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed = '1001', 1, 1, 3, 1, 100, 9, 42
disclosure = ['rnd', 'period', 'step','currentBid','currentAsk','buy','sell','price','sale']
buyerStrategies = ['SAC']
sellerStrategies = ['TruthTeller']
gameData = [gamereinforcers, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed] 
buyers, sellers = generateAgents(gameData,buyerStrategies,sellerStrategies,disclosure)
log = Log(gameData, buyerStrategies, sellerStrategies, disclosure)

for rnd in range(numRounds):
    roundData = roundSetup(*gameData)
    buyerValues, sellerCosts, demand, supply, prices, clearingPrice, clearingQuantity  = roundData[0:7]
    [buyerReservationPrices, sellerReservationPrices, buyerSurplus, sellerSurplus, totalSurplus, buyerSurplusFrac, sellerSurplusFrac] = roundData[7:]
    log.addRound([rnd] + roundData)
    resetRounds(buyers, sellers, buyerValues, sellerCosts)
    for period in range(numPeriods):
        resetPeriods(buyers, sellers)
        for step in range(numSteps):
            resetSteps(buyers, sellers)
            bids, asks = collectOffers(buyers, sellers)
            currentAsk, currentAskIdx, currentBid, currentBidIdx = bestOffers(bids, asks)
            price, buy, sell = trade(buyers, sellers, currentAsk, currentAskIdx, currentBid, currentBidIdx)
            bprofit, sprofit = 0, 0
            if price > 0:
                buyers[currentBidIdx].transact(price)
                sellers[currentAskIdx].transact(price)
                bprofit = buyers[currentBidIdx].stepProfits
                sprofit = sellers[currentAskIdx].stepProfits
            log.addStep([rnd, period, step, bids, asks, currentBid, currentBidIdx, currentAsk, currentAskIdx, buy, sell, price, price>0, bprofit, sprofit])
            observe(buyers, sellers, log.disclose()) # observe new state
            updateStates(buyers, sellers)
        updatePolicy(buyers, sellers)
        
        if period % (numPeriods/numPeriods) == 0:
            print(f'\n{period}')
            display(log.getPeriod(rnd, period).tail(100)[['bprofit', 'currentBidIdx']].groupby('currentBidIdx').sum())
            display(log.getPeriod(rnd, period).tail(100)[['sprofit', 'currentAskIdx']].groupby('currentAskIdx').sum())
            display(log.getPeriod(rnd,period))
# Out:
# 0
#                bprofit
# currentBidIdx
# 0.0             -15.05
#                sprofit
# currentAskIdx
# 0.0             -84.25
#    rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 0    0       0     0  [90.7]   [0.0]        90.7            0.0         0.0
# 1    0       0     1  [63.6]  [41.8]        63.6            0.0        41.8
# 2    0       0     2  [90.2]  [62.2]        90.2            0.0        62.2
# 3    0       0     3   [nan]   [nan]         NaN            NaN         NaN
# 4    0       0     4   [nan]   [nan]         NaN            NaN         NaN
# 5    0       0     5   [nan]   [nan]         NaN            NaN         NaN
# 6    0       0     6   [nan]   [nan]         NaN            NaN         NaN
# 7    0       0     7   [nan]   [nan]         NaN            NaN         NaN
# 8    0       0     8   [nan]   [nan]         NaN            NaN         NaN
#
#    currentAskIdx  buy sell  price   sale  bprofit  sprofit
# 0            0.0  1.0  1.0  45.35   True   -54.65   -45.35
# 1            0.0  1.0  1.0  52.70   True    -5.70   -10.90
# 2            0.0  0.0  1.0  90.20   True    45.30   -28.00
# 3            NaN  NaN  NaN    NaN  False     0.00     0.00
# 4            NaN  NaN  NaN    NaN  False     0.00     0.00
# 5            NaN  NaN  NaN    NaN  False     0.00     0.00
# 6            NaN  NaN  NaN    NaN  False     0.00     0.00
# 7            NaN  NaN  NaN    NaN  False     0.00     0.00
# 8            NaN  NaN  NaN    NaN  False     0.00     0.00
# 1
#                bprofit
# currentBidIdx
# 0.0             -45.45
#                sprofit
# currentAskIdx
# 0.0             -53.85
#     rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 9     0       1     0  [62.0]   [0.0]        62.0            0.0         0.0
# 10    0       1     1  [47.3]  [41.8]        47.3            0.0        41.8
# 11    0       1     2   [2.7]  [62.2]         2.7            0.0        62.2
# 12    0       1     3  [62.1]  [62.2]        62.1            0.0        62.2
# 13    0       1     4  [52.2]  [62.2]        52.2            0.0        62.2
# 14    0       1     5  [50.8]  [62.2]        50.8            0.0        62.2
# 15    0       1     6  [25.7]  [62.2]        25.7            0.0        62.2
# 16    0       1     7  [44.0]  [62.2]        44.0            0.0        62.2
# 17    0       1     8  [82.3]  [62.2]        82.3            0.0        62.2
#
#     currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 9             0.0   True   True  31.00   True   -69.00   -31.00
# 10            0.0   True   True  44.55   True   -13.85    -2.75
# 11            0.0  False  False    NaN  False     0.00     0.00
# 12            0.0  False  False    NaN  False     0.00     0.00
# 13            0.0  False  False    NaN  False     0.00     0.00
# 14            0.0  False  False    NaN  False     0.00     0.00
# 15            0.0  False  False    NaN  False     0.00     0.00
# 16            0.0  False  False    NaN  False     0.00     0.00
# 17            0.0  False   True  82.30   True    37.40   -20.10
# 2
#                bprofit
# currentBidIdx
# 0.0              -69.8
#                sprofit
# currentAskIdx
# 0.0              -29.5
#     rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 18    0       2     0  [12.8]   [0.0]        12.8            0.0         0.0
# 19    0       2     1  [49.2]  [41.8]        49.2            0.0        41.8
# 20    0       2     2  [46.6]  [62.2]        46.6            0.0        62.2
# 21    0       2     3  [47.5]  [62.2]        47.5            0.0        62.2
# 22    0       2     4  [58.8]  [62.2]        58.8            0.0        62.2
# 23    0       2     5  [81.6]  [62.2]        81.6            0.0        62.2
# 24    0       2     6   [nan]   [nan]         NaN            NaN         NaN
# 25    0       2     7   [nan]   [nan]         NaN            NaN         NaN
# 26    0       2     8   [nan]   [nan]         NaN            NaN         NaN
#
#     currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 18            0.0   True   True    6.4   True    -93.6     -6.4
# 19            0.0   True   True   45.5   True    -12.9     -3.7
# 20            0.0  False  False    NaN  False      0.0      0.0
# 21            0.0  False  False    NaN  False      0.0      0.0
# 22            0.0  False  False    NaN  False      0.0      0.0
# 23            0.0  False   True   81.6   True     36.7    -19.4
# 24            NaN    NaN    NaN    NaN  False      0.0      0.0
# 25            NaN    NaN    NaN    NaN  False      0.0      0.0
# 26            NaN    NaN    NaN    NaN  False      0.0      0.0
# 3
#                bprofit
# currentBidIdx
# 0.0            -104.05
#                sprofit
# currentAskIdx
# 0.0             -12.55
#     rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 27    0       3     0   [7.4]   [0.0]         7.4            0.0         0.0
# 28    0       3     1  [59.5]  [41.8]        59.5            0.0        41.8
# 29    0       3     2  [60.7]  [62.2]        60.7            0.0        62.2
# 30    0       3     3  [29.3]  [62.2]        29.3            0.0        62.2
# 31    0       3     4  [44.0]  [62.2]        44.0            0.0        62.2
# 32    0       3     5  [60.1]  [62.2]        60.1            0.0        62.2
# 33    0       3     6  [34.7]  [62.2]        34.7            0.0        62.2
# 34    0       3     7   [8.8]  [62.2]         8.8            0.0        62.2
# 35    0       3     8  [21.9]  [62.2]        21.9            0.0        62.2
#
#     currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 27            0.0   True   True   3.70   True   -96.30    -3.70
# 28            0.0   True   True  50.65   True    -7.75    -8.85
# 29            0.0  False  False    NaN  False     0.00     0.00
# 30            0.0  False  False    NaN  False     0.00     0.00
# 31            0.0  False  False    NaN  False     0.00     0.00
# 32            0.0  False  False    NaN  False     0.00     0.00
# 33            0.0  False  False    NaN  False     0.00     0.00
# 34            0.0  False  False    NaN  False     0.00     0.00
# 35            0.0  False  False    NaN  False     0.00     0.00
# 4
#                bprofit
# currentBidIdx
# 0.0             -69.25
#                sprofit
# currentAskIdx
# 0.0             -30.05
#     rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 36    0       4     0  [50.1]   [0.0]        50.1            0.0         0.0
# 37    0       4     1  [18.2]  [41.8]        18.2            0.0        41.8
# 38    0       4     2  [67.2]  [62.2]        67.2            0.0        62.2
# 39    0       4     3   [nan]   [nan]         NaN            NaN         NaN
# 40    0       4     4   [nan]   [nan]         NaN            NaN         NaN
# 41    0       4     5   [nan]   [nan]         NaN            NaN         NaN
# 42    0       4     6   [nan]   [nan]         NaN            NaN         NaN
# 43    0       4     7   [nan]   [nan]         NaN            NaN         NaN
# 44    0       4     8   [nan]   [nan]         NaN            NaN         NaN
#
#     currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 36            0.0   True   True  25.05   True   -74.95   -25.05
# 37            0.0   True  False  41.80   True   -16.60     0.00
# 38            0.0  False   True  67.20   True    22.30    -5.00
# 39            NaN    NaN    NaN    NaN  False     0.00     0.00
# 40            NaN    NaN    NaN    NaN  False     0.00     0.00
# 41            NaN    NaN    NaN    NaN  False     0.00     0.00
# 42            NaN    NaN    NaN    NaN  False     0.00     0.00
# 43            NaN    NaN    NaN    NaN  False     0.00     0.00
# 44            NaN    NaN    NaN    NaN  False     0.00     0.00
# 5
#                bprofit
# currentBidIdx
# 0.0             -52.15
#                sprofit
# currentAskIdx
# 0.0             -47.15
#     rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 45    0       5     0  [52.7]   [0.0]        52.7            0.0         0.0
# 46    0       5     1   [2.7]  [41.8]         2.7            0.0        41.8
# 47    0       5     2  [83.0]  [62.2]        83.0            0.0        62.2
# 48    0       5     3   [nan]   [nan]         NaN            NaN         NaN
# 49    0       5     4   [nan]   [nan]         NaN            NaN         NaN
# 50    0       5     5   [nan]   [nan]         NaN            NaN         NaN
# 51    0       5     6   [nan]   [nan]         NaN            NaN         NaN
# 52    0       5     7   [nan]   [nan]         NaN            NaN         NaN
# 53    0       5     8   [nan]   [nan]         NaN            NaN         NaN
#
#     currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 45            0.0   True   True  26.35   True   -73.65   -26.35
# 46            0.0   True  False  41.80   True   -16.60     0.00
# 47            0.0  False   True  83.00   True    38.10   -20.80
# 48            NaN    NaN    NaN    NaN  False     0.00     0.00
# 49            NaN    NaN    NaN    NaN  False     0.00     0.00
# 50            NaN    NaN    NaN    NaN  False     0.00     0.00
# 51            NaN    NaN    NaN    NaN  False     0.00     0.00
# 52            NaN    NaN    NaN    NaN  False     0.00     0.00
# 53            NaN    NaN    NaN    NaN  False     0.00     0.00
# 6
#                bprofit
# currentBidIdx
# 0.0             -72.55
#                sprofit
# currentAskIdx
# 0.0             -26.75
#     rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 54    0       6     0  [24.3]   [0.0]        24.3            0.0         0.0
# 55    0       6     1   [5.2]  [41.8]         5.2            0.0        41.8
# 56    0       6     2  [42.7]  [62.2]        42.7            0.0        62.2
# 57    0       6     3  [21.4]  [62.2]        21.4            0.0        62.2
# 58    0       6     4  [59.6]  [62.2]        59.6            0.0        62.2
# 59    0       6     5  [55.8]  [62.2]        55.8            0.0        62.2
# 60    0       6     6  [76.8]  [62.2]        76.8            0.0        62.2
# 61    0       6     7   [nan]   [nan]         NaN            NaN         NaN
# 62    0       6     8   [nan]   [nan]         NaN            NaN         NaN
#
#     currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 54            0.0   True   True  12.15   True   -87.85   -12.15
# 55            0.0   True  False  41.80   True   -16.60     0.00
# 56            0.0  False  False    NaN  False     0.00     0.00
# 57            0.0  False  False    NaN  False     0.00     0.00
# 58            0.0  False  False    NaN  False     0.00     0.00
# 59            0.0  False  False    NaN  False     0.00     0.00
# 60            0.0  False   True  76.80   True    31.90   -14.60
# 61            NaN    NaN    NaN    NaN  False     0.00     0.00
# 62            NaN    NaN    NaN    NaN  False     0.00     0.00
# 7
#                bprofit
# currentBidIdx
# 0.0              -75.4
#                sprofit
# currentAskIdx
# 0.0              -23.9
#     rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 63    0       7     0  [10.8]   [0.0]        10.8            0.0         0.0
# 64    0       7     1  [18.5]  [41.8]        18.5            0.0        41.8
# 65    0       7     2  [80.7]  [62.2]        80.7            0.0        62.2
# 66    0       7     3   [nan]   [nan]         NaN            NaN         NaN
# 67    0       7     4   [nan]   [nan]         NaN            NaN         NaN
# 68    0       7     5   [nan]   [nan]         NaN            NaN         NaN
# 69    0       7     6   [nan]   [nan]         NaN            NaN         NaN
# 70    0       7     7   [nan]   [nan]         NaN            NaN         NaN
# 71    0       7     8   [nan]   [nan]         NaN            NaN         NaN
#
#     currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 63            0.0   True   True    5.4   True    -94.6     -5.4
# 64            0.0   True  False   41.8   True    -16.6      0.0
# 65            0.0  False   True   80.7   True     35.8    -18.5
# 66            NaN    NaN    NaN    NaN  False      0.0      0.0
# 67            NaN    NaN    NaN    NaN  False      0.0      0.0
# 68            NaN    NaN    NaN    NaN  False      0.0      0.0
# 69            NaN    NaN    NaN    NaN  False      0.0      0.0
# 70            NaN    NaN    NaN    NaN  False      0.0      0.0
# 71            NaN    NaN    NaN    NaN  False      0.0      0.0
# 8
#                bprofit
# currentBidIdx
# 0.0             -44.85
#                sprofit
# currentAskIdx
# 0.0             -54.45
#     rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 72    0       8     0  [64.7]   [0.0]        64.7            0.0         0.0
# 73    0       8     1  [41.6]  [41.8]        41.6            0.0        41.8
# 74    0       8     2  [53.3]  [62.2]        53.3            0.0        62.2
# 75    0       8     3   [4.0]  [62.2]         4.0            0.0        62.2
# 76    0       8     4  [26.0]  [62.2]        26.0            0.0        62.2
# 77    0       8     5  [84.3]  [62.2]        84.3            0.0        62.2
# 78    0       8     6   [nan]   [nan]         NaN            NaN         NaN
# 79    0       8     7   [nan]   [nan]         NaN            NaN         NaN
# 80    0       8     8   [nan]   [nan]         NaN            NaN         NaN
#
#     currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 72            0.0   True   True  32.35   True   -67.65   -32.35
# 73            0.0   True  False  41.80   True   -16.60     0.00
# 74            0.0  False  False    NaN  False     0.00     0.00
# 75            0.0  False  False    NaN  False     0.00     0.00
# 76            0.0  False  False    NaN  False     0.00     0.00
# 77            0.0  False   True  84.30   True    39.40   -22.10
# 78            NaN    NaN    NaN    NaN  False     0.00     0.00
# 79            NaN    NaN    NaN    NaN  False     0.00     0.00
# 80            NaN    NaN    NaN    NaN  False     0.00     0.00
# 9
#                bprofit
# currentBidIdx
# 0.0             -29.05
#                sprofit
# currentAskIdx
# 0.0             -70.25
#     rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 81    0       9     0  [35.9]   [0.0]        35.9            0.0         0.0
# 82    0       9     1  [86.6]  [41.8]        86.6            0.0        41.8
# 83    0       9     2  [45.6]  [62.2]        45.6            0.0        62.2
# 84    0       9     3  [92.1]  [62.2]        92.1            0.0        62.2
# 85    0       9     4   [nan]   [nan]         NaN            NaN         NaN
# 86    0       9     5   [nan]   [nan]         NaN            NaN         NaN
# 87    0       9     6   [nan]   [nan]         NaN            NaN         NaN
# 88    0       9     7   [nan]   [nan]         NaN            NaN         NaN
# 89    0       9     8   [nan]   [nan]         NaN            NaN         NaN
#
#     currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 81            0.0   True   True  17.95   True   -82.05   -17.95
# 82            0.0   True   True  64.20   True     5.80   -22.40
# 83            0.0  False  False    NaN  False     0.00     0.00
# 84            0.0  False   True  92.10   True    47.20   -29.90
# 85            NaN    NaN    NaN    NaN  False     0.00     0.00
# 86            NaN    NaN    NaN    NaN  False     0.00     0.00
# 87            NaN    NaN    NaN    NaN  False     0.00     0.00
# 88            NaN    NaN    NaN    NaN  False     0.00     0.00
# 89            NaN    NaN    NaN    NaN  False     0.00     0.00
# 10
#                bprofit
# currentBidIdx
# 0.0             -78.45
#                sprofit
# currentAskIdx
# 0.0             -38.15
#     rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 90    0      10     0  [56.5]   [0.0]        56.5            0.0         0.0
# 91    0      10     1  [61.6]  [41.8]        61.6            0.0        41.8
# 92    0      10     2  [48.4]  [62.2]        48.4            0.0        62.2
# 93    0      10     3  [13.0]  [62.2]        13.0            0.0        62.2
# 94    0      10     4  [14.5]  [62.2]        14.5            0.0        62.2
# 95    0      10     5   [2.0]  [62.2]         2.0            0.0        62.2
# 96    0      10     6  [33.2]  [62.2]        33.2            0.0        62.2
# 97    0      10     7  [57.9]  [62.2]        57.9            0.0        62.2
# 98    0      10     8   [7.5]  [62.2]         7.5            0.0        62.2
#
#     currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 90            0.0   True   True  28.25   True   -71.75   -28.25
# 91            0.0   True   True  51.70   True    -6.70    -9.90
# 92            0.0  False  False    NaN  False     0.00     0.00
# 93            0.0  False  False    NaN  False     0.00     0.00
# 94            0.0  False  False    NaN  False     0.00     0.00
# 95            0.0  False  False    NaN  False     0.00     0.00
# 96            0.0  False  False    NaN  False     0.00     0.00
# 97            0.0  False  False    NaN  False     0.00     0.00
# 98            0.0  False  False    NaN  False     0.00     0.00
# 11
#                bprofit
# currentBidIdx
# 0.0             -46.95
#                sprofit
# currentAskIdx
# 0.0             -52.35
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 99     0      11     0  [63.8]   [0.0]        63.8            0.0         0.0
# 100    0      11     1  [44.9]  [41.8]        44.9            0.0        41.8
# 101    0      11     2  [81.1]  [62.2]        81.1            0.0        62.2
# 102    0      11     3   [nan]   [nan]         NaN            NaN         NaN
# 103    0      11     4   [nan]   [nan]         NaN            NaN         NaN
# 104    0      11     5   [nan]   [nan]         NaN            NaN         NaN
# 105    0      11     6   [nan]   [nan]         NaN            NaN         NaN
# 106    0      11     7   [nan]   [nan]         NaN            NaN         NaN
# 107    0      11     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy  sell  price   sale  bprofit  sprofit
# 99             0.0   True  True  31.90   True   -68.10   -31.90
# 100            0.0   True  True  43.35   True   -15.05    -1.55
# 101            0.0  False  True  81.10   True    36.20   -18.90
# 102            NaN    NaN   NaN    NaN  False     0.00     0.00
# 103            NaN    NaN   NaN    NaN  False     0.00     0.00
# 104            NaN    NaN   NaN    NaN  False     0.00     0.00
# 105            NaN    NaN   NaN    NaN  False     0.00     0.00
# 106            NaN    NaN   NaN    NaN  False     0.00     0.00
# 107            NaN    NaN   NaN    NaN  False     0.00     0.00
# 12
#                bprofit
# currentBidIdx
# 0.0             -57.15
#                sprofit
# currentAskIdx
# 0.0             -42.15
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 108    0      12     0  [63.5]   [0.0]        63.5            0.0         0.0
# 109    0      12     1   [8.2]  [41.8]         8.2            0.0        41.8
# 110    0      12     2  [45.6]  [62.2]        45.6            0.0        62.2
# 111    0      12     3  [72.6]  [62.2]        72.6            0.0        62.2
# 112    0      12     4   [nan]   [nan]         NaN            NaN         NaN
# 113    0      12     5   [nan]   [nan]         NaN            NaN         NaN
# 114    0      12     6   [nan]   [nan]         NaN            NaN         NaN
# 115    0      12     7   [nan]   [nan]         NaN            NaN         NaN
# 116    0      12     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 108            0.0   True   True  31.75   True   -68.25   -31.75
# 109            0.0   True  False  41.80   True   -16.60     0.00
# 110            0.0  False  False    NaN  False     0.00     0.00
# 111            0.0  False   True  72.60   True    27.70   -10.40
# 112            NaN    NaN    NaN    NaN  False     0.00     0.00
# 113            NaN    NaN    NaN    NaN  False     0.00     0.00
# 114            NaN    NaN    NaN    NaN  False     0.00     0.00
# 115            NaN    NaN    NaN    NaN  False     0.00     0.00
# 116            NaN    NaN    NaN    NaN  False     0.00     0.00
# 13
#                bprofit
# currentBidIdx
# 0.0             -40.55
#                sprofit
# currentAskIdx
# 0.0             -58.75
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 117    0      13     0  [71.7]   [0.0]        71.7            0.0         0.0
# 118    0      13     1  [72.2]  [41.8]        72.2            0.0        41.8
# 119    0      13     2  [36.6]  [62.2]        36.6            0.0        62.2
# 120    0      13     3  [69.9]  [62.2]        69.9            0.0        62.2
# 121    0      13     4   [nan]   [nan]         NaN            NaN         NaN
# 122    0      13     5   [nan]   [nan]         NaN            NaN         NaN
# 123    0      13     6   [nan]   [nan]         NaN            NaN         NaN
# 124    0      13     7   [nan]   [nan]         NaN            NaN         NaN
# 125    0      13     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 117            0.0   True   True  35.85   True   -64.15   -35.85
# 118            0.0   True   True  57.00   True    -1.40   -15.20
# 119            0.0  False  False    NaN  False     0.00     0.00
# 120            0.0  False   True  69.90   True    25.00    -7.70
# 121            NaN    NaN    NaN    NaN  False     0.00     0.00
# 122            NaN    NaN    NaN    NaN  False     0.00     0.00
# 123            NaN    NaN    NaN    NaN  False     0.00     0.00
# 124            NaN    NaN    NaN    NaN  False     0.00     0.00
# 125            NaN    NaN    NaN    NaN  False     0.00     0.00
# 14
#                bprofit
# currentBidIdx
# 0.0             -58.85
#                sprofit
# currentAskIdx
# 0.0             -40.45
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 126    0      14     0  [25.2]   [0.0]        25.2            0.0         0.0
# 127    0      14     1  [61.7]  [41.8]        61.7            0.0        41.8
# 128    0      14     2  [12.5]  [62.2]        12.5            0.0        62.2
# 129    0      14     3  [26.7]  [62.2]        26.7            0.0        62.2
# 130    0      14     4  [80.1]  [62.2]        80.1            0.0        62.2
# 131    0      14     5   [nan]   [nan]         NaN            NaN         NaN
# 132    0      14     6   [nan]   [nan]         NaN            NaN         NaN
# 133    0      14     7   [nan]   [nan]         NaN            NaN         NaN
# 134    0      14     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 126            0.0   True   True  12.60   True   -87.40   -12.60
# 127            0.0   True   True  51.75   True    -6.65    -9.95
# 128            0.0  False  False    NaN  False     0.00     0.00
# 129            0.0  False  False    NaN  False     0.00     0.00
# 130            0.0  False   True  80.10   True    35.20   -17.90
# 131            NaN    NaN    NaN    NaN  False     0.00     0.00
# 132            NaN    NaN    NaN    NaN  False     0.00     0.00
# 133            NaN    NaN    NaN    NaN  False     0.00     0.00
# 134            NaN    NaN    NaN    NaN  False     0.00     0.00
# 15
#                bprofit
# currentBidIdx
# 0.0              -35.1
#                sprofit
# currentAskIdx
# 0.0              -64.2
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 135    0      15     0  [92.0]   [0.0]        92.0            0.0         0.0
# 136    0      15     1  [62.2]  [41.8]        62.2            0.0        41.8
# 137    0      15     2  [54.7]  [62.2]        54.7            0.0        62.2
# 138    0      15     3  [20.2]  [62.2]        20.2            0.0        62.2
# 139    0      15     4  [18.3]  [62.2]        18.3            0.0        62.2
# 140    0      15     5  [37.0]  [62.2]        37.0            0.0        62.2
# 141    0      15     6  [70.2]  [62.2]        70.2            0.0        62.2
# 142    0      15     7   [nan]   [nan]         NaN            NaN         NaN
# 143    0      15     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 135            0.0   True   True   46.0   True    -54.0    -46.0
# 136            0.0   True   True   52.0   True     -6.4    -10.2
# 137            0.0  False  False    NaN  False      0.0      0.0
# 138            0.0  False  False    NaN  False      0.0      0.0
# 139            0.0  False  False    NaN  False      0.0      0.0
# 140            0.0  False  False    NaN  False      0.0      0.0
# 141            0.0  False   True   70.2   True     25.3     -8.0
# 142            NaN    NaN    NaN    NaN  False      0.0      0.0
# 143            NaN    NaN    NaN    NaN  False      0.0      0.0
# 16
#                bprofit
# currentBidIdx
# 0.0              -51.1
#                sprofit
# currentAskIdx
# 0.0              -48.2
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 144    0      16     0  [77.8]   [0.0]        77.8            0.0         0.0
# 145    0      16     1  [34.9]  [41.8]        34.9            0.0        41.8
# 146    0      16     2  [14.5]  [62.2]        14.5            0.0        62.2
# 147    0      16     3  [71.5]  [62.2]        71.5            0.0        62.2
# 148    0      16     4   [nan]   [nan]         NaN            NaN         NaN
# 149    0      16     5   [nan]   [nan]         NaN            NaN         NaN
# 150    0      16     6   [nan]   [nan]         NaN            NaN         NaN
# 151    0      16     7   [nan]   [nan]         NaN            NaN         NaN
# 152    0      16     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 144            0.0   True   True   38.9   True    -61.1    -38.9
# 145            0.0   True  False   41.8   True    -16.6      0.0
# 146            0.0  False  False    NaN  False      0.0      0.0
# 147            0.0  False   True   71.5   True     26.6     -9.3
# 148            NaN    NaN    NaN    NaN  False      0.0      0.0
# 149            NaN    NaN    NaN    NaN  False      0.0      0.0
# 150            NaN    NaN    NaN    NaN  False      0.0      0.0
# 151            NaN    NaN    NaN    NaN  False      0.0      0.0
# 152            NaN    NaN    NaN    NaN  False      0.0      0.0
# 17
#                bprofit
# currentBidIdx
# 0.0             -16.65
#                sprofit
# currentAskIdx
# 0.0             -82.65
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 153    0      17     0  [91.6]   [0.0]        91.6            0.0         0.0
# 154    0      17     1  [79.1]  [41.8]        79.1            0.0        41.8
# 155    0      17     2  [80.4]  [62.2]        80.4            0.0        62.2
# 156    0      17     3   [nan]   [nan]         NaN            NaN         NaN
# 157    0      17     4   [nan]   [nan]         NaN            NaN         NaN
# 158    0      17     5   [nan]   [nan]         NaN            NaN         NaN
# 159    0      17     6   [nan]   [nan]         NaN            NaN         NaN
# 160    0      17     7   [nan]   [nan]         NaN            NaN         NaN
# 161    0      17     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy  sell  price   sale  bprofit  sprofit
# 153            0.0   True  True  45.80   True   -54.20   -45.80
# 154            0.0   True  True  60.45   True     2.05   -18.65
# 155            0.0  False  True  80.40   True    35.50   -18.20
# 156            NaN    NaN   NaN    NaN  False     0.00     0.00
# 157            NaN    NaN   NaN    NaN  False     0.00     0.00
# 158            NaN    NaN   NaN    NaN  False     0.00     0.00
# 159            NaN    NaN   NaN    NaN  False     0.00     0.00
# 160            NaN    NaN   NaN    NaN  False     0.00     0.00
# 161            NaN    NaN   NaN    NaN  False     0.00     0.00
# 18
#                bprofit
# currentBidIdx
# 0.0             -78.65
#                sprofit
# currentAskIdx
# 0.0             -20.65
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 162    0      18     0  [32.6]   [0.0]        32.6            0.0         0.0
# 163    0      18     1  [50.5]  [41.8]        50.5            0.0        41.8
# 164    0      18     2  [42.7]  [62.2]        42.7            0.0        62.2
# 165    0      18     3  [21.3]  [62.2]        21.3            0.0        62.2
# 166    0      18     4  [62.2]  [62.2]        62.2            0.0        62.2
# 167    0      18     5   [nan]   [nan]         NaN            NaN         NaN
# 168    0      18     6   [nan]   [nan]         NaN            NaN         NaN
# 169    0      18     7   [nan]   [nan]         NaN            NaN         NaN
# 170    0      18     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 162            0.0   True   True  16.30   True   -83.70   -16.30
# 163            0.0   True   True  46.15   True   -12.25    -4.35
# 164            0.0  False  False    NaN  False     0.00     0.00
# 165            0.0  False  False    NaN  False     0.00     0.00
# 166            0.0  False   True  62.20   True    17.30     0.00
# 167            NaN    NaN    NaN    NaN  False     0.00     0.00
# 168            NaN    NaN    NaN    NaN  False     0.00     0.00
# 169            NaN    NaN    NaN    NaN  False     0.00     0.00
# 170            NaN    NaN    NaN    NaN  False     0.00     0.00
# 19
#                bprofit
# currentBidIdx
# 0.0             -61.15
#                sprofit
# currentAskIdx
# 0.0             -38.15
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 171    0      19     0  [17.6]   [0.0]        17.6            0.0         0.0
# 172    0      19     1  [84.1]  [41.8]        84.1            0.0        41.8
# 173    0      19     2  [70.4]  [62.2]        70.4            0.0        62.2
# 174    0      19     3   [nan]   [nan]         NaN            NaN         NaN
# 175    0      19     4   [nan]   [nan]         NaN            NaN         NaN
# 176    0      19     5   [nan]   [nan]         NaN            NaN         NaN
# 177    0      19     6   [nan]   [nan]         NaN            NaN         NaN
# 178    0      19     7   [nan]   [nan]         NaN            NaN         NaN
# 179    0      19     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy  sell  price   sale  bprofit  sprofit
# 171            0.0   True  True   8.80   True   -91.20    -8.80
# 172            0.0   True  True  62.95   True     4.55   -21.15
# 173            0.0  False  True  70.40   True    25.50    -8.20
# 174            NaN    NaN   NaN    NaN  False     0.00     0.00
# 175            NaN    NaN   NaN    NaN  False     0.00     0.00
# 176            NaN    NaN   NaN    NaN  False     0.00     0.00
# 177            NaN    NaN   NaN    NaN  False     0.00     0.00
# 178            NaN    NaN   NaN    NaN  False     0.00     0.00
# 179            NaN    NaN   NaN    NaN  False     0.00     0.00
# 20
#                bprofit
# currentBidIdx
# 0.0              -62.8
#                sprofit
# currentAskIdx
# 0.0              -36.5
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 180    0      20     0  [17.4]   [0.0]        17.4            0.0         0.0
# 181    0      20     1  [28.0]  [41.8]        28.0            0.0        41.8
# 182    0      20     2  [41.2]  [62.2]        41.2            0.0        62.2
# 183    0      20     3  [90.0]  [62.2]        90.0            0.0        62.2
# 184    0      20     4   [nan]   [nan]         NaN            NaN         NaN
# 185    0      20     5   [nan]   [nan]         NaN            NaN         NaN
# 186    0      20     6   [nan]   [nan]         NaN            NaN         NaN
# 187    0      20     7   [nan]   [nan]         NaN            NaN         NaN
# 188    0      20     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 180            0.0   True   True    8.7   True    -91.3     -8.7
# 181            0.0   True  False   41.8   True    -16.6      0.0
# 182            0.0  False  False    NaN  False      0.0      0.0
# 183            0.0  False   True   90.0   True     45.1    -27.8
# 184            NaN    NaN    NaN    NaN  False      0.0      0.0
# 185            NaN    NaN    NaN    NaN  False      0.0      0.0
# 186            NaN    NaN    NaN    NaN  False      0.0      0.0
# 187            NaN    NaN    NaN    NaN  False      0.0      0.0
# 188            NaN    NaN    NaN    NaN  False      0.0      0.0
# 21
#                bprofit
# currentBidIdx
# 0.0              -35.9
#                sprofit
# currentAskIdx
# 0.0              -63.4
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 189    0      21     0  [68.2]   [0.0]        68.2            0.0         0.0
# 190    0      21     1  [20.7]  [41.8]        20.7            0.0        41.8
# 191    0      21     2  [49.3]  [62.2]        49.3            0.0        62.2
# 192    0      21     3  [60.0]  [62.2]        60.0            0.0        62.2
# 193    0      21     4  [50.0]  [62.2]        50.0            0.0        62.2
# 194    0      21     5  [91.5]  [62.2]        91.5            0.0        62.2
# 195    0      21     6   [nan]   [nan]         NaN            NaN         NaN
# 196    0      21     7   [nan]   [nan]         NaN            NaN         NaN
# 197    0      21     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 189            0.0   True   True   34.1   True    -65.9    -34.1
# 190            0.0   True  False   41.8   True    -16.6      0.0
# 191            0.0  False  False    NaN  False      0.0      0.0
# 192            0.0  False  False    NaN  False      0.0      0.0
# 193            0.0  False  False    NaN  False      0.0      0.0
# 194            0.0  False   True   91.5   True     46.6    -29.3
# 195            NaN    NaN    NaN    NaN  False      0.0      0.0
# 196            NaN    NaN    NaN    NaN  False      0.0      0.0
# 197            NaN    NaN    NaN    NaN  False      0.0      0.0
# 22
#                bprofit
# currentBidIdx
# 0.0              -50.1
#                sprofit
# currentAskIdx
# 0.0              -49.2
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 198    0      22     0  [90.2]   [0.0]        90.2            0.0         0.0
# 199    0      22     1  [20.8]  [41.8]        20.8            0.0        41.8
# 200    0      22     2  [38.8]  [62.2]        38.8            0.0        62.2
# 201    0      22     3  [37.2]  [62.2]        37.2            0.0        62.2
# 202    0      22     4  [11.2]  [62.2]        11.2            0.0        62.2
# 203    0      22     5  [66.3]  [62.2]        66.3            0.0        62.2
# 204    0      22     6   [nan]   [nan]         NaN            NaN         NaN
# 205    0      22     7   [nan]   [nan]         NaN            NaN         NaN
# 206    0      22     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 198            0.0   True   True   45.1   True    -54.9    -45.1
# 199            0.0   True  False   41.8   True    -16.6      0.0
# 200            0.0  False  False    NaN  False      0.0      0.0
# 201            0.0  False  False    NaN  False      0.0      0.0
# 202            0.0  False  False    NaN  False      0.0      0.0
# 203            0.0  False   True   66.3   True     21.4     -4.1
# 204            NaN    NaN    NaN    NaN  False      0.0      0.0
# 205            NaN    NaN    NaN    NaN  False      0.0      0.0
# 206            NaN    NaN    NaN    NaN  False      0.0      0.0
# 23
#                bprofit
# currentBidIdx
# 0.0             -27.75
#                sprofit
# currentAskIdx
# 0.0             -71.55
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 207    0      23     0  [66.3]   [0.0]        66.3            0.0         0.0
# 208    0      23     1  [73.4]  [41.8]        73.4            0.0        41.8
# 209    0      23     2  [84.8]  [62.2]        84.8            0.0        62.2
# 210    0      23     3   [nan]   [nan]         NaN            NaN         NaN
# 211    0      23     4   [nan]   [nan]         NaN            NaN         NaN
# 212    0      23     5   [nan]   [nan]         NaN            NaN         NaN
# 213    0      23     6   [nan]   [nan]         NaN            NaN         NaN
# 214    0      23     7   [nan]   [nan]         NaN            NaN         NaN
# 215    0      23     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy  sell  price   sale  bprofit  sprofit
# 207            0.0   True  True  33.15   True   -66.85   -33.15
# 208            0.0   True  True  57.60   True    -0.80   -15.80
# 209            0.0  False  True  84.80   True    39.90   -22.60
# 210            NaN    NaN   NaN    NaN  False     0.00     0.00
# 211            NaN    NaN   NaN    NaN  False     0.00     0.00
# 212            NaN    NaN   NaN    NaN  False     0.00     0.00
# 213            NaN    NaN   NaN    NaN  False     0.00     0.00
# 214            NaN    NaN   NaN    NaN  False     0.00     0.00
# 215            NaN    NaN   NaN    NaN  False     0.00     0.00
# 24
#                bprofit
# currentBidIdx
# 0.0             -68.55
#                sprofit
# currentAskIdx
# 0.0             -30.75
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 216    0      24     0   [9.4]   [0.0]         9.4            0.0         0.0
# 217    0      24     1  [67.7]  [41.8]        67.7            0.0        41.8
# 218    0      24     2  [22.9]  [62.2]        22.9            0.0        62.2
# 219    0      24     3   [9.1]  [62.2]         9.1            0.0        62.2
# 220    0      24     4  [75.3]  [62.2]        75.3            0.0        62.2
# 221    0      24     5   [nan]   [nan]         NaN            NaN         NaN
# 222    0      24     6   [nan]   [nan]         NaN            NaN         NaN
# 223    0      24     7   [nan]   [nan]         NaN            NaN         NaN
# 224    0      24     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 216            0.0   True   True   4.70   True   -95.30    -4.70
# 217            0.0   True   True  54.75   True    -3.65   -12.95
# 218            0.0  False  False    NaN  False     0.00     0.00
# 219            0.0  False  False    NaN  False     0.00     0.00
# 220            0.0  False   True  75.30   True    30.40   -13.10
# 221            NaN    NaN    NaN    NaN  False     0.00     0.00
# 222            NaN    NaN    NaN    NaN  False     0.00     0.00
# 223            NaN    NaN    NaN    NaN  False     0.00     0.00
# 224            NaN    NaN    NaN    NaN  False     0.00     0.00
# 25
#                bprofit
# currentBidIdx
# 0.0             -23.05
#                sprofit
# currentAskIdx
# 0.0             -76.25
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 225    0      25     0  [78.5]   [0.0]        78.5            0.0         0.0
# 226    0      25     1  [42.8]  [41.8]        42.8            0.0        41.8
# 227    0      25     2  [24.9]  [62.2]        24.9            0.0        62.2
# 228    0      25     3  [53.4]  [62.2]        53.4            0.0        62.2
# 229    0      25     4  [98.7]  [62.2]        98.7            0.0        62.2
# 230    0      25     5   [nan]   [nan]         NaN            NaN         NaN
# 231    0      25     6   [nan]   [nan]         NaN            NaN         NaN
# 232    0      25     7   [nan]   [nan]         NaN            NaN         NaN
# 233    0      25     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 225            0.0   True   True  39.25   True   -60.75   -39.25
# 226            0.0   True   True  42.30   True   -16.10    -0.50
# 227            0.0  False  False    NaN  False     0.00     0.00
# 228            0.0  False  False    NaN  False     0.00     0.00
# 229            0.0  False   True  98.70   True    53.80   -36.50
# 230            NaN    NaN    NaN    NaN  False     0.00     0.00
# 231            NaN    NaN    NaN    NaN  False     0.00     0.00
# 232            NaN    NaN    NaN    NaN  False     0.00     0.00
# 233            NaN    NaN    NaN    NaN  False     0.00     0.00
# 26
#                bprofit
# currentBidIdx
# 0.0             -36.05
#                sprofit
# currentAskIdx
# 0.0             -63.25
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 234    0      26     0  [53.5]   [0.0]        53.5            0.0         0.0
# 235    0      26     1  [89.8]  [41.8]        89.8            0.0        41.8
# 236    0      26     2  [12.1]  [62.2]        12.1            0.0        62.2
# 237    0      26     3  [52.9]  [62.2]        52.9            0.0        62.2
# 238    0      26     4  [61.5]  [62.2]        61.5            0.0        62.2
# 239    0      26     5  [36.6]  [62.2]        36.6            0.0        62.2
# 240    0      26     6  [58.9]  [62.2]        58.9            0.0        62.2
# 241    0      26     7  [11.8]  [62.2]        11.8            0.0        62.2
# 242    0      26     8  [74.7]  [62.2]        74.7            0.0        62.2
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 234            0.0   True   True  26.75   True   -73.25   -26.75
# 235            0.0   True   True  65.80   True     7.40   -24.00
# 236            0.0  False  False    NaN  False     0.00     0.00
# 237            0.0  False  False    NaN  False     0.00     0.00
# 238            0.0  False  False    NaN  False     0.00     0.00
# 239            0.0  False  False    NaN  False     0.00     0.00
# 240            0.0  False  False    NaN  False     0.00     0.00
# 241            0.0  False  False    NaN  False     0.00     0.00
# 242            0.0  False   True  74.70   True    29.80   -12.50
# 27
#                bprofit
# currentBidIdx
# 0.0              -58.7
#                sprofit
# currentAskIdx
# 0.0              -40.6
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 243    0      27     0  [19.0]   [0.0]        19.0            0.0         0.0
# 244    0      27     1  [21.2]  [41.8]        21.2            0.0        41.8
# 245    0      27     2  [93.3]  [62.2]        93.3            0.0        62.2
# 246    0      27     3   [nan]   [nan]         NaN            NaN         NaN
# 247    0      27     4   [nan]   [nan]         NaN            NaN         NaN
# 248    0      27     5   [nan]   [nan]         NaN            NaN         NaN
# 249    0      27     6   [nan]   [nan]         NaN            NaN         NaN
# 250    0      27     7   [nan]   [nan]         NaN            NaN         NaN
# 251    0      27     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 243            0.0   True   True    9.5   True    -90.5     -9.5
# 244            0.0   True  False   41.8   True    -16.6      0.0
# 245            0.0  False   True   93.3   True     48.4    -31.1
# 246            NaN    NaN    NaN    NaN  False      0.0      0.0
# 247            NaN    NaN    NaN    NaN  False      0.0      0.0
# 248            NaN    NaN    NaN    NaN  False      0.0      0.0
# 249            NaN    NaN    NaN    NaN  False      0.0      0.0
# 250            NaN    NaN    NaN    NaN  False      0.0      0.0
# 251            NaN    NaN    NaN    NaN  False      0.0      0.0
# 28
#                bprofit
# currentBidIdx
# 0.0              -41.5
#                sprofit
# currentAskIdx
# 0.0              -57.8
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 252    0      28     0  [57.6]   [0.0]        57.6            0.0         0.0
# 253    0      28     1  [90.4]  [41.8]        90.4            0.0        41.8
# 254    0      28     2  [39.2]  [62.2]        39.2            0.0        62.2
# 255    0      28     3  [66.9]  [62.2]        66.9            0.0        62.2
# 256    0      28     4   [nan]   [nan]         NaN            NaN         NaN
# 257    0      28     5   [nan]   [nan]         NaN            NaN         NaN
# 258    0      28     6   [nan]   [nan]         NaN            NaN         NaN
# 259    0      28     7   [nan]   [nan]         NaN            NaN         NaN
# 260    0      28     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 252            0.0   True   True   28.8   True    -71.2    -28.8
# 253            0.0   True   True   66.1   True      7.7    -24.3
# 254            0.0  False  False    NaN  False      0.0      0.0
# 255            0.0  False   True   66.9   True     22.0     -4.7
# 256            NaN    NaN    NaN    NaN  False      0.0      0.0
# 257            NaN    NaN    NaN    NaN  False      0.0      0.0
# 258            NaN    NaN    NaN    NaN  False      0.0      0.0
# 259            NaN    NaN    NaN    NaN  False      0.0      0.0
# 260            NaN    NaN    NaN    NaN  False      0.0      0.0
# 29
#                bprofit
# currentBidIdx
# 0.0             -33.15
#                sprofit
# currentAskIdx
# 0.0             -66.15
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 261    0      29     0  [93.9]   [0.0]        93.9            0.0         0.0
# 262    0      29     1  [28.3]  [41.8]        28.3            0.0        41.8
# 263    0      29     2  [81.4]  [62.2]        81.4            0.0        62.2
# 264    0      29     3   [nan]   [nan]         NaN            NaN         NaN
# 265    0      29     4   [nan]   [nan]         NaN            NaN         NaN
# 266    0      29     5   [nan]   [nan]         NaN            NaN         NaN
# 267    0      29     6   [nan]   [nan]         NaN            NaN         NaN
# 268    0      29     7   [nan]   [nan]         NaN            NaN         NaN
# 269    0      29     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 261            0.0   True   True  46.95   True   -53.05   -46.95
# 262            0.0   True  False  41.80   True   -16.60     0.00
# 263            0.0  False   True  81.40   True    36.50   -19.20
# 264            NaN    NaN    NaN    NaN  False     0.00     0.00
# ...
# 810    0      90     0  [45.5]   [0.0]        45.5            0.0         0.0
# 811    0      90     1  [33.8]  [41.8]        33.8            0.0        41.8
# 812    0      90     2   [9.4]  [62.2]         9.4            0.0        62.2
# 813    0      90     3  [74.9]  [62.2]        74.9            0.0        62.2
# 814    0      90     4   [nan]   [nan]         NaN            NaN         NaN
# 815    0      90     5   [nan]   [nan]         NaN            NaN         NaN
# 816    0      90     6   [nan]   [nan]         NaN            NaN         NaN
# 817    0      90     7   [nan]   [nan]         NaN            NaN         NaN
# 818    0      90     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 810            0.0   True   True  22.75   True   -77.25   -22.75
# 811            0.0   True  False  41.80   True   -16.60     0.00
# 812            0.0  False  False    NaN  False     0.00     0.00
# 813            0.0  False   True  74.90   True    30.00   -12.70
# 814            NaN    NaN    NaN    NaN  False     0.00     0.00
# 815            NaN    NaN    NaN    NaN  False     0.00     0.00
# 816            NaN    NaN    NaN    NaN  False     0.00     0.00
# 817            NaN    NaN    NaN    NaN  False     0.00     0.00
# 818            NaN    NaN    NaN    NaN  False     0.00     0.00
# 91
#                bprofit
# currentBidIdx
# 0.0             -66.15
#                sprofit
# currentAskIdx
# 0.0             -33.15
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 819    0      91     0  [65.7]   [0.0]        65.7            0.0         0.0
# 820    0      91     1  [37.9]  [41.8]        37.9            0.0        41.8
# 821    0      91     2  [57.4]  [62.2]        57.4            0.0        62.2
# 822    0      91     3   [6.7]  [62.2]         6.7            0.0        62.2
# 823    0      91     4  [22.4]  [62.2]        22.4            0.0        62.2
# 824    0      91     5  [62.5]  [62.2]        62.5            0.0        62.2
# 825    0      91     6   [nan]   [nan]         NaN            NaN         NaN
# 826    0      91     7   [nan]   [nan]         NaN            NaN         NaN
# 827    0      91     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 819            0.0   True   True  32.85   True   -67.15   -32.85
# 820            0.0   True  False  41.80   True   -16.60     0.00
# 821            0.0  False  False    NaN  False     0.00     0.00
# 822            0.0  False  False    NaN  False     0.00     0.00
# 823            0.0  False  False    NaN  False     0.00     0.00
# 824            0.0  False   True  62.50   True    17.60    -0.30
# 825            NaN    NaN    NaN    NaN  False     0.00     0.00
# 826            NaN    NaN    NaN    NaN  False     0.00     0.00
# 827            NaN    NaN    NaN    NaN  False     0.00     0.00
# 92
#                bprofit
# currentBidIdx
# 0.0              -44.8
#                sprofit
# currentAskIdx
# 0.0              -54.5
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 828    0      92     0  [10.0]   [0.0]        10.0            0.0         0.0
# 829    0      92     1  [84.4]  [41.8]        84.4            0.0        41.8
# 830    0      92     2  [90.4]  [62.2]        90.4            0.0        62.2
# 831    0      92     3   [nan]   [nan]         NaN            NaN         NaN
# 832    0      92     4   [nan]   [nan]         NaN            NaN         NaN
# 833    0      92     5   [nan]   [nan]         NaN            NaN         NaN
# 834    0      92     6   [nan]   [nan]         NaN            NaN         NaN
# 835    0      92     7   [nan]   [nan]         NaN            NaN         NaN
# 836    0      92     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy  sell  price   sale  bprofit  sprofit
# 828            0.0   True  True    5.0   True    -95.0     -5.0
# 829            0.0   True  True   63.1   True      4.7    -21.3
# 830            0.0  False  True   90.4   True     45.5    -28.2
# 831            NaN    NaN   NaN    NaN  False      0.0      0.0
# 832            NaN    NaN   NaN    NaN  False      0.0      0.0
# 833            NaN    NaN   NaN    NaN  False      0.0      0.0
# 834            NaN    NaN   NaN    NaN  False      0.0      0.0
# 835            NaN    NaN   NaN    NaN  False      0.0      0.0
# 836            NaN    NaN   NaN    NaN  False      0.0      0.0
# 93
#                bprofit
# currentBidIdx
# 0.0              -40.6
#                sprofit
# currentAskIdx
# 0.0              -58.7
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 837    0      93     0  [77.2]   [0.0]        77.2            0.0         0.0
# 838    0      93     1  [44.6]  [41.8]        44.6            0.0        41.8
# 839    0      93     2  [80.9]  [62.2]        80.9            0.0        62.2
# 840    0      93     3   [nan]   [nan]         NaN            NaN         NaN
# 841    0      93     4   [nan]   [nan]         NaN            NaN         NaN
# 842    0      93     5   [nan]   [nan]         NaN            NaN         NaN
# 843    0      93     6   [nan]   [nan]         NaN            NaN         NaN
# 844    0      93     7   [nan]   [nan]         NaN            NaN         NaN
# 845    0      93     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy  sell  price   sale  bprofit  sprofit
# 837            0.0   True  True   38.6   True    -61.4    -38.6
# 838            0.0   True  True   43.2   True    -15.2     -1.4
# 839            0.0  False  True   80.9   True     36.0    -18.7
# 840            NaN    NaN   NaN    NaN  False      0.0      0.0
# 841            NaN    NaN   NaN    NaN  False      0.0      0.0
# 842            NaN    NaN   NaN    NaN  False      0.0      0.0
# 843            NaN    NaN   NaN    NaN  False      0.0      0.0
# 844            NaN    NaN   NaN    NaN  False      0.0      0.0
# 845            NaN    NaN   NaN    NaN  False      0.0      0.0
# 94
#                bprofit
# currentBidIdx
# 0.0             -39.55
#                sprofit
# currentAskIdx
# 0.0             -59.75
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 846    0      94     0  [70.1]   [0.0]        70.1            0.0         0.0
# 847    0      94     1  [26.5]  [41.8]        26.5            0.0        41.8
# 848    0      94     2  [24.6]  [62.2]        24.6            0.0        62.2
# 849    0      94     3  [86.9]  [62.2]        86.9            0.0        62.2
# 850    0      94     4   [nan]   [nan]         NaN            NaN         NaN
# 851    0      94     5   [nan]   [nan]         NaN            NaN         NaN
# 852    0      94     6   [nan]   [nan]         NaN            NaN         NaN
# 853    0      94     7   [nan]   [nan]         NaN            NaN         NaN
# 854    0      94     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 846            0.0   True   True  35.05   True   -64.95   -35.05
# 847            0.0   True  False  41.80   True   -16.60     0.00
# 848            0.0  False  False    NaN  False     0.00     0.00
# 849            0.0  False   True  86.90   True    42.00   -24.70
# 850            NaN    NaN    NaN    NaN  False     0.00     0.00
# 851            NaN    NaN    NaN    NaN  False     0.00     0.00
# 852            NaN    NaN    NaN    NaN  False     0.00     0.00
# 853            NaN    NaN    NaN    NaN  False     0.00     0.00
# 854            NaN    NaN    NaN    NaN  False     0.00     0.00
# 95
#                bprofit
# currentBidIdx
# 0.0              -61.9
#                sprofit
# currentAskIdx
# 0.0              -37.4
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 855    0      95     0  [29.0]   [0.0]        29.0            0.0         0.0
# 856    0      95     1  [16.4]  [41.8]        16.4            0.0        41.8
# 857    0      95     2  [85.1]  [62.2]        85.1            0.0        62.2
# 858    0      95     3   [nan]   [nan]         NaN            NaN         NaN
# 859    0      95     4   [nan]   [nan]         NaN            NaN         NaN
# 860    0      95     5   [nan]   [nan]         NaN            NaN         NaN
# 861    0      95     6   [nan]   [nan]         NaN            NaN         NaN
# 862    0      95     7   [nan]   [nan]         NaN            NaN         NaN
# 863    0      95     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 855            0.0   True   True   14.5   True    -85.5    -14.5
# 856            0.0   True  False   41.8   True    -16.6      0.0
# 857            0.0  False   True   85.1   True     40.2    -22.9
# 858            NaN    NaN    NaN    NaN  False      0.0      0.0
# 859            NaN    NaN    NaN    NaN  False      0.0      0.0
# 860            NaN    NaN    NaN    NaN  False      0.0      0.0
# 861            NaN    NaN    NaN    NaN  False      0.0      0.0
# 862            NaN    NaN    NaN    NaN  False      0.0      0.0
# 863            NaN    NaN    NaN    NaN  False      0.0      0.0
# 96
#                bprofit
# currentBidIdx
# 0.0             -29.45
#                sprofit
# currentAskIdx
# 0.0             -69.85
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 864    0      96     0  [93.5]   [0.0]        93.5            0.0         0.0
# 865    0      96     1  [32.9]  [41.8]        32.9            0.0        41.8
# 866    0      96     2  [52.4]  [62.2]        52.4            0.0        62.2
# 867    0      96     3  [45.5]  [62.2]        45.5            0.0        62.2
# 868    0      96     4  [42.8]  [62.2]        42.8            0.0        62.2
# 869    0      96     5  [11.6]  [62.2]        11.6            0.0        62.2
# 870    0      96     6  [85.3]  [62.2]        85.3            0.0        62.2
# 871    0      96     7   [nan]   [nan]         NaN            NaN         NaN
# 872    0      96     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 864            0.0   True   True  46.75   True   -53.25   -46.75
# 865            0.0   True  False  41.80   True   -16.60     0.00
# 866            0.0  False  False    NaN  False     0.00     0.00
# 867            0.0  False  False    NaN  False     0.00     0.00
# 868            0.0  False  False    NaN  False     0.00     0.00
# 869            0.0  False  False    NaN  False     0.00     0.00
# 870            0.0  False   True  85.30   True    40.40   -23.10
# 871            NaN    NaN    NaN    NaN  False     0.00     0.00
# 872            NaN    NaN    NaN    NaN  False     0.00     0.00
# 97
#                bprofit
# currentBidIdx
# 0.0             -81.25
#                sprofit
# currentAskIdx
# 0.0             -18.05
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 873    0      97     0  [30.5]   [0.0]        30.5            0.0         0.0
# 874    0      97     1  [35.9]  [41.8]        35.9            0.0        41.8
# 875    0      97     2  [29.8]  [62.2]        29.8            0.0        62.2
# 876    0      97     3  [65.0]  [62.2]        65.0            0.0        62.2
# 877    0      97     4   [nan]   [nan]         NaN            NaN         NaN
# 878    0      97     5   [nan]   [nan]         NaN            NaN         NaN
# 879    0      97     6   [nan]   [nan]         NaN            NaN         NaN
# 880    0      97     7   [nan]   [nan]         NaN            NaN         NaN
# 881    0      97     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 873            0.0   True   True  15.25   True   -84.75   -15.25
# 874            0.0   True  False  41.80   True   -16.60     0.00
# 875            0.0  False  False    NaN  False     0.00     0.00
# 876            0.0  False   True  65.00   True    20.10    -2.80
# 877            NaN    NaN    NaN    NaN  False     0.00     0.00
# 878            NaN    NaN    NaN    NaN  False     0.00     0.00
# 879            NaN    NaN    NaN    NaN  False     0.00     0.00
# 880            NaN    NaN    NaN    NaN  False     0.00     0.00
# 881            NaN    NaN    NaN    NaN  False     0.00     0.00
# 98
#                bprofit
# currentBidIdx
# 0.0             -33.95
#                sprofit
# currentAskIdx
# 0.0             -65.35
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 882    0      98     0  [22.4]   [0.0]        22.4            0.0         0.0
# 883    0      98     1  [82.1]  [41.8]        82.1            0.0        41.8
# 884    0      98     2  [36.8]  [62.2]        36.8            0.0        62.2
# 885    0      98     3  [29.3]  [62.2]        29.3            0.0        62.2
# 886    0      98     4  [96.2]  [62.2]        96.2            0.0        62.2
# 887    0      98     5   [nan]   [nan]         NaN            NaN         NaN
# 888    0      98     6   [nan]   [nan]         NaN            NaN         NaN
# 889    0      98     7   [nan]   [nan]         NaN            NaN         NaN
# 890    0      98     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 882            0.0   True   True  11.20   True   -88.80   -11.20
# 883            0.0   True   True  61.95   True     3.55   -20.15
# 884            0.0  False  False    NaN  False     0.00     0.00
# 885            0.0  False  False    NaN  False     0.00     0.00
# 886            0.0  False   True  96.20   True    51.30   -34.00
# 887            NaN    NaN    NaN    NaN  False     0.00     0.00
# 888            NaN    NaN    NaN    NaN  False     0.00     0.00
# 889            NaN    NaN    NaN    NaN  False     0.00     0.00
# 890            NaN    NaN    NaN    NaN  False     0.00     0.00
# 99
#                bprofit
# currentBidIdx
# 0.0              -59.1
#                sprofit
# currentAskIdx
# 0.0              -40.2
#      rnd  period  step    bids    asks  currentBid  currentBidIdx  currentAsk  \
# 891    0      99     0  [13.2]   [0.0]        13.2            0.0         0.0
# 892    0      99     1  [49.0]  [41.8]        49.0            0.0        41.8
# 893    0      99     2  [92.2]  [62.2]        92.2            0.0        62.2
# 894    0      99     3   [nan]   [nan]         NaN            NaN         NaN
# 895    0      99     4   [nan]   [nan]         NaN            NaN         NaN
# 896    0      99     5   [nan]   [nan]         NaN            NaN         NaN
# 897    0      99     6   [nan]   [nan]         NaN            NaN         NaN
# 898    0      99     7   [nan]   [nan]         NaN            NaN         NaN
# 899    0      99     8   [nan]   [nan]         NaN            NaN         NaN
#
#      currentAskIdx    buy  sell  price   sale  bprofit  sprofit
# 891            0.0   True  True    6.6   True    -93.4     -6.6
# 892            0.0   True  True   45.4   True    -13.0     -3.6
# 893            0.0  False  True   92.2   True     47.3    -30.0
# 894            NaN    NaN   NaN    NaN  False      0.0      0.0
# 895            NaN    NaN   NaN    NaN  False      0.0      0.0
# 896            NaN    NaN   NaN    NaN  False      0.0      0.0
# 897            NaN    NaN   NaN    NaN  False      0.0      0.0
# 898            NaN    NaN   NaN    NaN  False      0.0      0.0
# 899            NaN    NaN   NaN    NaN  False      0.0      0.0

# %%
class SAC(Trader):
    def __init__(self, gameData, disclosure, index, buyer, reinforcer):
        super().__init__(gameData, disclosure, index, buyer, reinforcer)
        self.learningRate = 0.0002
        self.gamma = 0.99
        self.numActions = 100
        self.depth = 1
        self.numStates = 8 + 6 * self.depth
        history = [-1] * self.numStates
        self.state = np.nan_to_num(np.array(history, dtype = np.float32), nan=-9)
        self.memory = ReplayBuffer()
        self.q1, self.q2, self.q1_target, self.q2_target = QNet(lr_q), QNet(lr_q), QNet(lr_q), QNet(lr_q)
        self.pi = PolicyNet(lr_pi, self.numStates)
        self.q1_target.load_state_dict(self.q1.state_dict())
        self.q2_target.load_state_dict(self.q2.state_dict())
        self.done = False
        self.truncated = False
        self.info = {}

    def observe(self):
        agentState = [self.periodStep, self.stepTokenValue, self.stepBid, self.stepAsk, self.stepTrades, self.stepProfits, self.periodTrades, self.periodProfits]
        history = self.df.iloc[-self.depth:][['currentBid', 'currentAsk', 'buy', 'sell', 'price', 'price']].values.reshape(-1,).tolist()
        if len(history) != (6 * self.depth):
            history = [-1] * (6 * self.depth)
        self.newState = np.nan_to_num(np.array(agentState + history, dtype = np.float32), nan=-9)
        if self.periodStep == self.numSteps:
            self.done = True
        memory.put((self.state, self.a.item(), self.stepProfits/100.0, self.newState, self.done)) 
        if memory.size()>1000:
            for i in range(20):
                mini_batch = memory.sample(batch_size)
                td_target = calc_target(self.pi, self.q1_target, self.q2_target, mini_batch)
                self.q1.train_net(td_target, mini_batch)
                self.q2.train_net(td_target, mini_batch)
                entropy = pi.train_net(self.q1, self.q2, mini_batch)
                self.q1.soft_update(self.q1_target)
                self.q2.soft_update(self.q2_target)
        self.state = self.newState
        
    def bid(self):
        self.stepBid = np.nan
        if self.stepTokenValue > 0:
            self.a, self.log_prob = self.pi(torch.from_numpy(self.state).float())
            frac = (self.a.item()+1)/2
            self.stepBid = np.round(frac * 100,1)
        return self.stepBid
        
    def ask(self):
        self.stepAsk = np.nan
        if self.stepTokenValue > 0:
            self.a, self.log_prob = self.pi(torch.from_numpy(self.state).float())
            frac = (self.a.item()+1)/2
            self.stepAsk = np.round(frac * 100,1)
        return self.stepAsk

def updatePolicy(buyers, sellers):
    for buyer in buyers:
        if buyer.reinforcer == 2:
            buyer.model.train_net()
    for seller in sellers:
        if seller.reinforcer == 2:
            seller.model.train_net()

def updateStates(buyers, sellers):
    for buyer in buyers:
        if buyer.reinforcer == 2:
            buyer.observe()
    for seller in sellers:
        if seller.reinforcer == 2:
            seller.observe()

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Normal
import numpy as np
import collections, random

#Hyperparameters
lr_pi           = 0.0005
lr_q            = 0.001
init_alpha      = 0.01
gamma           = 0.98
batch_size      = 32
buffer_limit    = 50000
tau             = 0.01 # for target network soft update
target_entropy  = -1.0 # for automated alpha update
lr_alpha        = 0.001  # for automated alpha update

class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)

    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []

        for transition in mini_batch:
            s, a, r, s_prime, done = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask = 0.0 if done else 1.0 
            done_mask_lst.append([done_mask])
        
        return torch.tensor(s_lst, dreinforcer=torch.float), torch.tensor(a_lst, dreinforcer=torch.float), \
                torch.tensor(r_lst, dreinforcer=torch.float), torch.tensor(s_prime_lst, dreinforcer=torch.float), \
                torch.tensor(done_mask_lst, dreinforcer=torch.float)
    
    def size(self):
        return len(self.buffer)

class PolicyNet(nn.Module):
    def __init__(self, learning_rate, numStates):
        super(PolicyNet, self).__init__()
        self.fc1 = nn.Linear(numStates, 128)
        self.fc_mu = nn.Linear(128,1)
        self.fc_std  = nn.Linear(128,1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)
        self.log_alpha = torch.tensor(np.log(init_alpha))
        self.log_alpha.requires_grad = True
        self.log_alpha_optimizer = optim.Adam([self.log_alpha], lr=lr_alpha)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        mu = self.fc_mu(x)
        std = F.softplus(self.fc_std(x))
        dist = Normal(mu, std)
        action = dist.rsample()
        log_prob = dist.log_prob(action)
        real_action = torch.tanh(action)
        real_log_prob = log_prob - torch.log(1-torch.tanh(action).pow(2) + 1e-7)
        return real_action, real_log_prob

    def train_net(self, q1, q2, mini_batch):
        s, _, _, _, _ = mini_batch
        a, log_prob = self.forward(s)
        entropy = -self.log_alpha.exp() * log_prob
        q1_val, q2_val = q1(s,a), q2(s,a)
        q1_q2 = torch.cat([q1_val, q2_val], dim=1)
        min_q = torch.min(q1_q2, 1, keepdim=True)[0]
        loss = -min_q - entropy # for gradient ascent
        self.optimizer.zero_grad()
        loss.mean().backward()
        self.optimizer.step()
        self.log_alpha_optimizer.zero_grad()
        alpha_loss = -(self.log_alpha.exp() * (log_prob + target_entropy).detach()).mean()
        alpha_loss.backward()
        self.log_alpha_optimizer.step()

class QNet(nn.Module):
    def __init__(self, learning_rate):
        super(QNet, self).__init__()
        self.fc_s = nn.Linear(3, 64)
        self.fc_a = nn.Linear(1,64)
        self.fc_cat = nn.Linear(128,32)
        self.fc_out = nn.Linear(32,1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, x, a):
        h1 = F.relu(self.fc_s(x))
        h2 = F.relu(self.fc_a(a))
        cat = torch.cat([h1,h2], dim=1)
        q = F.relu(self.fc_cat(cat))
        q = self.fc_out(q)
        return q

    def train_net(self, target, mini_batch):
        s, a, r, s_prime, done = mini_batch
        loss = F.smooth_l1_loss(self.forward(s, a) , target)
        self.optimizer.zero_grad()
        loss.mean().backward()
        self.optimizer.step()

    def soft_update(self, net_target):
        for param_target, param in zip(net_target.parameters(), self.parameters()):
            param_target.data.copy_(param_target.data * (1.0 - tau) + param.data * tau)

def calc_target(pi, q1, q2, mini_batch):
    s, a, r, s_prime, done = mini_batch

    with torch.no_grad():
        a_prime, log_prob= pi(s_prime)
        entropy = -pi.log_alpha.exp() * log_prob
        q1_val, q2_val = q1(s_prime,a_prime), q2(s_prime,a_prime)
        q1_q2 = torch.cat([q1_val, q2_val], dim=1)
        min_q = torch.min(q1_q2, 1, keepdim=True)[0]
        target = r + gamma * done * (min_q + entropy)
    return target

# %%
def generateAgents(gameData,buyerStrategies,sellerStrategies,disclosure):
    buyers, sellers = [], []
    for idx,i in enumerate(buyerStrategies):
        if i == 'TruthTeller':
            buyers.append(TruthTeller(gameData, disclosure, index=idx, buyer=1, reinforcer=0)) 
        if i == 'ZeroIntelligence':
            buyers.append(ZeroIntelligence(gameData, disclosure, index=idx, buyer=1, reinforcer=0)) 
        if i == 'REINFORCE':
            buyers.append(REINFORCE(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 
        if i == 'PPO':
            buyers.append(PPO(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 
        if i == 'SAC':
            buyers.append(SAC(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 
        if i == 'DQN':
            buyers.append(DQN(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 

    for idx,i in enumerate(sellerStrategies):
        if i == 'TruthTeller':
            sellers.append(TruthTeller(gameData, disclosure, index=idx, buyer=0, reinforcer=0)) 
        if i == 'ZeroIntelligence':
            sellers.append(ZeroIntelligence(gameData, disclosure, index=idx, buyer=0, reinforcer=0)) 
        if i == 'REINFORCE':
            sellers.append(REINFORCE(gameData, disclosure, index=idx, buyer=0, reinforcer=1)) 
        if i == 'PPO':
            sellers.append(PPO(gameData, disclosure, index=idx, buyer=0, reinforcer=1)) 
        if i == 'SAC':
            sellers.append(SAC(gameData, disclosure, index=idx, buyer=0, reinforcer=1)) 
        if i == 'DQN':
            sellers.append(DQN(gameData, disclosure, index=idx, buyer=0, reinforcer=1)) 
    return buyers, sellers
