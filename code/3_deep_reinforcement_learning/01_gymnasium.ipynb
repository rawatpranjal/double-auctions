# %% [markdown]
# ### Gymnasium
# - API for single agent RL environments
# - contains common environments (MDPs)
# - 5 functions:
#     - make: creates the environment, inbuilt or custom
#     - reset: resets the game to the initial state. (e.g. Chess at the start)
#     - step: given the state, playing an action, observing the reward and transitioning to new state
#         - begins from initial state, until termination / truncation i.e game completion
#         - then reset() moves back to initial state
#     - render: how env should be visualized
#     - close: delete memory
# - Environment objects: expected input and output
#     - action spaces:
#         - types: Box (n-d continous, bounded), Discrete (0,1...N), Dict, Tuple, MultiBinary, Multidiscrete
#         - .sample() gets you a random action
#     - observation space (observed state)
#         - types: Box (n-d continous, bounded), Discrete (0,1...N), Dict, Tuple, MultiBinary, Multidiscrete
#     - reward_range
# - wrappers: modifies state.
#     - FlattenObservation, TimeLimit (to steps), ClipAction, RescaleAction, TimeAwareObs (ensure Markov)

# %%
import gymnasium as gym

from stable_baselines3 import PPO
env = gym.make("CartPole-v1")
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render()
    # VecEnv resets automatically
    # if done:
    #   obs = env.reset()

env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | 20.2     |
# | time/              |          |
# |    fps             | 788      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------

# %% [markdown]
# #### Lunar Lander

# %%
import gymnasium as gym
env = gym.make("LunarLander-v2", render_mode="human")
observation, info = env.reset(seed=42)
for _ in range(1000):
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        observation, info = env.reset()
env.close()

# %% [markdown]
# #### Cartpole

# %%
import gymnasium as gym
from stable_baselines3 import A2C
env = gym.make("CartPole-v1", render_mode="human")
model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
    # VecEnv resets automatically
    # if done:
    #   obs = vec_env.reset()

# %% [markdown]
# #### Mountain Car

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env
import os
import time

# %%
# Saving logs to visulise in Tensorboard, saving models
models_dir = f"models/Mountain-{time.time()}"
logdir = f"logs/Mountain-{time.time()}"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logdir):
    os.makedirs(logdir)

# %%
# Parallel environments
env = make_vec_env("MountainCarContinuous-v0", n_envs=1)

# The learning agent and hyperparameters
model = PPO(
    policy=MlpPolicy,
    env=env,
    seed=0,
    batch_size=256,
    ent_coef=0.00429,
    learning_rate=7.77e-05,
    n_epochs=10,
    n_steps=8,
    gae_lambda=0.9,
    gamma=0.9999,
    clip_range=0.1,
    max_grad_norm =5,
    vf_coef=0.19,
    use_sde=True,
    policy_kwargs=dict(log_std_init=-3.29, ortho_init=False),
    verbose=1,
    tensorboard_log=logdir
    )
# Out:
# Using cpu device
# /usr/local/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:148: UserWarning: You have specified a mini-batch size of 256, but because the `RolloutBuffer` is of size `n_steps * n_envs = 8`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 8
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=8 and n_envs=1)
#   warnings.warn(

# %%
#Training and saving models along the way
TIMESTEPS = 20000
for i in range(10): 
    model.learn(total_timesteps=TIMESTEPS,reset_num_timesteps=False, tb_log_name="PPO")
    model.save(f"{models_dir}/{TIMESTEPS*i}")
# Out:
# Logging to logs/Mountain-1694368241.423321/PPO_0
# ----------------------------
# | time/              |     |
# |    fps             | 385 |
# |    iterations      | 1   |
# |    time_elapsed    | 0   |
# |    total_timesteps | 8   |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 145          |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 16           |
# | train/                  |              |
# |    approx_kl            | 7.599592e-07 |
# |    clip_fraction        | 0.2          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.38         |
# |    explained_variance   | -0.158       |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00516      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 5.52e-05     |
# |    std                  | 0.0373       |
# |    value_loss           | 4.43e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 138           |
# |    iterations           | 3             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 24            |
# | train/                  |               |
# |    approx_kl            | 0.00047791004 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.39          |
# |    explained_variance   | -2.11         |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00601       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | 5.08e-05      |
# |    std                  | 0.0373        |
# |    value_loss           | 6.46e-06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 134          |
# |    iterations           | 4            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 32           |
# | train/                  |              |
# |    approx_kl            | 0.0017271712 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.4          |
# |    explained_variance   | -0.624       |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00497      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000403    |
# |    std                  | 0.0372       |
# |    value_loss           | 2.86e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 129           |
# |    iterations           | 5             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 40            |
# | train/                  |               |
# |    approx_kl            | 0.00074899197 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.41          |
# |    explained_variance   | -8.55         |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00629       |
# |    n_updates            | 40            |
# |    policy_gradient_loss | 0.000193      |
# |    std                  | 0.0372        |
# |    value_loss           | 5.01e-06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 6            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 48           |
# | train/                  |              |
# |    approx_kl            | 0.0007907748 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.41         |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00584      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0001      |
# |    std                  | 0.0373       |
# |    value_loss           | 4.16e-08     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 7           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 56          |
# | train/                  |             |
# |    approx_kl            | 0.004907176 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.00499     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00139    |
# |    std                  | 0.0373      |
# |    value_loss           | 2.76e-05    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 117           |
# |    iterations           | 8             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 64            |
# | train/                  |               |
# |    approx_kl            | 0.00040002167 |
# |    clip_fraction        | 0.1           |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.39          |
# |    explained_variance   | 0.275         |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00281       |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.0013       |
# |    std                  | 0.0373        |
# |    value_loss           | 3.05e-05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 9            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 72           |
# | train/                  |              |
# |    approx_kl            | 0.0023679435 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.38         |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00495      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000529    |
# |    std                  | 0.0373       |
# |    value_loss           | 1.77e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 10           |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 80           |
# | train/                  |              |
# |    approx_kl            | 0.0059157163 |
# |    clip_fraction        | 0.2          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.38         |
# |    explained_variance   | -0.0601      |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00803      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.00105      |
# |    std                  | 0.0373       |
# |    value_loss           | 0.000126     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 120           |
# |    iterations           | 11            |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 88            |
# | train/                  |               |
# |    approx_kl            | 3.0487776e-05 |
# |    clip_fraction        | 0.1           |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.39          |
# |    explained_variance   | -0.232        |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00331       |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000983     |
# |    std                  | 0.0373        |
# |    value_loss           | 7.84e-05      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 12          |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 96          |
# | train/                  |             |
# |    approx_kl            | 0.005145505 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | -11.8       |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.00751     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.000172    |
# |    std                  | 0.0373      |
# |    value_loss           | 2.34e-06    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 123           |
# |    iterations           | 13            |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 104           |
# | train/                  |               |
# |    approx_kl            | 5.1915646e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.41          |
# |    explained_variance   | -0.366        |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00623       |
# |    n_updates            | 120           |
# |    policy_gradient_loss | 0.000128      |
# |    std                  | 0.0373        |
# |    value_loss           | 2.76e-06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 14           |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 112          |
# | train/                  |              |
# |    approx_kl            | 0.0035731941 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.41         |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00518      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000324    |
# |    std                  | 0.0374       |
# |    value_loss           | 4.57e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 15          |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 120         |
# | train/                  |             |
# |    approx_kl            | 0.003563054 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | -0.0762     |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | -0.00149    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00223    |
# |    std                  | 0.0374      |
# |    value_loss           | 3.99e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 122          |
# |    iterations           | 16           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0026894212 |
# |    clip_fraction        | 0.075        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.38         |
# |    explained_variance   | 0.276        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.000656     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00237     |
# |    std                  | 0.0374       |
# |    value_loss           | 2.98e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 123          |
# |    iterations           | 17           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 136          |
# | train/                  |              |
# |    approx_kl            | 0.0010929331 |
# |    clip_fraction        | 0.2          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.37         |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.000504     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000334    |
# |    std                  | 0.0374       |
# |    value_loss           | 4.17e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 123          |
# |    iterations           | 18           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 144          |
# | train/                  |              |
# |    approx_kl            | 0.0033248663 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.37         |
# |    explained_variance   | -0.0793      |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00582      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -3.5e-05     |
# |    std                  | 0.0374       |
# |    value_loss           | 1.82e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 120          |
# |    iterations           | 19           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 152          |
# | train/                  |              |
# |    approx_kl            | 0.0021432638 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.38         |
# |    explained_variance   | -0.567       |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00317      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000737    |
# |    std                  | 0.0374       |
# |    value_loss           | 2.2e-05      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 116           |
# |    iterations           | 20            |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 160           |
# | train/                  |               |
# |    approx_kl            | 8.6307526e-05 |
# |    clip_fraction        | 0.2           |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.39          |
# |    explained_variance   | -0.451        |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00244       |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 0.00114       |
# |    std                  | 0.0374        |
# |    value_loss           | 4.06e-05      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 113            |
# |    iterations           | 21             |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 168            |
# | train/                  |                |
# |    approx_kl            | 0.000109642744 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.1            |
# |    entropy_loss         | 1.41           |
# |    explained_variance   | -1.37          |
# |    learning_rate        | 7.77e-05       |
# |    loss                 | 0.00109        |
# |    n_updates            | 200            |
# |    policy_gradient_loss | -0.00216       |
# |    std                  | 0.0374         |
# |    value_loss           | 8.79e-06       |
# --------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 22          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 176         |
# | train/                  |             |
# |    approx_kl            | 0.003798671 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.42        |
# |    explained_variance   | -0.0832     |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.00569     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00109     |
# |    std                  | 0.0374      |
# |    value_loss           | 3.11e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 23          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 184         |
# | train/                  |             |
# |    approx_kl            | 0.004424922 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.41        |
# |    explained_variance   | -2.74       |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.00455     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.000437    |
# |    std                  | 0.0374      |
# |    value_loss           | 6.38e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 111          |
# |    iterations           | 24           |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 192          |
# | train/                  |              |
# |    approx_kl            | 0.0005430132 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.4          |
# |    explained_variance   | -0.561       |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | -0.0028      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00367     |
# |    std                  | 0.0374       |
# |    value_loss           | 1.96e-06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 110           |
# |    iterations           | 25            |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 200           |
# | train/                  |               |
# |    approx_kl            | 0.00025408715 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.38          |
# |    explained_variance   | 0.943         |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | -0.00494      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.0053       |
# |    std                  | 0.0374        |
# |    value_loss           | 1.82e-08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 110           |
# |    iterations           | 26            |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 208           |
# | train/                  |               |
# |    approx_kl            | 0.00032803416 |
# |    clip_fraction        | 0.1           |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.36          |
# |    explained_variance   | 0.0566        |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.000164      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.00251      |
# |    std                  | 0.0374        |
# |    value_loss           | 0.000225      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 27          |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 216         |
# | train/                  |             |
# |    approx_kl            | 0.004476741 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.36        |
# |    explained_variance   | -0.082      |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.00612     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.000804    |
# |    std                  | 0.0374      |
# |    value_loss           | 0.00025     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 109          |
# |    iterations           | 28           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 224          |
# | train/                  |              |
# |    approx_kl            | 0.0018929541 |
# |    clip_fraction        | 0.05         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.38         |
# |    explained_variance   | -0.229       |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | -0.0016      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00409     |
# |    std                  | 0.0374       |
# |    value_loss           | 6.98e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 29          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 232         |
# | train/                  |             |
# |    approx_kl            | 0.008824185 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | -0.792      |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0149      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00109     |
# |    std                  | 0.0374      |
# |    value_loss           | 5.26e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 30           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 240          |
# | train/                  |              |
# |    approx_kl            | 0.0015979335 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.42         |
# |    explained_variance   | -0.0679      |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00747      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.00116      |
# |    std                  | 0.0374       |
# |    value_loss           | 3.91e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 107           |
# |    iterations           | 31            |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 248           |
# | train/                  |               |
# |    approx_kl            | 2.2187829e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.42          |
# |    explained_variance   | 0.159         |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00526       |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000393     |
# |    std                  | 0.0374        |
# |    value_loss           | 6.67e-06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 107           |
# |    iterations           | 32            |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 0.00021189451 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.41          |
# |    explained_variance   | 0.194         |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00506       |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000132     |
# |    std                  | 0.0374        |
# |    value_loss           | 1.37e-05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 107          |
# |    iterations           | 33           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 264          |
# | train/                  |              |
# |    approx_kl            | 0.0018309355 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.39         |
# |    explained_variance   | 0.0998       |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | -0.00139     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00287     |
# |    std                  | 0.0374       |
# |    value_loss           | 7.42e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 34           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 272          |
# | train/                  |              |
# |    approx_kl            | 9.063631e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.37         |
# |    explained_variance   | 0.0871       |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00698      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.000751     |
# |    std                  | 0.0375       |
# |    value_loss           | 2.77e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 35          |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 280         |
# | train/                  |             |
# |    approx_kl            | 0.000500232 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.36        |
# |    explained_variance   | -0.00713    |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.00586     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 1.08e-05    |
# |    std                  | 0.0375      |
# |    value_loss           | 0.000156    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 36           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 288          |
# | train/                  |              |
# |    approx_kl            | 1.937151e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.37         |
# |    explained_variance   | -0.0298      |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00554      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000144    |
# |    std                  | 0.0375       |
# |    value_loss           | 3.07e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 37           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 296          |
# | train/                  |              |
# |    approx_kl            | 7.137656e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.39         |
# |    explained_variance   | 0.036        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00571      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000132    |
# |    std                  | 0.0375       |
# |    value_loss           | 1.19e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 38           |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 304          |
# | train/                  |              |
# |    approx_kl            | 0.0069932267 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.41         |
# |    explained_variance   | 0.0649       |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0104       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000207    |
# |    std                  | 0.0375       |
# |    value_loss           | 2.32e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 39           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 312          |
# | train/                  |              |
# |    approx_kl            | 6.839633e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.42         |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00602      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -5.78e-05    |
# |    std                  | 0.0375       |
# |    value_loss           | 3.09e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 40           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 320          |
# | train/                  |              |
# |    approx_kl            | 0.0030259192 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.42         |
# |    explained_variance   | 0.853        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00432      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000531    |
# |    std                  | 0.0375       |
# |    value_loss           | 1.25e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 41          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 328         |
# | train/                  |             |
# |    approx_kl            | 0.002313532 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.4         |
# |    explained_variance   | -0.0709     |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | -0.00211    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00349    |
# |    std                  | 0.0375      |
# |    value_loss           | 5.76e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 42          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 336         |
# | train/                  |             |
# |    approx_kl            | 0.001293771 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.38        |
# |    explained_variance   | -0.161      |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.00347     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.000894   |
# |    std                  | 0.0375      |
# |    value_loss           | 2.3e-05     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 98           |
# |    iterations           | 43           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 344          |
# | train/                  |              |
# |    approx_kl            | 0.0026135445 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.37         |
# |    explained_variance   | -0.0361      |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0055       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000203    |
# |    std                  | 0.0375       |
# |    value_loss           | 8.97e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 98           |
# |    iterations           | 44           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 352          |
# | train/                  |              |
# |    approx_kl            | 0.0035120696 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.36         |
# |    explained_variance   | 0.0176       |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00553      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000123    |
# |    std                  | 0.0375       |
# |    value_loss           | 0.000194     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 98           |
# |    iterations           | 45           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 360          |
# | train/                  |              |
# |    approx_kl            | 7.374585e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.38         |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00245      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00146     |
# |    std                  | 0.0375       |
# |    value_loss           | 0.000134     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 98           |
# |    iterations           | 46           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 368          |
# | train/                  |              |
# |    approx_kl            | 0.0037855208 |
# |    clip_fraction        | 0.075        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.4          |
# |    explained_variance   | 0.248        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | -0.00152     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00339     |
# |    std                  | 0.0375       |
# |    value_loss           | 5.77e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 47           |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 376          |
# | train/                  |              |
# |    approx_kl            | 0.0002721101 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.42         |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.000807     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00222     |
# |    std                  | 0.0375       |
# |    value_loss           | 4.47e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 99            |
# |    iterations           | 48            |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 384           |
# | train/                  |               |
# |    approx_kl            | 0.00075124204 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.43          |
# |    explained_variance   | -0.0276       |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00635       |
# |    n_updates            | 470           |
# |    policy_gradient_loss | 0.000132      |
# |    std                  | 0.0375        |
# |    value_loss           | 2.31e-05      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 49          |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 392         |
# | train/                  |             |
# |    approx_kl            | 0.005448386 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.42        |
# |    explained_variance   | -5.7        |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.0035      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00189    |
# |    std                  | 0.0375      |
# |    value_loss           | 5.55e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 50           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 400          |
# | train/                  |              |
# |    approx_kl            | 0.0027465522 |
# |    clip_fraction        | 0.163        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.4          |
# |    explained_variance   | -0.19        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | -0.00841     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00274     |
# |    std                  | 0.0375       |
# |    value_loss           | 0.000384     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 51           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 408          |
# | train/                  |              |
# |    approx_kl            | 0.0029684752 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.37         |
# |    explained_variance   | -0.211       |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | -0.0015      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00382     |
# |    std                  | 0.0375       |
# |    value_loss           | 0.000211     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 52            |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 416           |
# | train/                  |               |
# |    approx_kl            | 0.00024235249 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.36          |
# |    explained_variance   | -0.216        |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00666       |
# |    n_updates            | 510           |
# |    policy_gradient_loss | 0.000534      |
# |    std                  | 0.0375        |
# |    value_loss           | 1.87e-05      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 53          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 424         |
# | train/                  |             |
# |    approx_kl            | 0.006169498 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 1.36        |
# |    explained_variance   | 0.0659      |
# |    learning_rate        | 7.77e-05    |
# |    loss                 | 0.00535     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00194    |
# |    std                  | 0.0375      |
# |    value_loss           | 0.000786    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 54           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 432          |
# | train/                  |              |
# |    approx_kl            | 0.0003886968 |
# |    clip_fraction        | 0.3          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.38         |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00506      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | 0.00296      |
# |    std                  | 0.0376       |
# |    value_loss           | 2.33e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 55           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 440          |
# | train/                  |              |
# |    approx_kl            | 0.0015937537 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.4          |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.0047       |
# |    n_updates            | 540          |
# |    policy_gradient_loss | 0.000167     |
# |    std                  | 0.0376       |
# |    value_loss           | 1.73e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 56           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 448          |
# | train/                  |              |
# |    approx_kl            | 9.834766e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.42         |
# |    explained_variance   | 0.418        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00584      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | 0.000109     |
# |    std                  | 0.0376       |
# |    value_loss           | 1.2e-05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 57           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 456          |
# | train/                  |              |
# |    approx_kl            | 0.0026856884 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.42         |
# |    explained_variance   | -1.56        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00519      |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.000602    |
# |    std                  | 0.0376       |
# |    value_loss           | 1.18e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 58           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 464          |
# | train/                  |              |
# |    approx_kl            | 0.0044120103 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.4          |
# |    explained_variance   | -3.23        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | -0.00619     |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00789     |
# |    std                  | 0.0376       |
# |    value_loss           | 5.18e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 59           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 472          |
# | train/                  |              |
# |    approx_kl            | 0.0011390746 |
# |    clip_fraction        | 0.3          |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.38         |
# |    explained_variance   | -10          |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | -0.0174      |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00627     |
# |    std                  | 0.0376       |
# |    value_loss           | 1.91e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 60           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 480          |
# | train/                  |              |
# |    approx_kl            | 6.863475e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.35         |
# |    explained_variance   | -0.19        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00869      |
# |    n_updates            | 590          |
# |    policy_gradient_loss | 0.00227      |
# |    std                  | 0.0376       |
# |    value_loss           | 0.000371     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 61           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 488          |
# | train/                  |              |
# |    approx_kl            | 0.0021771342 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.35         |
# |    explained_variance   | 0.165        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00556      |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.000106    |
# |    std                  | 0.0376       |
# |    value_loss           | 7.97e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 101           |
# |    iterations           | 62            |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 496           |
# | train/                  |               |
# |    approx_kl            | 2.6866794e-05 |
# |    clip_fraction        | 0.163         |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.36          |
# |    explained_variance   | 0.747         |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.0031        |
# |    n_updates            | 610           |
# |    policy_gradient_loss | -0.00158      |
# |    std                  | 0.0376        |
# |    value_loss           | 6.96e-06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 63           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 504          |
# | train/                  |              |
# |    approx_kl            | 0.0016322881 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.39         |
# |    explained_variance   | 0.528        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00473      |
# |    n_updates            | 620          |
# |    policy_gradient_loss | 1.63e-05     |
# |    std                  | 0.0376       |
# |    value_loss           | 7.56e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 64           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0046690106 |
# |    clip_fraction        | 0.15         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.41         |
# |    explained_variance   | 0.426        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | -0.00152     |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.00514     |
# |    std                  | 0.0376       |
# |    value_loss           | 0.000132     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 65           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 520          |
# | train/                  |              |
# |    approx_kl            | 0.0019071847 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 1.43         |
# |    explained_variance   | 0.376        |
# |    learning_rate        | 7.77e-05     |
# |    loss                 | 0.00475      |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.000705    |
# |    std                  | 0.0376       |
# |    value_loss           | 2.36e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 66            |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 528           |
# | train/                  |               |
# |    approx_kl            | 0.00021889806 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.1           |
# |    entropy_loss         | 1.43          |
# |    explained_variance   | -7.38         |
# |    learning_rate        | 7.77e-05      |
# |    loss                 | 0.00554       |
# |    n_updates            | 650           |
# |    policy_gradient_loss | -0.000272     |
# |    std                  | 0.0376        |
# |    value_loss           | 2.44e-05      |
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 4
#       2 TIMESTEPS = 20000
#       3 for i in range(10):
# ----> 4     model.learn(total_timesteps=TIMESTEPS,reset_num_timesteps=False, tb_log_name="PPO")
#       5     model.save(f"{models_dir}/{TIMESTEPS*i}")
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:281, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     278         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     279         self.logger.dump(step=self.num_timesteps)
# --> 281     self.train()
#     283 callback.on_training_end()
#     285 return self
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:272, in PPO.train(self)
#     270 # Optimization step
#     271 self.policy.optimizer.zero_grad()
# --> 272 loss.backward()
#     273 # Clip grad norm
#     274 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# File /usr/local/lib/python3.10/site-packages/torch/_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File /usr/local/lib/python3.10/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
import gym
import random
from keras import Sequential
from collections import deque
from keras.layers import Dense
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from keras.activations import relu, linear

import numpy as np
env = gym.make('MountainCar-v0')
#env.seed(110)
np.random.seed(10)


class DQN:

    """ Implementation of deep q learning algorithm """

    def __init__(self, action_space, state_space):
        self.action_space = action_space
        self.state_space = state_space
        self.epsilon = 1.0
        self.gamma = .95
        self.batch_size = 64
        self.epsilon_min = .01
        self.lr = 0.001
        self.epsilon_decay = .995
        self.memory = deque(maxlen=100000)
        self.model = self.build_model()

    def build_model(self):
        model = Sequential()
        model.add(Dense(20, input_dim=self.state_space, activation=relu))
        model.add(Dense(25, activation=relu))
        model.add(Dense(self.action_space, activation=linear))
        model.compile(loss='mse', optimizer=Adam(lr=self.lr))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_space)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])

    def replay(self):
        if len(self.memory) < self.batch_size:
            return
        minibatch = random.sample(self.memory, self.batch_size)
        states = np.array([i[0] for i in minibatch])
        actions = np.array([i[1] for i in minibatch])
        rewards = np.array([i[2] for i in minibatch])
        next_states = np.array([i[3] for i in minibatch])
        dones = np.array([i[4] for i in minibatch])
        states = np.squeeze(states)
        next_states = np.squeeze(next_states)
        targets = rewards + self.gamma*(np.amax(self.model.predict_on_batch(next_states), axis=1))*(1-dones)
        targets_full = self.model.predict_on_batch(states)
        ind = np.array([i for i in range(self.batch_size)])
        targets_full[[ind], [actions]] = targets
        self.model.fit(states, targets_full, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay


def get_reward(state):
    if state[0] >= 0.5:
        print("Car has reached the goal")
        return 10
    if state[0] > -0.4:
        return (1+state[0])**2
    return 0


def train_dqn(episode):
    loss = []
    agent = DQN(env.action_space.n, env.observation_space.shape[0])
    for e in range(episode):
        state = env.reset()
        state = np.reshape(state, (1, 2))
        score = 0
        max_steps = 1000
        for i in range(max_steps):
            action = agent.act(state)
            env.render()
            #print(env.step(action))
            next_state, reward, done, _, _ = env.step(action)
            reward = get_reward(next_state)
            score += reward
            next_state = np.reshape(next_state, (1, 2))
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            agent.replay()
            if done:
                print("episode: {}/{}, score: {}".format(e, episode, score))
                break
        loss.append(score)
    return loss


def random_policy(episode, step):
    for i_episode in range(episode):
        env.reset()
        for t in range(step):
            env.render()
            action = env.action_space.sample()
            state, reward, done, info = env.step(action)
            if done:
                print("Episode finished after {} timesteps".format(t+1))
                break
            print("Starting next episode")


if __name__ == '__main__':
    print(env.observation_space)
    print(env.action_space)
    episodes = 60
    loss = train_dqn(episodes)
    plt.plot([i+1 for i in range(episodes)], loss)
    plt.show()
# Out:
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# Discrete(3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [7], line 134
#     132 print(env.action_space)
#     133 episodes = 60
# --> 134 loss = train_dqn(episodes)
#     135 plt.plot([i+1 for i in range(episodes)], loss)
#     136 plt.show()
#
# Cell In [7], line 107, in train_dqn(episode)
#     105 agent.remember(state, action, reward, next_state, done)
#     106 state = next_state
# --> 107 agent.replay()
#     108 if done:
#     109     print("episode: {}/{}, score: {}".format(e, episode, score))
#
# Cell In [7], line 68, in DQN.replay(self)
#      65 next_states = np.squeeze(next_states)
#      67 targets = rewards + self.gamma*(np.amax(self.model.predict_on_batch(next_states), axis=1))*(1-dones)
# ---> 68 targets_full = self.model.predict_on_batch(states)
#      70 ind = np.array([i for i in range(self.batch_size)])
#      71 targets_full[[ind], [actions]] = targets
#
# File /usr/local/lib/python3.10/site-packages/keras/engine/training.py:2567, in Model.predict_on_batch(self, x)
#    2565 _disallow_inside_tf_function("predict_on_batch")
#    2566 with self.distribute_strategy.scope():
# -> 2567     iterator = data_adapter.single_batch_iterator(
#    2568         self.distribute_strategy, x
#    2569     )
#    2570     self.predict_function = self.make_predict_function()
#    2571     outputs = self.predict_function(iterator)
#
# File /usr/local/lib/python3.10/site-packages/keras/engine/data_adapter.py:1820, in single_batch_iterator(strategy, x, y, sample_weight, class_weight)
#    1816 def single_batch_iterator(
#    1817     strategy, x, y=None, sample_weight=None, class_weight=None
#    1818 ):
#    1819     """Creates a single-batch dataset."""
# -> 1820     x, y, sample_weight = _process_tensorlike((x, y, sample_weight))
#    1821     if y is None:
#    1822         data = (x,)
#
# File /usr/local/lib/python3.10/site-packages/keras/engine/data_adapter.py:1139, in _process_tensorlike(inputs)
#    1136         return _scipy_sparse_to_sparse_tensor(x)
#    1137     return x
# -> 1139 inputs = tf.nest.map_structure(_convert_single_tensor, inputs)
#    1140 return tf.__internal__.nest.list_to_tuple(inputs)
#
# File /usr/local/lib/python3.10/site-packages/tensorflow/python/util/nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File /usr/local/lib/python3.10/site-packages/tensorflow/python/util/nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File /usr/local/lib/python3.10/site-packages/keras/engine/data_adapter.py:1134, in _process_tensorlike.<locals>._convert_single_tensor(x)
#    1132     if issubclass(x.dtype.type, np.floating):
#    1133         dtype = backend.floatx()
# -> 1134     return tf.convert_to_tensor(x, dtype=dtype)
#    1135 elif _is_scipy_sparse(x):
#    1136     return _scipy_sparse_to_sparse_tensor(x)
#
# File /usr/local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File /usr/local/lib/python3.10/site-packages/tensorflow/python/framework/constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float).
