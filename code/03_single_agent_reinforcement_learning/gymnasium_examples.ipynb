# %%
import gymnasium as gym

from stable_baselines3 import DQN

env = gym.make("CartPole-v1", render_mode="human")

model = DQN("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000, log_interval=4)
model.save("dqn_cartpole")

del model # remove to demonstrate saving and loading

model = DQN.load("dqn_cartpole")

obs, info = env.reset()
while True:
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        obs, info = env.reset()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 24       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 59       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 30       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.779    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 35       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 233      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.706    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 37       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 309      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.4     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 39       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 387      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 39       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 468      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.465    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 40       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 563      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.353    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 41       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 681      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 41       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 781      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.193    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 42       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 850      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.105    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 42       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 942      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 42       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 43       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1167     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 43       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 1292     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 43       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 1356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.7     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 42       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 1452     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 42       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 1537     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 42       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 1609     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.6     |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 42       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 1715     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 42       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 1783     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 43       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 1941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 43       |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 2002     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 43       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 2053     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 43       |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 2134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 43       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 2190     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 43       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 2248     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 43       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 2315     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 43       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 2421     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.8     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 43       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 2486     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 43       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 2589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 43       |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 2679     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22       |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 43       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 2762     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 43       |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 2834     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 43       |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 2947     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 43       |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 2996     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 44       |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 3044     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 44       |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 3160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 44       |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 3219     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 44       |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 3326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 44       |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 3408     |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 8
#       5 env = gym.make("CartPole-v1", render_mode="human")
#       7 model = DQN("MlpPolicy", env, verbose=1)
# ----> 8 model.learn(total_timesteps=10000, log_interval=4)
#       9 model.save("dqn_cartpole")
#      11 del model # remove to demonstrate saving and loading
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/dqn/dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:312, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     309 callback.on_training_start(locals(), globals())
#     311 while self.num_timesteps < total_timesteps:
# --> 312     rollout = self.collect_rollouts(
#     313         self.env,
#     314         train_freq=self.train_freq,
#     315         action_noise=self.action_noise,
#     316         callback=callback,
#     317         learning_starts=self.learning_starts,
#     318         replay_buffer=self.replay_buffer,
#     319         log_interval=log_interval,
#     320     )
#     322     if rollout.continue_training is False:
#     323         break
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:544, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     541 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     543 # Rescale and perform action
# --> 544 new_obs, rewards, dones, infos = env.step(actions)
#     546 self.num_timesteps += env.num_envs
#     547 num_collected_steps += 1
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:197, in VecEnv.step(self, actions)
#     190 """
#     191 Step the environments with the given action
#     192
#     193 :param actions: the action
#     194 :return: observation, reward, done, information
#     195 """
#     196 self.step_async(actions)
# --> 197 return self.step_wait()
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File /usr/local/lib/python3.10/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File /usr/local/lib/python3.10/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File /usr/local/lib/python3.10/site-packages/gymnasium/wrappers/env_checker.py:49, in PassiveEnvChecker.step(self, action)
#      47     return env_step_passive_checker(self.env, action)
#      48 else:
# ---> 49     return self.env.step(action)
#
# File /usr/local/lib/python3.10/site-packages/gymnasium/envs/classic_control/cartpole.py:190, in CartPoleEnv.step(self, action)
#     187     reward = 0.0
#     189 if self.render_mode == "human":
# --> 190     self.render()
#     191 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File /usr/local/lib/python3.10/site-packages/gymnasium/envs/classic_control/cartpole.py:303, in CartPoleEnv.render(self)
#     301     pygame.event.pump()
#     302     self.clock.tick(self.metadata["render_fps"])
# --> 303     pygame.display.flip()
#     305 elif self.render_mode == "rgb_array":
#     306     return np.transpose(
#     307         np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
#     308     )
#
# KeyboardInterrupt:

# %%
import gymnasium as gym

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy


# Create environment
env = gym.make("LunarLander-v2", render_mode="human")

# Instantiate the agent
model = DQN("MlpPolicy", env, verbose=1)
# Train the agent and display a progress bar
model.learn(total_timesteps=int(2e5), progress_bar=True)
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading

# Load the trained agent
# NOTE: if you have loading issue, you can pass `print_system_info=True`
# to compare the system on which the model was trained vs the current one
# model = DQN.load("dqn_lunar", env=env, print_system_info=True)
model = DQN.load("dqn_lunar", env=env)

# Evaluate the agent
# NOTE: If you use wrappers with your environment that modify rewards,
#       this will be reflected here. To evaluate with original rewards,
#       wrap environment in a "Monitor" wrapper before other wrappers.
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)

# Enjoy trained agent
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Output()
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.8     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 41       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 327      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -221     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 44       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 739      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -212     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 45       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1081     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -206     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 43       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 1444     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.5     |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 44       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 1749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.1     |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 44       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 2043     |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 13
#      11 model = DQN("MlpPolicy", env, verbose=1)
#      12 # Train the agent and display a progress bar
# ---> 13 model.learn(total_timesteps=int(2e5), progress_bar=True)
#      14 # Save the agent
#      15 model.save("dqn_lunar")
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/dqn/dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:312, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     309 callback.on_training_start(locals(), globals())
#     311 while self.num_timesteps < total_timesteps:
# --> 312     rollout = self.collect_rollouts(
#     313         self.env,
#     314         train_freq=self.train_freq,
#     315         action_noise=self.action_noise,
#     316         callback=callback,
#     317         learning_starts=self.learning_starts,
#     318         replay_buffer=self.replay_buffer,
#     319         log_interval=log_interval,
#     320     )
#     322     if rollout.continue_training is False:
#     323         break
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:544, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     541 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     543 # Rescale and perform action
# --> 544 new_obs, rewards, dones, infos = env.step(actions)
#     546 self.num_timesteps += env.num_envs
#     547 num_collected_steps += 1
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:197, in VecEnv.step(self, actions)
#     190 """
#     191 Step the environments with the given action
#     192
#     193 :param actions: the action
#     194 :return: observation, reward, done, information
#     195 """
#     196 self.step_async(actions)
# --> 197 return self.step_wait()
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File /usr/local/lib/python3.10/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File /usr/local/lib/python3.10/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File /usr/local/lib/python3.10/site-packages/gymnasium/wrappers/env_checker.py:49, in PassiveEnvChecker.step(self, action)
#      47     return env_step_passive_checker(self.env, action)
#      48 else:
# ---> 49     return self.env.step(action)
#
# File /usr/local/lib/python3.10/site-packages/gymnasium/envs/box2d/lunar_lander.py:675, in LunarLander.step(self, action)
#     672     reward = +100
#     674 if self.render_mode == "human":
# --> 675     self.render()
#     676 return np.array(state, dtype=np.float32), reward, terminated, False, {}
#
# File /usr/local/lib/python3.10/site-packages/gymnasium/envs/box2d/lunar_lander.py:787, in LunarLander.render(self)
#     785     self.screen.blit(self.surf, (0, 0))
#     786     pygame.event.pump()
# --> 787     self.clock.tick(self.metadata["render_fps"])
#     788     pygame.display.flip()
#     789 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Parallel environments
vec_env = make_vec_env("CartPole-v1", n_envs=4)

model = PPO("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo_cartpole")

del model # remove to demonstrate saving and loading

model = PPO.load("ppo_cartpole")

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 21.1     |
# | time/              |          |
# |    fps             | 3794     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.5        |
# |    ep_rew_mean          | 33.5        |
# | time/                   |             |
# |    fps                  | 1703        |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014396748 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.000539    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.51        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0248     |
# |    value_loss           | 18.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 67.8       |
# |    ep_rew_mean          | 67.8       |
# | time/                   |            |
# |    fps                  | 1438       |
# |    iterations           | 3          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01623698 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.647     |
# |    explained_variance   | 0.389      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11         |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0338    |
# |    value_loss           | 26.1       |
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 9
#       6 vec_env = make_vec_env("CartPole-v1", n_envs=4)
#       8 model = PPO("MlpPolicy", vec_env, verbose=1)
# ----> 9 model.learn(total_timesteps=25000)
#      10 model.save("ppo_cartpole")
#      12 del model # remove to demonstrate saving and loading
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:281, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     278         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     279         self.logger.dump(step=self.num_timesteps)
# --> 281     self.train()
#     283 callback.on_training_end()
#     285 return self
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:272, in PPO.train(self)
#     270 # Optimization step
#     271 self.policy.optimizer.zero_grad()
# --> 272 loss.backward()
#     273 # Clip grad norm
#     274 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# File /usr/local/lib/python3.10/site-packages/torch/_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File /usr/local/lib/python3.10/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
