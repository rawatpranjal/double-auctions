# %%
#from setup import *
#from agents import *
#from env import *
buyerStrategies = ['DDPG']
sellerStrategies = ['TruthTeller', 'TruthTeller', 'TruthTeller', 'TruthTeller']
gamereinforcers, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed = '1001', len(buyerStrategies), len(sellerStrategies), 3, 1, 10000, 9, 42
disclosure = ['rnd', 'period', 'step','currentBid','currentAsk','buy','sell','price','sale']
gameData = [gamereinforcers, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed] 
buyers, sellers = generateAgents(gameData,buyerStrategies,sellerStrategies,disclosure)
log = Log(gameData, buyerStrategies, sellerStrategies, disclosure)


#Hyperparameters
lr_mu        = 0.0005
lr_q         = 0.001
gamma        = 0.99
batch_size   = 32
buffer_limit = 50000
tau          = 0.005 # for target network soft update

for rnd in range(numRounds):
    roundData = roundSetup(*gameData)
    redemptionValues, tokenCosts, demand, supply, prices, peq, qeq  = roundData[0:7]
    [buyerReservationPrices, sellerReservationPrices, buyerSurplus, sellerSurplus, totalSurplus, buyerSurplusFrac, sellerSurplusFrac] = roundData[7:]
    log.addRound([rnd] + roundData)
    resetRounds(buyers, sellers, redemptionValues, tokenCosts)
    for period in range(numPeriods):
        resetPeriods(buyers, sellers)
        for step in range(numSteps):
            resetSteps(buyers, sellers)
            bids, asks = collectOffers(buyers, sellers)
            currentAsk, currentAskIdx, currentBid, currentBidIdx = bestOffers(bids, asks)
            price, buy, sell = trade(buyers, sellers, currentAsk, currentAskIdx, currentBid, currentBidIdx)
            bprofit, sprofit = 0, 0
            if price > 0:
                buyers[currentBidIdx].transact(price)
                sellers[currentAskIdx].transact(price)
                bprofit = buyers[currentBidIdx].stepProfits
                sprofit = sellers[currentAskIdx].stepProfits
            log.addStep([rnd, period, step, bids, asks, currentBid, currentBidIdx, currentAsk, currentAskIdx, buy, sell, price, price>0, bprofit, sprofit])
            observe(buyers, sellers, log.disclose()) # observe new state
            updateStates(buyers, sellers)
        updatePolicy(buyers, sellers)
        
        if period % (numPeriods/1000) == 0:
            print(f'\n{period}')
            display(log.getPeriod(rnd, period).tail(100)[['bprofit', 'currentBidIdx']].groupby('currentBidIdx').sum())
            #display(log.getPeriod(rnd, period).tail(100)[['sprofit', 'currentAskIdx']].groupby('currentAskIdx').sum())
            display(log.getPeriod(rnd,period))
# Out:
# 0
#                   bprofit
# currentBidIdx
# 0.0            161.021579
#    rnd  period  step                 bids                      asks  \
# 0    0       0     0   [50.0676271123065]     [0.7, 52.0, 0.0, 4.4]
# 1    0       0     1  [85.25063212149391]    [0.7, 52.0, 95.0, 4.4]
# 2    0       0     2  [50.53858188417778]   [13.8, 52.0, 95.0, 4.4]
# 3    0       0     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 4    0       0     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 5    0       0     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 6    0       0     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7    0       0     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 8    0       0     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#    currentBid  currentBidIdx  currentAsk  currentAskIdx  buy sell      price  \
# 0   50.067627            0.0         0.0              2  1.0  1.0  25.033814
# 1   85.250632            0.0         0.7              0  1.0  1.0  42.975316
# 2   50.538582            0.0         4.4              3  1.0  1.0  27.469291
# 3         NaN            NaN        13.8              0  NaN  NaN        NaN
# 4         NaN            NaN        13.8              0  NaN  NaN        NaN
# 5         NaN            NaN        13.8              0  NaN  NaN        NaN
# 6         NaN            NaN        13.8              0  NaN  NaN        NaN
# 7         NaN            NaN        13.8              0  NaN  NaN        NaN
# 8         NaN            NaN        13.8              0  NaN  NaN        NaN
#
#     sale    bprofit    sprofit
# 0   True  65.366186  25.033814
# 1   True  41.724684  42.275316
# 2   True  53.930709  23.069291
# 3  False   0.000000   0.000000
# 4  False   0.000000   0.000000
# 5  False   0.000000   0.000000
# 6  False   0.000000   0.000000
# 7  False   0.000000   0.000000
# 8  False   0.000000   0.000000
# 10
#                   bprofit
# currentBidIdx
# 0.0            171.528594
#     rnd  period  step                  bids                      asks  \
# 90    0      10     0  [43.317591645025615]     [0.7, 52.0, 0.0, 4.4]
# 91    0      10     1   [82.25393390109025]    [0.7, 52.0, 95.0, 4.4]
# 92    0      10     2   [39.27128554919222]   [13.8, 52.0, 95.0, 4.4]
# 93    0      10     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 94    0      10     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 95    0      10     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 96    0      10     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 97    0      10     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 98    0      10     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#     currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 90   43.317592            0.0         0.0              2  True  True
# 91   82.253934            0.0         0.7              0  True  True
# 92   39.271286            0.0         4.4              3  True  True
# 93         NaN            NaN        13.8              0   NaN   NaN
# 94         NaN            NaN        13.8              0   NaN   NaN
# 95         NaN            NaN        13.8              0   NaN   NaN
# 96         NaN            NaN        13.8              0   NaN   NaN
# 97         NaN            NaN        13.8              0   NaN   NaN
# 98         NaN            NaN        13.8              0   NaN   NaN
#
#         price   sale    bprofit    sprofit
# 90  21.658796   True  68.741204  21.658796
# 91  41.476967   True  43.223033  40.776967
# 92  21.835643   True  59.564357  17.435643
# 93        NaN  False   0.000000   0.000000
# 94        NaN  False   0.000000   0.000000
# 95        NaN  False   0.000000   0.000000
# 96        NaN  False   0.000000   0.000000
# 97        NaN  False   0.000000   0.000000
# 98        NaN  False   0.000000   0.000000
# 20
#                   bprofit
# currentBidIdx
# 0.0            173.047768
#      rnd  period  step                 bids                      asks  \
# 180    0      20     0  [43.13932189180305]     [0.7, 52.0, 0.0, 4.4]
# 181    0      20     1  [81.54917774301289]    [0.7, 52.0, 95.0, 4.4]
# 182    0      20     2  [37.11596344649795]   [13.8, 52.0, 95.0, 4.4]
# 183    0      20     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 184    0      20     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 185    0      20     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 186    0      20     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 187    0      20     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 188    0      20     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#      currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 180   43.139322            0.0         0.0              2  True  True
# 181   81.549178            0.0         0.7              0  True  True
# 182   37.115963            0.0         4.4              3  True  True
# 183         NaN            NaN        13.8              0   NaN   NaN
# 184         NaN            NaN        13.8              0   NaN   NaN
# 185         NaN            NaN        13.8              0   NaN   NaN
# 186         NaN            NaN        13.8              0   NaN   NaN
# 187         NaN            NaN        13.8              0   NaN   NaN
# 188         NaN            NaN        13.8              0   NaN   NaN
#
#          price   sale    bprofit    sprofit
# 180  21.569661   True  68.830339  21.569661
# 181  41.124589   True  43.575411  40.424589
# 182  20.757982   True  60.642018  16.357982
# 183        NaN  False   0.000000   0.000000
# 184        NaN  False   0.000000   0.000000
# 185        NaN  False   0.000000   0.000000
# 186        NaN  False   0.000000   0.000000
# 187        NaN  False   0.000000   0.000000
# 188        NaN  False   0.000000   0.000000
# 30
#                   bprofit
# currentBidIdx
# 0.0            170.651756
#      rnd  period  step                  bids                      asks  \
# 270    0      30     0   [44.80558558411168]     [0.7, 52.0, 0.0, 4.4]
# 271    0      30     1   [82.49055252064193]    [0.7, 52.0, 95.0, 4.4]
# 272    0      30     2  [39.300350627768786]   [13.8, 52.0, 95.0, 4.4]
# 273    0      30     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 274    0      30     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 275    0      30     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 276    0      30     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 277    0      30     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 278    0      30     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#      currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 270   44.805586            0.0         0.0              2  True  True
# 271   82.490553            0.0         0.7              0  True  True
# 272   39.300351            0.0         4.4              3  True  True
# 273         NaN            NaN        13.8              0   NaN   NaN
# 274         NaN            NaN        13.8              0   NaN   NaN
# 275         NaN            NaN        13.8              0   NaN   NaN
# 276         NaN            NaN        13.8              0   NaN   NaN
# 277         NaN            NaN        13.8              0   NaN   NaN
# 278         NaN            NaN        13.8              0   NaN   NaN
#
#          price   sale    bprofit    sprofit
# 270  22.402793   True  67.997207  22.402793
# 271  41.595276   True  43.104724  40.895276
# 272  21.850175   True  59.549825  17.450175
# 273        NaN  False   0.000000   0.000000
# 274        NaN  False   0.000000   0.000000
# 275        NaN  False   0.000000   0.000000
# 276        NaN  False   0.000000   0.000000
# 277        NaN  False   0.000000   0.000000
# 278        NaN  False   0.000000   0.000000
# 40
#                   bprofit
# currentBidIdx
# 0.0            172.134596
#      rnd  period  step                  bids                      asks  \
# 360    0      40     0  [44.591890189907005]     [0.7, 52.0, 0.0, 4.4]
# 361    0      40     1   [80.95363689743596]    [0.7, 52.0, 95.0, 4.4]
# 362    0      40     2   [38.08528184734179]   [13.8, 52.0, 95.0, 4.4]
# 363    0      40     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 364    0      40     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 365    0      40     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 366    0      40     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 367    0      40     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 368    0      40     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#      currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 360   44.591890            0.0         0.0              2  True  True
# 361   80.953637            0.0         0.7              0  True  True
# 362   38.085282            0.0         4.4              3  True  True
# 363         NaN            NaN        13.8              0   NaN   NaN
# 364         NaN            NaN        13.8              0   NaN   NaN
# 365         NaN            NaN        13.8              0   NaN   NaN
# 366         NaN            NaN        13.8              0   NaN   NaN
# 367         NaN            NaN        13.8              0   NaN   NaN
# 368         NaN            NaN        13.8              0   NaN   NaN
#
#          price   sale    bprofit    sprofit
# 360  22.295945   True  68.104055  22.295945
# 361  40.826818   True  43.873182  40.126818
# 362  21.242641   True  60.157359  16.842641
# 363        NaN  False   0.000000   0.000000
# 364        NaN  False   0.000000   0.000000
# 365        NaN  False   0.000000   0.000000
# 366        NaN  False   0.000000   0.000000
# 367        NaN  False   0.000000   0.000000
# 368        NaN  False   0.000000   0.000000
# 50
#                   bprofit
# currentBidIdx
# 0.0            173.969872
#      rnd  period  step                  bids                      asks  \
# 450    0      50     0   [40.90430694610045]     [0.7, 52.0, 0.0, 4.4]
# 451    0      50     1   [81.51496677467533]    [0.7, 52.0, 95.0, 4.4]
# 452    0      50     2  [37.540982686488675]   [13.8, 52.0, 95.0, 4.4]
# 453    0      50     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 454    0      50     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 455    0      50     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 456    0      50     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 457    0      50     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 458    0      50     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#      currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 450   40.904307            0.0         0.0              2  True  True
# 451   81.514967            0.0         0.7              0  True  True
# 452   37.540983            0.0         4.4              3  True  True
# 453         NaN            NaN        13.8              0   NaN   NaN
# 454         NaN            NaN        13.8              0   NaN   NaN
# 455         NaN            NaN        13.8              0   NaN   NaN
# 456         NaN            NaN        13.8              0   NaN   NaN
# 457         NaN            NaN        13.8              0   NaN   NaN
# 458         NaN            NaN        13.8              0   NaN   NaN
#
#          price   sale    bprofit    sprofit
# 450  20.452153   True  69.947847  20.452153
# 451  41.107483   True  43.592517  40.407483
# 452  20.970491   True  60.429509  16.570491
# 453        NaN  False   0.000000   0.000000
# 454        NaN  False   0.000000   0.000000
# 455        NaN  False   0.000000   0.000000
# 456        NaN  False   0.000000   0.000000
# 457        NaN  False   0.000000   0.000000
# 458        NaN  False   0.000000   0.000000
# 60
#                  bprofit
# currentBidIdx
# 0.0            175.43026
#      rnd  period  step                 bids                      asks  \
# 540    0      60     0  [41.05340615058522]     [0.7, 52.0, 0.0, 4.4]
# 541    0      60     1  [80.29963409264657]    [0.7, 52.0, 95.0, 4.4]
# 542    0      60     2   [35.6864396945966]   [13.8, 52.0, 95.0, 4.4]
# 543    0      60     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 544    0      60     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 545    0      60     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 546    0      60     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 547    0      60     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 548    0      60     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#      currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 540   41.053406            0.0         0.0              2  True  True
# 541   80.299634            0.0         0.7              0  True  True
# 542   35.686440            0.0         4.4              3  True  True
# 543         NaN            NaN        13.8              0   NaN   NaN
# 544         NaN            NaN        13.8              0   NaN   NaN
# 545         NaN            NaN        13.8              0   NaN   NaN
# 546         NaN            NaN        13.8              0   NaN   NaN
# 547         NaN            NaN        13.8              0   NaN   NaN
# 548         NaN            NaN        13.8              0   NaN   NaN
#
#          price   sale    bprofit    sprofit
# 540  20.526703   True  69.873297  20.526703
# 541  40.499817   True  44.200183  39.799817
# 542  20.043220   True  61.356780  15.643220
# 543        NaN  False   0.000000   0.000000
# 544        NaN  False   0.000000   0.000000
# 545        NaN  False   0.000000   0.000000
# 546        NaN  False   0.000000   0.000000
# 547        NaN  False   0.000000   0.000000
# 548        NaN  False   0.000000   0.000000
# 70
#                   bprofit
# currentBidIdx
# 0.0            178.903285
#      rnd  period  step                 bids                      asks  \
# 630    0      70     0  [37.57995280664842]     [0.7, 52.0, 0.0, 4.4]
# 631    0      70     1  [78.37627868520565]    [0.7, 52.0, 95.0, 4.4]
# 632    0      70     2   [34.1371991644102]   [13.8, 52.0, 95.0, 4.4]
# 633    0      70     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 634    0      70     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 635    0      70     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 636    0      70     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 637    0      70     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 638    0      70     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#      currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 630   37.579953            0.0         0.0              2  True  True
# 631   78.376279            0.0         0.7              0  True  True
# 632   34.137199            0.0         4.4              3  True  True
# 633         NaN            NaN        13.8              0   NaN   NaN
# 634         NaN            NaN        13.8              0   NaN   NaN
# 635         NaN            NaN        13.8              0   NaN   NaN
# 636         NaN            NaN        13.8              0   NaN   NaN
# 637         NaN            NaN        13.8              0   NaN   NaN
# 638         NaN            NaN        13.8              0   NaN   NaN
#
#          price   sale    bprofit    sprofit
# 630  18.789976   True  71.610024  18.789976
# 631  39.538139   True  45.161861  38.838139
# 632  19.268600   True  62.131400  14.868600
# 633        NaN  False   0.000000   0.000000
# 634        NaN  False   0.000000   0.000000
# 635        NaN  False   0.000000   0.000000
# 636        NaN  False   0.000000   0.000000
# 637        NaN  False   0.000000   0.000000
# 638        NaN  False   0.000000   0.000000
# 80
#                   bprofit
# currentBidIdx
# 0.0            180.049713
#      rnd  period  step                 bids                      asks  \
# 720    0      80     0  [34.58996970928647]     [0.7, 52.0, 0.0, 4.4]
# 721    0      80     1  [77.08358762773528]    [0.7, 52.0, 95.0, 4.4]
# 722    0      80     2  [36.12701673584633]   [13.8, 52.0, 95.0, 4.4]
# 723    0      80     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 724    0      80     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 725    0      80     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 726    0      80     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 727    0      80     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 728    0      80     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#      currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 720   34.589970            0.0         0.0              2  True  True
# 721   77.083588            0.0         0.7              0  True  True
# 722   36.127017            0.0         4.4              3  True  True
# 723         NaN            NaN        13.8              0   NaN   NaN
# 724         NaN            NaN        13.8              0   NaN   NaN
# 725         NaN            NaN        13.8              0   NaN   NaN
# 726         NaN            NaN        13.8              0   NaN   NaN
# 727         NaN            NaN        13.8              0   NaN   NaN
# 728         NaN            NaN        13.8              0   NaN   NaN
#
#          price   sale    bprofit    sprofit
# 720  17.294985   True  73.105015  17.294985
# 721  38.891794   True  45.808206  38.191794
# 722  20.263508   True  61.136492  15.863508
# 723        NaN  False   0.000000   0.000000
# 724        NaN  False   0.000000   0.000000
# 725        NaN  False   0.000000   0.000000
# 726        NaN  False   0.000000   0.000000
# 727        NaN  False   0.000000   0.000000
# 728        NaN  False   0.000000   0.000000
# 90
#                   bprofit
# currentBidIdx
# 0.0            177.595778
#      rnd  period  step                  bids                      asks  \
# 810    0      90     0   [37.05576073576301]     [0.7, 52.0, 0.0, 4.4]
# 811    0      90     1   [79.60808365200153]    [0.7, 52.0, 95.0, 4.4]
# 812    0      90     2  [36.044600289094014]   [13.8, 52.0, 95.0, 4.4]
# 813    0      90     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 814    0      90     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 815    0      90     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 816    0      90     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 817    0      90     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 818    0      90     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#      currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 810   37.055761            0.0         0.0              2  True  True
# 811   79.608084            0.0         0.7              0  True  True
# 812   36.044600            0.0         4.4              3  True  True
# 813         NaN            NaN        13.8              0   NaN   NaN
# 814         NaN            NaN        13.8              0   NaN   NaN
# 815         NaN            NaN        13.8              0   NaN   NaN
# 816         NaN            NaN        13.8              0   NaN   NaN
# 817         NaN            NaN        13.8              0   NaN   NaN
# 818         NaN            NaN        13.8              0   NaN   NaN
#
#          price   sale    bprofit    sprofit
# 810  18.527880   True  71.872120  18.527880
# 811  40.154042   True  44.545958  39.454042
# 812  20.222300   True  61.177700  15.822300
# 813        NaN  False   0.000000   0.000000
# 814        NaN  False   0.000000   0.000000
# 815        NaN  False   0.000000   0.000000
# 816        NaN  False   0.000000   0.000000
# 817        NaN  False   0.000000   0.000000
# 818        NaN  False   0.000000   0.000000
# 100
#                   bprofit
# currentBidIdx
# 0.0            182.275183
#      rnd  period  step                 bids                      asks  \
# 900    0     100     0  [33.55057637732817]     [0.7, 52.0, 0.0, 4.4]
# 901    0     100     1  [75.79139139109178]    [0.7, 52.0, 95.0, 4.4]
# 902    0     100     2  [34.00766648492365]   [13.8, 52.0, 95.0, 4.4]
# 903    0     100     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 904    0     100     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 905    0     100     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 906    0     100     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 907    0     100     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 908    0     100     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#      currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 900   33.550576            0.0         0.0              2  True  True
# 901   75.791391            0.0         0.7              0  True  True
# 902   34.007666            0.0         4.4              3  True  True
# 903         NaN            NaN        13.8              0   NaN   NaN
# 904         NaN            NaN        13.8              0   NaN   NaN
# 905         NaN            NaN        13.8              0   NaN   NaN
# 906         NaN            NaN        13.8              0   NaN   NaN
# 907         NaN            NaN        13.8              0   NaN   NaN
# 908         NaN            NaN        13.8              0   NaN   NaN
#
#          price   sale    bprofit    sprofit
# 900  16.775288   True  73.624712  16.775288
# 901  38.245696   True  46.454304  37.545696
# 902  19.203833   True  62.196167  14.803833
# 903        NaN  False   0.000000   0.000000
# 904        NaN  False   0.000000   0.000000
# 905        NaN  False   0.000000   0.000000
# 906        NaN  False   0.000000   0.000000
# 907        NaN  False   0.000000   0.000000
# 908        NaN  False   0.000000   0.000000
# 110
#                   bprofit
# currentBidIdx
# 0.0            180.615512
#      rnd  period  step                  bids                      asks  \
# 990    0     110     0   [36.49708615968767]     [0.7, 52.0, 0.0, 4.4]
# 991    0     110     1    [76.9332242829269]    [0.7, 52.0, 95.0, 4.4]
# 992    0     110     2  [33.238665114762405]   [13.8, 52.0, 95.0, 4.4]
# 993    0     110     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 994    0     110     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 995    0     110     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 996    0     110     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 997    0     110     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 998    0     110     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#      currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 990   36.497086            0.0         0.0              2  True  True
# 991   76.933224            0.0         0.7              0  True  True
# 992   33.238665            0.0         4.4              3  True  True
# 993         NaN            NaN        13.8              0   NaN   NaN
# 994         NaN            NaN        13.8              0   NaN   NaN
# 995         NaN            NaN        13.8              0   NaN   NaN
# 996         NaN            NaN        13.8              0   NaN   NaN
# 997         NaN            NaN        13.8              0   NaN   NaN
# 998         NaN            NaN        13.8              0   NaN   NaN
#
#          price   sale    bprofit    sprofit
# 990  18.248543   True  72.151457  18.248543
# 991  38.816612   True  45.883388  38.116612
# 992  18.819333   True  62.580667  14.419333
# 993        NaN  False   0.000000   0.000000
# 994        NaN  False   0.000000   0.000000
# 995        NaN  False   0.000000   0.000000
# 996        NaN  False   0.000000   0.000000
# 997        NaN  False   0.000000   0.000000
# 998        NaN  False   0.000000   0.000000
# 120
#                   bprofit
# currentBidIdx
# 0.0            184.032328
#       rnd  period  step                  bids                      asks  \
# 1080    0     120     0  [30.006076533901943]     [0.7, 52.0, 0.0, 4.4]
# 1081    0     120     1    [74.4721524377935]    [0.7, 52.0, 95.0, 4.4]
# 1082    0     120     2   [35.35711476247455]   [13.8, 52.0, 95.0, 4.4]
# 1083    0     120     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1084    0     120     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1085    0     120     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1086    0     120     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1087    0     120     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1088    0     120     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 1080   30.006077            0.0         0.0              2  True  True
# 1081   74.472152            0.0         0.7              0  True  True
# 1082   35.357115            0.0         4.4              3  True  True
# 1083         NaN            NaN        13.8              0   NaN   NaN
# 1084         NaN            NaN        13.8              0   NaN   NaN
# 1085         NaN            NaN        13.8              0   NaN   NaN
# 1086         NaN            NaN        13.8              0   NaN   NaN
# 1087         NaN            NaN        13.8              0   NaN   NaN
# 1088         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 1080  15.003038   True  75.396962  15.003038
# 1081  37.586076   True  47.113924  36.886076
# 1082  19.878557   True  61.521443  15.478557
# 1083        NaN  False   0.000000   0.000000
# 1084        NaN  False   0.000000   0.000000
# 1085        NaN  False   0.000000   0.000000
# 1086        NaN  False   0.000000   0.000000
# 1087        NaN  False   0.000000   0.000000
# 1088        NaN  False   0.000000   0.000000
# 130
#                   bprofit
# currentBidIdx
# 0.0            182.098254
#       rnd  period  step                 bids                      asks  \
# 1170    0     130     0  [33.69517447457889]     [0.7, 52.0, 0.0, 4.4]
# 1171    0     130     1  [76.28894953802195]    [0.7, 52.0, 95.0, 4.4]
# 1172    0     130     2  [33.71936855555611]   [13.8, 52.0, 95.0, 4.4]
# 1173    0     130     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1174    0     130     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1175    0     130     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1176    0     130     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1177    0     130     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1178    0     130     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 1170   33.695174            0.0         0.0              2  True  True
# 1171   76.288950            0.0         0.7              0  True  True
# 1172   33.719369            0.0         4.4              3  True  True
# 1173         NaN            NaN        13.8              0   NaN   NaN
# 1174         NaN            NaN        13.8              0   NaN   NaN
# 1175         NaN            NaN        13.8              0   NaN   NaN
# 1176         NaN            NaN        13.8              0   NaN   NaN
# 1177         NaN            NaN        13.8              0   NaN   NaN
# 1178         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 1170  16.847587   True  73.552413  16.847587
# 1171  38.494475   True  46.205525  37.794475
# 1172  19.059684   True  62.340316  14.659684
# 1173        NaN  False   0.000000   0.000000
# 1174        NaN  False   0.000000   0.000000
# 1175        NaN  False   0.000000   0.000000
# 1176        NaN  False   0.000000   0.000000
# 1177        NaN  False   0.000000   0.000000
# 1178        NaN  False   0.000000   0.000000
# 140
#                  bprofit
# currentBidIdx
# 0.0            184.06893
#       rnd  period  step                  bids                      asks  \
# 1260    0     140     0   [32.27199359243042]     [0.7, 52.0, 0.0, 4.4]
# 1261    0     140     1   [74.55764742980816]    [0.7, 52.0, 95.0, 4.4]
# 1262    0     140     2  [32.932498545014056]   [13.8, 52.0, 95.0, 4.4]
# 1263    0     140     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1264    0     140     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1265    0     140     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1266    0     140     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1267    0     140     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1268    0     140     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 1260   32.271994            0.0         0.0              2  True  True
# 1261   74.557647            0.0         0.7              0  True  True
# 1262   32.932499            0.0         4.4              3  True  True
# 1263         NaN            NaN        13.8              0   NaN   NaN
# 1264         NaN            NaN        13.8              0   NaN   NaN
# 1265         NaN            NaN        13.8              0   NaN   NaN
# 1266         NaN            NaN        13.8              0   NaN   NaN
# 1267         NaN            NaN        13.8              0   NaN   NaN
# 1268         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 1260  16.135997   True  74.264003  16.135997
# 1261  37.628824   True  47.071176  36.928824
# 1262  18.666249   True  62.733751  14.266249
# 1263        NaN  False   0.000000   0.000000
# 1264        NaN  False   0.000000   0.000000
# 1265        NaN  False   0.000000   0.000000
# 1266        NaN  False   0.000000   0.000000
# 1267        NaN  False   0.000000   0.000000
# 1268        NaN  False   0.000000   0.000000
# 150
#                  bprofit
# currentBidIdx
# 0.0            179.54317
#       rnd  period  step                 bids                      asks  \
# 1350    0     150     0  [35.19099466216126]     [0.7, 52.0, 0.0, 4.4]
# 1351    0     150     1  [78.54075681692309]    [0.7, 52.0, 95.0, 4.4]
# 1352    0     150     2  [35.08190796380035]   [13.8, 52.0, 95.0, 4.4]
# 1353    0     150     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1354    0     150     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1355    0     150     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1356    0     150     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1357    0     150     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1358    0     150     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 1350   35.190995            0.0         0.0              2  True  True
# 1351   78.540757            0.0         0.7              0  True  True
# 1352   35.081908            0.0         4.4              3  True  True
# 1353         NaN            NaN        13.8              0   NaN   NaN
# 1354         NaN            NaN        13.8              0   NaN   NaN
# 1355         NaN            NaN        13.8              0   NaN   NaN
# 1356         NaN            NaN        13.8              0   NaN   NaN
# 1357         NaN            NaN        13.8              0   NaN   NaN
# 1358         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 1350  17.595497   True  72.804503  17.595497
# 1351  39.620378   True  45.079622  38.920378
# 1352  19.740954   True  61.659046  15.340954
# 1353        NaN  False   0.000000   0.000000
# 1354        NaN  False   0.000000   0.000000
# 1355        NaN  False   0.000000   0.000000
# 1356        NaN  False   0.000000   0.000000
# 1357        NaN  False   0.000000   0.000000
# 1358        NaN  False   0.000000   0.000000
# 160
#                   bprofit
# currentBidIdx
# 0.0            181.253362
#       rnd  period  step                  bids                      asks  \
# 1440    0     160     0   [36.08811228017295]     [0.7, 52.0, 0.0, 4.4]
# 1441    0     160     1   [76.19630295659198]    [0.7, 52.0, 95.0, 4.4]
# 1442    0     160     2  [33.108860578833536]   [13.8, 52.0, 95.0, 4.4]
# 1443    0     160     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1444    0     160     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1445    0     160     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1446    0     160     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1447    0     160     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1448    0     160     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 1440   36.088112            0.0         0.0              2  True  True
# 1441   76.196303            0.0         0.7              0  True  True
# 1442   33.108861            0.0         4.4              3  True  True
# 1443         NaN            NaN        13.8              0   NaN   NaN
# 1444         NaN            NaN        13.8              0   NaN   NaN
# 1445         NaN            NaN        13.8              0   NaN   NaN
# 1446         NaN            NaN        13.8              0   NaN   NaN
# 1447         NaN            NaN        13.8              0   NaN   NaN
# 1448         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 1440  18.044056   True  72.355944  18.044056
# 1441  38.448151   True  46.251849  37.748151
# 1442  18.754430   True  62.645570  14.354430
# 1443        NaN  False   0.000000   0.000000
# 1444        NaN  False   0.000000   0.000000
# 1445        NaN  False   0.000000   0.000000
# 1446        NaN  False   0.000000   0.000000
# 1447        NaN  False   0.000000   0.000000
# 1448        NaN  False   0.000000   0.000000
# 170
#                   bprofit
# currentBidIdx
# 0.0            175.769815
#       rnd  period  step                 bids                      asks  \
# 1530    0     170     0  [39.43568714471601]     [0.7, 52.0, 0.0, 4.4]
# 1531    0     170     1  [80.38448753053744]    [0.7, 52.0, 95.0, 4.4]
# 1532    0     170     2  [36.54019517946718]   [13.8, 52.0, 95.0, 4.4]
# 1533    0     170     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1534    0     170     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1535    0     170     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1536    0     170     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1537    0     170     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1538    0     170     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 1530   39.435687            0.0         0.0              2  True  True
# 1531   80.384488            0.0         0.7              0  True  True
# 1532   36.540195            0.0         4.4              3  True  True
# 1533         NaN            NaN        13.8              0   NaN   NaN
# 1534         NaN            NaN        13.8              0   NaN   NaN
# 1535         NaN            NaN        13.8              0   NaN   NaN
# 1536         NaN            NaN        13.8              0   NaN   NaN
# 1537         NaN            NaN        13.8              0   NaN   NaN
# 1538         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 1530  19.717844   True  70.682156  19.717844
# 1531  40.542244   True  44.157756  39.842244
# 1532  20.470098   True  60.929902  16.070098
# 1533        NaN  False   0.000000   0.000000
# 1534        NaN  False   0.000000   0.000000
# 1535        NaN  False   0.000000   0.000000
# 1536        NaN  False   0.000000   0.000000
# 1537        NaN  False   0.000000   0.000000
# 1538        NaN  False   0.000000   0.000000
# 180
#                   bprofit
# currentBidIdx
# 0.0            174.213471
#       rnd  period  step                  bids                      asks  \
# 1620    0     180     0  [42.959645594243774]     [0.7, 52.0, 0.0, 4.4]
# 1621    0     180     1   [80.34201833326293]    [0.7, 52.0, 95.0, 4.4]
# 1622    0     180     2   [36.17139483362532]   [13.8, 52.0, 95.0, 4.4]
# 1623    0     180     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1624    0     180     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1625    0     180     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1626    0     180     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1627    0     180     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1628    0     180     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 1620   42.959646            0.0         0.0              2  True  True
# 1621   80.342018            0.0         0.7              0  True  True
# 1622   36.171395            0.0         4.4              3  True  True
# 1623         NaN            NaN        13.8              0   NaN   NaN
# 1624         NaN            NaN        13.8              0   NaN   NaN
# 1625         NaN            NaN        13.8              0   NaN   NaN
# 1626         NaN            NaN        13.8              0   NaN   NaN
# 1627         NaN            NaN        13.8              0   NaN   NaN
# 1628         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 1620  21.479823   True  68.920177  21.479823
# 1621  40.521009   True  44.178991  39.821009
# 1622  20.285697   True  61.114303  15.885697
# 1623        NaN  False   0.000000   0.000000
# 1624        NaN  False   0.000000   0.000000
# 1625        NaN  False   0.000000   0.000000
# 1626        NaN  False   0.000000   0.000000
# 1627        NaN  False   0.000000   0.000000
# 1628        NaN  False   0.000000   0.000000
# 190
#                   bprofit
# currentBidIdx
# 0.0            173.412504
#       rnd  period  step                 bids                      asks  \
# 1710    0     190     0  [42.90088310516697]     [0.7, 52.0, 0.0, 4.4]
# 1711    0     190     1  [80.98329983119471]    [0.7, 52.0, 95.0, 4.4]
# 1712    0     190     2  [37.19080946999446]   [13.8, 52.0, 95.0, 4.4]
# 1713    0     190     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1714    0     190     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1715    0     190     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1716    0     190     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1717    0     190     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1718    0     190     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 1710   42.900883            0.0         0.0              2  True  True
# 1711   80.983300            0.0         0.7              0  True  True
# 1712   37.190809            0.0         4.4              3  True  True
# 1713         NaN            NaN        13.8              0   NaN   NaN
# 1714         NaN            NaN        13.8              0   NaN   NaN
# 1715         NaN            NaN        13.8              0   NaN   NaN
# 1716         NaN            NaN        13.8              0   NaN   NaN
# 1717         NaN            NaN        13.8              0   NaN   NaN
# 1718         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 1710  21.450442   True  68.949558  21.450442
# 1711  40.841650   True  43.858350  40.141650
# 1712  20.795405   True  60.604595  16.395405
# 1713        NaN  False   0.000000   0.000000
# 1714        NaN  False   0.000000   0.000000
# 1715        NaN  False   0.000000   0.000000
# 1716        NaN  False   0.000000   0.000000
# 1717        NaN  False   0.000000   0.000000
# 1718        NaN  False   0.000000   0.000000
# 200
#                   bprofit
# currentBidIdx
# 0.0            177.974903
#       rnd  period  step                  bids                      asks  \
# 1800    0     200     0  [38.362096871744185]     [0.7, 52.0, 0.0, 4.4]
# 1801    0     200     1    [79.2992261799814]    [0.7, 52.0, 95.0, 4.4]
# 1802    0     200     2  [34.288870372998424]   [13.8, 52.0, 95.0, 4.4]
# 1803    0     200     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1804    0     200     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1805    0     200     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1806    0     200     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1807    0     200     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1808    0     200     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 1800   38.362097            0.0         0.0              2  True  True
# 1801   79.299226            0.0         0.7              0  True  True
# 1802   34.288870            0.0         4.4              3  True  True
# 1803         NaN            NaN        13.8              0   NaN   NaN
# 1804         NaN            NaN        13.8              0   NaN   NaN
# 1805         NaN            NaN        13.8              0   NaN   NaN
# 1806         NaN            NaN        13.8              0   NaN   NaN
# 1807         NaN            NaN        13.8              0   NaN   NaN
# 1808         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 1800  19.181048   True  71.218952  19.181048
# 1801  39.999613   True  44.700387  39.299613
# 1802  19.344435   True  62.055565  14.944435
# 1803        NaN  False   0.000000   0.000000
# 1804        NaN  False   0.000000   0.000000
# 1805        NaN  False   0.000000   0.000000
# 1806        NaN  False   0.000000   0.000000
# 1807        NaN  False   0.000000   0.000000
# 1808        NaN  False   0.000000   0.000000
# 210
#                   bprofit
# currentBidIdx
# 0.0            176.774952
#       rnd  period  step                  bids                      asks  \
# 1890    0     210     0   [40.26358907984589]     [0.7, 52.0, 0.0, 4.4]
# 1891    0     210     1   [78.75683984828426]    [0.7, 52.0, 95.0, 4.4]
# 1892    0     210     2  [35.329667292502585]   [13.8, 52.0, 95.0, 4.4]
# 1893    0     210     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1894    0     210     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1895    0     210     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1896    0     210     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1897    0     210     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 1898    0     210     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 1890   40.263589            0.0         0.0              2  True  True
# 1891   78.756840            0.0         0.7              0  True  True
# 1892   35.329667            0.0         4.4              3  True  True
# 1893         NaN            NaN        13.8              0   NaN   NaN
# 1894         NaN            NaN        13.8              0   NaN   NaN
# 1895         NaN            NaN        13.8              0   NaN   NaN
# 1896         NaN            NaN        13.8              0   NaN   NaN
# 1897         NaN            NaN        13.8              0   NaN   NaN
# 1898         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 1890  20.131795   True  70.268205  20.131795
# 1891  39.728420   True  44.971580  39.028420
# 1892  19.864834   True  61.535166  15.464834
# 1893        NaN  False   0.000000   0.000000
# 1894        NaN  False   0.000000   0.000000
# 1895        NaN  False   0.000000   0.000000
# 1896        NaN  False   0.000000   0.000000
# 1897        NaN  False   0.000000   0.000000
# 1898        NaN  False   0.000000   0.000000
# 220
#                   bprofit
# currentBidIdx
# 0.0            175.874009
#       rnd  period  step                 bids                      asks  \
# 1980    0     220     0  [38.70398040596514]     [0.7, 52.0, 0.0, 4.4]
# 1981    0     220     1  [80.44610453084448]    [0.7, 52.0, 95.0, 4.4]
# 1982    0     220     2  [37.00189782421839]   [13.8, 52.0, 95.0, 4.4]
# 1983    0     220     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1984    0     220     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1985    0     220     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1986    0     220     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1987    0     220     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 1988    0     220     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 1980   38.703980            0.0         0.0              2  True  True
# 1981   80.446105            0.0         0.7              0  True  True
# 1982   37.001898            0.0         4.4              3  True  True
# 1983         NaN            NaN        13.8              0   NaN   NaN
# 1984         NaN            NaN        13.8              0   NaN   NaN
# 1985         NaN            NaN        13.8              0   NaN   NaN
# 1986         NaN            NaN        13.8              0   NaN   NaN
# 1987         NaN            NaN        13.8              0   NaN   NaN
# 1988         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 1980  19.351990   True  71.048010  19.351990
# 1981  40.573052   True  44.126948  39.873052
# 1982  20.700949   True  60.699051  16.300949
# 1983        NaN  False   0.000000   0.000000
# 1984        NaN  False   0.000000   0.000000
# 1985        NaN  False   0.000000   0.000000
# 1986        NaN  False   0.000000   0.000000
# 1987        NaN  False   0.000000   0.000000
# 1988        NaN  False   0.000000   0.000000
# /tmp/ipykernel_18190/2701512781.py:38: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst, dtype=torch.float), \
# 230
#                  bprofit
# currentBidIdx
# 0.0            99.985498
#       rnd  period  step                  bids                      asks  \
# 2070    0     230     0  [102.52371311020765]     [0.7, 52.0, 0.0, 4.4]
# 2071    0     230     1   [102.5690623874733]    [0.7, 52.0, 95.0, 4.4]
# 2072    0     230     2  [102.83622827305624]   [13.8, 52.0, 95.0, 4.4]
# 2073    0     230     3                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 2074    0     230     4                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 2075    0     230     5                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 2076    0     230     6                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 2077    0     230     7                 [nan]  [13.8, 52.0, 95.0, 14.9]
# 2078    0     230     8                 [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 2070  102.523713            0.0         0.0              2  True  True
# 2071  102.569062            0.0         0.7              0  True  True
# 2072  102.836228            0.0         4.4              3  True  True
# 2073         NaN            NaN        13.8              0   NaN   NaN
# ...
# 7112    0     790     2   [87.9002001471745]   [13.8, 52.0, 95.0, 4.4]
# 7113    0     790     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7114    0     790     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7115    0     790     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7116    0     790     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7117    0     790     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7118    0     790     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 7110   86.673130            0.0         0.0              2  True  True
# 7111   87.146565            0.0         0.7              0  True  True
# 7112   87.900200            0.0         4.4              3  True  True
# 7113         NaN            NaN        13.8              0   NaN   NaN
# 7114         NaN            NaN        13.8              0   NaN   NaN
# 7115         NaN            NaN        13.8              0   NaN   NaN
# 7116         NaN            NaN        13.8              0   NaN   NaN
# 7117         NaN            NaN        13.8              0   NaN   NaN
# 7118         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 7110  43.336565   True  47.063435  43.336565
# 7111  43.923282   True  40.776718  43.223282
# 7112  46.150100   True  35.249900  41.750100
# 7113        NaN  False   0.000000   0.000000
# 7114        NaN  False   0.000000   0.000000
# 7115        NaN  False   0.000000   0.000000
# 7116        NaN  False   0.000000   0.000000
# 7117        NaN  False   0.000000   0.000000
# 7118        NaN  False   0.000000   0.000000
# 800
#                   bprofit
# currentBidIdx
# 0.0            121.870668
#       rnd  period  step                 bids                      asks  \
# 7200    0     800     0  [88.38920327918525]     [0.7, 52.0, 0.0, 4.4]
# 7201    0     800     1  [87.82186702965433]    [0.7, 52.0, 95.0, 4.4]
# 7202    0     800     2  [87.94759358093835]   [13.8, 52.0, 95.0, 4.4]
# 7203    0     800     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7204    0     800     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7205    0     800     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7206    0     800     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7207    0     800     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7208    0     800     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 7200   88.389203            0.0         0.0              2  True  True
# 7201   87.821867            0.0         0.7              0  True  True
# 7202   87.947594            0.0         4.4              3  True  True
# 7203         NaN            NaN        13.8              0   NaN   NaN
# 7204         NaN            NaN        13.8              0   NaN   NaN
# 7205         NaN            NaN        13.8              0   NaN   NaN
# 7206         NaN            NaN        13.8              0   NaN   NaN
# 7207         NaN            NaN        13.8              0   NaN   NaN
# 7208         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 7200  44.194602   True  46.205398  44.194602
# 7201  44.260934   True  40.439066  43.560934
# 7202  46.173797   True  35.226203  41.773797
# 7203        NaN  False   0.000000   0.000000
# 7204        NaN  False   0.000000   0.000000
# 7205        NaN  False   0.000000   0.000000
# 7206        NaN  False   0.000000   0.000000
# 7207        NaN  False   0.000000   0.000000
# 7208        NaN  False   0.000000   0.000000
# 810
#                   bprofit
# currentBidIdx
# 0.0            119.641962
#       rnd  period  step                 bids                      asks  \
# 7290    0     810     0  [89.24248925068716]     [0.7, 52.0, 0.0, 4.4]
# 7291    0     810     1  [89.66499875451056]    [0.7, 52.0, 95.0, 4.4]
# 7292    0     810     2  [89.70858700933047]   [13.8, 52.0, 95.0, 4.4]
# 7293    0     810     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7294    0     810     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7295    0     810     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7296    0     810     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7297    0     810     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7298    0     810     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 7290   89.242489            0.0         0.0              2  True  True
# 7291   89.664999            0.0         0.7              0  True  True
# 7292   89.708587            0.0         4.4              3  True  True
# 7293         NaN            NaN        13.8              0   NaN   NaN
# 7294         NaN            NaN        13.8              0   NaN   NaN
# 7295         NaN            NaN        13.8              0   NaN   NaN
# 7296         NaN            NaN        13.8              0   NaN   NaN
# 7297         NaN            NaN        13.8              0   NaN   NaN
# 7298         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 7290  44.621245   True  45.778755  44.621245
# 7291  45.182499   True  39.517501  44.482499
# 7292  47.054294   True  34.345706  42.654294
# 7293        NaN  False   0.000000   0.000000
# 7294        NaN  False   0.000000   0.000000
# 7295        NaN  False   0.000000   0.000000
# 7296        NaN  False   0.000000   0.000000
# 7297        NaN  False   0.000000   0.000000
# 7298        NaN  False   0.000000   0.000000
# 820
#                   bprofit
# currentBidIdx
# 0.0            124.608428
#       rnd  period  step                 bids                      asks  \
# 7380    0     820     0  [87.11070597550133]     [0.7, 52.0, 0.0, 4.4]
# 7381    0     820     1  [86.27250320595323]    [0.7, 52.0, 95.0, 4.4]
# 7382    0     820     2  [85.29993560292905]   [13.8, 52.0, 95.0, 4.4]
# 7383    0     820     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7384    0     820     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7385    0     820     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7386    0     820     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7387    0     820     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7388    0     820     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 7380   87.110706            0.0         0.0              2  True  True
# 7381   86.272503            0.0         0.7              0  True  True
# 7382   85.299936            0.0         4.4              3  True  True
# 7383         NaN            NaN        13.8              0   NaN   NaN
# 7384         NaN            NaN        13.8              0   NaN   NaN
# 7385         NaN            NaN        13.8              0   NaN   NaN
# 7386         NaN            NaN        13.8              0   NaN   NaN
# 7387         NaN            NaN        13.8              0   NaN   NaN
# 7388         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 7380  43.555353   True  46.844647  43.555353
# 7381  43.486252   True  41.213748  42.786252
# 7382  44.849968   True  36.550032  40.449968
# 7383        NaN  False   0.000000   0.000000
# 7384        NaN  False   0.000000   0.000000
# 7385        NaN  False   0.000000   0.000000
# 7386        NaN  False   0.000000   0.000000
# 7387        NaN  False   0.000000   0.000000
# 7388        NaN  False   0.000000   0.000000
# 830
#                  bprofit
# currentBidIdx
# 0.0            124.53974
#       rnd  period  step                 bids                      asks  \
# 7470    0     830     0  [86.53111549566012]     [0.7, 52.0, 0.0, 4.4]
# 7471    0     830     1  [86.27368830546236]    [0.7, 52.0, 95.0, 4.4]
# 7472    0     830     2   [86.0157171186748]   [13.8, 52.0, 95.0, 4.4]
# 7473    0     830     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7474    0     830     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7475    0     830     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7476    0     830     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7477    0     830     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7478    0     830     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 7470   86.531115            0.0         0.0              2  True  True
# 7471   86.273688            0.0         0.7              0  True  True
# 7472   86.015717            0.0         4.4              3  True  True
# 7473         NaN            NaN        13.8              0   NaN   NaN
# 7474         NaN            NaN        13.8              0   NaN   NaN
# 7475         NaN            NaN        13.8              0   NaN   NaN
# 7476         NaN            NaN        13.8              0   NaN   NaN
# 7477         NaN            NaN        13.8              0   NaN   NaN
# 7478         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 7470  43.265558   True  47.134442  43.265558
# 7471  43.486844   True  41.213156  42.786844
# 7472  45.207859   True  36.192141  40.807859
# 7473        NaN  False   0.000000   0.000000
# 7474        NaN  False   0.000000   0.000000
# 7475        NaN  False   0.000000   0.000000
# 7476        NaN  False   0.000000   0.000000
# 7477        NaN  False   0.000000   0.000000
# 7478        NaN  False   0.000000   0.000000
# 840
#                   bprofit
# currentBidIdx
# 0.0            124.940602
#       rnd  period  step                 bids                      asks  \
# 7560    0     840     0  [85.54090452919696]     [0.7, 52.0, 0.0, 4.4]
# 7561    0     840     1  [86.17832355545205]    [0.7, 52.0, 95.0, 4.4]
# 7562    0     840     2  [86.29956867185666]   [13.8, 52.0, 95.0, 4.4]
# 7563    0     840     3                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7564    0     840     4                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7565    0     840     5                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7566    0     840     6                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7567    0     840     7                [nan]  [13.8, 52.0, 95.0, 14.9]
# 7568    0     840     8                [nan]  [13.8, 52.0, 95.0, 14.9]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  \
# 7560   85.540905            0.0         0.0              2  True  True
# 7561   86.178324            0.0         0.7              0  True  True
# 7562   86.299569            0.0         4.4              3  True  True
# 7563         NaN            NaN        13.8              0   NaN   NaN
# 7564         NaN            NaN        13.8              0   NaN   NaN
# 7565         NaN            NaN        13.8              0   NaN   NaN
# 7566         NaN            NaN        13.8              0   NaN   NaN
# 7567         NaN            NaN        13.8              0   NaN   NaN
# 7568         NaN            NaN        13.8              0   NaN   NaN
#
#           price   sale    bprofit    sprofit
# 7560  42.770452   True  47.629548  42.770452
# 7561  43.439162   True  41.260838  42.739162
# 7562  45.349784   True  36.050216  40.949784
# 7563        NaN  False   0.000000   0.000000
# 7564        NaN  False   0.000000   0.000000
# 7565        NaN  False   0.000000   0.000000
# 7566        NaN  False   0.000000   0.000000
# 7567        NaN  False   0.000000   0.000000
# 7568        NaN  False   0.000000   0.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 41
#      39         sprofit = sellers[currentAskIdx].stepProfits
#      40     log.addStep([rnd, period, step, bids, asks, currentBid, currentBidIdx, currentAsk, currentAskIdx, buy, sell, price, price>0, bprofit, sprofit])
# ---> 41     observe(buyers, sellers, log.disclose()) # observe new state
#      42     updateStates(buyers, sellers)
#      43 updatePolicy(buyers, sellers)
#
# File /econ_share/home/pp712/double-auctions/code/7_clean/setup.py:153, in observe(buyers, sellers, data)
#     151 def observe(buyers, sellers, data):
#     152     for i, agent in enumerate(buyers+sellers):
# --> 153         agent.df = pd.concat([agent.df, data.to_frame().T], ignore_index=True)
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/pandas/core/reshape/concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
#     391 )
#     393 return op.get_result()
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/pandas/core/reshape/concat.py:447, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     445 # figure out what our result ndim is going to be
#     446 ndims = self._get_ndims(objs)
# --> 447 sample, objs = self._get_sample_object(objs, ndims, keys, names, levels)
#     449 # Standardize axis parameter to int
#     450 if sample.ndim == 1:
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/pandas/core/reshape/concat.py:565, in _Concatenator._get_sample_object(self, objs, ndims, keys, names, levels)
#     560             break
#     562 else:
#     563     # filter out the empties if we have not multi-index possibilities
#     564     # note to keep empty Series as it affect to result columns / name
# --> 565     non_empties = [obj for obj in objs if sum(obj.shape) > 0 or obj.ndim == 1]
#     567     if len(non_empties) and (
#     568         keys is None and names is None and levels is None and not self.intersect
#     569     ):
#     570         objs = non_empties
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/pandas/core/reshape/concat.py:565, in <listcomp>(.0)
#     560             break
#     562 else:
#     563     # filter out the empties if we have not multi-index possibilities
#     564     # note to keep empty Series as it affect to result columns / name
# --> 565     non_empties = [obj for obj in objs if sum(obj.shape) > 0 or obj.ndim == 1]
#     567     if len(non_empties) and (
#     568         keys is None and names is None and levels is None and not self.intersect
#     569     ):
#     570         objs = non_empties
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/pandas/core/frame.py:989, in DataFrame.shape(self)
#     969 @property
#     970 def shape(self) -> tuple[int, int]:
#     971     """
#     972     Return a tuple representing the dimensionality of the DataFrame.
#     973
#    (...)
#     987     (2, 3)
#     988     """
# --> 989     return len(self.index), len(self.columns)
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:908, in Index.__len__(self)
#     898     return {
#     899         c
#     900         for c in self.unique(level=0)[: get_option("display.max_dir_items")]
#     901         if isinstance(c, str) and c.isidentifier()
#     902     }
#     904 # --------------------------------------------------------------------
#     905 # Array-Like Methods
#     906
#     907 # ndarray compat
# --> 908 def __len__(self) -> int:
#     909     """
#     910     Return the length of the Index.
#     911     """
#     912     return len(self._data)
#
# KeyboardInterrupt:

# %%
class DDPG(Trader):
    def __init__(self, gameData, disclosure, index, buyer, reinforcer):
        super().__init__(gameData, disclosure, index, buyer, reinforcer)
        self.numActions = 100
        self.depth = 9
        self.numStates = 8 + 6 * self.depth
        history = [-1] * self.numStates
        self.state = np.nan_to_num(np.array(history, dtype = np.float32), nan=-9)  
        self.memory = ReplayBuffer()
        self.q, self.q_target = QNet(self.numStates), QNet(self.numStates)
        self.q_target.load_state_dict(self.q.state_dict())
        self.mu, self.mu_target = MuNet(self.numStates), MuNet(self.numStates)
        self.mu_target.load_state_dict(self.mu.state_dict())
        self.mu_optimizer = optim.Adam(self.mu.parameters(), lr=lr_mu)
        self.q_optimizer  = optim.Adam(self.q.parameters(), lr=lr_q)
        self.ou_noise = OrnsteinUhlenbeckNoise(mu=np.zeros(1))
        self.done = False

    def observe(self):
        agentState = [self.periodStep, self.stepTokenValue, self.stepBid, self.stepAsk, self.stepTrades, self.stepProfits, self.periodTrades, self.periodProfits]
        history = self.df.iloc[-self.depth:][['currentBid', 'currentAsk', 'buy', 'sell', 'price', 'price']].values.reshape(-1,).tolist()
        if len(history) != (6 * self.depth):
            history = [-1] * (6 * self.depth)
        self.newState = np.nan_to_num(np.array(agentState + history, dtype = np.float32), nan=-9)
        if self.periodStep == self.numSteps:
            self.done = True
        self.memory.put((self.state,self.a,self.stepProfits/100.0,self.newState,self.done))
        self.state = self.newState 

    def train(self):
        if self.memory.size()>2000:
            for i in range(10):
                train(self.mu, self.mu_target, self.q, self.q_target, self.memory, self.q_optimizer, self.mu_optimizer)
                soft_update(self.mu, self.mu_target)
                soft_update(self.q,  self.q_target)
        
    def bid(self):
        self.stepBid = np.nan
        if self.stepTokenValue > 0:
            a = self.mu(torch.from_numpy(self.state).float()) 
            self.a = a.item() + self.ou_noise()[0]
            frac = (self.a+1)/2
            self.stepBid = 1*frac + (1-frac)*100
        return np.round(self.stepBid,1)
        
    def ask(self):
        self.stepAsk = np.nan
        if self.stepTokenValue > 0:
            self.mu, self.std = self.model.pi(torch.from_numpy(self.state).float())
            dist = Normal(self.mu, self.std)
            self.action = dist.sample()
            self.log_prob = dist.log_prob(self.action)
            frac = self.action.item()
            self.stepAsk = np.round(frac * 100,1)
        return self.stepAsk

# %%
import gym
import random
import collections
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#Hyperparameters
lr_mu        = 0.0005
lr_q         = 0.001
gamma        = 0.99
batch_size   = 32
buffer_limit = 50000
tau          = 0.005 # for target network soft update

class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)

    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []

        for transition in mini_batch:
            s, a, r, s_prime, done = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask = 0.0 if done else 1.0 
            done_mask_lst.append([done_mask])
        
        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst, dtype=torch.float), \
                torch.tensor(r_lst, dtype=torch.float), torch.tensor(s_prime_lst, dtype=torch.float), \
                torch.tensor(done_mask_lst, dtype=torch.float)
    
    def size(self):
        return len(self.buffer)

class MuNet(nn.Module):
    def __init__(self, numStates):
        super(MuNet, self).__init__()
        self.fc1 = nn.Linear(numStates, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc_mu = nn.Linear(64, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mu = torch.tanh(self.fc_mu(x)) # Multipled by 2 because the action space of the Pendulum-v0 is [-2,2]
        return mu

class QNet(nn.Module):
    def __init__(self, numStates):
        super(QNet, self).__init__()
        self.fc_s = nn.Linear(numStates, 64)
        self.fc_a = nn.Linear(1,64)
        self.fc_q = nn.Linear(128, 32)
        self.fc_out = nn.Linear(32,1)

    def forward(self, x, a):
        h1 = F.relu(self.fc_s(x))
        h2 = F.relu(self.fc_a(a))
        cat = torch.cat([h1,h2], dim=1)
        q = F.relu(self.fc_q(cat))
        q = self.fc_out(q)
        return q

class OrnsteinUhlenbeckNoise:
    def __init__(self, mu):
        self.theta, self.dt, self.sigma = 0.1, 0.01, 0.1
        self.mu = mu
        self.x_prev = np.zeros_like(self.mu)

    def __call__(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
                self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x
      
def train(mu, mu_target, q, q_target, memory, q_optimizer, mu_optimizer):
    s,a,r,s_prime,done_mask  = memory.sample(batch_size)
    
    target = r + gamma * q_target(s_prime, mu_target(s_prime)) * done_mask
    q_loss = F.smooth_l1_loss(q(s,a), target.detach())
    q_optimizer.zero_grad()
    q_loss.backward()
    q_optimizer.step()
    
    mu_loss = -q(s,mu(s)).mean() # That's all for the policy loss.
    mu_optimizer.zero_grad()
    mu_loss.backward()
    mu_optimizer.step()
    
def soft_update(net, net_target):
    for param_target, param in zip(net_target.parameters(), net.parameters()):
        param_target.data.copy_(param_target.data * (1.0 - tau) + param.data * tau)

# %%
def generateAgents(gameData,buyerStrategies,sellerStrategies,disclosure):
    buyers, sellers = [], []
    for idx,i in enumerate(buyerStrategies):
        if i == 'TruthTeller':
            buyers.append(TruthTeller(gameData, disclosure, index=idx, buyer=1, reinforer=0)) 
        if i == 'ZeroIntelligence':
            buyers.append(ZeroIntelligence(gameData, disclosure, index=idx, buyer=1, reinforer=0)) 
        if i == 'REINFORCE':
            buyers.append(REINFORCE(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 
        if i == 'PPO':
            buyers.append(PPO(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 
        if i == 'SAC':
            buyers.append(SAC(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 
        if i == 'DQN':
            buyers.append(DQN(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 
        if i == 'DDPG':
            buyers.append(DDPG(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 

    for idx,i in enumerate(sellerStrategies):
        if i == 'TruthTeller':
            sellers.append(TruthTeller(gameData, disclosure, index=idx, buyer=0, reinforcer=0)) 
        if i == 'ZeroIntelligence':
            sellers.append(ZeroIntelligence(gameData, disclosure, index=idx, buyer=0, reinforcer=0)) 
        if i == 'REINFORCE':
            sellers.append(REINFORCE(gameData, disclosure, index=idx, buyer=0, reinforcer=1)) 
        if i == 'PPO':
            sellers.append(PPO(gameData, disclosure, index=idx, buyer=0, reinforcer=1)) 
        if i == 'SAC':
            sellers.append(SAC(gameData, disclosure, index=idx, buyer=0, reinforcer=1)) 
        if i == 'DDPG':
            sellers.append(DDPG(gameData, disclosure, index=idx, buyer=0, reinforcer=1)) 
    return buyers, sellers
