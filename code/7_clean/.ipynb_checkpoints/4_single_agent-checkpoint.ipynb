# %%
from setup import *
from agents import *
from env import *
gameTypes, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps = '1001', 3, 3, 3, 1, 1, 9
disclosure = ['rnd', 'period', 'step','currentBid','currentAsk','buy','sell','price','sale']
buyerStrategies = ['ZeroIntelligence', 'ZeroIntelligence','ZeroIntelligence']
sellerStrategies = ['ZeroIntelligence', 'ZeroIntelligence','ZeroIntelligence']
metaData = [gameTypes, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, disclosure, buyerStrategies, sellerStrategies]
env = BaseEnv(metaData)
env.simulate()

# %%
import gymnasium as gym
from gymnasium import spaces

class SingleAgentEnv1(gym.Env):
    def __init__(self, metaData):
        self.gameData = metaData[0:7]
        self.gameTypes, self.numBuyers, self.numSellers, self.numTokens, self.numRounds, self.numPeriods, self.numSteps = self.gameData
        self.disclosure, self.buyerStrategies, self.sellerStrategies = metaData[7:]
        self.buyers, self.sellers = generateAgents(self.gameData,self.buyerStrategies,self.sellerStrategies,self.disclosure)
        self.log = Log(self.gameData, self.buyerStrategies, self.sellerStrategies, self.disclosure)
        self.roundData = roundSetup(*self.gameData)
        self.redemptionValues, self.tokenCosts, self.demand, self.supply, self.prices, self.peq, self.qeq  = self.roundData[0:7]
        [self.buyerReservationPrices, self.sellerReservationPrices, self.buyerSurplus, self.sellerSurplus, self.totalSurplus, self.buyerSurplusFrac, self.sellerSurplusFrac] = self.roundData[7:]
        self.log.addRound([0] + self.roundData)
        resetRounds(self.buyers, self.sellers, self.redemptionValues, self.tokenCosts)
        self.depth = 9
        self.numStates = 8 + 6 * self.depth
        self.action_space = spaces.Box(-1,1,(1,),dtype=np.float32)
        self.observation_space = spaces.Box(-1000,1000,(self.numStates,),dtype=np.float32)
        self.timePeriod = 0
        self.timeStep = 0

    def reset(self, seed = None):
        resetPeriods(self.buyers, self.sellers)
        resetSteps(self.buyers, self.sellers)
        agent = self.buyers[0]
        agentState = [self.timeStep, agent.stepTokenValue, agent.stepBid, agent.stepAsk, agent.stepTrades, agent.stepProfits, agent.periodTrades, agent.periodProfits]
        history = [-1, -1, -1, -1, -1, -1] * self.depth
        state = np.nan_to_num(np.array(agentState + history, dtype = np.float32), nan=-9)
        self.numStates = state.shape[0]
        return state, {}

    def step(self, action):
        # convert action into bid
        minBid = 0
        maxBid = 100
        frac = (action.item()+1)/2
        bids, asks = collectOffers(self.buyers, self.sellers)
        bids[0] = np.round(frac * minBid + (1-frac) * maxBid,1)

        # simulate market
        currentAsk, currentAskIdx, currentBid, currentBidIdx = bestOffers(bids, asks)
        price, buy, sell = trade(self.buyers, self.sellers, currentAsk, currentAskIdx, currentBid, currentBidIdx)
        bprofit, sprofit = 0, 0
        if price > 0:
            self.buyers[currentBidIdx].transact(price)
            self.sellers[currentAskIdx].transact(price)
            bprofit = self.buyers[currentBidIdx].stepProfits
            sprofit = self.sellers[currentAskIdx].stepProfits
        self.log.addStep([0, self.timePeriod, self.timeStep, bids, asks, currentBid, currentBidIdx, currentAsk, currentAskIdx, buy, sell, price, price>0, bprofit, sprofit])
        observe(self.buyers, self.sellers, self.log.disclose())

        # compute reward and transition
        reward = 0.0
        if price > 0 and currentBidIdx == 0:
            reward = np.nan_to_num(bprofit,nan=0)
        agent = self.buyers[0]
        agentState = [self.timeStep, agent.stepTokenValue, agent.stepBid, agent.stepAsk, agent.stepTrades, agent.stepProfits, agent.periodTrades, agent.periodProfits]
        history = self.buyers[0].df.iloc[-self.depth:][['currentBid', 'currentAsk', 'buy', 'sell', 'price', 'price']].values.reshape(-1,).tolist()
        if len(history) == (6 * self.depth):
            pass
        else:
            history = [-1] * (6 * self.depth)
        newState = np.nan_to_num(np.array(agentState + history, dtype = np.float32), nan=-9)
        # check termination
        if self.timeStep == self.numSteps - 1:
            terminated = True
            self.timePeriod += 1
            self.timeStep = 0
        else:
            self.timeStep += 1
            terminated = False
        infos = {"TimeLimit.truncated":True}
        truncated = False
        resetSteps(self.buyers, self.sellers)
        return newState, reward, terminated, truncated, infos

    def graphSales(self, rnd, period):
        fig, ax = graphMarket(*self.gameData, *self.log.getRoundList(rnd))
        periodBids, periodAsks, periodPrices, periodSales = self.log.getPeriodActivity(rnd,period)
        plt.plot(range(1,len(periodPrices)+1), periodPrices, color='darkgreen', linestyle='--', label='Actual Prices')
        print(np.array([periodBids[i][0] for i in range(self.numSteps) if periodPrices[i] > 0]))
        plt.plot([periodSales[i] for i in range(self.numSteps) if periodPrices[i] > 0],[periodBids[i][0] for i in range(self.numSteps) if periodPrices[i] > 0], color='darkorange', linestyle='--', label='Reinforcer Bids')
        for i in range(self.numSteps):
            if (periodPrices[i] > 0):
                ax.scatter(np.array([periodSales[i]] * len(periodBids[i][1:])), np.array(periodBids[i][1:]), s=10, alpha=0.5, c='purple')
                ax.scatter([periodSales[i]] * len(periodAsks[i]), periodAsks[i], s=10, alpha=0.5, c='blue')
        ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=5)
        plt.show()

    def graphOffers(self, rnd, period):
        periodBids, periodAsks, periodPrices, periodSales = self.log.getPeriodActivity(rnd,period)
        fig, ax = plt.subplots()
        ax.plot(np.array(periodBids)[:, 0], c='red', linestyle='--', label='Bids')
        ax.plot(np.array(periodBids)[:, 1:], c='purple', linestyle='--', label='Bids')
        ax.plot(periodAsks, c='darkgreen', linestyle='--', label='Asks')
        print(len(range(self.numSteps)))
        print(len(periodPrices))
        ax.scatter(range(self.numSteps), periodPrices, c='black', label='Prices')
        ax.set_title('Bids (red), Asks (blue), and Prices (green) over trading steps')
        plt.show()

# %% [markdown]
# ### Check

# %%
from stable_baselines3.common.env_checker import check_env
env = SingleAgentEnv1(metaData)
check_env(env)
# Out:
# 2023-09-30 19:01:28.128843: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-09-30 19:01:28.129411: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-09-30 19:01:28.129446: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-09-30 19:01:28.140353: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-30 19:01:29.126115: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
env.log.stepData
# Out:
#     rnd  period  step                bids               asks  currentBid  \
# 0     0       0     0  [86.6, 93.2, 35.2]    [nan, 2.9, 9.3]        93.2
# 1     0       0     1  [13.1, 48.5, 57.0]    [nan, 3.1, 9.3]        57.0
# 2     0       0     2  [53.3, 37.6, 24.5]   [nan, 38.2, 7.9]        53.3
# 3     0       0     3  [78.0, 86.7, 11.9]  [nan, 38.6, 37.6]        86.7
# 4     0       0     4  [88.7, 12.3, 45.4]  [nan, 35.1, 40.5]        88.7
# 5     0       0     5  [78.4, 40.0, 15.6]  [nan, 45.5, 50.3]        78.4
# 6     0       0     6  [49.9, 11.9, 18.9]   [nan, nan, 62.6]        49.9
# 7     0       0     7  [11.3, 44.8, 23.6]    [nan, nan, nan]        44.8
# 8     0       0     8  [37.6, 20.6, 54.3]    [nan, nan, nan]        54.3
# 9     0       1     0  [31.6, 15.1, 73.6]   [nan, 2.6, 12.4]        73.6
# 10    0       1     1  [23.9, 67.8, 26.9]   [nan, 32.3, 6.7]        67.8
#
#     currentBidIdx  currentAsk  currentAskIdx   buy  sell  price   sale  \
# 0               1         2.9            1.0   1.0   1.0  48.05   True
# 1               2         3.1            1.0   1.0   1.0  30.05   True
# 2               0         7.9            2.0   1.0   1.0  30.60   True
# 3               1        37.6            2.0   1.0   1.0  62.15   True
# 4               0        35.1            1.0   1.0   1.0  61.90   True
# 5               0        45.5            1.0   1.0   1.0  61.95   True
# 6               0        62.6            2.0   0.0   1.0  49.90   True
# 7               1         NaN            NaN   NaN   NaN    NaN  False
# 8               2         NaN            NaN   NaN   NaN    NaN  False
# 9               2         2.6            1.0  True  True  38.10   True
# 10              1         6.7            2.0  True  True  37.25   True
#
#     bprofit  sprofit
# 0     51.95    46.25
# 1     66.85    28.25
# 2     58.50    24.00
# 3     37.85    33.15
# 4     24.10    33.40
# 5     -6.75    32.35
# 6       NaN    16.50
# 7      0.00     0.00
# 8      0.00     0.00
# 9     58.80    36.30
# 10    62.75    30.65

# %% [markdown]
# ### SB3

# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO, SAC
from stable_baselines3.ppo.policies import MlpPolicy
from stable_baselines3.common.base_class import BaseAlgorithm
env = SingleAgentEnv1(metaData)
print(env.log.getRound(0).redemptionValues.item())
policy_kwargs = dict(net_arch=dict(pi=[256, 256], qf=[256, 256]))
model = SAC("MlpPolicy", env, policy_kwargs=policy_kwargs, verbose=1,)
model.learn(50000, progress_bar = True)
# Out:
# Output()
# [[ 97.5  84.8  53.7]
#  [100.   97.3  66.4]
#  [ 45.1  42.4  29.3]]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 82.5     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 214      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 36       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.8     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 220      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 72       |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 9         |
# |    ep_rew_mean     | 73.7      |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 189       |
# |    time_elapsed    | 0         |
# |    total_timesteps | 108       |
# | train/             |           |
# |    actor_loss      | 0.847     |
# |    critic_loss     | 426       |
# |    ent_coef        | 1         |
# |    ent_coef_loss   | -0.000481 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 7         |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 70.6     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 130      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 144      |
# | train/             |          |
# |    actor_loss      | -6.8     |
# |    critic_loss     | 211      |
# |    ent_coef        | 0.996    |
# |    ent_coef_loss   | -0.00616 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 68.1     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 109      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | -7.07    |
# |    critic_loss     | 174      |
# |    ent_coef        | 0.984    |
# |    ent_coef_loss   | -0.0259  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 69.9     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 98       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 216      |
# | train/             |          |
# |    actor_loss      | -5.52    |
# |    critic_loss     | 194      |
# |    ent_coef        | 0.973    |
# |    ent_coef_loss   | -0.0434  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 115      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 70.4     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 92       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 252      |
# | train/             |          |
# |    actor_loss      | -6.12    |
# |    critic_loss     | 121      |
# |    ent_coef        | 0.962    |
# |    ent_coef_loss   | -0.0602  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 151      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 72       |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 87       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 288      |
# | train/             |          |
# |    actor_loss      | -5.33    |
# |    critic_loss     | 147      |
# |    ent_coef        | 0.951    |
# |    ent_coef_loss   | -0.0795  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 187      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 69.4     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 84       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 324      |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 159      |
# |    ent_coef        | 0.94     |
# |    ent_coef_loss   | -0.0984  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 223      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 70.8     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 82       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 360      |
# | train/             |          |
# |    actor_loss      | -11.9    |
# |    critic_loss     | 116      |
# |    ent_coef        | 0.93     |
# |    ent_coef_loss   | -0.114   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 259      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 73.3     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 80       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 396      |
# | train/             |          |
# |    actor_loss      | -10      |
# |    critic_loss     | 127      |
# |    ent_coef        | 0.92     |
# |    ent_coef_loss   | -0.125   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 295      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.5     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 78       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 432      |
# | train/             |          |
# |    actor_loss      | -11.8    |
# |    critic_loss     | 118      |
# |    ent_coef        | 0.91     |
# |    ent_coef_loss   | -0.145   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 331      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.7     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 77       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 468      |
# | train/             |          |
# |    actor_loss      | -9.5     |
# |    critic_loss     | 138      |
# |    ent_coef        | 0.9      |
# |    ent_coef_loss   | -0.156   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 367      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.4     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 76       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 504      |
# | train/             |          |
# |    actor_loss      | -8.72    |
# |    critic_loss     | 133      |
# |    ent_coef        | 0.89     |
# |    ent_coef_loss   | -0.173   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 403      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.5     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 75       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 540      |
# | train/             |          |
# |    actor_loss      | -10.6    |
# |    critic_loss     | 122      |
# |    ent_coef        | 0.881    |
# |    ent_coef_loss   | -0.202   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 439      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.8     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 74       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 576      |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 66.8     |
# |    ent_coef        | 0.871    |
# |    ent_coef_loss   | -0.216   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 475      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.7     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 72       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 612      |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 75.9     |
# |    ent_coef        | 0.862    |
# |    ent_coef_loss   | -0.214   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 511      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.1     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 72       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 648      |
# | train/             |          |
# |    actor_loss      | -12.8    |
# |    critic_loss     | 93.7     |
# |    ent_coef        | 0.853    |
# |    ent_coef_loss   | -0.252   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 547      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.1     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 71       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 684      |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 65.5     |
# |    ent_coef        | 0.844    |
# |    ent_coef_loss   | -0.237   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 583      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.8     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 71       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 720      |
# | train/             |          |
# |    actor_loss      | -12.4    |
# |    critic_loss     | 66.6     |
# |    ent_coef        | 0.836    |
# |    ent_coef_loss   | -0.276   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 619      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 77.2     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 70       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 756      |
# | train/             |          |
# |    actor_loss      | -8.35    |
# |    critic_loss     | 57.8     |
# |    ent_coef        | 0.827    |
# |    ent_coef_loss   | -0.274   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 655      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 77.4     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 70       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 792      |
# | train/             |          |
# |    actor_loss      | -9.74    |
# |    critic_loss     | 70.6     |
# |    ent_coef        | 0.819    |
# |    ent_coef_loss   | -0.296   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 691      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 77.1     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 70       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 828      |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 47.2     |
# |    ent_coef        | 0.81     |
# |    ent_coef_loss   | -0.313   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 727      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 77.7     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 70       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 864      |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 50.1     |
# |    ent_coef        | 0.802    |
# |    ent_coef_loss   | -0.327   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 763      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 77.5     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 69       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 900      |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 38.6     |
# |    ent_coef        | 0.794    |
# |    ent_coef_loss   | -0.358   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 799      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.1     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 69       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 936      |
# | train/             |          |
# |    actor_loss      | -9.22    |
# |    critic_loss     | 51.5     |
# |    ent_coef        | 0.786    |
# |    ent_coef_loss   | -0.351   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 835      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76       |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 69       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 972      |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 47       |
# |    ent_coef        | 0.778    |
# |    ent_coef_loss   | -0.371   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 871      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.6     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 69       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1008     |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 44       |
# |    ent_coef        | 0.771    |
# |    ent_coef_loss   | -0.368   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 907      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 77.1     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 68       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1044     |
# | train/             |          |
# |    actor_loss      | -11      |
# |    critic_loss     | 68.3     |
# |    ent_coef        | 0.763    |
# |    ent_coef_loss   | -0.367   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 943      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 78.3     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 68       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1080     |
# | train/             |          |
# |    actor_loss      | -9.31    |
# |    critic_loss     | 41.5     |
# |    ent_coef        | 0.755    |
# |    ent_coef_loss   | -0.355   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 979      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 78.4     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 68       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1116     |
# | train/             |          |
# |    actor_loss      | -11.2    |
# |    critic_loss     | 35.4     |
# |    ent_coef        | 0.748    |
# |    ent_coef_loss   | -0.397   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1015     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 78.4     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 67       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1152     |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 49.4     |
# |    ent_coef        | 0.74     |
# |    ent_coef_loss   | -0.383   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1051     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 77.5     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 67       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1188     |
# | train/             |          |
# |    actor_loss      | -9.3     |
# |    critic_loss     | 42.8     |
# |    ent_coef        | 0.733    |
# |    ent_coef_loss   | -0.438   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1087     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 78.8     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 67       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1224     |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 31       |
# |    ent_coef        | 0.725    |
# |    ent_coef_loss   | -0.488   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1123     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 78.1     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 67       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1260     |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 47.8     |
# |    ent_coef        | 0.718    |
# |    ent_coef_loss   | -0.464   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1159     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.6     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 67       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1296     |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 58.8     |
# |    ent_coef        | 0.71     |
# |    ent_coef_loss   | -0.445   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1195     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.7     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 66       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1332     |
# | train/             |          |
# |    actor_loss      | -10.6    |
# |    critic_loss     | 31.1     |
# |    ent_coef        | 0.703    |
# |    ent_coef_loss   | -0.472   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1231     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.5     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 66       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 1368     |
# | train/             |          |
# |    actor_loss      | -9.41    |
# |    critic_loss     | 46.5     |
# |    ent_coef        | 0.696    |
# |    ent_coef_loss   | -0.518   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1267     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.3     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 66       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1404     |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 68.9     |
# |    ent_coef        | 0.689    |
# |    ent_coef_loss   | -0.445   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1303     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.4     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 66       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1440     |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 37.4     |
# |    ent_coef        | 0.682    |
# |    ent_coef_loss   | -0.542   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1339     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.8     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 65       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 1476     |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 32.2     |
# |    ent_coef        | 0.675    |
# |    ent_coef_loss   | -0.493   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1375     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76       |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 65       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 1512     |
# | train/             |          |
# |    actor_loss      | -11      |
# |    critic_loss     | 38.6     |
# |    ent_coef        | 0.668    |
# |    ent_coef_loss   | -0.597   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1411     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.7     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 65       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 1548     |
# | train/             |          |
# |    actor_loss      | -8.67    |
# |    critic_loss     | 33.3     |
# |    ent_coef        | 0.661    |
# |    ent_coef_loss   | -0.544   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1447     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.3     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 65       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 1584     |
# | train/             |          |
# |    actor_loss      | -9.12    |
# |    critic_loss     | 39.1     |
# |    ent_coef        | 0.654    |
# |    ent_coef_loss   | -0.635   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1483     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.6     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 65       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 1620     |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 36.4     |
# |    ent_coef        | 0.647    |
# |    ent_coef_loss   | -0.579   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1519     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.2     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 65       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 1656     |
# | train/             |          |
# |    actor_loss      | -12.6    |
# |    critic_loss     | 40.2     |
# |    ent_coef        | 0.641    |
# |    ent_coef_loss   | -0.608   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1555     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.4     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 65       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 1692     |
# | train/             |          |
# |    actor_loss      | -7.07    |
# |    critic_loss     | 27.7     |
# |    ent_coef        | 0.634    |
# |    ent_coef_loss   | -0.657   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1591     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75       |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 65       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 1728     |
# | train/             |          |
# |    actor_loss      | -10.3    |
# |    critic_loss     | 42.6     |
# |    ent_coef        | 0.628    |
# |    ent_coef_loss   | -0.605   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1627     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 74.4     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 65       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 1764     |
# | train/             |          |
# |    actor_loss      | -7.53    |
# |    critic_loss     | 50.5     |
# |    ent_coef        | 0.621    |
# |    ent_coef_loss   | -0.655   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1663     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.1     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 65       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 34.5     |
# |    ent_coef        | 0.615    |
# |    ent_coef_loss   | -0.659   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.6     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 64       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 1836     |
# | train/             |          |
# |    actor_loss      | -9.43    |
# |    critic_loss     | 35.7     |
# |    ent_coef        | 0.608    |
# |    ent_coef_loss   | -0.67    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1735     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 77.1     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 64       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 1872     |
# | train/             |          |
# |    actor_loss      | -8.95    |
# |    critic_loss     | 31.3     |
# |    ent_coef        | 0.602    |
# |    ent_coef_loss   | -0.617   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1771     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.4     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 64       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 1908     |
# | train/             |          |
# |    actor_loss      | -10.4    |
# |    critic_loss     | 54.7     |
# |    ent_coef        | 0.596    |
# |    ent_coef_loss   | -0.723   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1807     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.3     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 64       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 1944     |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 52.1     |
# |    ent_coef        | 0.59     |
# |    ent_coef_loss   | -0.663   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1843     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 74.9     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 64       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 1980     |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 43.8     |
# |    ent_coef        | 0.584    |
# |    ent_coef_loss   | -0.67    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1879     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.5     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 64       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 2016     |
# | train/             |          |
# |    actor_loss      | -9.68    |
# |    critic_loss     | 47.5     |
# |    ent_coef        | 0.578    |
# |    ent_coef_loss   | -0.764   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1915     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76       |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 64       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 2052     |
# | train/             |          |
# |    actor_loss      | -6.27    |
# |    critic_loss     | 33       |
# |    ent_coef        | 0.572    |
# |    ent_coef_loss   | -0.739   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1951     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.5     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 64       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 2088     |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 37.2     |
# |    ent_coef        | 0.566    |
# |    ent_coef_loss   | -0.788   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1987     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.3     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 64       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 2124     |
# | train/             |          |
# |    actor_loss      | -8.49    |
# |    critic_loss     | 48.5     |
# |    ent_coef        | 0.56     |
# |    ent_coef_loss   | -0.765   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2023     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.5     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 64       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 2160     |
# | train/             |          |
# |    actor_loss      | -9.76    |
# |    critic_loss     | 35.3     |
# |    ent_coef        | 0.555    |
# |    ent_coef_loss   | -0.749   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2059     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.3     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 64       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2196     |
# | train/             |          |
# |    actor_loss      | -9.1     |
# |    critic_loss     | 40.7     |
# |    ent_coef        | 0.549    |
# |    ent_coef_loss   | -0.755   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2095     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76       |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 64       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2232     |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 35.5     |
# |    ent_coef        | 0.543    |
# |    ent_coef_loss   | -0.801   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2131     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.4     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 64       |
# |    time_elapsed    | 35       |
# |    total_timesteps | 2268     |
# | train/             |          |
# |    actor_loss      | -7.61    |
# |    critic_loss     | 29.4     |
# |    ent_coef        | 0.538    |
# |    ent_coef_loss   | -0.812   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2167     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.7     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 64       |
# |    time_elapsed    | 35       |
# |    total_timesteps | 2304     |
# | train/             |          |
# |    actor_loss      | -8.4     |
# |    critic_loss     | 41       |
# |    ent_coef        | 0.533    |
# |    ent_coef_loss   | -0.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2203     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.9     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 64       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 2340     |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 42.3     |
# |    ent_coef        | 0.527    |
# |    ent_coef_loss   | -0.774   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2239     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76       |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 64       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 2376     |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 33.8     |
# |    ent_coef        | 0.522    |
# |    ent_coef_loss   | -0.771   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2275     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.7     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 63       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 2412     |
# | train/             |          |
# |    actor_loss      | -7.12    |
# |    critic_loss     | 33.5     |
# |    ent_coef        | 0.517    |
# |    ent_coef_loss   | -0.695   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2311     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.7     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 63       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 2448     |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 40.7     |
# |    ent_coef        | 0.511    |
# |    ent_coef_loss   | -0.944   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2347     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.4     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 63       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 2484     |
# | train/             |          |
# |    actor_loss      | -9.33    |
# |    critic_loss     | 35       |
# |    ent_coef        | 0.506    |
# |    ent_coef_loss   | -0.846   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2383     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.2     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 63       |
# |    time_elapsed    | 39       |
# |    total_timesteps | 2520     |
# | train/             |          |
# |    actor_loss      | -9.71    |
# |    critic_loss     | 23.3     |
# |    ent_coef        | 0.501    |
# |    ent_coef_loss   | -0.894   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2419     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.1     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 63       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 2556     |
# | train/             |          |
# |    actor_loss      | -8.66    |
# |    critic_loss     | 36.7     |
# |    ent_coef        | 0.496    |
# |    ent_coef_loss   | -0.818   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2455     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.2     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 63       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 2592     |
# | train/             |          |
# |    actor_loss      | -6.69    |
# |    critic_loss     | 46.2     |
# |    ent_coef        | 0.491    |
# |    ent_coef_loss   | -0.873   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2491     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.8     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 63       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 2628     |
# | train/             |          |
# |    actor_loss      | -8.61    |
# |    critic_loss     | 23.1     |
# |    ent_coef        | 0.486    |
# |    ent_coef_loss   | -0.957   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2527     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.3     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 63       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 2664     |
# | train/             |          |
# |    actor_loss      | -6.85    |
# |    critic_loss     | 35.6     |
# |    ent_coef        | 0.481    |
# |    ent_coef_loss   | -1.06    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2563     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.6     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 63       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 2700     |
# | train/             |          |
# |    actor_loss      | -6.36    |
# |    critic_loss     | 36.9     |
# |    ent_coef        | 0.477    |
# |    ent_coef_loss   | -0.897   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.5     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 63       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 2736     |
# | train/             |          |
# |    actor_loss      | -9.15    |
# |    critic_loss     | 48.7     |
# |    ent_coef        | 0.472    |
# |    ent_coef_loss   | -0.85    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2635     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.5     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 63       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 2772     |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 41.3     |
# |    ent_coef        | 0.467    |
# |    ent_coef_loss   | -0.894   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2671     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.9     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 63       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 2808     |
# | train/             |          |
# |    actor_loss      | -7.23    |
# |    critic_loss     | 28.5     |
# |    ent_coef        | 0.463    |
# |    ent_coef_loss   | -0.866   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2707     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76       |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 63       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 2844     |
# | train/             |          |
# |    actor_loss      | -8.39    |
# |    critic_loss     | 36.9     |
# |    ent_coef        | 0.458    |
# |    ent_coef_loss   | -0.889   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2743     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 76.7     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 63       |
# |    time_elapsed    | 45       |
# |    total_timesteps | 2880     |
# | train/             |          |
# |    actor_loss      | -8.51    |
# |    critic_loss     | 37       |
# |    ent_coef        | 0.454    |
# |    ent_coef_loss   | -0.892   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2779     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.7     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 62       |
# |    time_elapsed    | 46       |
# |    total_timesteps | 2916     |
# | train/             |          |
# |    actor_loss      | -3.71    |
# |    critic_loss     | 28.6     |
# |    ent_coef        | 0.449    |
# |    ent_coef_loss   | -0.981   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2815     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75.4     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 62       |
# |    time_elapsed    | 46       |
# |    total_timesteps | 2952     |
# | train/             |          |
# |    actor_loss      | -4.29    |
# |    critic_loss     | 31.8     |
# |    ent_coef        | 0.445    |
# |    ent_coef_loss   | -0.948   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2851     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 74.9     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 62       |
# |    time_elapsed    | 47       |
# |    total_timesteps | 2988     |
# | train/             |          |
# |    actor_loss      | -8.47    |
# |    critic_loss     | 27.2     |
# |    ent_coef        | 0.441    |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2887     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 75       |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 62       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 3024     |
# ...
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48895    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 96.1     |
# | time/              |          |
# |    episodes        | 5448     |
# |    fps             | 28       |
# |    time_elapsed    | 1700     |
# |    total_timesteps | 49032    |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 22.3     |
# |    ent_coef        | 0.0579   |
# |    ent_coef_loss   | -0.566   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48931    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 96.4     |
# | time/              |          |
# |    episodes        | 5452     |
# |    fps             | 28       |
# |    time_elapsed    | 1702     |
# |    total_timesteps | 49068    |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 31.4     |
# |    ent_coef        | 0.0579   |
# |    ent_coef_loss   | -0.156   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48967    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 96.9     |
# | time/              |          |
# |    episodes        | 5456     |
# |    fps             | 28       |
# |    time_elapsed    | 1704     |
# |    total_timesteps | 49104    |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 25.6     |
# |    ent_coef        | 0.0578   |
# |    ent_coef_loss   | -0.117   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49003    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 97.3     |
# | time/              |          |
# |    episodes        | 5460     |
# |    fps             | 28       |
# |    time_elapsed    | 1706     |
# |    total_timesteps | 49140    |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 30.8     |
# |    ent_coef        | 0.0577   |
# |    ent_coef_loss   | 0.0215   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49039    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 96.8     |
# | time/              |          |
# |    episodes        | 5464     |
# |    fps             | 28       |
# |    time_elapsed    | 1708     |
# |    total_timesteps | 49176    |
# | train/             |          |
# |    actor_loss      | -19.1    |
# |    critic_loss     | 27.2     |
# |    ent_coef        | 0.0579   |
# |    ent_coef_loss   | -0.184   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49075    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 96.5     |
# | time/              |          |
# |    episodes        | 5468     |
# |    fps             | 28       |
# |    time_elapsed    | 1710     |
# |    total_timesteps | 49212    |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 26       |
# |    ent_coef        | 0.058    |
# |    ent_coef_loss   | -0.0342  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49111    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 96.5     |
# | time/              |          |
# |    episodes        | 5472     |
# |    fps             | 28       |
# |    time_elapsed    | 1713     |
# |    total_timesteps | 49248    |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 24.5     |
# |    ent_coef        | 0.0577   |
# |    ent_coef_loss   | -0.0806  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49147    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 96.4     |
# | time/              |          |
# |    episodes        | 5476     |
# |    fps             | 28       |
# |    time_elapsed    | 1715     |
# |    total_timesteps | 49284    |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 22.5     |
# |    ent_coef        | 0.0577   |
# |    ent_coef_loss   | -0.223   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49183    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 96.9     |
# | time/              |          |
# |    episodes        | 5480     |
# |    fps             | 28       |
# |    time_elapsed    | 1717     |
# |    total_timesteps | 49320    |
# | train/             |          |
# |    actor_loss      | -18.6    |
# |    critic_loss     | 26.7     |
# |    ent_coef        | 0.058    |
# |    ent_coef_loss   | -0.111   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49219    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 97.1     |
# | time/              |          |
# |    episodes        | 5484     |
# |    fps             | 28       |
# |    time_elapsed    | 1719     |
# |    total_timesteps | 49356    |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 24.4     |
# |    ent_coef        | 0.0576   |
# |    ent_coef_loss   | -0.154   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49255    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 98.3     |
# | time/              |          |
# |    episodes        | 5488     |
# |    fps             | 28       |
# |    time_elapsed    | 1721     |
# |    total_timesteps | 49392    |
# | train/             |          |
# |    actor_loss      | -16.4    |
# |    critic_loss     | 19.1     |
# |    ent_coef        | 0.0572   |
# |    ent_coef_loss   | -0.725   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49291    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 98.4     |
# | time/              |          |
# |    episodes        | 5492     |
# |    fps             | 28       |
# |    time_elapsed    | 1723     |
# |    total_timesteps | 49428    |
# | train/             |          |
# |    actor_loss      | -13.8    |
# |    critic_loss     | 16.6     |
# |    ent_coef        | 0.0571   |
# |    ent_coef_loss   | -0.422   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49327    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 99.6     |
# | time/              |          |
# |    episodes        | 5496     |
# |    fps             | 28       |
# |    time_elapsed    | 1726     |
# |    total_timesteps | 49464    |
# | train/             |          |
# |    actor_loss      | -12.4    |
# |    critic_loss     | 21.5     |
# |    ent_coef        | 0.0574   |
# |    ent_coef_loss   | -0.27    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49363    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 99.9     |
# | time/              |          |
# |    episodes        | 5500     |
# |    fps             | 28       |
# |    time_elapsed    | 1728     |
# |    total_timesteps | 49500    |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 22.1     |
# |    ent_coef        | 0.058    |
# |    ent_coef_loss   | -0.0974  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 99       |
# | time/              |          |
# |    episodes        | 5504     |
# |    fps             | 28       |
# |    time_elapsed    | 1730     |
# |    total_timesteps | 49536    |
# | train/             |          |
# |    actor_loss      | -15.3    |
# |    critic_loss     | 22.1     |
# |    ent_coef        | 0.0586   |
# |    ent_coef_loss   | 0.0994   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49435    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 99.2     |
# | time/              |          |
# |    episodes        | 5508     |
# |    fps             | 28       |
# |    time_elapsed    | 1732     |
# |    total_timesteps | 49572    |
# | train/             |          |
# |    actor_loss      | -17.7    |
# |    critic_loss     | 25       |
# |    ent_coef        | 0.0588   |
# |    ent_coef_loss   | -0.305   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49471    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 99.2     |
# | time/              |          |
# |    episodes        | 5512     |
# |    fps             | 28       |
# |    time_elapsed    | 1734     |
# |    total_timesteps | 49608    |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 29.6     |
# |    ent_coef        | 0.059    |
# |    ent_coef_loss   | 0.0572   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49507    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 99.6     |
# | time/              |          |
# |    episodes        | 5516     |
# |    fps             | 28       |
# |    time_elapsed    | 1736     |
# |    total_timesteps | 49644    |
# | train/             |          |
# |    actor_loss      | -17      |
# |    critic_loss     | 30.5     |
# |    ent_coef        | 0.059    |
# |    ent_coef_loss   | -0.024   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49543    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 5520     |
# |    fps             | 28       |
# |    time_elapsed    | 1739     |
# |    total_timesteps | 49680    |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 28.7     |
# |    ent_coef        | 0.0592   |
# |    ent_coef_loss   | 0.0217   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49579    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 5524     |
# |    fps             | 28       |
# |    time_elapsed    | 1741     |
# |    total_timesteps | 49716    |
# | train/             |          |
# |    actor_loss      | -17      |
# |    critic_loss     | 24.6     |
# |    ent_coef        | 0.0592   |
# |    ent_coef_loss   | 0.0807   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49615    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 5528     |
# |    fps             | 28       |
# |    time_elapsed    | 1743     |
# |    total_timesteps | 49752    |
# | train/             |          |
# |    actor_loss      | -18      |
# |    critic_loss     | 25.1     |
# |    ent_coef        | 0.0591   |
# |    ent_coef_loss   | -0.183   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49651    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 99.8     |
# | time/              |          |
# |    episodes        | 5532     |
# |    fps             | 28       |
# |    time_elapsed    | 1745     |
# |    total_timesteps | 49788    |
# | train/             |          |
# |    actor_loss      | -20.2    |
# |    critic_loss     | 38.2     |
# |    ent_coef        | 0.0586   |
# |    ent_coef_loss   | -0.0873  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49687    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 5536     |
# |    fps             | 28       |
# |    time_elapsed    | 1747     |
# |    total_timesteps | 49824    |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 35.8     |
# |    ent_coef        | 0.0584   |
# |    ent_coef_loss   | 0.152    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49723    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 5540     |
# |    fps             | 28       |
# |    time_elapsed    | 1750     |
# |    total_timesteps | 49860    |
# | train/             |          |
# |    actor_loss      | -18.7    |
# |    critic_loss     | 26.4     |
# |    ent_coef        | 0.0588   |
# |    ent_coef_loss   | -0.0307  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49759    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 5544     |
# |    fps             | 28       |
# |    time_elapsed    | 1752     |
# |    total_timesteps | 49896    |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 24.9     |
# |    ent_coef        | 0.0588   |
# |    ent_coef_loss   | -0.0747  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49795    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 5548     |
# |    fps             | 28       |
# |    time_elapsed    | 1754     |
# |    total_timesteps | 49932    |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 26.4     |
# |    ent_coef        | 0.0583   |
# |    ent_coef_loss   | -0.0656  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49831    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 5552     |
# |    fps             | 28       |
# |    time_elapsed    | 1756     |
# |    total_timesteps | 49968    |
# | train/             |          |
# |    actor_loss      | -14.4    |
# |    critic_loss     | 20.5     |
# |    ent_coef        | 0.0582   |
# |    ent_coef_loss   | -0.276   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49867    |
# ---------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
model.learn(50000, progress_bar = False)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.75     |
# |    ep_rew_mean     | 63.9     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 9        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 35       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.88     |
# |    ep_rew_mean     | 70.8     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 9        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 71       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.92     |
# |    ep_rew_mean     | 74.7     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 9        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 107      |
# | train/             |          |
# |    actor_loss      | -24.9    |
# |    critic_loss     | 28.3     |
# |    ent_coef        | 0.0875   |
# |    ent_coef_loss   | -0.159   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99806    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.94     |
# |    ep_rew_mean     | 84.4     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 9        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 143      |
# | train/             |          |
# |    actor_loss      | -20.8    |
# |    critic_loss     | 20.6     |
# |    ent_coef        | 0.0872   |
# |    ent_coef_loss   | -0.176   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99842    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.95     |
# |    ep_rew_mean     | 89.7     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 8        |
# |    time_elapsed    | 20       |
# |    total_timesteps | 179      |
# | train/             |          |
# |    actor_loss      | -25.3    |
# |    critic_loss     | 30       |
# |    ent_coef        | 0.0872   |
# |    ent_coef_loss   | 0.0304   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99878    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.96     |
# |    ep_rew_mean     | 94.1     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 8        |
# |    time_elapsed    | 24       |
# |    total_timesteps | 215      |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 33       |
# |    ent_coef        | 0.0873   |
# |    ent_coef_loss   | -0.0083  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99914    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.96     |
# |    ep_rew_mean     | 96.6     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 8        |
# |    time_elapsed    | 28       |
# |    total_timesteps | 251      |
# | train/             |          |
# |    actor_loss      | -21.6    |
# |    critic_loss     | 29.3     |
# |    ent_coef        | 0.0876   |
# |    ent_coef_loss   | -0.301   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99950    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.97     |
# |    ep_rew_mean     | 98.1     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 8        |
# |    time_elapsed    | 33       |
# |    total_timesteps | 287      |
# | train/             |          |
# |    actor_loss      | -20.9    |
# |    critic_loss     | 24.2     |
# |    ent_coef        | 0.0873   |
# |    ent_coef_loss   | 0.244    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99986    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.97     |
# |    ep_rew_mean     | 98.5     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 8        |
# |    time_elapsed    | 37       |
# |    total_timesteps | 323      |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 27.6     |
# |    ent_coef        | 0.0871   |
# |    ent_coef_loss   | -0.0427  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100022   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.97     |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 8        |
# |    time_elapsed    | 41       |
# |    total_timesteps | 359      |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 22.3     |
# |    ent_coef        | 0.0866   |
# |    ent_coef_loss   | -0.0907  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100058   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.98     |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 8        |
# |    time_elapsed    | 46       |
# |    total_timesteps | 395      |
# | train/             |          |
# |    actor_loss      | -21.7    |
# |    critic_loss     | 26.4     |
# |    ent_coef        | 0.0859   |
# |    ent_coef_loss   | -0.0589  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100094   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.98     |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 8        |
# |    time_elapsed    | 50       |
# |    total_timesteps | 431      |
# | train/             |          |
# |    actor_loss      | -24.4    |
# |    critic_loss     | 29       |
# |    ent_coef        | 0.0852   |
# |    ent_coef_loss   | -0.0677  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100130   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.98     |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 8        |
# |    time_elapsed    | 55       |
# |    total_timesteps | 467      |
# | train/             |          |
# |    actor_loss      | -20.2    |
# |    critic_loss     | 16.1     |
# |    ent_coef        | 0.0849   |
# |    ent_coef_loss   | 0.144    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100166   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.98     |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 8        |
# |    time_elapsed    | 59       |
# |    total_timesteps | 503      |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 25.3     |
# |    ent_coef        | 0.0851   |
# |    ent_coef_loss   | -0.279   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100202   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.98     |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 8        |
# |    time_elapsed    | 63       |
# |    total_timesteps | 539      |
# | train/             |          |
# |    actor_loss      | -25.8    |
# |    critic_loss     | 34.6     |
# |    ent_coef        | 0.085    |
# |    ent_coef_loss   | 0.0693   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100238   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.98     |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 8        |
# |    time_elapsed    | 68       |
# |    total_timesteps | 575      |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 25.9     |
# |    ent_coef        | 0.0848   |
# |    ent_coef_loss   | 0.0719   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100274   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.99     |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 8        |
# |    time_elapsed    | 72       |
# |    total_timesteps | 611      |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 25.1     |
# |    ent_coef        | 0.0844   |
# |    ent_coef_loss   | 0.237    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100310   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.99     |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 8        |
# |    time_elapsed    | 76       |
# |    total_timesteps | 647      |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 27.2     |
# |    ent_coef        | 0.0843   |
# |    ent_coef_loss   | -0.34    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100346   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.99     |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 8        |
# |    time_elapsed    | 81       |
# |    total_timesteps | 683      |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 27.7     |
# |    ent_coef        | 0.0842   |
# |    ent_coef_loss   | -0.122   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100382   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.99     |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 8        |
# |    time_elapsed    | 85       |
# |    total_timesteps | 719      |
# | train/             |          |
# |    actor_loss      | -23.8    |
# |    critic_loss     | 22.1     |
# |    ent_coef        | 0.0841   |
# |    ent_coef_loss   | -0.405   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100418   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.99     |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 8        |
# |    time_elapsed    | 89       |
# |    total_timesteps | 755      |
# | train/             |          |
# |    actor_loss      | -22.3    |
# |    critic_loss     | 32.2     |
# |    ent_coef        | 0.0836   |
# |    ent_coef_loss   | -0.0846  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100454   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.99     |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 8        |
# |    time_elapsed    | 94       |
# |    total_timesteps | 791      |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 23.5     |
# |    ent_coef        | 0.0831   |
# |    ent_coef_loss   | -0.0893  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100490   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.99     |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 8        |
# |    time_elapsed    | 98       |
# |    total_timesteps | 827      |
# | train/             |          |
# |    actor_loss      | -24.8    |
# |    critic_loss     | 33.2     |
# |    ent_coef        | 0.083    |
# |    ent_coef_loss   | -0.142   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100526   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.99     |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 8        |
# |    time_elapsed    | 103      |
# |    total_timesteps | 863      |
# | train/             |          |
# |    actor_loss      | -20.2    |
# |    critic_loss     | 21.8     |
# |    ent_coef        | 0.0827   |
# |    ent_coef_loss   | 0.202    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100562   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.99     |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 8        |
# |    time_elapsed    | 107      |
# |    total_timesteps | 899      |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 37.7     |
# |    ent_coef        | 0.0826   |
# |    ent_coef_loss   | -0.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100598   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 8        |
# |    time_elapsed    | 112      |
# |    total_timesteps | 935      |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 26.8     |
# |    ent_coef        | 0.0822   |
# |    ent_coef_loss   | 0.142    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100634   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 8        |
# |    time_elapsed    | 116      |
# |    total_timesteps | 971      |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 27.7     |
# |    ent_coef        | 0.0818   |
# |    ent_coef_loss   | -0.128   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100670   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 8        |
# |    time_elapsed    | 121      |
# |    total_timesteps | 1007     |
# | train/             |          |
# |    actor_loss      | -25.1    |
# |    critic_loss     | 30.1     |
# |    ent_coef        | 0.0817   |
# |    ent_coef_loss   | -0.171   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100706   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 8        |
# |    time_elapsed    | 125      |
# |    total_timesteps | 1043     |
# | train/             |          |
# |    actor_loss      | -22.4    |
# |    critic_loss     | 25.5     |
# |    ent_coef        | 0.0816   |
# |    ent_coef_loss   | -0.151   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100742   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 8        |
# |    time_elapsed    | 129      |
# |    total_timesteps | 1079     |
# | train/             |          |
# |    actor_loss      | -24.6    |
# |    critic_loss     | 23.8     |
# |    ent_coef        | 0.0815   |
# |    ent_coef_loss   | -0.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100778   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 8        |
# |    time_elapsed    | 134      |
# |    total_timesteps | 1115     |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 23.2     |
# |    ent_coef        | 0.0814   |
# |    ent_coef_loss   | -0.287   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100814   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 8        |
# |    time_elapsed    | 138      |
# |    total_timesteps | 1151     |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 25.5     |
# |    ent_coef        | 0.0812   |
# |    ent_coef_loss   | 0.0513   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100850   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 8        |
# |    time_elapsed    | 143      |
# |    total_timesteps | 1187     |
# | train/             |          |
# |    actor_loss      | -24.9    |
# |    critic_loss     | 24.7     |
# |    ent_coef        | 0.0815   |
# |    ent_coef_loss   | 0.165    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100886   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 8        |
# |    time_elapsed    | 148      |
# |    total_timesteps | 1223     |
# | train/             |          |
# |    actor_loss      | -22.7    |
# |    critic_loss     | 27.6     |
# |    ent_coef        | 0.082    |
# |    ent_coef_loss   | 0.0753   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100922   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 8        |
# |    time_elapsed    | 152      |
# |    total_timesteps | 1259     |
# | train/             |          |
# |    actor_loss      | -26.1    |
# |    critic_loss     | 26.5     |
# |    ent_coef        | 0.0821   |
# |    ent_coef_loss   | -0.0471  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100958   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 8        |
# |    time_elapsed    | 156      |
# |    total_timesteps | 1295     |
# | train/             |          |
# |    actor_loss      | -23.8    |
# |    critic_loss     | 30       |
# |    ent_coef        | 0.0823   |
# |    ent_coef_loss   | -0.0306  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 100994   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 8        |
# |    time_elapsed    | 161      |
# |    total_timesteps | 1331     |
# | train/             |          |
# |    actor_loss      | -21.4    |
# |    critic_loss     | 24.6     |
# |    ent_coef        | 0.0827   |
# |    ent_coef_loss   | -0.0137  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101030   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 8        |
# |    time_elapsed    | 165      |
# |    total_timesteps | 1367     |
# | train/             |          |
# |    actor_loss      | -20.6    |
# |    critic_loss     | 21.1     |
# |    ent_coef        | 0.0827   |
# |    ent_coef_loss   | 0.0709   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101066   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 8        |
# |    time_elapsed    | 170      |
# |    total_timesteps | 1403     |
# | train/             |          |
# |    actor_loss      | -21.9    |
# |    critic_loss     | 31.4     |
# |    ent_coef        | 0.0828   |
# |    ent_coef_loss   | 0.137    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101102   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 8        |
# |    time_elapsed    | 174      |
# |    total_timesteps | 1439     |
# | train/             |          |
# |    actor_loss      | -24.4    |
# |    critic_loss     | 26.4     |
# |    ent_coef        | 0.0826   |
# |    ent_coef_loss   | 0.277    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101138   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 8        |
# |    time_elapsed    | 179      |
# |    total_timesteps | 1475     |
# | train/             |          |
# |    actor_loss      | -20.9    |
# |    critic_loss     | 22.6     |
# |    ent_coef        | 0.0824   |
# |    ent_coef_loss   | -0.134   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101174   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 8        |
# |    time_elapsed    | 183      |
# |    total_timesteps | 1511     |
# | train/             |          |
# |    actor_loss      | -28.4    |
# |    critic_loss     | 29.7     |
# |    ent_coef        | 0.0822   |
# |    ent_coef_loss   | 0.467    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101210   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 8        |
# |    time_elapsed    | 187      |
# |    total_timesteps | 1547     |
# | train/             |          |
# |    actor_loss      | -23.8    |
# |    critic_loss     | 23.7     |
# |    ent_coef        | 0.0826   |
# |    ent_coef_loss   | 0.146    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101246   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 8        |
# |    time_elapsed    | 192      |
# |    total_timesteps | 1583     |
# | train/             |          |
# |    actor_loss      | -25.6    |
# |    critic_loss     | 30.7     |
# |    ent_coef        | 0.0823   |
# |    ent_coef_loss   | -0.0924  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101282   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 8        |
# |    time_elapsed    | 196      |
# |    total_timesteps | 1619     |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 24.2     |
# |    ent_coef        | 0.0819   |
# |    ent_coef_loss   | -0.0102  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101318   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 8        |
# |    time_elapsed    | 201      |
# |    total_timesteps | 1655     |
# | train/             |          |
# |    actor_loss      | -23.8    |
# |    critic_loss     | 35       |
# |    ent_coef        | 0.082    |
# |    ent_coef_loss   | 0.353    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101354   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 8        |
# |    time_elapsed    | 205      |
# |    total_timesteps | 1691     |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 17.7     |
# |    ent_coef        | 0.082    |
# |    ent_coef_loss   | 0.0203   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101390   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 8        |
# |    time_elapsed    | 210      |
# |    total_timesteps | 1727     |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 29.8     |
# |    ent_coef        | 0.0819   |
# |    ent_coef_loss   | 0.512    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101426   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 8        |
# |    time_elapsed    | 214      |
# |    total_timesteps | 1763     |
# | train/             |          |
# |    actor_loss      | -26.9    |
# |    critic_loss     | 39.6     |
# |    ent_coef        | 0.0824   |
# |    ent_coef_loss   | 0.411    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101462   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 8        |
# |    time_elapsed    | 219      |
# |    total_timesteps | 1799     |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 29.6     |
# |    ent_coef        | 0.0827   |
# |    ent_coef_loss   | 0.29     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 8        |
# |    time_elapsed    | 223      |
# |    total_timesteps | 1835     |
# | train/             |          |
# |    actor_loss      | -19.7    |
# |    critic_loss     | 27       |
# |    ent_coef        | 0.0828   |
# |    ent_coef_loss   | 0.274    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101534   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 8        |
# |    time_elapsed    | 227      |
# |    total_timesteps | 1871     |
# | train/             |          |
# |    actor_loss      | -21.5    |
# |    critic_loss     | 22.1     |
# |    ent_coef        | 0.0832   |
# |    ent_coef_loss   | -0.328   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101570   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 8        |
# |    time_elapsed    | 232      |
# |    total_timesteps | 1907     |
# | train/             |          |
# |    actor_loss      | -20.7    |
# |    critic_loss     | 22.5     |
# |    ent_coef        | 0.0833   |
# |    ent_coef_loss   | 0.318    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101606   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 8        |
# |    time_elapsed    | 236      |
# |    total_timesteps | 1943     |
# | train/             |          |
# |    actor_loss      | -22.4    |
# |    critic_loss     | 33.1     |
# |    ent_coef        | 0.0837   |
# |    ent_coef_loss   | -0.0786  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101642   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 8        |
# |    time_elapsed    | 241      |
# |    total_timesteps | 1979     |
# | train/             |          |
# |    actor_loss      | -21.1    |
# |    critic_loss     | 24.8     |
# |    ent_coef        | 0.0832   |
# |    ent_coef_loss   | 0.112    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101678   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 8        |
# |    time_elapsed    | 245      |
# |    total_timesteps | 2015     |
# | train/             |          |
# |    actor_loss      | -24.2    |
# |    critic_loss     | 30.6     |
# |    ent_coef        | 0.0826   |
# |    ent_coef_loss   | 0.422    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101714   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 8        |
# |    time_elapsed    | 250      |
# |    total_timesteps | 2051     |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 29.9     |
# |    ent_coef        | 0.0825   |
# |    ent_coef_loss   | 0.0544   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101750   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 8        |
# |    time_elapsed    | 254      |
# |    total_timesteps | 2087     |
# | train/             |          |
# |    actor_loss      | -23.9    |
# |    critic_loss     | 30.8     |
# |    ent_coef        | 0.0826   |
# |    ent_coef_loss   | 0.139    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101786   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 8        |
# |    time_elapsed    | 258      |
# |    total_timesteps | 2123     |
# | train/             |          |
# |    actor_loss      | -25.1    |
# |    critic_loss     | 28.6     |
# |    ent_coef        | 0.0819   |
# |    ent_coef_loss   | -0.0181  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101822   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 8        |
# |    time_elapsed    | 263      |
# |    total_timesteps | 2159     |
# | train/             |          |
# |    actor_loss      | -22.7    |
# |    critic_loss     | 24.8     |
# |    ent_coef        | 0.0815   |
# |    ent_coef_loss   | -0.0701  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101858   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 8        |
# |    time_elapsed    | 267      |
# |    total_timesteps | 2195     |
# | train/             |          |
# |    actor_loss      | -21.5    |
# |    critic_loss     | 18.4     |
# |    ent_coef        | 0.0815   |
# |    ent_coef_loss   | 0.474    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101894   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 8        |
# |    time_elapsed    | 272      |
# |    total_timesteps | 2231     |
# | train/             |          |
# |    actor_loss      | -21.9    |
# |    critic_loss     | 30.1     |
# |    ent_coef        | 0.0824   |
# |    ent_coef_loss   | 0.355    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101930   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 8        |
# |    time_elapsed    | 276      |
# |    total_timesteps | 2267     |
# | train/             |          |
# |    actor_loss      | -18      |
# |    critic_loss     | 22.5     |
# |    ent_coef        | 0.0825   |
# |    ent_coef_loss   | -0.00911 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 101966   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 8        |
# |    time_elapsed    | 281      |
# |    total_timesteps | 2303     |
# | train/             |          |
# |    actor_loss      | -25      |
# |    critic_loss     | 33.1     |
# |    ent_coef        | 0.0826   |
# |    ent_coef_loss   | -0.0188  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102002   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 8        |
# |    time_elapsed    | 285      |
# |    total_timesteps | 2339     |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 33.9     |
# |    ent_coef        | 0.0826   |
# |    ent_coef_loss   | 0.476    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102038   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 8        |
# |    time_elapsed    | 290      |
# |    total_timesteps | 2375     |
# | train/             |          |
# |    actor_loss      | -19.4    |
# |    critic_loss     | 22       |
# |    ent_coef        | 0.0835   |
# |    ent_coef_loss   | 0.26     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102074   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 8        |
# |    time_elapsed    | 294      |
# |    total_timesteps | 2411     |
# | train/             |          |
# |    actor_loss      | -25.4    |
# |    critic_loss     | 29.7     |
# |    ent_coef        | 0.0843   |
# |    ent_coef_loss   | 0.0861   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102110   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 8        |
# |    time_elapsed    | 299      |
# |    total_timesteps | 2447     |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 26.4     |
# |    ent_coef        | 0.0842   |
# |    ent_coef_loss   | 0.31     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102146   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 8        |
# |    time_elapsed    | 303      |
# |    total_timesteps | 2483     |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 31.6     |
# |    ent_coef        | 0.0844   |
# |    ent_coef_loss   | 0.411    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102182   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 8        |
# |    time_elapsed    | 307      |
# |    total_timesteps | 2519     |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 29.5     |
# |    ent_coef        | 0.0843   |
# |    ent_coef_loss   | 0.262    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102218   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 8        |
# |    time_elapsed    | 312      |
# |    total_timesteps | 2555     |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 27.9     |
# |    ent_coef        | 0.0846   |
# |    ent_coef_loss   | -0.135   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102254   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 8        |
# |    time_elapsed    | 316      |
# |    total_timesteps | 2591     |
# | train/             |          |
# |    actor_loss      | -23.9    |
# |    critic_loss     | 22.5     |
# |    ent_coef        | 0.0849   |
# |    ent_coef_loss   | -0.0537  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102290   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 8        |
# |    time_elapsed    | 321      |
# |    total_timesteps | 2627     |
# | train/             |          |
# |    actor_loss      | -19.6    |
# |    critic_loss     | 23.6     |
# |    ent_coef        | 0.085    |
# |    ent_coef_loss   | -0.0325  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102326   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 8        |
# |    time_elapsed    | 325      |
# |    total_timesteps | 2663     |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 32.4     |
# |    ent_coef        | 0.0849   |
# |    ent_coef_loss   | 0.0391   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102362   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 8        |
# |    time_elapsed    | 330      |
# |    total_timesteps | 2699     |
# | train/             |          |
# |    actor_loss      | -20      |
# |    critic_loss     | 18.9     |
# |    ent_coef        | 0.0851   |
# |    ent_coef_loss   | 0.189    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102398   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 8        |
# |    time_elapsed    | 334      |
# |    total_timesteps | 2735     |
# | train/             |          |
# |    actor_loss      | -22.3    |
# |    critic_loss     | 37.8     |
# |    ent_coef        | 0.0849   |
# |    ent_coef_loss   | 0.294    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102434   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 8        |
# |    time_elapsed    | 339      |
# |    total_timesteps | 2771     |
# | train/             |          |
# |    actor_loss      | -21.3    |
# |    critic_loss     | 32.2     |
# |    ent_coef        | 0.0854   |
# |    ent_coef_loss   | -0.0351  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102470   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 8        |
# |    time_elapsed    | 343      |
# |    total_timesteps | 2807     |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 37.7     |
# |    ent_coef        | 0.085    |
# |    ent_coef_loss   | 0.05     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102506   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 8        |
# |    time_elapsed    | 348      |
# |    total_timesteps | 2843     |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 30.8     |
# |    ent_coef        | 0.085    |
# |    ent_coef_loss   | 0.107    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102542   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 8        |
# |    time_elapsed    | 352      |
# |    total_timesteps | 2879     |
# | train/             |          |
# |    actor_loss      | -21.2    |
# |    critic_loss     | 21.2     |
# |    ent_coef        | 0.0851   |
# |    ent_coef_loss   | 0.0285   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102578   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 8        |
# |    time_elapsed    | 357      |
# |    total_timesteps | 2915     |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 27.8     |
# |    ent_coef        | 0.0852   |
# |    ent_coef_loss   | 0.0626   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102614   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 8        |
# |    time_elapsed    | 361      |
# |    total_timesteps | 2951     |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 28       |
# |    ent_coef        | 0.0858   |
# |    ent_coef_loss   | -0.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102650   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 8        |
# |    time_elapsed    | 365      |
# |    total_timesteps | 2987     |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 26.9     |
# |    ent_coef        | 0.0859   |
# |    ent_coef_loss   | 0.282    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 102686   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 8        |
# |    time_elapsed    | 370      |
# |    total_timesteps | 3023     |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 32.2     |
# |    ent_coef        | 0.0864   |
# |    ent_coef_loss   | 0.174    |
# ...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 2012     |
# |    fps             | 7        |
# |    time_elapsed    | 2422     |
# |    total_timesteps | 18107    |
# | train/             |          |
# |    actor_loss      | -26.2    |
# |    critic_loss     | 35.9     |
# |    ent_coef        | 0.0787   |
# |    ent_coef_loss   | 0.345    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 117806   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 2016     |
# |    fps             | 7        |
# |    time_elapsed    | 2427     |
# |    total_timesteps | 18143    |
# | train/             |          |
# |    actor_loss      | -25.7    |
# |    critic_loss     | 32       |
# |    ent_coef        | 0.0786   |
# |    ent_coef_loss   | -0.188   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 117842   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 2020     |
# |    fps             | 7        |
# |    time_elapsed    | 2433     |
# |    total_timesteps | 18179    |
# | train/             |          |
# |    actor_loss      | -25.1    |
# |    critic_loss     | 30.6     |
# |    ent_coef        | 0.0782   |
# |    ent_coef_loss   | 0.0161   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 117878   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 2024     |
# |    fps             | 7        |
# |    time_elapsed    | 2438     |
# |    total_timesteps | 18215    |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 24.8     |
# |    ent_coef        | 0.078    |
# |    ent_coef_loss   | 0.592    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 117914   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 2028     |
# |    fps             | 7        |
# |    time_elapsed    | 2443     |
# |    total_timesteps | 18251    |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 27       |
# |    ent_coef        | 0.0785   |
# |    ent_coef_loss   | 0.0281   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 117950   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 2032     |
# |    fps             | 7        |
# |    time_elapsed    | 2448     |
# |    total_timesteps | 18287    |
# | train/             |          |
# |    actor_loss      | -22.1    |
# |    critic_loss     | 29.6     |
# |    ent_coef        | 0.0783   |
# |    ent_coef_loss   | 0.0617   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 117986   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 2036     |
# |    fps             | 7        |
# |    time_elapsed    | 2454     |
# |    total_timesteps | 18323    |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 30       |
# |    ent_coef        | 0.0782   |
# |    ent_coef_loss   | -0.392   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118022   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 2040     |
# |    fps             | 7        |
# |    time_elapsed    | 2459     |
# |    total_timesteps | 18359    |
# | train/             |          |
# |    actor_loss      | -20.9    |
# |    critic_loss     | 23.1     |
# |    ent_coef        | 0.078    |
# |    ent_coef_loss   | -0.0639  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118058   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 2044     |
# |    fps             | 7        |
# |    time_elapsed    | 2465     |
# |    total_timesteps | 18395    |
# | train/             |          |
# |    actor_loss      | -24.7    |
# |    critic_loss     | 29.4     |
# |    ent_coef        | 0.0781   |
# |    ent_coef_loss   | -0.125   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118094   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 2048     |
# |    fps             | 7        |
# |    time_elapsed    | 2470     |
# |    total_timesteps | 18431    |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 36.8     |
# |    ent_coef        | 0.0779   |
# |    ent_coef_loss   | 0.227    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118130   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 2052     |
# |    fps             | 7        |
# |    time_elapsed    | 2475     |
# |    total_timesteps | 18467    |
# | train/             |          |
# |    actor_loss      | -25.5    |
# |    critic_loss     | 29.2     |
# |    ent_coef        | 0.0777   |
# |    ent_coef_loss   | 0.497    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118166   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 2056     |
# |    fps             | 7        |
# |    time_elapsed    | 2480     |
# |    total_timesteps | 18503    |
# | train/             |          |
# |    actor_loss      | -23.1    |
# |    critic_loss     | 25.2     |
# |    ent_coef        | 0.0781   |
# |    ent_coef_loss   | 0.291    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118202   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 2060     |
# |    fps             | 7        |
# |    time_elapsed    | 2486     |
# |    total_timesteps | 18539    |
# | train/             |          |
# |    actor_loss      | -26.5    |
# |    critic_loss     | 34.6     |
# |    ent_coef        | 0.0783   |
# |    ent_coef_loss   | 0.273    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118238   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 2064     |
# |    fps             | 7        |
# |    time_elapsed    | 2491     |
# |    total_timesteps | 18575    |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 32.4     |
# |    ent_coef        | 0.0782   |
# |    ent_coef_loss   | -0.0539  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118274   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 2068     |
# |    fps             | 7        |
# |    time_elapsed    | 2496     |
# |    total_timesteps | 18611    |
# | train/             |          |
# |    actor_loss      | -27.6    |
# |    critic_loss     | 31.9     |
# |    ent_coef        | 0.0781   |
# |    ent_coef_loss   | 0.224    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118310   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9        |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 2072     |
# |    fps             | 7        |
# |    time_elapsed    | 2501     |
# |    total_timesteps | 18647    |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 32.8     |
# |    ent_coef        | 0.0778   |
# |    ent_coef_loss   | -0.285   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 118346   |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 118675
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 model.learn(50000, progress_bar = False)
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/sac/sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/common/off_policy_algorithm.py:312, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     309 callback.on_training_start(locals(), globals())
#     311 while self.num_timesteps < total_timesteps:
# --> 312     rollout = self.collect_rollouts(
#     313         self.env,
#     314         train_freq=self.train_freq,
#     315         action_noise=self.action_noise,
#     316         callback=callback,
#     317         learning_starts=self.learning_starts,
#     318         replay_buffer=self.replay_buffer,
#     319         log_interval=log_interval,
#     320     )
#     322     if rollout.continue_training is False:
#     323         break
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/common/off_policy_algorithm.py:544, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     541 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     543 # Rescale and perform action
# --> 544 new_obs, rewards, dones, infos = env.step(actions)
#     546 self.num_timesteps += env.num_envs
#     547 num_collected_steps += 1
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:197, in VecEnv.step(self, actions)
#     190 """
#     191 Step the environments with the given action
#     192
#     193 :param actions: the action
#     194 :return: observation, reward, done, information
#     195 """
#     196 self.step_async(actions)
# --> 197 return self.step_wait()
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# Cell In[20], line 50, in SingleAgentEnv1.step(self, action)
#      48     bprofit = self.buyers[currentBidIdx].stepProfits
#      49     sprofit = self.sellers[currentAskIdx].stepProfits
# ---> 50 self.log.addStep([0, self.timePeriod, self.timeStep, bids, asks, currentBid, currentBidIdx, currentAsk, currentAskIdx, buy, sell, price, price>0, bprofit, sprofit])
#      51 observe(self.buyers, self.sellers, self.log.disclose())
#      53 # compute reward and transition
#
# File /econ_share/home/pp712/double-auctions/code/7_clean/env.py:19, in Log.addStep(self, stepData)
#      18 def addStep(self, stepData):
# ---> 19     self.stepData.loc[len(self.stepData.index)] = stepData
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/pandas/core/indexing.py:881, in _LocationIndexer.__setitem__(self, key, value)
#     879 else:
#     880     key = com.apply_if_callable(key, self.obj)
# --> 881 indexer = self._get_setitem_indexer(key)
#     882 self._has_valid_setitem_indexer(key)
#     884 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/pandas/core/indexing.py:764, in _LocationIndexer._get_setitem_indexer(self, key)
#     760 if isinstance(key, range):
#     761     # GH#45479 test_loc_setitem_range_key
#     762     key = list(key)
# --> 764 return self._convert_to_indexer(key, axis=0)
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/pandas/core/indexing.py:1455, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1448 if is_scalar(key) or (
#    1449     isinstance(labels, MultiIndex) and is_hashable(key) and not contains_slice
#    1450 ):
#    1451     # Otherwise get_loc will raise InvalidIndexError
#    1452
#    1453     # if we are a label return me
#    1454     try:
# -> 1455         return labels.get_loc(key)
#    1456     except LookupError:
#    1457         if isinstance(key, tuple) and isinstance(labels, MultiIndex):
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3793, in Index.get_loc(self, key)
#    3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#    3792     if isinstance(casted_key, slice) or (
# -> 3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
#    3797     raise KeyError(key) from err
#
# File <frozen abc>:117, in __instancecheck__(cls, instance)
#
# KeyboardInterrupt:

# %%
env.log.getPeriod(0,1)
# Out:
#     rnd  period  step                bids               asks  currentBid  \
# 9     0       1     0  [61.1, 91.5, 19.0]    [9.6, nan, 3.3]        91.5
# 10    0       1     1  [21.7, 39.5, 34.2]   [7.9, nan, 20.1]        39.5
# 11    0       1     2  [93.9, 51.9, 36.9]  [25.4, nan, 29.4]        93.9
# 12    0       1     3  [71.1, 61.9, 29.6]  [86.7, nan, 23.6]        71.1
# 13    0       1     4   [3.5, 40.0, 25.2]  [80.4, nan, 76.3]        40.0
# 14    0       1     5  [12.1, 25.5, 44.4]  [94.7, nan, 56.7]        44.4
# 15    0       1     6  [32.0, 28.8, 21.9]  [67.1, nan, 54.8]        32.0
# 16    0       1     7  [93.0, 51.5, 28.7]  [60.0, nan, 55.4]        93.0
# 17    0       1     8  [24.3, 34.9, 25.9]  [110.4, nan, nan]        34.9
#
#     currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 9               1         3.3            2.0   True   True  47.40   True
# 10              1         7.9            0.0   True   True  23.70   True
# 11              0        25.4            0.0   True   True  59.65   True
# 12              0        23.6            2.0   True   True  47.35   True
# 13              1        76.3            2.0  False  False    NaN  False
# 14              2        56.7            2.0  False  False    NaN  False
# 15              0        54.8            2.0  False  False    NaN  False
# 16              0        55.4            2.0  False   True  93.00   True
# 17              1       110.4            0.0  False  False    NaN  False
#
#     bprofit  sprofit
# 9     52.60    45.00
# 10    73.60    18.10
# 11    37.85    40.55
# 12    37.45    27.95
# 13     0.00     0.00
# 14     0.00     0.00
# 15     0.00     0.00
# 16   -39.30    44.00
# 17     0.00     0.00

# %%
env.log.getRound(0).redemptionValues.item()
# Out:
# array([[ 97.5,  84.8,  53.7],
#        [100. ,  97.3,  66.4],
#        [ 45.1,  42.4,  29.3]])

# %%
env.graphSales(0,13100)

# %%
env.graphOffers(0,13100)
# Out:
# 9
# 9

# %%
env.graphOffers(0,13050)
# Out:
# 9
# 9

# %%
env.log.stepData.tail(9*200).groupby('currentBidIdx').sum()
# Out:
#                rnd    period  step  \
# currentBidIdx
# 0                0  10169322  2723
# 1                0   8204257  1961
# 2                0   5180521  2516
#
#                                                             bids  \
# currentBidIdx
# 0              [62.4, 58.7, 7.2, 55.9, nan, 19.3, 19.6, nan, ...
# 1              [50.6, 67.9, 18.7, 58.6, 89.3, 25.6, 34.6, 47....
# 2              [14.0, nan, 37.3, 18.8, nan, 22.3, 10.6, nan, ...
#
#                                                             asks  currentBid  \
# currentBidIdx
# 0              [10.0, nan, 35.8, 87.3, nan, 36.5, 79.2, nan, ...     40169.9
# 1              [21.4, nan, 32.5, 111.9, nan, 22.1, 82.0, nan,...     40737.6
# 2              [77.7, nan, nan, 80.3, nan, nan, 104.2, nan, n...     12298.8
#
#                currentAsk  currentAskIdx  buy sell     price  sale   bprofit  \
# currentBidIdx
# 0                 26545.0          662.0  466  494  21941.50   525  22316.50
# 1                 21568.7          636.0  498  469  27092.90   531  20756.50
# 2                 30320.2          220.0    1    1     33.35     1     11.75
#
#                 sprofit
# currentBidIdx
# 0              12558.20
# 1              13802.60
# 2                 13.95

# %%
env.log.stepData.tail(9*200).groupby('currentAskIdx').sum()
# Out:
#                rnd    period  step  \
# currentAskIdx
# 0.0              0  11815442  3842
# 2.0              0   9932523  2365
#
#                                                             bids  \
# currentAskIdx
# 0.0            [62.4, 58.7, 7.2, 50.6, 67.9, 18.7, 14.0, nan,...
# 2.0            [58.6, 89.3, 25.6, 34.6, 47.7, 13.5, 56.7, 74....
#
#                                                             asks  currentBid  \
# currentAskIdx
# 0.0            [10.0, nan, 35.8, 21.4, nan, 32.5, 77.7, nan, ...     43956.0
# 2.0            [111.9, nan, 22.1, 82.0, nan, 60.2, 8.9, nan, ...     40713.7
#
#                currentBidIdx  currentAsk  buy sell     price  sale   bprofit  \
# currentAskIdx
# 0.0                      805     48327.8  449  452  22245.75   480  20049.45
# 2.0                      538     30106.1  516  512  26822.00   577  23035.30
#
#                 sprofit
# currentAskIdx
# 0.0            12585.75
# 2.0            13789.00

# %% [markdown]
# ### Stablebaselines

# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO, A2C, DQN, SAC
from stable_baselines3.ppo.policies import MlpPolicy
from stable_baselines3.common.base_class import BaseAlgorithm
from stable_baselines3.common.evaluation import evaluate_policy
eval_steps = 1000
training_step = 50000
env = SingleAgentEnv1(metaData)
policy_kwargs = dict(net_arch=dict(pi=[128, 128, 128], qf=[128, 128, 128]))
model = SAC("MlpPolicy", env, policy_kwargs=policy_kwargs, verbose=1,)
model.learn(training_step, progress_bar = True)
# Out:
# Output()
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 35.1     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 212      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 64       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 33.4     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 146      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 128      |
# | train/             |          |
# |    actor_loss      | -3.5     |
# |    critic_loss     | 86.3     |
# |    ent_coef        | 0.996    |
# |    ent_coef_loss   | -0.0069  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 33.2     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 105      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 192      |
# | train/             |          |
# |    actor_loss      | -4.18    |
# |    critic_loss     | 70       |
# |    ent_coef        | 0.976    |
# |    ent_coef_loss   | -0.041   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 91       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 33.3     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 92       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 256      |
# | train/             |          |
# |    actor_loss      | -5.51    |
# |    critic_loss     | 59.8     |
# |    ent_coef        | 0.957    |
# |    ent_coef_loss   | -0.0728  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 155      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 30.1     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 86       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 320      |
# | train/             |          |
# |    actor_loss      | -6.28    |
# |    critic_loss     | 48.5     |
# |    ent_coef        | 0.938    |
# |    ent_coef_loss   | -0.107   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 219      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 29.2     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 81       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 384      |
# | train/             |          |
# |    actor_loss      | -5.97    |
# |    critic_loss     | 49.9     |
# |    ent_coef        | 0.92     |
# |    ent_coef_loss   | -0.139   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 283      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 28.9     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 79       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 448      |
# | train/             |          |
# |    actor_loss      | -6.33    |
# |    critic_loss     | 37.7     |
# |    ent_coef        | 0.903    |
# |    ent_coef_loss   | -0.167   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 347      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 28.2     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 77       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 512      |
# | train/             |          |
# |    actor_loss      | -6.84    |
# |    critic_loss     | 37.5     |
# |    ent_coef        | 0.886    |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 411      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 27.5     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 75       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 576      |
# | train/             |          |
# |    actor_loss      | -4.96    |
# |    critic_loss     | 20.6     |
# |    ent_coef        | 0.869    |
# |    ent_coef_loss   | -0.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 475      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 31.1     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 73       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 640      |
# | train/             |          |
# |    actor_loss      | -5.42    |
# |    critic_loss     | 33.7     |
# |    ent_coef        | 0.854    |
# |    ent_coef_loss   | -0.244   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 539      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 72       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 704      |
# | train/             |          |
# |    actor_loss      | -5.47    |
# |    critic_loss     | 23.7     |
# |    ent_coef        | 0.838    |
# |    ent_coef_loss   | -0.262   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 603      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 32.7     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 72       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 768      |
# | train/             |          |
# |    actor_loss      | -7.82    |
# |    critic_loss     | 16.9     |
# |    ent_coef        | 0.824    |
# |    ent_coef_loss   | -0.289   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 667      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 34.9     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 71       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 832      |
# | train/             |          |
# |    actor_loss      | -4.25    |
# |    critic_loss     | 15.4     |
# |    ent_coef        | 0.81     |
# |    ent_coef_loss   | -0.292   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 731      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 36.5     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 70       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 896      |
# | train/             |          |
# |    actor_loss      | -8       |
# |    critic_loss     | 15.2     |
# |    ent_coef        | 0.798    |
# |    ent_coef_loss   | -0.248   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 795      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 38.5     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 69       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 960      |
# | train/             |          |
# |    actor_loss      | -8.62    |
# |    critic_loss     | 14.3     |
# |    ent_coef        | 0.786    |
# |    ent_coef_loss   | -0.271   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 859      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 40.3     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 69       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1024     |
# | train/             |          |
# |    actor_loss      | -8.28    |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.775    |
# |    ent_coef_loss   | -0.246   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 923      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 41.5     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 68       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1088     |
# | train/             |          |
# |    actor_loss      | -7.94    |
# |    critic_loss     | 10.3     |
# |    ent_coef        | 0.765    |
# |    ent_coef_loss   | -0.264   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 987      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 43.6     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 68       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1152     |
# | train/             |          |
# |    actor_loss      | -9.59    |
# |    critic_loss     | 11.2     |
# |    ent_coef        | 0.756    |
# |    ent_coef_loss   | -0.242   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1051     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 45.3     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 68       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1216     |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 8.4      |
# |    ent_coef        | 0.747    |
# |    ent_coef_loss   | -0.243   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1115     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 47.5     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 67       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1280     |
# | train/             |          |
# |    actor_loss      | -9.33    |
# |    critic_loss     | 11.1     |
# |    ent_coef        | 0.738    |
# |    ent_coef_loss   | -0.215   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1179     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 49.7     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 67       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1344     |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 9.7      |
# |    ent_coef        | 0.73     |
# |    ent_coef_loss   | -0.183   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1243     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 51.1     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 66       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1408     |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 11.1     |
# |    ent_coef        | 0.722    |
# |    ent_coef_loss   | -0.223   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1307     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 53.1     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 66       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 1472     |
# | train/             |          |
# |    actor_loss      | -13.7    |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.715    |
# |    ent_coef_loss   | -0.204   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1371     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 54.8     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 66       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 1536     |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 7.21     |
# |    ent_coef        | 0.707    |
# |    ent_coef_loss   | -0.235   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1435     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 56.3     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 66       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 7.49     |
# |    ent_coef        | 0.699    |
# |    ent_coef_loss   | -0.241   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 58.8     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 65       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 1664     |
# | train/             |          |
# |    actor_loss      | -15.5    |
# |    critic_loss     | 5.83     |
# |    ent_coef        | 0.691    |
# |    ent_coef_loss   | -0.195   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1563     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 61.6     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 65       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 1728     |
# | train/             |          |
# |    actor_loss      | -16.2    |
# |    critic_loss     | 7.13     |
# |    ent_coef        | 0.684    |
# |    ent_coef_loss   | -0.262   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1627     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 63.5     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 65       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 1792     |
# | train/             |          |
# |    actor_loss      | -15.3    |
# |    critic_loss     | 7.96     |
# |    ent_coef        | 0.676    |
# |    ent_coef_loss   | -0.259   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1691     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 66       |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 65       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 1856     |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 6.46     |
# |    ent_coef        | 0.668    |
# |    ent_coef_loss   | -0.264   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1755     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 68.8     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 65       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 1920     |
# | train/             |          |
# |    actor_loss      | -20      |
# |    critic_loss     | 10.3     |
# |    ent_coef        | 0.66     |
# |    ent_coef_loss   | -0.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1819     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 71.8     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 64       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 1984     |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 7.62     |
# |    ent_coef        | 0.653    |
# |    ent_coef_loss   | -0.272   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1883     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 73.9     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 64       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 2048     |
# | train/             |          |
# |    actor_loss      | -21.5    |
# |    critic_loss     | 5.93     |
# |    ent_coef        | 0.645    |
# |    ent_coef_loss   | -0.213   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1947     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 76.5     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 64       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 2112     |
# | train/             |          |
# |    actor_loss      | -21.1    |
# |    critic_loss     | 7.16     |
# |    ent_coef        | 0.638    |
# |    ent_coef_loss   | -0.293   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2011     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 78.9     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 64       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 2176     |
# | train/             |          |
# |    actor_loss      | -21.9    |
# |    critic_loss     | 6.57     |
# |    ent_coef        | 0.631    |
# |    ent_coef_loss   | -0.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2075     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 79.5     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 64       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2240     |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 6.73     |
# |    ent_coef        | 0.624    |
# |    ent_coef_loss   | -0.136   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2139     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 81.7     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 63       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 2304     |
# | train/             |          |
# |    actor_loss      | -22.5    |
# |    critic_loss     | 5.37     |
# |    ent_coef        | 0.617    |
# |    ent_coef_loss   | -0.112   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2203     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 83.8     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 63       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 2368     |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 8.74     |
# |    ent_coef        | 0.611    |
# |    ent_coef_loss   | -0.268   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2267     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 85.3     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 63       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 2432     |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 8.41     |
# |    ent_coef        | 0.604    |
# |    ent_coef_loss   | -0.201   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2331     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 86.7     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 63       |
# |    time_elapsed    | 39       |
# |    total_timesteps | 2496     |
# | train/             |          |
# |    actor_loss      | -25.7    |
# |    critic_loss     | 4.8      |
# |    ent_coef        | 0.598    |
# |    ent_coef_loss   | -0.185   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2395     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 88.2     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 63       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 2560     |
# | train/             |          |
# |    actor_loss      | -29      |
# |    critic_loss     | 6.69     |
# |    ent_coef        | 0.592    |
# |    ent_coef_loss   | -0.262   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2459     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 89.5     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 62       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 2624     |
# | train/             |          |
# |    actor_loss      | -31.7    |
# |    critic_loss     | 4.55     |
# |    ent_coef        | 0.586    |
# |    ent_coef_loss   | -0.151   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2523     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 91.3     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 62       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 2688     |
# | train/             |          |
# |    actor_loss      | -29.2    |
# |    critic_loss     | 5.74     |
# |    ent_coef        | 0.58     |
# |    ent_coef_loss   | -0.245   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2587     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 91.8     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 62       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 2752     |
# | train/             |          |
# |    actor_loss      | -29.6    |
# |    critic_loss     | 5.93     |
# |    ent_coef        | 0.575    |
# |    ent_coef_loss   | -0.195   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2651     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 92.8     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 62       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 2816     |
# | train/             |          |
# |    actor_loss      | -32      |
# |    critic_loss     | 4.71     |
# |    ent_coef        | 0.57     |
# |    ent_coef_loss   | -0.164   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2715     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 93.1     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 62       |
# |    time_elapsed    | 46       |
# |    total_timesteps | 2880     |
# | train/             |          |
# |    actor_loss      | -33.1    |
# |    critic_loss     | 6.82     |
# |    ent_coef        | 0.566    |
# |    ent_coef_loss   | -0.0464  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2779     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 92.8     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 62       |
# |    time_elapsed    | 47       |
# |    total_timesteps | 2944     |
# | train/             |          |
# |    actor_loss      | -37.4    |
# |    critic_loss     | 7        |
# |    ent_coef        | 0.561    |
# |    ent_coef_loss   | -0.173   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2843     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 93.6     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 62       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 3008     |
# | train/             |          |
# |    actor_loss      | -34.9    |
# |    critic_loss     | 7        |
# |    ent_coef        | 0.556    |
# |    ent_coef_loss   | -0.155   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2907     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 93.5     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 62       |
# |    time_elapsed    | 49       |
# |    total_timesteps | 3072     |
# | train/             |          |
# |    actor_loss      | -34.3    |
# |    critic_loss     | 5.32     |
# |    ent_coef        | 0.551    |
# |    ent_coef_loss   | -0.111   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2971     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 94.1     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 61       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 3136     |
# | train/             |          |
# |    actor_loss      | -33.7    |
# |    critic_loss     | 3.94     |
# |    ent_coef        | 0.547    |
# |    ent_coef_loss   | -0.209   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3035     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 94.3     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 61       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | -37.8    |
# |    critic_loss     | 5.84     |
# |    ent_coef        | 0.542    |
# |    ent_coef_loss   | -0.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 94.7     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 61       |
# |    time_elapsed    | 52       |
# |    total_timesteps | 3264     |
# | train/             |          |
# |    actor_loss      | -37.6    |
# |    critic_loss     | 4.63     |
# |    ent_coef        | 0.538    |
# |    ent_coef_loss   | -0.204   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3163     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 94.7     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 61       |
# |    time_elapsed    | 53       |
# |    total_timesteps | 3328     |
# | train/             |          |
# |    actor_loss      | -34.9    |
# |    critic_loss     | 5.72     |
# |    ent_coef        | 0.534    |
# |    ent_coef_loss   | -0.148   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3227     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 95.5     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 61       |
# |    time_elapsed    | 55       |
# |    total_timesteps | 3392     |
# | train/             |          |
# |    actor_loss      | -41.9    |
# |    critic_loss     | 6.67     |
# |    ent_coef        | 0.53     |
# |    ent_coef_loss   | -0.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3291     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 95.7     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 61       |
# |    time_elapsed    | 56       |
# |    total_timesteps | 3456     |
# | train/             |          |
# |    actor_loss      | -44.1    |
# |    critic_loss     | 3.71     |
# |    ent_coef        | 0.526    |
# |    ent_coef_loss   | -0.151   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3355     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 96.3     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 61       |
# |    time_elapsed    | 57       |
# |    total_timesteps | 3520     |
# | train/             |          |
# |    actor_loss      | -42      |
# |    critic_loss     | 4.17     |
# |    ent_coef        | 0.522    |
# |    ent_coef_loss   | -0.104   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3419     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 96.4     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 61       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 3584     |
# | train/             |          |
# |    actor_loss      | -43.3    |
# |    critic_loss     | 5.89     |
# |    ent_coef        | 0.519    |
# |    ent_coef_loss   | -0.231   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3483     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 97.3     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 61       |
# |    time_elapsed    | 59       |
# |    total_timesteps | 3648     |
# | train/             |          |
# |    actor_loss      | -41.9    |
# |    critic_loss     | 5.09     |
# |    ent_coef        | 0.516    |
# |    ent_coef_loss   | -0.119   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3547     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 98       |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 60       |
# |    time_elapsed    | 60       |
# |    total_timesteps | 3712     |
# | train/             |          |
# |    actor_loss      | -44.9    |
# |    critic_loss     | 3.88     |
# |    ent_coef        | 0.512    |
# |    ent_coef_loss   | -0.202   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3611     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 98.8     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 60       |
# |    time_elapsed    | 62       |
# |    total_timesteps | 3776     |
# | train/             |          |
# |    actor_loss      | -46      |
# |    critic_loss     | 5.31     |
# |    ent_coef        | 0.508    |
# |    ent_coef_loss   | -0.115   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3675     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 99.7     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 60       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 3840     |
# | train/             |          |
# |    actor_loss      | -46.2    |
# |    critic_loss     | 5.23     |
# |    ent_coef        | 0.505    |
# |    ent_coef_loss   | 0.00511  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3739     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 60       |
# |    time_elapsed    | 64       |
# |    total_timesteps | 3904     |
# | train/             |          |
# |    actor_loss      | -49      |
# |    critic_loss     | 4        |
# |    ent_coef        | 0.501    |
# |    ent_coef_loss   | -0.166   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3803     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 60       |
# |    time_elapsed    | 65       |
# |    total_timesteps | 3968     |
# | train/             |          |
# |    actor_loss      | -47.3    |
# |    critic_loss     | 3.68     |
# |    ent_coef        | 0.497    |
# |    ent_coef_loss   | -0.194   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3867     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 60       |
# |    time_elapsed    | 67       |
# |    total_timesteps | 4032     |
# | train/             |          |
# |    actor_loss      | -49.1    |
# |    critic_loss     | 4.62     |
# |    ent_coef        | 0.493    |
# |    ent_coef_loss   | -0.193   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3931     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 60       |
# |    time_elapsed    | 68       |
# |    total_timesteps | 4096     |
# | train/             |          |
# |    actor_loss      | -45.9    |
# |    critic_loss     | 4.62     |
# |    ent_coef        | 0.489    |
# |    ent_coef_loss   | -0.285   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3995     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 59       |
# |    time_elapsed    | 69       |
# |    total_timesteps | 4160     |
# | train/             |          |
# |    actor_loss      | -51.3    |
# |    critic_loss     | 4.21     |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -0.214   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4059     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 59       |
# |    time_elapsed    | 70       |
# |    total_timesteps | 4224     |
# | train/             |          |
# |    actor_loss      | -51.5    |
# |    critic_loss     | 4.56     |
# |    ent_coef        | 0.48     |
# |    ent_coef_loss   | -0.201   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4123     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 59       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 4288     |
# | train/             |          |
# |    actor_loss      | -47.9    |
# |    critic_loss     | 3.86     |
# |    ent_coef        | 0.476    |
# |    ent_coef_loss   | -0.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4187     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 59       |
# |    time_elapsed    | 73       |
# |    total_timesteps | 4352     |
# | train/             |          |
# |    actor_loss      | -53.3    |
# |    critic_loss     | 3.68     |
# |    ent_coef        | 0.47     |
# |    ent_coef_loss   | -0.227   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4251     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 59       |
# |    time_elapsed    | 74       |
# |    total_timesteps | 4416     |
# | train/             |          |
# |    actor_loss      | -49.5    |
# |    critic_loss     | 2.95     |
# |    ent_coef        | 0.465    |
# |    ent_coef_loss   | -0.00175 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4315     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 59       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 4480     |
# | train/             |          |
# |    actor_loss      | -51.1    |
# |    critic_loss     | 2.94     |
# |    ent_coef        | 0.459    |
# |    ent_coef_loss   | 0.0104   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4379     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 59       |
# |    time_elapsed    | 76       |
# |    total_timesteps | 4544     |
# | train/             |          |
# |    actor_loss      | -50.6    |
# |    critic_loss     | 3.34     |
# |    ent_coef        | 0.453    |
# |    ent_coef_loss   | -0.0917  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4443     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 59       |
# |    time_elapsed    | 77       |
# |    total_timesteps | 4608     |
# | train/             |          |
# |    actor_loss      | -53.1    |
# |    critic_loss     | 3.03     |
# |    ent_coef        | 0.447    |
# |    ent_coef_loss   | -0.202   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4507     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 59       |
# |    time_elapsed    | 79       |
# |    total_timesteps | 4672     |
# | train/             |          |
# |    actor_loss      | -55.5    |
# |    critic_loss     | 4.67     |
# |    ent_coef        | 0.44     |
# |    ent_coef_loss   | -0.403   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4571     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 58       |
# |    time_elapsed    | 80       |
# |    total_timesteps | 4736     |
# | train/             |          |
# |    actor_loss      | -53.5    |
# |    critic_loss     | 2.7      |
# |    ent_coef        | 0.433    |
# |    ent_coef_loss   | -0.136   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4635     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 58       |
# |    time_elapsed    | 81       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -52.8    |
# |    critic_loss     | 3.75     |
# |    ent_coef        | 0.427    |
# |    ent_coef_loss   | -0.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 58       |
# |    time_elapsed    | 82       |
# |    total_timesteps | 4864     |
# | train/             |          |
# |    actor_loss      | -54.1    |
# |    critic_loss     | 2.49     |
# |    ent_coef        | 0.42     |
# |    ent_coef_loss   | -0.24    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4763     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 58       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 4928     |
# | train/             |          |
# |    actor_loss      | -56.6    |
# |    critic_loss     | 2.49     |
# |    ent_coef        | 0.413    |
# |    ent_coef_loss   | -0.396   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4827     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 58       |
# |    time_elapsed    | 85       |
# |    total_timesteps | 4992     |
# | train/             |          |
# |    actor_loss      | -59.4    |
# |    critic_loss     | 2.28     |
# |    ent_coef        | 0.407    |
# |    ent_coef_loss   | -0.382   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4891     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 58       |
# |    time_elapsed    | 86       |
# |    total_timesteps | 5056     |
# | train/             |          |
# |    actor_loss      | -54.5    |
# |    critic_loss     | 2.12     |
# |    ent_coef        | 0.4      |
# |    ent_coef_loss   | -0.312   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4955     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 58       |
# |    time_elapsed    | 87       |
# |    total_timesteps | 5120     |
# | train/             |          |
# |    actor_loss      | -54.4    |
# |    critic_loss     | 3.47     |
# |    ent_coef        | 0.392    |
# |    ent_coef_loss   | -0.287   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5019     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 58       |
# |    time_elapsed    | 88       |
# |    total_timesteps | 5184     |
# | train/             |          |
# |    actor_loss      | -55      |
# |    critic_loss     | 3.69     |
# |    ent_coef        | 0.386    |
# |    ent_coef_loss   | -0.307   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5083     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 58       |
# |    time_elapsed    | 90       |
# |    total_timesteps | 5248     |
# | train/             |          |
# |    actor_loss      | -56.4    |
# |    critic_loss     | 2.11     |
# |    ent_coef        | 0.379    |
# |    ent_coef_loss   | -0.404   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5147     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 58       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 5312     |
# | train/             |          |
# |    actor_loss      | -55.2    |
# |    critic_loss     | 1.59     |
# |    ent_coef        | 0.373    |
# |    ent_coef_loss   | -0.308   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5211     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 107      |
# ...
# |    total_timesteps | 6464     |
# | train/             |          |
# |    actor_loss      | -67.1    |
# |    critic_loss     | 2.42     |
# |    ent_coef        | 0.291    |
# |    ent_coef_loss   | -0.248   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6363     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 56       |
# |    time_elapsed    | 115      |
# |    total_timesteps | 6528     |
# | train/             |          |
# |    actor_loss      | -66.1    |
# |    critic_loss     | 2.66     |
# |    ent_coef        | 0.287    |
# |    ent_coef_loss   | -0.354   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6427     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 56       |
# |    time_elapsed    | 116      |
# |    total_timesteps | 6592     |
# | train/             |          |
# |    actor_loss      | -66.4    |
# |    critic_loss     | 1.98     |
# |    ent_coef        | 0.284    |
# |    ent_coef_loss   | -0.175   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6491     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 127      |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 56       |
# |    time_elapsed    | 118      |
# |    total_timesteps | 6656     |
# | train/             |          |
# |    actor_loss      | -67.3    |
# |    critic_loss     | 1.98     |
# |    ent_coef        | 0.281    |
# |    ent_coef_loss   | -0.435   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6555     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 128      |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 56       |
# |    time_elapsed    | 119      |
# |    total_timesteps | 6720     |
# | train/             |          |
# |    actor_loss      | -68      |
# |    critic_loss     | 1.86     |
# |    ent_coef        | 0.278    |
# |    ent_coef_loss   | -0.371   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6619     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 129      |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 56       |
# |    time_elapsed    | 120      |
# |    total_timesteps | 6784     |
# | train/             |          |
# |    actor_loss      | -66.8    |
# |    critic_loss     | 2.96     |
# |    ent_coef        | 0.275    |
# |    ent_coef_loss   | -0.0914  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6683     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 129      |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 56       |
# |    time_elapsed    | 121      |
# |    total_timesteps | 6848     |
# | train/             |          |
# |    actor_loss      | -63.8    |
# |    critic_loss     | 1.97     |
# |    ent_coef        | 0.273    |
# |    ent_coef_loss   | -0.109   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6747     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 56       |
# |    time_elapsed    | 123      |
# |    total_timesteps | 6912     |
# | train/             |          |
# |    actor_loss      | -71.1    |
# |    critic_loss     | 2.52     |
# |    ent_coef        | 0.27     |
# |    ent_coef_loss   | -0.213   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6811     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 55       |
# |    time_elapsed    | 124      |
# |    total_timesteps | 6976     |
# | train/             |          |
# |    actor_loss      | -71.7    |
# |    critic_loss     | 2.79     |
# |    ent_coef        | 0.267    |
# |    ent_coef_loss   | -0.057   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6875     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 55       |
# |    time_elapsed    | 125      |
# |    total_timesteps | 7040     |
# | train/             |          |
# |    actor_loss      | -67.5    |
# |    critic_loss     | 2.6      |
# |    ent_coef        | 0.265    |
# |    ent_coef_loss   | -0.235   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6939     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 55       |
# |    time_elapsed    | 127      |
# |    total_timesteps | 7104     |
# | train/             |          |
# |    actor_loss      | -73.1    |
# |    critic_loss     | 3.35     |
# |    ent_coef        | 0.262    |
# |    ent_coef_loss   | -0.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7003     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 55       |
# |    time_elapsed    | 128      |
# |    total_timesteps | 7168     |
# | train/             |          |
# |    actor_loss      | -70.4    |
# |    critic_loss     | 2.49     |
# |    ent_coef        | 0.259    |
# |    ent_coef_loss   | 0.0531   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7067     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 55       |
# |    time_elapsed    | 129      |
# |    total_timesteps | 7232     |
# | train/             |          |
# |    actor_loss      | -72.5    |
# |    critic_loss     | 3.94     |
# |    ent_coef        | 0.256    |
# |    ent_coef_loss   | -0.177   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7131     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 55       |
# |    time_elapsed    | 131      |
# |    total_timesteps | 7296     |
# | train/             |          |
# |    actor_loss      | -67.8    |
# |    critic_loss     | 3.49     |
# |    ent_coef        | 0.253    |
# |    ent_coef_loss   | -0.286   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7195     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 55       |
# |    time_elapsed    | 132      |
# |    total_timesteps | 7360     |
# | train/             |          |
# |    actor_loss      | -71.4    |
# |    critic_loss     | 3.43     |
# |    ent_coef        | 0.25     |
# |    ent_coef_loss   | -0.378   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7259     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 55       |
# |    time_elapsed    | 133      |
# |    total_timesteps | 7424     |
# | train/             |          |
# |    actor_loss      | -73.9    |
# |    critic_loss     | 3.33     |
# |    ent_coef        | 0.247    |
# |    ent_coef_loss   | -0.324   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7323     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 55       |
# |    time_elapsed    | 135      |
# |    total_timesteps | 7488     |
# | train/             |          |
# |    actor_loss      | -76      |
# |    critic_loss     | 4.49     |
# |    ent_coef        | 0.245    |
# |    ent_coef_loss   | -0.407   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7387     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 132      |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 55       |
# |    time_elapsed    | 136      |
# |    total_timesteps | 7552     |
# | train/             |          |
# |    actor_loss      | -72.5    |
# |    critic_loss     | 6.36     |
# |    ent_coef        | 0.242    |
# |    ent_coef_loss   | -0.292   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7451     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 132      |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 55       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 7616     |
# | train/             |          |
# |    actor_loss      | -74.8    |
# |    critic_loss     | 4.39     |
# |    ent_coef        | 0.239    |
# |    ent_coef_loss   | -0.211   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7515     |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[212], line 12
#      10 policy_kwargs = dict(net_arch=dict(pi=[128, 128, 128], qf=[128, 128, 128]))
#      11 model = SAC("MlpPolicy", env, policy_kwargs=policy_kwargs, verbose=1,)
# ---> 12 model.learn(50000, progress_bar = True)
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/sac/sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/common/off_policy_algorithm.py:331, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     329         # Special case when the user passes `gradient_steps=0`
#     330         if gradient_steps > 0:
# --> 331             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     333 callback.on_training_end()
#     335 return self
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/sac/sac.py:281, in SAC.train(self, gradient_steps, batch_size)
#     279 self.actor.optimizer.zero_grad()
#     280 actor_loss.backward()
# --> 281 self.actor.optimizer.step()
#     283 # Update target networks
#     284 if gradient_step % self.target_update_interval == 0:
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/optim/optimizer.py:33, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      31 try:
#      32     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33     ret = func(self, *args, **kwargs)
#      34 finally:
#      35     torch.set_grad_enabled(prev_grad)
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/optim/adam.py:141, in Adam.step(self, closure)
#     130     beta1, beta2 = group['betas']
#     132     self._init_group(
#     133         group,
#     134         params_with_grad,
#    (...)
#     138         max_exp_avg_sqs,
#     139         state_steps)
# --> 141     adam(
#     142         params_with_grad,
#     143         grads,
#     144         exp_avgs,
#     145         exp_avg_sqs,
#     146         max_exp_avg_sqs,
#     147         state_steps,
#     148         amsgrad=group['amsgrad'],
#     149         beta1=beta1,
#     150         beta2=beta2,
#     151         lr=group['lr'],
#     152         weight_decay=group['weight_decay'],
#     153         eps=group['eps'],
#     154         maximize=group['maximize'],
#     155         foreach=group['foreach'],
#     156         capturable=group['capturable'],
#     157         differentiable=group['differentiable'],
#     158         fused=group['fused'],
#     159         grad_scale=getattr(self, "grad_scale", None),
#     160         found_inf=getattr(self, "found_inf", None),
#     161     )
#     163 return loss
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/optim/adam.py:281, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     278 else:
#     279     func = _single_tensor_adam
# --> 281 func(params,
#     282      grads,
#     283      exp_avgs,
#     284      exp_avg_sqs,
#     285      max_exp_avg_sqs,
#     286      state_steps,
#     287      amsgrad=amsgrad,
#     288      beta1=beta1,
#     289      beta2=beta2,
#     290      lr=lr,
#     291      weight_decay=weight_decay,
#     292      eps=eps,
#     293      maximize=maximize,
#     294      capturable=capturable,
#     295      differentiable=differentiable,
#     296      grad_scale=grad_scale,
#     297      found_inf=found_inf)
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/optim/adam.py:344, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     341     param = torch.view_as_real(param)
#     343 # Decay the first and second moment running average coefficient
# --> 344 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#     345 exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     347 if capturable or differentiable:
#
# KeyboardInterrupt:

# %%
env.graphOffers(0,450)
# Out:
# 16
# 16

# %%
env.log.getPeriod(0,450)
# Out:
#       rnd  period  step                                    bids  \
# 7200    0     450     0  [44.17999982833862, 80.2, 69.7, 100.0]
# 7201    0     450     1   [38.18705677986145, 80.2, 69.7, 86.9]
# 7202    0     450     2   [31.58971071243286, 80.2, 69.7, 76.3]
# 7203    0     450     3  [33.173930644989014, 62.3, 69.7, 76.3]
# 7204    0     450     4  [40.809863805770874, 62.3, 69.7, 61.5]
# 7205    0     450     5   [25.69015622138977, 62.3, 66.7, 61.5]
# 7206    0     450     6  [23.520880937576294, 62.3, 28.6, 61.5]
# 7207    0     450     7  [15.351784229278564, 56.4, 28.6, 61.5]
# 7208    0     450     8   [12.024950981140137, 56.4, 28.6, nan]
# 7209    0     450     9   [5.7601988315582275, 44.9, 28.6, nan]
# 7210    0     450    10    [3.6008715629577637, nan, 28.6, nan]
# 7211    0     450    11    [0.1837611198425293, nan, 17.4, nan]
# 7212    0     450    12     [0.6467700004577637, nan, nan, nan]
# 7213    0     450    13      [7.209688425064087, nan, nan, nan]
# 7214    0     450    14     [1.3059794902801514, nan, nan, nan]
# 7215    0     450    15     [2.0053505897521973, nan, nan, nan]
#
#                          asks  currentBid  currentBidIdx  currentAsk  \
# 7200     [0.8, 1.0, 2.4, 0.0]  100.000000              3         0.0
# 7201     [0.8, 1.0, 2.4, 6.0]   86.900000              3         0.8
# 7202    [13.2, 1.0, 2.4, 6.0]   80.200000              1         1.0
# 7203    [13.2, 2.8, 2.4, 6.0]   76.300000              3         2.4
# 7204    [13.2, 2.8, 2.8, 6.0]   69.700000              2         2.8
# 7205    [13.2, 4.4, 2.8, 6.0]   66.700000              2         2.8
# 7206    [13.2, 4.4, 3.7, 6.0]   62.300000              1         3.7
# 7207   [13.2, 4.4, 10.8, 6.0]   61.500000              3         4.4
# 7208   [13.2, 5.5, 10.8, 6.0]   56.400000              1         5.5
# 7209   [13.2, nan, 10.8, 6.0]   44.900000              1         6.0
# 7210  [13.2, nan, 10.8, 20.5]   28.600000              2        10.8
# 7211   [13.2, nan, nan, 20.5]   17.400000              2        13.2
# 7212   [14.7, nan, nan, 20.5]    0.646770              0        14.7
# 7213   [17.4, nan, nan, 20.5]    7.209688              0        17.4
# 7214    [nan, nan, nan, 20.5]    1.305979              0        20.5
# 7215    [nan, nan, nan, 21.7]    2.005351              0        21.7
#
#       currentAskIdx   buy   sell  price  sale  bprofit  sprofit
# 7200              3  True   True  50.00  True    50.00    50.00
# 7201              0  True   True  43.85  True    43.05    43.05
# 7202              1  True   True  40.60  True    39.60    39.60
# 7203              2  True   True  39.35  True    36.95    36.95
# 7204              1  True   True  36.25  True    33.45    33.45
# 7205              2  True   True  34.75  True    31.95    31.95
# 7206              2  True   True  33.00  True    29.30    29.30
# 7207              1  True   True  32.95  True    28.55    28.55
# 7208              1  True   True  30.95  True    25.45    25.45
# 7209              3  True   True  25.45  True    19.45    19.45
# 7210              2  True   True  19.70  True     8.90     8.90
# 7211              0  True   True  15.30  True     2.10     2.10
# 7212              0  True  False  14.70  True    58.70     0.00
# 7213              0  True  False  17.40  True    47.60     0.00
# 7214              3  True  False  20.50  True    24.30     0.00
# 7215              3  True  False  21.70  True     1.20     0.00
