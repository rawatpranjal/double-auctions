# %%
from setup import *
from agents import *
from env import *

# %%
buyerStrategies = ['DDPG', 'DDPG']
sellerStrategies = ['TruthTeller', 'TruthTeller', 'TruthTeller', 'TruthTeller', 'TruthTeller', 'TruthTeller']
gamereinforcers, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed = '1001', len(buyerStrategies), len(sellerStrategies), 3, 1, 10000, 9, 42
disclosure = ['rnd', 'period', 'step','currentBid','currentAsk','buy','sell','price','sale']
gameData = [gamereinforcers, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed] 
buyers, sellers = generateAgents(gameData,buyerStrategies,sellerStrategies,disclosure)
log = Log(gameData, buyerStrategies, sellerStrategies, disclosure)

#Hyperparameters
lr_mu        = 0.0005
lr_q         = 0.001
gamma        = 0.99
batch_size   = 32
buffer_limit = 50000
tau          = 0.005 # for target network soft update

for rnd in range(numRounds):
    roundData = roundSetup(*gameData)
    redemptionValues, tokenCosts, demand, supply, prices, peq, qeq  = roundData[0:7]
    [buyerReservationPrices, sellerReservationPrices, buyerSurplus, sellerSurplus, totalSurplus, buyerSurplusFrac, sellerSurplusFrac] = roundData[7:]
    log.addRound([rnd] + roundData)
    resetRounds(buyers, sellers, redemptionValues, tokenCosts)
    for period in range(numPeriods):
        resetPeriods(buyers, sellers)
        bids_ = []
        for step in range(numSteps):
            resetSteps(buyers, sellers)
            bids, asks = collectOffers(buyers, sellers)
            currentAsk, currentAskIdx, currentBid, currentBidIdx = bestOffers(bids, asks)
            price, buy, sell = trade(buyers, sellers, currentAsk, currentAskIdx, currentBid, currentBidIdx)
            bprofit, sprofit = 0, 0
            bids_.append(bids)
            if price > 0:
                buyers[currentBidIdx].transact(price)
                sellers[currentAskIdx].transact(price)
                bprofit = buyers[currentBidIdx].stepProfits
                sprofit = sellers[currentAskIdx].stepProfits
            log.addStep([rnd, period, step, bids, asks, currentBid, currentBidIdx, currentAsk, currentAskIdx, buy, sell, price, price>0, bprofit, sprofit])
            observe(buyers, sellers, log.disclose()) # observe new state
            updateStates(buyers, sellers)
        updatePolicy(buyers, sellers)
        
        if period % (numPeriods/1000) == 0:
            print(f'{period},{log.getPeriod(rnd, period).tail(100)[["bprofit", "currentBidIdx"]].groupby("currentBidIdx").sum().bprofit}, {np.nanmean(bids_, axis=0)}')
            #display(log.getPeriod(rnd, period).tail(100)[['sprofit', 'currentAskIdx']].groupby('currentAskIdx').sum())
            #display(log.getPeriod(rnd,period))
# Out:
# 0,currentBidIdx
# 0.0    146.1
# 1.0     86.6
# Name: bprofit, dtype: float64, [22.31666667 53.65      ]
# 10,currentBidIdx
# 0.0    144.30
# 1.0     89.35
# Name: bprofit, dtype: float64, [ 8.7 61.7]
# 20,currentBidIdx
# 0.0    144.3
# 1.0    108.6
# Name: bprofit, dtype: float64, [ 1.         48.86666667]
# 30,currentBidIdx
# 0.0    144.3
# 1.0    116.8
# Name: bprofit, dtype: float64, [ 1.  43.4]
# 40,currentBidIdx
# 0.0    144.3
# 1.0    127.6
# Name: bprofit, dtype: float64, [ 1.  36.2]
# 50,currentBidIdx
# 0.0    144.3
# 1.0    129.7
# Name: bprofit, dtype: float64, [ 1.  34.8]
# 60,currentBidIdx
# 0.0    144.30
# 1.0    130.05
# Name: bprofit, dtype: float64, [ 1.         34.56666667]
# 70,currentBidIdx
# 0.0    144.3
# 1.0    140.9
# Name: bprofit, dtype: float64, [ 5.51666667 27.33333333]
# 80,currentBidIdx
# 0.0    144.3
# 1.0    128.0
# Name: bprofit, dtype: float64, [12.7        35.93333333]
# 90,currentBidIdx
# 0.0    144.30
# 1.0    124.05
# Name: bprofit, dtype: float64, [19.26666667 38.56666667]
# 100,currentBidIdx
# 0.0    144.3
# 1.0    119.5
# Name: bprofit, dtype: float64, [18.85 41.6 ]
# 110,currentBidIdx
# 0.0    144.30
# 1.0    141.65
# Name: bprofit, dtype: float64, [17.18333333 26.83333333]
# 120,currentBidIdx
# 0.0    144.30
# 1.0    138.85
# Name: bprofit, dtype: float64, [15.68333333 28.7       ]
# 130,currentBidIdx
# 0.0    144.3
# 1.0    144.0
# Name: bprofit, dtype: float64, [18.21666667 25.26666667]
# 140,currentBidIdx
# 0.0    166.9
# 1.0    118.6
# Name: bprofit, dtype: float64, [21.78333333 24.62      ]
# 150,currentBidIdx
# 0.0    143.55
# 1.0    127.30
# Name: bprofit, dtype: float64, [29.36666667 36.4       ]
# 160,currentBidIdx
# 0.0    161.90
# 1.0    115.05
# Name: bprofit, dtype: float64, [29.96666667 28.24      ]
# 170,currentBidIdx
# 0.0    144.0
# 1.0    122.7
# Name: bprofit, dtype: float64, [28.33333333 39.46666667]
# 180,currentBidIdx
# 0.0    144.3
# 1.0    138.0
# Name: bprofit, dtype: float64, [23.06666667 29.26666667]
# 190,currentBidIdx
# 0.0    144.30
# 1.0    124.15
# Name: bprofit, dtype: float64, [13.2 38.5]
# 200,currentBidIdx
# 0.0    144.30
# 1.0    128.65
# Name: bprofit, dtype: float64, [16.23333333 35.5       ]
# 210,currentBidIdx
# 0.0    144.3
# 1.0    122.4
# Name: bprofit, dtype: float64, [24.95       39.66666667]
# 220,currentBidIdx
# 0.0    144.3
# 1.0    127.8
# Name: bprofit, dtype: float64, [20.83333333 36.06666667]
# 230,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.   1.]
# 240,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.          22.06666667]
# 250,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.          24.78333333]
# 260,currentBidIdx
# 0.0    90.20
# 1.0    84.25
# Name: bprofit, dtype: float64, [100.          25.56666667]
# 270,currentBidIdx
# 0.0    90.2
# 1.0    84.4
# Name: bprofit, dtype: float64, [100.          32.63333333]
# 280,currentBidIdx
# 0.0    90.20
# 1.0    81.25
# Name: bprofit, dtype: float64, [100.          36.76666667]
# 290,currentBidIdx
# 0.0    90.20
# 1.0    82.35
# Name: bprofit, dtype: float64, [100.          32.56666667]
# 300,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.          17.43333333]
# 310,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.          12.51666667]
# 320,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.           7.38333333]
# 330,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.   10.6]
# 340,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.    15.45]
# 350,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.           9.26666667]
# 360,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.           5.43333333]
# 370,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.    3.6]
# 380,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.           3.81666667]
# 390,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.           4.53333333]
# 400,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.     7.05]
# 410,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.     5.05]
# 420,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.          18.11666667]
# 430,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.   15.7]
# 440,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.    7.9]
# 450,currentBidIdx
# 0.0    90.2
# 1.0    86.0
# Name: bprofit, dtype: float64, [100.           5.78333333]
# 460,currentBidIdx
# 0.0    195.55
# 1.0     80.60
# Name: bprofit, dtype: float64, [16.475      13.23333333]
# 470,currentBidIdx
# 0.0    195.2
# 1.0     64.2
# Name: bprofit, dtype: float64, [16.85 27.6 ]
# 480,currentBidIdx
# 0.0    195.45
# 1.0     74.05
# Name: bprofit, dtype: float64, [16.325      19.18333333]
# 490,currentBidIdx
# 0.0    144.30
# 1.0    132.55
# Name: bprofit, dtype: float64, [11.2 32.9]
# 500,currentBidIdx
# 0.0    144.3
# 1.0    124.5
# Name: bprofit, dtype: float64, [ 2.5        38.26666667]
# 510,currentBidIdx
# 0.0    144.30
# 1.0    125.85
# Name: bprofit, dtype: float64, [ 2.86666667 37.36666667]
# 520,currentBidIdx
# 0.0    144.3
# 1.0    107.6
# Name: bprofit, dtype: float64, [ 1.         49.53333333]
# 530,currentBidIdx
# 0.0    144.3
# 1.0    110.6
# Name: bprofit, dtype: float64, [ 3.11666667 47.53333333]
# 540,currentBidIdx
# 0.0    144.30
# 1.0    118.55
# Name: bprofit, dtype: float64, [ 4.73333333 42.23333333]
# 550,currentBidIdx
# 0.0    144.30
# 1.0    107.65
# Name: bprofit, dtype: float64, [ 6.46666667 49.5       ]
# 560,currentBidIdx
# 0.0    144.30
# 1.0    103.25
# Name: bprofit, dtype: float64, [ 7.4        52.43333333]
# 570,currentBidIdx
# 0.0    144.3
# 1.0    100.0
# Name: bprofit, dtype: float64, [10.21666667 54.6       ]
# 580,currentBidIdx
# 0.0    144.30
# 1.0    107.05
# Name: bprofit, dtype: float64, [10.45 49.9 ]
# 590,currentBidIdx
# 0.0    144.3
# 1.0     97.3
# Name: bprofit, dtype: float64, [25.28333333 56.4       ]
# 600,currentBidIdx
# 0.0    133.65
# 1.0     95.20
# Name: bprofit, dtype: float64, [39.1 57.8]
# 610,currentBidIdx
# 0.0    140.60
# 1.0     90.85
# Name: bprofit, dtype: float64, [36.45 60.7 ]
# 620,currentBidIdx
# 0.0    141.85
# 1.0    101.85
# Name: bprofit, dtype: float64, [31.55       53.36666667]
# 630,currentBidIdx
# 0.0    141.75
# 1.0     93.50
# Name: bprofit, dtype: float64, [33.35       58.93333333]
# 640,currentBidIdx
# 0.0    134.0
# 1.0     89.5
# Name: bprofit, dtype: float64, [38.16666667 61.6       ]
# 650,currentBidIdx
# 0.0    127.0
# 1.0    100.7
# Name: bprofit, dtype: float64, [43.81666667 54.13333333]
# 660,currentBidIdx
# 0.0    134.6
# 1.0    102.1
# Name: bprofit, dtype: float64, [39.78333333 53.2       ]
# 670,currentBidIdx
# 0.0    143.45
# 1.0    113.80
# Name: bprofit, dtype: float64, [30.98333333 45.4       ]
# 680,currentBidIdx
# 0.0    141.80
# 1.0     94.85
# Name: bprofit, dtype: float64, [32.76666667 58.03333333]
# 690,currentBidIdx
# 0.0    137.6
# 1.0    101.5
# Name: bprofit, dtype: float64, [36.3 53.6]
# 700,currentBidIdx
# 0.0    138.90
# 1.0    106.95
# Name: bprofit, dtype: float64, [36.53333333 49.96666667]
# 710,currentBidIdx
# 0.0    126.15
# 1.0    103.40
# Name: bprofit, dtype: float64, [44.78333333 52.33333333]
# 720,currentBidIdx
# 0.0    122.85
# 1.0    104.70
# Name: bprofit, dtype: float64, [45.48333333 51.46666667]
# 730,currentBidIdx
# 0.0    115.20
# 1.0    101.05
# Name: bprofit, dtype: float64, [52.36666667 53.9       ]
# 740,currentBidIdx
# 0.0    155.1
# 1.0     86.0
# Name: bprofit, dtype: float64, [56.73333333 35.28333333]
# 750,currentBidIdx
# 0.0    150.15
# 1.0     86.00
# Name: bprofit, dtype: float64, [60.03333333 33.1       ]
# 760,currentBidIdx
# 0.0    146.15
# 1.0     86.00
# Name: bprofit, dtype: float64, [62.7  34.65]
# 770,currentBidIdx
# 0.0    160.45
# 1.0     86.00
# Name: bprofit, dtype: float64, [53.16666667 29.01666667]
# 780,currentBidIdx
# 0.0    148.1
# 1.0     94.9
# Name: bprofit, dtype: float64, [40.06       32.46666667]
# 790,currentBidIdx
# 0.0    141.85
# 1.0     96.35
# Name: bprofit, dtype: float64, [32.83333333 57.03333333]
# 800,currentBidIdx
# 0.0    144.3
# 1.0    102.1
# Name: bprofit, dtype: float64, [18.96666667 53.2       ]
# 810,currentBidIdx
# 0.0    144.3
# 1.0    101.0
# Name: bprofit, dtype: float64, [ 4.13333333 53.93333333]
# 820,currentBidIdx
# 0.0    144.30
# 1.0     94.85
# Name: bprofit, dtype: float64, [13.06666667 58.03333333]
# 830,currentBidIdx
# 0.0    144.30
# 1.0     88.55
# Name: bprofit, dtype: float64, [21.36666667 62.23333333]
# 840,currentBidIdx
# 0.0    144.30
# 1.0     90.75
# Name: bprofit, dtype: float64, [25.13333333 60.76666667]
# 850,currentBidIdx
# 0.0    144.3
# 1.0     81.5
# Name: bprofit, dtype: float64, [21.4        66.93333333]
# 860,currentBidIdx
# 0.0    144.3
# 1.0     79.4
# Name: bprofit, dtype: float64, [12.88333333 68.33333333]
# 870,currentBidIdx
# 0.0    144.30
# 1.0     84.05
# Name: bprofit, dtype: float64, [13.8        65.23333333]
# 880,currentBidIdx
# 0.0    144.3
# 1.0     92.2
# Name: bprofit, dtype: float64, [12.5 59.8]
# 890,currentBidIdx
# 0.0    144.3
# 1.0     77.5
# Name: bprofit, dtype: float64, [11.08333333 69.6       ]
# 900,currentBidIdx
# 0.0    144.3
# 1.0     71.7
# Name: bprofit, dtype: float64, [10.81666667 73.46666667]
# 910,currentBidIdx
# 0.0    144.30
# 1.0     76.85
# Name: bprofit, dtype: float64, [ 9.06666667 70.03333333]
# 920,currentBidIdx
# 0.0    144.30
# 1.0     70.85
# Name: bprofit, dtype: float64, [ 1.         74.03333333]
# 930,currentBidIdx
# 0.0    144.3
# 1.0     85.1
# Name: bprofit, dtype: float64, [ 1.         64.53333333]
# 940,currentBidIdx
# 0.0    144.3
# 1.0     74.3
# Name: bprofit, dtype: float64, [ 1.         71.73333333]
# 950,currentBidIdx
# 0.0    144.3
# 1.0     71.6
# Name: bprofit, dtype: float64, [ 1.         73.53333333]
# 960,currentBidIdx
# 0.0    144.3
# 1.0     76.2
# Name: bprofit, dtype: float64, [ 1.         70.46666667]
# 970,currentBidIdx
# 0.0    144.3
# 1.0     99.0
# Name: bprofit, dtype: float64, [ 1.         55.26666667]
# 980,currentBidIdx
# 0.0    144.30
# 1.0     96.95
# Name: bprofit, dtype: float64, [ 1.         56.63333333]
# 990,currentBidIdx
# 0.0    144.3
# 1.0     84.9
# Name: bprofit, dtype: float64, [ 1.         64.66666667]
# 1000,currentBidIdx
# 0.0    144.3
# 1.0     89.3
# Name: bprofit, dtype: float64, [ 1.         61.73333333]
# 1010,currentBidIdx
# 0.0    144.3
# 1.0     99.1
# Name: bprofit, dtype: float64, [ 1.  55.2]
# 1020,currentBidIdx
# 0.0    144.30
# 1.0     83.05
# Name: bprofit, dtype: float64, [ 1.  65.9]
# 1030,currentBidIdx
# 0.0    144.30
# 1.0     81.25
# Name: bprofit, dtype: float64, [ 1.  67.1]
# 1040,currentBidIdx
# 0.0    144.30
# 1.0     82.45
# Name: bprofit, dtype: float64, [ 1.  66.3]
# 1050,currentBidIdx
# 0.0    144.30
# 1.0     92.95
# Name: bprofit, dtype: float64, [ 1.  59.3]
# 1060,currentBidIdx
# 0.0    144.3
# 1.0     96.4
# Name: bprofit, dtype: float64, [ 1. 57.]
# 1070,currentBidIdx
# 0.0    144.3
# 1.0     90.9
# Name: bprofit, dtype: float64, [ 1.         60.66666667]
# 1080,currentBidIdx
# 0.0    144.30
# 1.0     95.25
# Name: bprofit, dtype: float64, [ 5.38333333 57.76666667]
# 1090,currentBidIdx
# 0.0    144.3
# 1.0     94.1
# Name: bprofit, dtype: float64, [ 1.         58.53333333]
# 1100,currentBidIdx
# 0.0    144.30
# 1.0     84.85
# Name: bprofit, dtype: float64, [ 1.  64.7]
# 1110,currentBidIdx
# 0.0    144.30
# 1.0     89.45
# Name: bprofit, dtype: float64, [ 1.         61.63333333]
# 1120,currentBidIdx
# 0.0    144.3
# 1.0     97.3
# Name: bprofit, dtype: float64, [ 1.  56.4]
# 1130,currentBidIdx
# 0.0    144.30
# 1.0    101.15
# Name: bprofit, dtype: float64, [ 1.         53.83333333]
# 1140,currentBidIdx
# 0.0    144.3
# 1.0     96.8
# Name: bprofit, dtype: float64, [ 1.         56.73333333]
# 1150,currentBidIdx
# 0.0    144.30
# 1.0    101.05
# Name: bprofit, dtype: float64, [ 4.01666667 53.9       ]
# 1160,currentBidIdx
# 0.0    144.30
# 1.0     86.65
# Name: bprofit, dtype: float64, [11.56666667 63.5       ]
# 1170,currentBidIdx
# 0.0    144.3
# 1.0     93.4
# Name: bprofit, dtype: float64, [14.71666667 59.        ]
# 1180,currentBidIdx
# 0.0    144.30
# 1.0     91.05
# Name: bprofit, dtype: float64, [ 1.         60.56666667]
# 1190,currentBidIdx
# 0.0    144.30
# 1.0     91.15
# Name: bprofit, dtype: float64, [ 1.36666667 60.5       ]
# 1200,currentBidIdx
# 0.0    144.30
# 1.0     83.05
# Name: bprofit, dtype: float64, [ 1.2 65.9]
# 1210,currentBidIdx
# 0.0    144.30
# 1.0     80.05
# Name: bprofit, dtype: float64, [ 1.  67.9]
# 1220,currentBidIdx
# 0.0    144.3
# 1.0     79.4
# Name: bprofit, dtype: float64, [ 6.76666667 68.33333333]
# 1230,currentBidIdx
# 0.0    144.3
# 1.0     83.8
# Name: bprofit, dtype: float64, [ 1.  65.4]
# 1240,currentBidIdx
# 0.0    144.3
# 1.0     83.4
# Name: bprofit, dtype: float64, [ 1.         65.66666667]
# 1250,currentBidIdx
# 0.0    144.3
# 1.0     89.3
# Name: bprofit, dtype: float64, [ 1.         61.73333333]
# 1260,currentBidIdx
# 0.0    144.30
# 1.0     86.55
# Name: bprofit, dtype: float64, [ 1.         63.56666667]
# 1270,currentBidIdx
# 0.0    144.3
# 1.0     88.2
# Name: bprofit, dtype: float64, [ 1.         62.46666667]
# 1280,currentBidIdx
# 0.0    144.3
# 1.0     75.3
# Name: bprofit, dtype: float64, [ 1.         71.06666667]
# 1290,currentBidIdx
# 0.0    144.30
# 1.0     78.85
# Name: bprofit, dtype: float64, [ 1.  68.7]
# 1300,currentBidIdx
# 0.0    144.30
# 1.0     84.45
# Name: bprofit, dtype: float64, [ 1.         64.96666667]
# 1310,currentBidIdx
# 0.0    144.3
# 1.0     76.8
# Name: bprofit, dtype: float64, [ 1.         70.06666667]
# 1320,currentBidIdx
# 0.0    144.30
# 1.0     89.05
# Name: bprofit, dtype: float64, [ 1.  61.9]
# 1330,currentBidIdx
# 0.0    144.3
# 1.0     82.3
# Name: bprofit, dtype: float64, [ 1.  66.4]
# 1340,currentBidIdx
# 0.0    144.30
# 1.0     92.25
# Name: bprofit, dtype: float64, [ 1.         59.76666667]
# 1350,currentBidIdx
# 0.0    144.30
# 1.0     87.15
# Name: bprofit, dtype: float64, [ 1.11666667 63.16666667]
# 1360,currentBidIdx
# 0.0    144.3
# 1.0     98.7
# Name: bprofit, dtype: float64, [ 2.63333333 55.46666667]
# 1370,currentBidIdx
# 0.0    144.3
# 1.0     92.9
# Name: bprofit, dtype: float64, [19.75       59.33333333]
# 1380,currentBidIdx
# 0.0    144.3
# 1.0    100.2
# Name: bprofit, dtype: float64, [19.75       54.46666667]
# 1390,currentBidIdx
# 0.0    144.3
# 1.0    106.0
# Name: bprofit, dtype: float64, [21.78333333 50.6       ]
# 1400,currentBidIdx
# 0.0    144.30
# 1.0     86.85
# Name: bprofit, dtype: float64, [ 8.68333333 63.36666667]
# 1410,currentBidIdx
# 0.0    144.30
# 1.0     83.75
# Name: bprofit, dtype: float64, [10.66666667 65.43333333]
# 1420,currentBidIdx
# 0.0    144.30
# 1.0     96.05
# Name: bprofit, dtype: float64, [17.83333333 57.23333333]
# 1430,currentBidIdx
# 0.0    142.6
# 1.0     93.2
# Name: bprofit, dtype: float64, [23.7        59.13333333]
# 1440,currentBidIdx
# 0.0    144.3
# 1.0    111.6
# Name: bprofit, dtype: float64, [13.35       46.86666667]
# 1450,currentBidIdx
# 0.0    144.3
# 1.0    112.3
# Name: bprofit, dtype: float64, [11.36666667 46.4       ]
# 1460,currentBidIdx
# 0.0    144.30
# 1.0    117.95
# Name: bprofit, dtype: float64, [13.41666667 42.63333333]
# 1470,currentBidIdx
# 0.0    144.3
# 1.0    115.2
# Name: bprofit, dtype: float64, [ 6.15       44.46666667]
# 1480,currentBidIdx
# 0.0    144.30
# 1.0    112.35
# Name: bprofit, dtype: float64, [ 2.83333333 46.36666667]
# 1490,currentBidIdx
# 0.0    144.3
# 1.0    120.2
# Name: bprofit, dtype: float64, [ 1.8        41.13333333]
# 1500,currentBidIdx
# 0.0    144.3
# 1.0    122.0
# Name: bprofit, dtype: float64, [ 1.91666667 39.93333333]
# 1510,currentBidIdx
# 0.0    144.3
# 1.0    110.4
# Name: bprofit, dtype: float64, [ 3.2        47.66666667]
# 1520,currentBidIdx
# 0.0    144.3
# 1.0    120.9
# Name: bprofit, dtype: float64, [ 2.73333333 40.66666667]
# 1530,currentBidIdx
# 0.0    144.30
# 1.0    120.95
# Name: bprofit, dtype: float64, [ 2.86666667 40.63333333]
# 1540,currentBidIdx
# 0.0    144.3
# 1.0    121.1
# Name: bprofit, dtype: float64, [ 7.98333333 40.53333333]
# 1550,currentBidIdx
# 0.0    150.05
# 1.0    117.85
# Name: bprofit, dtype: float64, [16.2 33. ]
# 1560,currentBidIdx
# 0.0    141.50
# 1.0    132.55
# Name: bprofit, dtype: float64, [19.38333333 21.1       ]
# 1570,currentBidIdx
# 0.0    141.75
# 1.0    124.25
# Name: bprofit, dtype: float64, [24.54       11.96666667]
# 1580,currentBidIdx
# 0.0    158.35
# 1.0    103.00
# Name: bprofit, dtype: float64, [35.6 10.4]
# 1590,currentBidIdx
# 0.0    165.15
# 1.0    101.30
# Name: bprofit, dtype: float64, [25.15 19.05]
# 1600,currentBidIdx
# 0.0    138.4
# 1.0    130.4
# Name: bprofit, dtype: float64, [23.03333333 23.1       ]
# 1610,currentBidIdx
# 0.0    142.95
# 1.0    137.20
# Name: bprofit, dtype: float64, [17.55 16.2 ]
# 1620,currentBidIdx
# 0.0    147.00
# 1.0    138.05
# Name: bprofit, dtype: float64, [13.25 16.3 ]
# 1630,currentBidIdx
# 0.0    145.95
# 1.0    131.10
# Name: bprofit, dtype: float64, [16.05 23.45]
# 1640,currentBidIdx
# 0.0    138.75
# 1.0    129.40
# Name: bprofit, dtype: float64, [23.46666667 32.95      ]
# 1650,currentBidIdx
# 0.0    156.50
# 1.0    103.75
# Name: bprofit, dtype: float64, [37.8        23.23333333]
# 1660,currentBidIdx
# 0.0    160.9
# 1.0    111.9
# Name: bprofit, dtype: float64, [26.78       16.76666667]
# 1670,currentBidIdx
# 0.0    161.3
# 1.0    104.3
# Name: bprofit, dtype: float64, [31.825      18.96666667]
# 1680,currentBidIdx
# 0.0    175.8
# 1.0     86.0
# Name: bprofit, dtype: float64, [42.93333333 11.08333333]
# 1690,currentBidIdx
# 0.0    168.55
# 1.0     86.00
# Name: bprofit, dtype: float64, [47.76666667 18.11666667]
# 1700,currentBidIdx
# 0.0    154.45
# 1.0     86.00
# Name: bprofit, dtype: float64, [57.16666667 14.51666667]
# 1710,currentBidIdx
# 0.0    159.05
# 1.0     86.00
# Name: bprofit, dtype: float64, [54.1        12.61666667]
# 1720,currentBidIdx
# 0.0    162.8
# 1.0     86.0
# Name: bprofit, dtype: float64, [51.6  15.45]
# 1730,currentBidIdx
# 0.0    152.10
# 1.0    104.85
# Name: bprofit, dtype: float64, [37.4        19.46666667]
# 1740,currentBidIdx
# 0.0    142.00
# 1.0    100.45
# Name: bprofit, dtype: float64, [43.375 26.15 ]
# 1750,currentBidIdx
# 0.0    124.05
# 1.0    111.15
# Name: bprofit, dtype: float64, [46.7 23.7]
# 1760,currentBidIdx
# 0.0    141.85
# 1.0    104.95
# Name: bprofit, dtype: float64, [43.35       22.01666667]
# 1770,currentBidIdx
# 0.0    140.80
# 1.0    100.35
# Name: bprofit, dtype: float64, [45.65 26.95]
# 1780,currentBidIdx
# 0.0    123.25
# 1.0    109.20
# Name: bprofit, dtype: float64, [47.52       26.26666667]
# 1790,currentBidIdx
# 0.0    167.05
# 1.0     86.00
# Name: bprofit, dtype: float64, [48.76666667 13.46666667]
# 1800,currentBidIdx
# 0.0    166.05
# 1.0     86.00
# Name: bprofit, dtype: float64, [49.43333333  7.96666667]
# 1810,currentBidIdx
# 0.0    161.2
# 1.0     86.0
# Name: bprofit, dtype: float64, [52.66666667  6.65      ]
# 1820,currentBidIdx
# 0.0    157.55
# 1.0     86.00
# Name: bprofit, dtype: float64, [55.1         7.31666667]
# 1830,currentBidIdx
# 0.0    156.2
# 1.0     86.0
# Name: bprofit, dtype: float64, [56.    5.85]
# 1840,currentBidIdx
# 0.0    162.65
# 1.0     86.00
# Name: bprofit, dtype: float64, [51.7   5.05]
# 1850,currentBidIdx
# 0.0    159.2
# 1.0     86.0
# Name: bprofit, dtype: float64, [54.          6.26666667]
# 1860,currentBidIdx
# 0.0    150.9
# 1.0     86.0
# Name: bprofit, dtype: float64, [59.53333333  7.61666667]
# 1870,currentBidIdx
# 0.0    158.2
# 1.0     86.0
# Name: bprofit, dtype: float64, [54.66666667  7.5       ]
# 1880,currentBidIdx
# 0.0    165.3
# 1.0     86.0
# Name: bprofit, dtype: float64, [49.93333333  5.75      ]
# 1890,currentBidIdx
# 0.0    167.7
# 1.0     86.0
# Name: bprofit, dtype: float64, [48.33333333  8.66666667]
# 1900,currentBidIdx
# 0.0    174.75
# 1.0     86.00
# Name: bprofit, dtype: float64, [43.03333333  6.63333333]
# 1910,currentBidIdx
# 0.0    146.70
# 1.0    110.95
# Name: bprofit, dtype: float64, [33.85  9.  ]
# 1920,currentBidIdx
# 0.0    175.15
# 1.0     86.00
# Name: bprofit, dtype: float64, [42.76666667  4.81666667]
# 1930,currentBidIdx
# 0.0    177.0
# 1.0     86.0
# Name: bprofit, dtype: float64, [41.53333333  5.31666667]
# 1940,currentBidIdx
# 0.0    173.0
# 1.0     86.0
# Name: bprofit, dtype: float64, [44.2         4.71666667]
# 1950,currentBidIdx
# 0.0    172.55
# 1.0     86.00
# Name: bprofit, dtype: float64, [44.5         2.68333333]
# 1960,currentBidIdx
# 0.0    166.25
# 1.0     86.00
# Name: bprofit, dtype: float64, [49.3  3. ]
# 1970,currentBidIdx
# 0.0    160.8
# 1.0     86.0
# Name: bprofit, dtype: float64, [52.93333333  2.96666667]
# 1980,currentBidIdx
# 0.0    150.05
# 1.0     86.00
# Name: bprofit, dtype: float64, [60.1   2.35]
# 1990,currentBidIdx
# 0.0    155.65
# 1.0     86.00
# Name: bprofit, dtype: float64, [56.36666667  3.01666667]
# 2000,currentBidIdx
# 0.0    156.3
# 1.0     86.0
# Name: bprofit, dtype: float64, [55.93333333  3.23333333]
# 2010,currentBidIdx
# 0.0    167.35
# 1.0     86.00
# Name: bprofit, dtype: float64, [48.56666667  4.93333333]
# 2020,currentBidIdx
# 0.0    167.9
# 1.0     86.0
# Name: bprofit, dtype: float64, [48.2         4.73333333]
# 2030,currentBidIdx
# 0.0    160.5
# 1.0     86.0
# Name: bprofit, dtype: float64, [53.13333333  5.26666667]
# 2040,currentBidIdx
# 0.0    169.5
# 1.0     86.0
# Name: bprofit, dtype: float64, [47.13333333  6.58333333]
# 2050,currentBidIdx
# 0.0    165.8
# 1.0     86.0
# Name: bprofit, dtype: float64, [49.6         8.31666667]
# 2060,currentBidIdx
# 0.0    164.6
# 1.0     86.0
# Name: bprofit, dtype: float64, [50.4        11.31666667]
# 2070,currentBidIdx
# 0.0    174.15
# 1.0     86.00
# Name: bprofit, dtype: float64, [43.43333333  8.        ]
# 2080,currentBidIdx
# 0.0    175.2
# 1.0     86.0
# Name: bprofit, dtype: float64, [42.73333333  7.51666667]
# 2090,currentBidIdx
# 0.0    175.35
# 1.0     86.00
# Name: bprofit, dtype: float64, [42.63333333  7.33333333]
# 2100,currentBidIdx
# 0.0    178.55
# 1.0     86.00
# Name: bprofit, dtype: float64, [40.5         7.83333333]
# 2110,currentBidIdx
# 0.0    175.1
# 1.0     86.0
# Name: bprofit, dtype: float64, [42.8  7.6]
# 2120,currentBidIdx
# 0.0    176.15
# 1.0     86.00
# Name: bprofit, dtype: float64, [42.1         7.88333333]
# 2130,currentBidIdx
# 0.0    169.85
# 1.0     86.00
# Name: bprofit, dtype: float64, [46.9         7.46666667]
# 2140,currentBidIdx
# 0.0    149.85
# 1.0    111.40
# Name: bprofit, dtype: float64, [32.275       8.11666667]
# 2150,currentBidIdx
# 0.0    152.3
# 1.0    111.4
# Name: bprofit, dtype: float64, [31.05  8.45]
# 2160,currentBidIdx
# 0.0    177.65
# 1.0     86.00
# Name: bprofit, dtype: float64, [41.1         7.36666667]
# 2170,currentBidIdx
# 0.0    191.4
# 1.0     86.0
# Name: bprofit, dtype: float64, [31.93333333  7.73333333]
# 2180,currentBidIdx
# 0.0    184.35
# 1.0     86.00
# Name: bprofit, dtype: float64, [36.63333333  5.93333333]
# 2190,currentBidIdx
# 0.0    186.9
# 1.0     86.0
# Name: bprofit, dtype: float64, [34.93333333  6.26666667]
# 2200,currentBidIdx
# 0.0    158.15
# 1.0    108.60
# Name: bprofit, dtype: float64, [28.125 13.2  ]
# 2210,currentBidIdx
# 0.0    182.55
# 1.0     86.00
# Name: bprofit, dtype: float64, [37.83333333  8.76666667]
# 2220,currentBidIdx
# 0.0    181.3
# 1.0     86.0
# Name: bprofit, dtype: float64, [38.66666667  8.15      ]
# 2230,currentBidIdx
# 0.0    175.35
# 1.0     86.00
# Name: bprofit, dtype: float64, [43.23333333  7.66666667]
# 2240,currentBidIdx
# 0.0    157.8
# 1.0    110.1
# Name: bprofit, dtype: float64, [28.3 11.9]
# 2250,currentBidIdx
# 0.0    104.6
# 1.0    127.3
# Name: bprofit, dtype: float64, [37.1  26.02]
# 2260,currentBidIdx
# 0.0    150.25
# 1.0    101.85
# Name: bprofit, dtype: float64, [32.175 26.85 ]
# 2270,currentBidIdx
# 0.0    107.3
# 1.0    122.9
# Name: bprofit, dtype: float64, [35.83333333 27.66      ]
# 2280,currentBidIdx
# 0.0    111.70
# 1.0    128.95
# Name: bprofit, dtype: float64, [30.03333333 28.25      ]
# 2290,currentBidIdx
# 0.0    123.55
# 1.0    120.95
# Name: bprofit, dtype: float64, [25.63333333 28.82      ]
# 2300,currentBidIdx
# 0.0    137.05
# 1.0    127.70
# Name: bprofit, dtype: float64, [14.11666667 35.075     ]
# 2310,currentBidIdx
# 0.0    125.20
# 1.0    119.05
# Name: bprofit, dtype: float64, [24.4  29.58]
# 2320,currentBidIdx
# 0.0    134.6
# 1.0    119.6
# Name: bprofit, dtype: float64, [16.61666667 36.025     ]
# 2330,currentBidIdx
# 0.0    144.30
# 1.0    119.35
# Name: bprofit, dtype: float64, [11.53333333 41.7       ]
# 2340,currentBidIdx
# 0.0    144.30
# 1.0    130.65
# Name: bprofit, dtype: float64, [10.26666667 34.16666667]
# 2350,currentBidIdx
# 0.0    144.3
# 1.0    115.7
# Name: bprofit, dtype: float64, [13.05       44.13333333]
# 2360,currentBidIdx
# 0.0    135.55
# 1.0    131.30
# Name: bprofit, dtype: float64, [15.8  30.15]
# 2370,currentBidIdx
# 0.0    144.3
# 1.0     95.7
# Name: bprofit, dtype: float64, [11.73333333 57.46666667]
# 2380,currentBidIdx
# 0.0    144.30
# 1.0    106.95
# Name: bprofit, dtype: float64, [15.85       49.96666667]

# %%
log.getPeriod(0,2450)
# Out:
#        rnd  period  step         bids                                  asks  \
# 22050    0    2450     0  [1.0, 13.4]     [1.0, 34.6, 41.6, 0.0, 28.2, 2.8]
# 22051    0    2450     1  [9.9, 51.3]    [1.0, 34.6, 41.6, 35.0, 28.2, 2.8]
# 22052    0    2450     2  [8.2, 20.5]   [51.3, 34.6, 41.6, 35.0, 28.2, 2.8]
# 22053    0    2450     3   [5.6, nan]  [51.3, 34.6, 41.6, 35.0, 28.2, 38.9]
# 22054    0    2450     4   [7.0, nan]  [51.3, 34.6, 41.6, 35.0, 54.1, 38.9]
# 22055    0    2450     5  [11.4, nan]  [51.3, 41.4, 41.6, 35.0, 54.1, 38.9]
# 22056    0    2450     6   [nan, nan]  [51.3, 41.4, 41.6, 43.3, 54.1, 38.9]
# 22057    0    2450     7   [nan, nan]  [51.3, 41.4, 41.6, 43.3, 54.1, 38.9]
# 22058    0    2450     8   [nan, nan]  [51.3, 41.4, 41.6, 43.3, 54.1, 38.9]
#
#        currentBid  currentBidIdx  currentAsk  currentAskIdx   buy   sell  \
# 22050        13.4            1.0         0.0              3  True   True
# 22051        51.3            1.0         1.0              0  True   True
# 22052        20.5            1.0         2.8              5  True   True
# 22053         5.6            0.0        28.2              4  True  False
# 22054         7.0            0.0        34.6              1  True  False
# 22055        11.4            0.0        35.0              3  True  False
# 22056         NaN            NaN        38.9              5   NaN    NaN
# 22057         NaN            NaN        38.9              5   NaN    NaN
# 22058         NaN            NaN        38.9              5   NaN    NaN
#
#        price   sale  bprofit  sprofit
# 22050   6.70   True    60.10     6.70
# 22051  26.15   True    40.05    25.15
# 22052  11.65   True    39.15     8.85
# 22053  28.20   True    71.80     0.00
# 22054  34.60   True    58.40     0.00
# 22055  35.00   True    14.10     0.00
# 22056    NaN  False     0.00     0.00
# 22057    NaN  False     0.00     0.00
# 22058    NaN  False     0.00     0.00

# %%
class DDPG(Trader):
    def __init__(self, gameData, disclosure, index, buyer, reinforcer):
        super().__init__(gameData, disclosure, index, buyer, reinforcer)
        self.numActions = 100
        self.depth = 20
        self.numStates = 8 + 6 * self.depth
        history = [-1] * self.numStates
        self.state = np.nan_to_num(np.array(history, dtype = np.float32), nan=-9)  
        self.memory = ReplayBuffer()
        self.q, self.q_target = QNet(self.numStates), QNet(self.numStates)
        self.q_target.load_state_dict(self.q.state_dict())
        self.mu, self.mu_target = MuNet(self.numStates), MuNet(self.numStates)
        self.mu_target.load_state_dict(self.mu.state_dict())
        self.mu_optimizer = optim.Adam(self.mu.parameters(), lr=lr_mu)
        self.q_optimizer  = optim.Adam(self.q.parameters(), lr=lr_q)
        self.ou_noise = OrnsteinUhlenbeckNoise(mu=np.zeros(1))
        self.done = False

    def observe(self):
        agentState = [self.periodStep, self.stepTokenValue, self.stepBid, self.stepAsk, self.stepTrades, self.stepProfits, self.periodTrades, self.periodProfits]
        history = self.df.iloc[-self.depth:][['currentBid', 'currentAsk', 'buy', 'sell', 'price', 'price']].values.reshape(-1,).tolist()
        if len(history) != (6 * self.depth):
            history = [-1] * (6 * self.depth)
        self.newState = np.nan_to_num(np.array(agentState + history, dtype = np.float32), nan=-9)
        if self.periodStep == self.numSteps:
            self.done = True
        self.memory.put((self.state,self.a,self.stepProfits/100.0,self.newState,self.done))
        self.state = self.newState 

    def train(self):
        if self.memory.size()>2000:
            for i in range(10):
                train(self.mu, self.mu_target, self.q, self.q_target, self.memory, self.q_optimizer, self.mu_optimizer)
                soft_update(self.mu, self.mu_target)
                soft_update(self.q,  self.q_target)
        
    def bid(self):
        self.stepBid = np.nan
        if self.stepTokenValue > 0:
            a = self.mu(torch.from_numpy(self.state).float()) 
            self.a = a.item() + self.ou_noise()[0]
            frac = np.clip(self.a,0,1)
            self.stepBid = 1*frac + (1-frac)*100
        return np.round(self.stepBid,1)
        
    def ask(self):
        self.stepAsk = np.nan
        if self.stepTokenValue > 0:
            self.mu, self.std = self.model.pi(torch.from_numpy(self.state).float())
            dist = Normal(self.mu, self.std)
            self.action = dist.sample()
            self.log_prob = dist.log_prob(self.action)
            frac = self.action.item()
            self.stepAsk = np.round(frac * 100,1)
        return self.stepAsk

# %%
import gym
import random
import collections
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#Hyperparameters
lr_mu        = 0.0005
lr_q         = 0.001
gamma        = 0.99
batch_size   = 32
buffer_limit = 50000
tau          = 0.005 # for target network soft update

class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)

    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []

        for transition in mini_batch:
            s, a, r, s_prime, done = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask = 0.0 if done else 1.0 
            done_mask_lst.append([done_mask])
        
        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst, dtype=torch.float), \
                torch.tensor(r_lst, dtype=torch.float), torch.tensor(s_prime_lst, dtype=torch.float), \
                torch.tensor(done_mask_lst, dtype=torch.float)
    
    def size(self):
        return len(self.buffer)

class MuNet(nn.Module):
    def __init__(self, numStates):
        super(MuNet, self).__init__()
        self.fc1 = nn.Linear(numStates, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc_mu = nn.Linear(64, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        mu = torch.sigmoid(self.fc_mu(x)) # Multipled by 2 because the action space of the Pendulum-v0 is [-2,2]
        return mu

class QNet(nn.Module):
    def __init__(self, numStates):
        super(QNet, self).__init__()
        self.fc_s = nn.Linear(numStates, 64)
        self.fc_a = nn.Linear(1,64)
        self.fc_q = nn.Linear(128, 32)
        self.fc_out = nn.Linear(32,1)

    def forward(self, x, a):
        h1 = F.relu(self.fc_s(x))
        h2 = F.relu(self.fc_a(a))
        cat = torch.cat([h1,h2], dim=1)
        q = F.relu(self.fc_q(cat))
        q = self.fc_out(q)
        return q

class OrnsteinUhlenbeckNoise:
    def __init__(self, mu):
        self.theta, self.dt, self.sigma = 0.1, 0.01, 0.1
        self.mu = mu
        self.x_prev = np.zeros_like(self.mu)

    def __call__(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
                self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x
      
def train(mu, mu_target, q, q_target, memory, q_optimizer, mu_optimizer):
    s,a,r,s_prime,done_mask  = memory.sample(batch_size)
    
    target = r + gamma * q_target(s_prime, mu_target(s_prime)) * done_mask
    q_loss = F.smooth_l1_loss(q(s,a), target.detach())
    q_optimizer.zero_grad()
    q_loss.backward()
    q_optimizer.step()
    
    mu_loss = -q(s,mu(s)).mean() # That's all for the policy loss.
    mu_optimizer.zero_grad()
    mu_loss.backward()
    mu_optimizer.step()
    
def soft_update(net, net_target):
    for param_target, param in zip(net_target.parameters(), net.parameters()):
        param_target.data.copy_(param_target.data * (1.0 - tau) + param.data * tau)

# %%
def generateAgents(gameData,buyerStrategies,sellerStrategies,disclosure):
    buyers, sellers = [], []
    for idx,i in enumerate(buyerStrategies):
        if i == 'TruthTeller':
            buyers.append(TruthTeller(gameData, disclosure, index=idx, buyer=1, reinforcer=0)) 
        if i == 'ZeroIntelligence':
            buyers.append(ZeroIntelligence(gameData, disclosure, index=idx, buyer=1, reinforcer=0)) 
        if i == 'REINFORCE':
            buyers.append(REINFORCE(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 
        if i == 'PPO':
            buyers.append(PPO(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 
        if i == 'SAC':
            buyers.append(SAC(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 
        if i == 'DQN':
            buyers.append(DQN(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 
        if i == 'DDPG':
            buyers.append(DDPG(gameData, disclosure, index=idx, buyer=1, reinforcer=1)) 

    for idx,i in enumerate(sellerStrategies):
        if i == 'TruthTeller':
            sellers.append(TruthTeller(gameData, disclosure, index=idx, buyer=0, reinforcer=0)) 
        if i == 'ZeroIntelligence':
            sellers.append(ZeroIntelligence(gameData, disclosure, index=idx, buyer=0, reinforcer=0)) 
        if i == 'REINFORCE':
            sellers.append(REINFORCE(gameData, disclosure, index=idx, buyer=0, reinforcer=1)) 
        if i == 'PPO':
            sellers.append(PPO(gameData, disclosure, index=idx, buyer=0, reinforcer=1)) 
        if i == 'SAC':
            sellers.append(SAC(gameData, disclosure, index=idx, buyer=0, reinforcer=1)) 
        if i == 'DDPG':
            sellers.append(DDPG(gameData, disclosure, index=idx, buyer=0, reinforcer=1)) 
    return buyers, sellers
