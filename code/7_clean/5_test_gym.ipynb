# %%
#import gymnasium as gym
#import numpy as np
from stable_baselines3 import PPO, SAC
#from stable_baselines3.ppo.policies import MlpPolicy
#from stable_baselines3.common.base_class import BaseAlgorithm
#env = SingleAgentEnv(metaData)
print(env.log.getRound(0).buyerValues.item())
policy_kwargs = dict(net_arch=dict(pi=[256, 256], qf=[256, 256]))
model = SAC("MlpPolicy", env, policy_kwargs=policy_kwargs, verbose=1,)
model.learn(50000, progress_bar = False)
# Out:
# [[100.   60.   54.9]
#  [ 63.   57.3  28.2]
#  [ 81.5  39.1  24.8]]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 7        |
# |    ep_rew_mean     | 73.8     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 21       |
# |    time_elapsed    | 1        |
# |    total_timesteps | 28       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8        |
# |    ep_rew_mean     | 69.5     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 21       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 64       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.33     |
# ...

# %%
from env import *
gameTypes, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed = '1001', 3, 3, 3, 1, 1, 9, 42
disclosure = ['rnd', 'period', 'step','currentBid','currentAsk','buy','sell','price','sale']
buyerStrategies = ['ZeroIntelligence', 'ZeroIntelligence','ZeroIntelligence']
sellerStrategies = ['ZeroIntelligence', 'ZeroIntelligence','ZeroIntelligence']
metaData = [gameTypes, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed, disclosure, buyerStrategies, sellerStrategies]

import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.ppo.policies import MlpPolicy
from stable_baselines3.common.base_class import BaseAlgorithm
env = SingleAgentEnv(metaData)
print(env.log.getRound(0).buyerValues.item())
model = PPO("MlpPolicy", env, verbose=1)
model.learn(50000, progress_bar = True)

# %%
print(env.log.getRound(0).buyerValues.item())
model = PPO("MlpPolicy", env, verbose=1)
model.learn(50000, progress_bar = True)
# Out:
# Output()
# [[100.   60.   54.9]
#  [ 63.   57.3  28.2]
#  [ 81.5  39.1  24.8]]
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 3
#       1 print(env.log.getRound(0).buyerValues.item())
#       2 model = PPO("MlpPolicy", env, verbose=1)
# ----> 3 model.learn(50000, progress_bar = True)
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/ppo/ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
# ...

# %%
env.log.stepData.tail()
# Out:
#        rnd  period  step                bids                asks  currentBid  \
# 51195    0    5688     3  [36.3, 56.1, 31.6]  [41.1, 31.0, 28.2]        56.1
# 51196    0    5688     4   [4.8, 21.5, 29.5]  [39.1, 30.7, 44.5]        29.5
# 51197    0    5688     5  [17.2, 23.8, 20.8]  [43.2, 59.6, 44.1]        23.8
# 51198    0    5688     6  [23.4, 23.4, 13.0]  [31.9, 54.6, 52.5]        23.4
# 51199    0    5688     7  [43.9, 15.0, 17.5]  [41.8, 64.2, 49.1]        43.9
#
#        currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 51195              1        28.2              2   True   True  42.15   True
# 51196              2        30.7              1   True  False  30.70   True
# 51197              1        43.2              0  False  False    NaN  False
# 51198              0        31.9              0   True  False  31.90   True
# 51199              0        41.8              0   True   True  42.85   True
#
#        bprofit  sprofit
# ...

# %%
env.log.getPeriod(0,5687)
# Out:
#        rnd  period  step                bids                asks  currentBid  \
# 51183    0    5687     0  [41.7, 59.7, 65.8]   [18.5, 0.0, 21.3]        65.8
# 51184    0    5687     1  [62.9, 61.4, 21.8]  [14.4, 41.1, 16.9]        62.9
# 51185    0    5687     2  [34.6, 50.5, 33.2]  [41.3, 43.5, 17.9]        50.5
# 51186    0    5687     3  [54.9, 29.7, 36.5]  [44.9, 34.5, 28.0]        54.9
# 51187    0    5687     4  [19.3, 37.4, 36.8]  [36.0, 41.3, 56.4]        37.4
# 51188    0    5687     5  [30.9, 21.6, 32.8]  [34.3, 41.6, 54.0]        32.8
# 51189    0    5687     6  [43.7, 23.7, 19.8]   [nan, 36.3, 46.5]        43.7
# 51190    0    5687     7  [33.6, 26.2, 22.2]   [nan, 47.9, 56.8]        33.6
# 51191    0    5687     8  [51.2, 27.0, 22.7]   [nan, 63.2, 47.0]        51.2
#
#        currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 51183              2         0.0              1   True   True  32.90   True
# ...

# %%
env.graphSales(0,5687)
# Out:
# [41.7 62.9 34.6 54.9 19.3 30.9 43.7 51.2]

# %%
env.graphSales(0,5687)

# %%
env.log.stepData.tail(9*200).groupby('currentBidIdx').sum()
# Out:
#                rnd   period  step  \
# currentBidIdx
# 0                0  4845199  4192
# 1                0  2871752  1760
# 2                0  2342149  1248
#
#                                                             bids  \
# currentBidIdx
# 0              [53.0, 17.3, 24.8, 76.0, 49.8, 67.9, 44.7, 34....
# 1              [39.6, 59.2, 53.1, 25.6, 34.7, 26.0, 22.2, 55....
# 2              [43.0, 30.8, 46.4, 11.3, 27.0, 35.2, 48.0, 60....
#
#                                                             asks  currentBid  \
# currentBidIdx
# 0              [nan, 54.9, 53.5, 13.5, 0.0, 20.9, 18.0, 36.3,...     39713.3
# 1              [32.5, 31.7, 22.5, 46.0, 43.9, 52.8, 16.0, 32....     21825.0
# 2              [44.6, 30.8, 28.8, nan, 64.7, 52.8, 14.3, 0.0,...     20082.6
#
#                currentAsk  currentAskIdx  buy  sell     price  sale   bprofit  \
# currentBidIdx
# 0                 28642.5            807  592   677  31201.60   770  20242.90
# ...

# %%
env.log.stepData.tail(9*200).groupby('currentAskIdx').sum()
# Out:
#                rnd   period  step  \
# currentAskIdx
# 0                0  3738388  2877
# 1                0  2856240  1775
# 2                0  3464472  2548
#
#                                                             bids  \
# currentAskIdx
# 0              [44.7, 34.9, 44.7, 38.5, 19.8, 20.5, 43.6, 14....
# 1              [76.0, 49.8, 67.9, 25.6, 34.7, 26.0, 48.0, 60....
# 2              [53.0, 17.3, 24.8, 39.6, 59.2, 53.1, 43.0, 30....
#
#                                                             asks  currentBid  \
# currentAskIdx
# 0              [18.0, 36.3, 22.0, 45.5, 53.5, 58.0, 34.8, 45....     28357.2
# 1              [13.5, 0.0, 20.9, 46.0, 43.9, 52.8, 14.3, 0.0,...     25635.3
# 2              [nan, 54.9, 53.5, 32.5, 31.7, 22.5, 44.6, 30.8...     27628.4
#
#                currentBidIdx  currentAsk  buy  sell     price  sale   bprofit  \
# currentAskIdx
# 0                        517     21143.2  515   501  22541.65   585  13051.65
# ...
