# %%
import gymnasium as gym

from stable_baselines3 import A2C

env = gym.make("CartPole-v1", render_mode="rgb_array")

model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
    # VecEnv resets automatically
    # if done:
    #   obs = vec_env.reset()
# Out:
# 2023-09-30 06:31:28.504316: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-09-30 06:31:28.504376: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-09-30 06:31:28.504408: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-09-30 06:31:28.514991: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-30 06:31:29.389022: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.3     |
# |    ep_rew_mean        | 26.3     |
# | time/                 |          |
# |    fps                | 927      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.672   |
# |    explained_variance | 0.201    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.62     |
# |    value_loss         | 5.83     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30.7     |
# |    ep_rew_mean        | 30.7     |
# | time/                 |          |
# |    fps                | 928      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.661   |
# |    explained_variance | -0.0597  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.43     |
# |    value_loss         | 7.54     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 35.5     |
# |    ep_rew_mean        | 35.5     |
# | time/                 |          |
# |    fps                | 930      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.599   |
# |    explained_variance | 0.00242  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0359  |
# |    value_loss         | 93.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 39.1     |
# |    ep_rew_mean        | 39.1     |
# | time/                 |          |
# |    fps                | 931      |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.659   |
# |    explained_variance | 0.00858  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -12.4    |
# |    value_loss         | 460      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42       |
# |    ep_rew_mean        | 42       |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 500      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.623   |
# |    explained_variance | 0.0637   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.751    |
# |    value_loss         | 5.02     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 44.7      |
# |    ep_rew_mean        | 44.7      |
# | time/                 |           |
# |    fps                | 928       |
# |    iterations         | 600       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -0.536    |
# |    explained_variance | -0.000151 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -3.1      |
# |    value_loss         | 636       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.5     |
# |    ep_rew_mean        | 46.5     |
# | time/                 |          |
# |    fps                | 929      |
# |    iterations         | 700      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.659   |
# |    explained_variance | 0.00184  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.09     |
# |    value_loss         | 4.01     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 53.8     |
# |    ep_rew_mean        | 53.8     |
# | time/                 |          |
# |    fps                | 930      |
# |    iterations         | 800      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.656   |
# |    explained_variance | 0.00011  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.798    |
# |    value_loss         | 3.47     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 57.1     |
# |    ep_rew_mean        | 57.1     |
# | time/                 |          |
# |    fps                | 930      |
# |    iterations         | 900      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | 0.000393 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.679    |
# |    value_loss         | 2.98     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 60       |
# |    ep_rew_mean        | 60       |
# | time/                 |          |
# |    fps                | 930      |
# |    iterations         | 1000     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.631   |
# |    explained_variance | 0.000655 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.766    |
# |    value_loss         | 2.51     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 64.7     |
# |    ep_rew_mean        | 64.7     |
# | time/                 |          |
# |    fps                | 931      |
# |    iterations         | 1100     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.501   |
# |    explained_variance | 6.96e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.549    |
# |    value_loss         | 2.08     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 68.8     |
# |    ep_rew_mean        | 68.8     |
# | time/                 |          |
# |    fps                | 931      |
# |    iterations         | 1200     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.498   |
# |    explained_variance | -0.00046 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.53     |
# |    value_loss         | 1.69     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 72        |
# |    ep_rew_mean        | 72        |
# | time/                 |           |
# |    fps                | 931       |
# |    iterations         | 1300      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.489    |
# |    explained_variance | -8.94e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.877     |
# |    value_loss         | 1.35      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 75.8     |
# |    ep_rew_mean        | 75.8     |
# | time/                 |          |
# |    fps                | 931      |
# |    iterations         | 1400     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.609   |
# |    explained_variance | 4.4e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.475    |
# |    value_loss         | 1.04     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77.8     |
# |    ep_rew_mean        | 77.8     |
# | time/                 |          |
# |    fps                | 931      |
# |    iterations         | 1500     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.475   |
# |    explained_variance | 1.73e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.425    |
# |    value_loss         | 0.78     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 79.2     |
# |    ep_rew_mean        | 79.2     |
# | time/                 |          |
# |    fps                | 931      |
# |    iterations         | 1600     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.374   |
# |    explained_variance | 9.45e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.242    |
# |    value_loss         | 0.569    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82       |
# |    ep_rew_mean        | 82       |
# | time/                 |          |
# |    fps                | 926      |
# |    iterations         | 1700     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.294   |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.325    |
# |    value_loss         | 0.389    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 85.2      |
# |    ep_rew_mean        | 85.2      |
# | time/                 |           |
# |    fps                | 922       |
# |    iterations         | 1800      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -0.348    |
# |    explained_variance | -5.11e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 0.262     |
# |    value_loss         | 0.251     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.4     |
# |    ep_rew_mean        | 87.4     |
# | time/                 |          |
# |    fps                | 918      |
# |    iterations         | 1900     |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.522   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.105    |
# |    value_loss         | 0.132    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 92.5      |
# |    ep_rew_mean        | 92.5      |
# | time/                 |           |
# |    fps                | 917       |
# |    iterations         | 2000      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.43     |
# |    explained_variance | -4.66e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.0465    |
# |    value_loss         | 0.0487    |
# -------------------------------------

# %%
from stable_baselines3 import A2C
model = A2C("MlpPolicy", "CartPole-v1").learn(10000)
# Out:
# 2023-09-30 06:32:00.798420: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-09-30 06:32:00.798483: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-09-30 06:32:00.798514: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-09-30 06:32:00.809623: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-30 06:32:01.674257: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env

# Parallel environments
vec_env = make_vec_env("CartPole-v1", n_envs=4)

model = A2C("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25000)
model.save("a2c_cartpole")

del model # remove to demonstrate saving and loading

model = A2C.load("a2c_cartpole")

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.1     |
# |    ep_rew_mean        | 20.1     |
# | time/                 |          |
# |    fps                | 3287     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.685   |
# |    explained_variance | 0.162    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 1.78     |
# |    value_loss         | 7.97     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.3     |
# |    ep_rew_mean        | 29.3     |
# | time/                 |          |
# |    fps                | 3291     |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.649   |
# |    explained_variance | 0.0484   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.382    |
# |    value_loss         | 18.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 40.2     |
# |    ep_rew_mean        | 40.2     |
# | time/                 |          |
# |    fps                | 3301     |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.578   |
# |    explained_variance | 0.0107   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.04     |
# |    value_loss         | 6.34     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 54.9     |
# |    ep_rew_mean        | 54.9     |
# | time/                 |          |
# |    fps                | 3307     |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.62    |
# |    explained_variance | 0.0534   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.27     |
# |    value_loss         | 5.81     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 71.5     |
# |    ep_rew_mean        | 71.5     |
# | time/                 |          |
# |    fps                | 3311     |
# |    iterations         | 500      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.637   |
# |    explained_variance | -0.00771 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.19     |
# |    value_loss         | 5.22     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.1     |
# |    ep_rew_mean        | 81.1     |
# | time/                 |          |
# |    fps                | 3313     |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.608   |
# |    explained_variance | 0.00103  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.21     |
# |    value_loss         | 4.57     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | 106      |
# | time/                 |          |
# |    fps                | 3315     |
# |    iterations         | 700      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | -0.00131 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -6.64    |
# |    value_loss         | 204      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 124      |
# |    ep_rew_mean        | 124      |
# | time/                 |          |
# |    fps                | 3316     |
# |    iterations         | 800      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.562   |
# |    explained_variance | -0.00266 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 1.33     |
# |    value_loss         | 3.59     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 137      |
# |    ep_rew_mean        | 137      |
# | time/                 |          |
# |    fps                | 3317     |
# |    iterations         | 900      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | 0.00103  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -1.47    |
# |    value_loss         | 198      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 150      |
# |    ep_rew_mean        | 150      |
# | time/                 |          |
# |    fps                | 3317     |
# |    iterations         | 1000     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.54    |
# |    explained_variance | 0.00334  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.858    |
# |    value_loss         | 2.69     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 158      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 3316     |
# |    iterations         | 1100     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.583   |
# |    explained_variance | 0.00377  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.751    |
# |    value_loss         | 2.28     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 178       |
# |    ep_rew_mean        | 178       |
# | time/                 |           |
# |    fps                | 3316      |
# |    iterations         | 1200      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.515    |
# |    explained_variance | -0.000133 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 0.641     |
# |    value_loss         | 1.88      |
# -------------------------------------
