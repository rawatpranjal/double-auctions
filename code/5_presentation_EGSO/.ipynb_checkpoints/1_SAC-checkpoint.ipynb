# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from functions import *
from itertools import count
buyer_strategies = ['Honest', 'Random', 'Random']
seller_strategies = ['Random', 'Random', 'Random']
nbuyers, nsellers = len(buyer_strategies), len(seller_strategies)
nrounds, nperiods, ntokens, nsteps, gametype, nbuyers, nsellers = 10, 10, 3, 12, '1234', len(buyer_strategies), len(seller_strategies)
R1, R2, R3, R4 = gametype_to_ran(gametype)
game_metadata = [nrounds, nperiods, ntokens, nbuyers, nsellers, nsteps, R1, R2, R3, R4]
db = Database(game_metadata, buyer_strategies, seller_strategies)
rnd = 0
db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
period = 0
num_states = nsteps
min_frac = 0.01
max_frac = 1.0

# %%
class TradingEnv(gym.Env):
    def __init__(self, db, nsteps, render_mode = None):
        self.rnd = 0
        self.period = -1
        self.nperiods = nperiods
        self.db = db
        self.action_space = spaces.Box(0,1,(1,),dtype=np.float32)
        self.observation_space = spaces.Box(-1,200,(13,),dtype=np.float32)

    def reset(self,seed=None):
        [buyer.next_token() for buyer in self.db.buyers]
        [seller.next_token() for seller in self.db.sellers]
        #self.db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
        self.db.reset_period(self.rnd)
        self.timestep = 0
        self.period += 1
        self.db.buyers[0].next_token()
        agent = self.db.buyers[0]
        observation = np.array([0,-1,-1,-1,-1,-1,-1,-1,agent.value,-1,-1,-1,agent.num_tokens_traded], dtype = np.float32)
        return observation, {}

    def step(self, action, seed=None, options=None):
        [buyer.next_token() for buyer in self.db.buyers]
        [seller.next_token() for seller in self.db.sellers]
        bid_frac = action.item()
        # convert action to bid
        self.db.buyers[0].next_token()
        min_bid = self.db.buyers[0].value * min_frac
        max_bid = self.db.buyers[0].value * max_frac
        bid = np.round(max_bid * bid_frac + (1 - bid_frac) * min_bid, 2)

        # simulate market
        bids = [buyer.bid(self.db) for buyer in self.db.buyers]
        bids[0] = bid
        asks = [seller.ask(self.db) for seller in self.db.sellers]
        current_ask, current_ask_idx, current_bid, current_bid_idx = current_bid_ask(bids, asks)
        sale, price, bprofit, sprofit, buy, sell = buy_sell(self.db, current_bid, current_bid_idx, current_ask, current_ask_idx)
        step_data = [self.rnd, self.period, self.timestep, bids, asks, current_bid, current_bid_idx, current_ask, current_ask_idx, buy, sell, price, sale, bprofit, sprofit]
        self.db.add_step(step_data)

        # compute reward, new state
        reward = 0.0
        if sale == 1 and current_bid_idx == 0:
            reward = bprofit
            
        agent = self.db.buyers[0]
        observation = np.array([self.timestep + 1, current_ask, current_ask_idx, current_bid, current_bid_idx,
                                sale, price, buy, sell, agent.value, agent.step_profit,
                                agent.sale, agent.num_tokens_traded],dtype = np.float32)
        idx = np.isnan(observation)
        observation[idx] = -1.0
        # check termination
        self.timestep += 1
        if self.timestep == nsteps:
            terminated = True
            self.timestep = 0
        else:
            terminated = False
        infos = {"TimeLimit.truncated":True}
        truncated = False
        return observation, reward, terminated, truncated, infos

# %%
from stable_baselines3.common.env_checker import check_env
db = Database(game_metadata, buyer_strategies, seller_strategies)
db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
env = TradingEnv(db, nsteps)
check_env(env)
# Out:
# 2023-09-28 15:51:21.415023: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-09-28 15:51:21.415069: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-09-28 15:51:21.415099: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-09-28 15:51:21.425977: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-28 15:51:22.258676: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
rnd = 0
db = Database(game_metadata, buyer_strategies, seller_strategies)
db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
env = TradingEnv(db, nsteps)
observation, info = env.reset()
for period in count():
    for timestep in count(): 
        action = env.action_space.sample()
        observation, reward, done, info, _ = env.step(action)
        print(f"Rnd: {rnd}, Period: {period}, New State: {observation}, Action:{np.round(action,1)}, Reward: {np.round(reward,1)}, Period End: {done}")
        if done:
            # If the episode is done, reset the environment
            #print('done')
            observation, info = env.reset()
            break
    if period == nperiods:
        period = 0
        break
env.close()
# Out:
# Rnd: 0, Period: 0, New State: [  1.   18.1   2.   93.7   1.    1.   55.9   1.    1.  103.9   0.    1.
#    0. ], Action:[0.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  2.   49.8   1.   71.8   1.    1.   60.8   1.    1.  103.9   0.    1.
#    0. ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  3.    54.3    0.    67.2    2.     1.    60.75   1.     1.   103.9
#    0.     1.     0.  ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  4.   54.2   1.   34.    2.    0.   -1.    0.    0.  103.9   0.    1.
#    0. ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  5.   60.1   0.   43.3   2.    0.   -1.    0.    0.  103.9   0.    1.
#    0. ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  6.   59.8   0.   39.8   2.    0.   -1.    0.    0.  103.9   0.    1.
#    0. ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  7.   54.8   0.   46.9   2.    0.   -1.    0.    0.  103.9   0.    1.
#    0. ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  8.   58.4   1.   28.3   2.    0.   -1.    0.    0.  103.9   0.    1.
#    0. ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  9.    59.5    0.    90.76   0.     1.    75.13   1.     1.   103.9
#   28.77   1.     1.  ], Action:[0.9], Reward: 28.8, Period End: False
# Rnd: 0, Period: 0, New State: [10.   58.6   1.   42.6   2.    0.   -1.    0.    0.   71.6  28.77  1.
#   1.  ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [11.   71.    1.   36.58  0.    1.   71.    1.    0.   71.6   0.6   1.
#   2.  ], Action:[0.5], Reward: 0.6, Period End: False
# Rnd: 0, Period: 0, New State: [12.  81.5  1.  28.7  2.   0.  -1.   0.   0.  20.   0.6  1.   2. ], Action:[0.8], Reward: 0.0, Period End: True
# Rnd: 0, Period: 1, New State: [  1.    24.8    2.    69.1    1.     1.    46.95   1.     1.   103.9
#    0.6    1.     0.  ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [  2.    47.     1.    92.62   0.     1.    69.81   1.     1.   103.9
#   34.09   1.     1.  ], Action:[0.9], Reward: 34.1, Period End: False
# Rnd: 0, Period: 1, New State: [ 3.   54.    0.   58.8   1.    1.   56.4   1.    1.   71.6  34.09  1.
#   1.  ], Action:[0.6], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 4.   53.9   1.   51.1   2.    1.   53.9   1.    0.   71.6  34.09  1.
#   1.  ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 5.   59.    0.   47.2   2.    0.   -1.    0.    0.   71.6  34.09  1.
#   1.  ], Action:[0.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 6.   80.4   0.   37.1   2.    0.   -1.    0.    0.   71.6  34.09  1.
#   1.  ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 7.    57.8    0.    63.13   0.     1.    60.465  1.     1.    71.6
#  11.135  1.     2.   ], Action:[0.9], Reward: 11.1, Period End: False
# Rnd: 0, Period: 1, New State: [ 8.    83.6    1.    33.4    2.     0.    -1.     0.     0.    20.
#  11.135  1.     2.   ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 9.    74.1    1.    27.     2.     0.    -1.     0.     0.    20.
#  11.135  1.     2.   ], Action:[0.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [10.    73.6    1.    44.2    2.     0.    -1.     0.     0.    20.
#  11.135  1.     2.   ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [11.    84.3    1.    30.7    2.     0.    -1.     0.     0.    20.
#  11.135  1.     2.   ], Action:[0.9], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [12.    87.2    1.    48.5    2.     0.    -1.     0.     0.    20.
#  11.135  1.     2.   ], Action:[0.1], Reward: 0.0, Period End: True
# Rnd: 0, Period: 2, New State: [  1.     26.4     2.     89.2     1.      1.     57.8     1.      1.
#  103.9    11.135   1.      0.   ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  2.     40.4     1.     78.8     1.      1.     59.6     1.      1.
#  103.9    11.135   1.      0.   ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  3.     41.8     0.     58.2     2.      1.     50.      1.      1.
#  103.9    11.135   1.      0.   ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  4.     53.5     1.     63.95    0.      1.     58.725   1.      1.
#  103.9    45.175   1.      1.   ], Action:[0.6], Reward: 45.2, Period End: False
# Rnd: 0, Period: 2, New State: [ 5.    57.2    0.    27.4    2.     0.    -1.     0.     0.    71.6
#  45.175  1.     1.   ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 6.    60.3    0.    48.1    2.     0.    -1.     0.     0.    71.6
#  45.175  1.     1.   ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 7.   67.3   0.   45.73  0.    1.   67.3   1.    0.   71.6   4.3   1.
#   2.  ], Action:[0.6], Reward: 4.3, Period End: False
# Rnd: 0, Period: 2, New State: [ 8.  73.9  1.  26.5  2.   0.  -1.   0.   0.  20.   4.3  1.   2. ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 9.  97.1  1.  38.   2.   0.  -1.   0.   0.  20.   4.3  1.   2. ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [10.  86.2  0.  25.7  2.   0.  -1.   0.   0.  20.   4.3  1.   2. ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [11.  82.3  1.  47.1  2.   0.  -1.   0.   0.  20.   4.3  1.   2. ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 12.  100.6   1.   25.9   2.    0.   -1.    0.    0.   20.    4.3   1.
#    2. ], Action:[0.], Reward: 0.0, Period End: True
# Rnd: 0, Period: 3, New State: [  1.   26.3   2.   53.5   2.    1.   39.9   1.    1.  103.9   4.3   1.
#    0. ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 3, New State: [  2.    37.6    1.    58.7    1.     1.    48.15   1.     1.   103.9
#    4.3    1.     0.  ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 3, New State: [  3.   51.9   0.   55.1   1.    1.   53.5   1.    1.  103.9   4.3   1.
#    0. ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 3, New State: [  4.     62.8     0.    103.43    0.      1.     83.115   1.      1.
#  103.9    20.785   1.      1.   ], Action:[1.], Reward: 20.8, Period End: False
# Rnd: 0, Period: 3, New State: [ 5.    64.7    1.    43.9    2.     0.    -1.     0.     0.    71.6
#  20.785  1.     1.   ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 3, New State: [ 6.    62.7    1.    45.2    2.     0.    -1.     0.     0.    71.6
#  20.785  1.     1.   ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 3, New State: [ 7.    78.3    1.    50.46   0.     0.    -1.     0.     0.    71.6
#  20.785  0.     1.   ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 3, New State: [ 8.   76.4   1.   66.95  0.    1.   66.95  0.    1.   71.6   4.65  0.
#   2.  ], Action:[0.9], Reward: 4.6, Period End: False
# Rnd: 0, Period: 3, New State: [ 9.   93.6   1.   41.4   2.    0.   -1.    0.    0.   20.    4.65  0.
#   2.  ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 3, New State: [10.   93.7   1.   42.8   2.    0.   -1.    0.    0.   20.    4.65  0.
#   2.  ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 3, New State: [11.   77.9   1.   42.7   2.    0.   -1.    0.    0.   20.    4.65  0.
#   2.  ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 3, New State: [12.   89.9   2.   33.9   2.    0.   -1.    0.    0.   20.    4.65  0.
#   2.  ], Action:[0.], Reward: 0.0, Period End: True
# Rnd: 0, Period: 4, New State: [  1.    21.6    2.    56.2    1.     1.    38.9    1.     1.   103.9
#    4.65   0.     0.  ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 4, New State: [  2.    41.1    1.    84.3    1.     1.    62.7    1.     1.   103.9
#    4.65   0.     0.  ], Action:[0.6], Reward: 0.0, Period End: False
# Rnd: 0, Period: 4, New State: [  3.     49.2     0.     61.73    0.      1.     55.465   1.      1.
#  103.9    48.435   1.      1.   ], Action:[0.6], Reward: 48.4, Period End: False
# Rnd: 0, Period: 4, New State: [ 4.    67.2    0.    49.7    2.     1.    67.2    1.     0.    71.6
#  48.435  1.     1.   ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 4, New State: [ 5.    79.2    1.    36.14   0.     0.    -1.     0.     0.    71.6
#  48.435  0.     1.   ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 4, New State: [ 6.   64.8   1.   50.07  0.    1.   64.8   1.    0.   71.6   6.8   1.
#   2.  ], Action:[0.7], Reward: 6.8, Period End: False
# Rnd: 0, Period: 4, New State: [ 7.  95.3  2.  47.1  2.   0.  -1.   0.   0.  20.   6.8  1.   2. ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 4, New State: [ 8.  84.4  2.  34.9  2.   0.  -1.   0.   0.  20.   6.8  1.   2. ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 4, New State: [ 9.  86.7  2.  25.8  2.   0.  -1.   0.   0.  20.   6.8  1.   2. ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 4, New State: [10.  80.9  1.  40.7  2.   0.  -1.   0.   0.  20.   6.8  1.   2. ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 4, New State: [11.  82.3  1.  39.8  2.   0.  -1.   0.   0.  20.   6.8  1.   2. ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 4, New State: [12.  75.1  1.  27.3  2.   0.  -1.   0.   0.  20.   6.8  1.   2. ], Action:[0.5], Reward: 0.0, Period End: True
# Rnd: 0, Period: 5, New State: [  1.    21.3    2.    78.2    1.     1.    49.75   1.     1.   103.9
#    6.8    1.     0.  ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 5, New State: [  2.    39.9    1.    70.12   0.     1.    55.01   1.     1.   103.9
#   48.89   1.     1.  ], Action:[0.7], Reward: 48.9, Period End: False
# Rnd: 0, Period: 5, New State: [ 3.   37.3   0.   84.4   1.    1.   60.85  1.    1.   71.6  48.89  1.
#   1.  ], Action:[1.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 5, New State: [ 4.  58.6  0.  57.8  0.   1.  58.2  1.   1.  71.6 13.4  1.   2. ], Action:[0.8], Reward: 13.4, Period End: False
# Rnd: 0, Period: 5, New State: [ 5.  64.5  1.  42.4  2.   1.  64.5  1.   0.  20.  13.4  1.   2. ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 5, New State: [ 6.  79.5  1.  42.2  2.   0.  -1.   0.   0.  20.  13.4  1.   2. ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 5, New State: [ 7.  76.5  1.  26.5  2.   0.  -1.   0.   0.  20.  13.4  1.   2. ], Action:[0.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 5, New State: [ 8.  81.5  2.  32.6  2.   0.  -1.   0.   0.  20.  13.4  1.   2. ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 5, New State: [ 9.  77.7  1.  32.6  2.   0.  -1.   0.   0.  20.  13.4  1.   2. ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 5, New State: [10.  85.6  2.  39.5  2.   0.  -1.   0.   0.  20.  13.4  1.   2. ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 5, New State: [11.  68.8  1.  30.6  2.   0.  -1.   0.   0.  20.  13.4  1.   2. ], Action:[0.6], Reward: 0.0, Period End: False
# Rnd: 0, Period: 5, New State: [12.  80.1  1.  44.9  2.   0.  -1.   0.   0.  20.  13.4  1.   2. ], Action:[0.3], Reward: 0.0, Period End: True
# Rnd: 0, Period: 6, New State: [  1.    23.     2.    92.5    1.     1.    57.75   1.     1.   103.9
#   13.4    1.     0.  ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 6, New State: [  2.    39.6    0.    72.1    1.     1.    55.85   1.     1.   103.9
#   13.4    1.     0.  ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 6, New State: [  3.     41.2     1.     92.35    0.      1.     66.775   1.      1.
#  103.9    37.125   1.      1.   ], Action:[0.9], Reward: 37.1, Period End: False
# Rnd: 0, Period: 6, New State: [ 4.    57.     0.    34.2    2.     1.    57.     1.     0.    71.6
#  37.125  1.     1.   ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 6, New State: [ 5.    58.5    1.    33.5    2.     0.    -1.     0.     0.    71.6
#  37.125  1.     1.   ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 6, New State: [ 6.    68.9    1.    65.51   0.     1.    67.205  1.     1.    71.6
#   4.395  1.     2.   ], Action:[0.9], Reward: 4.4, Period End: False
# Rnd: 0, Period: 6, New State: [ 7.    88.     2.    38.7    2.     0.    -1.     0.     0.    20.
#   4.395  1.     2.   ], Action:[1.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 6, New State: [ 8.    81.3    1.    47.3    2.     0.    -1.     0.     0.    20.
#   4.395  1.     2.   ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 6, New State: [ 9.    70.7    1.    26.7    2.     0.    -1.     0.     0.    20.
#   4.395  1.     2.   ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 6, New State: [10.    98.3    1.    43.7    2.     0.    -1.     0.     0.    20.
#   4.395  1.     2.   ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 6, New State: [11.    92.7    1.    31.7    2.     0.    -1.     0.     0.    20.
#   4.395  1.     2.   ], Action:[0.9], Reward: 0.0, Period End: False
# Rnd: 0, Period: 6, New State: [12.    72.8    1.    36.9    2.     0.    -1.     0.     0.    20.
#   4.395  1.     2.   ], Action:[0.7], Reward: 0.0, Period End: True
# Rnd: 0, Period: 7, New State: [  1.     23.9     2.     87.79    0.      1.     55.845   1.      1.
#  103.9    48.055   1.      1.   ], Action:[0.8], Reward: 48.1, Period End: False
# Rnd: 0, Period: 7, New State: [ 2.    37.9    1.    66.2    2.     1.    52.05   1.     1.    71.6
#  48.055  1.     1.   ], Action:[0.6], Reward: 0.0, Period End: False
# Rnd: 0, Period: 7, New State: [ 3.   45.2   0.   68.44  0.    1.   56.82  1.    1.   71.6  14.78  1.
#   2.  ], Action:[1.], Reward: 14.8, Period End: False
# Rnd: 0, Period: 7, New State: [ 4.   64.5   1.   72.6   1.    1.   68.55  1.    1.   20.   14.78  1.
#   2.  ], Action:[0.6], Reward: 0.0, Period End: False
# Rnd: 0, Period: 7, New State: [ 5.   77.1   0.   68.9   1.    1.   73.    1.    1.   20.   14.78  1.
#   2.  ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 7, New State: [ 6.   87.5   1.   48.4   2.    0.   -1.    0.    0.   20.   14.78  1.
#   2.  ], Action:[1.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 7, New State: [ 7.   81.1   1.   30.2   2.    0.   -1.    0.    0.   20.   14.78  1.
#   2.  ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 7, New State: [ 8.   96.6   2.   32.5   2.    0.   -1.    0.    0.   20.   14.78  1.
#   2.  ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 7, New State: [ 9.   83.9   1.   44.8   2.    0.   -1.    0.    0.   20.   14.78  1.
#   2.  ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 7, New State: [10.   95.4   2.   29.3   2.    0.   -1.    0.    0.   20.   14.78  1.
#   2.  ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 7, New State: [11.   93.4   1.   37.5   2.    0.   -1.    0.    0.   20.   14.78  1.
#   2.  ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 7, New State: [12.   88.3   0.   25.9   2.    0.   -1.    0.    0.   20.   14.78  1.
#   2.  ], Action:[0.4], Reward: 0.0, Period End: True
# Rnd: 0, Period: 8, New State: [  1.    19.5    2.    79.5    1.     1.    49.5    1.     1.   103.9
#   14.78   1.     0.  ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 8, New State: [  2.    43.3    1.    98.68   0.     1.    70.99   1.     1.   103.9
#   32.91   1.     1.  ], Action:[0.9], Reward: 32.9, Period End: False
# Rnd: 0, Period: 8, New State: [ 3.   45.8   0.   74.    1.    1.   59.9   1.    1.   71.6  32.91  1.
#   1.  ], Action:[0.9], Reward: 0.0, Period End: False
# Rnd: 0, Period: 8, New State: [ 4.   58.6   0.   36.5   2.    1.   58.6   1.    0.   71.6  32.91  1.
#   1.  ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 8, New State: [ 5.    69.1    1.    55.89   0.     1.    62.495  1.     1.    71.6
#   9.105  1.     2.   ], Action:[0.8], Reward: 9.1, Period End: False
# Rnd: 0, Period: 8, New State: [ 6.    78.3    1.    27.4    2.     0.    -1.     0.     0.    20.
#   9.105  1.     2.   ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 8, New State: [ 7.    84.1    2.    46.     2.     0.    -1.     0.     0.    20.
#   9.105  1.     2.   ], Action:[0.6], Reward: 0.0, Period End: False
# Rnd: 0, Period: 8, New State: [ 8.    81.7    2.    48.3    2.     0.    -1.     0.     0.    20.
#   9.105  1.     2.   ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 8, New State: [ 9.    78.2    1.    45.4    2.     0.    -1.     0.     0.    20.
#   9.105  1.     2.   ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 8, New State: [10.    93.6    0.    43.9    2.     0.    -1.     0.     0.    20.
#   9.105  1.     2.   ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 8, New State: [11.    79.7    1.    43.2    2.     0.    -1.     0.     0.    20.
#   9.105  1.     2.   ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 8, New State: [12.    72.8    1.    25.8    2.     0.    -1.     0.     0.    20.
#   9.105  1.     2.   ], Action:[0.5], Reward: 0.0, Period End: True
# Rnd: 0, Period: 9, New State: [  1.     25.9     2.     74.9     1.      1.     50.4     1.      1.
#  103.9     9.105   1.      0.   ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 9, New State: [  2.     46.9     0.     85.5     1.      1.     66.2     1.      1.
#  103.9     9.105   1.      0.   ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 9, New State: [  3.     44.1     1.     41.      2.      1.     42.55    1.      1.
#  103.9     9.105   1.      0.   ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 9, New State: [  4.    58.2    0.    66.24   0.     1.    62.22   1.     1.   103.9
#   41.68   1.     1.  ], Action:[0.6], Reward: 41.7, Period End: False
# Rnd: 0, Period: 9, New State: [ 5.   73.6   1.   43.8   2.    0.   -1.    0.    0.   71.6  41.68  1.
#   1.  ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 9, New State: [ 6.   74.8   1.   25.    2.    0.   -1.    0.    0.   71.6  41.68  1.
#   1.  ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 9, New State: [ 7.   77.5   1.   60.68  0.    1.   60.68  0.    1.   71.6  10.92  0.
#   2.  ], Action:[0.8], Reward: 10.9, Period End: False
# Rnd: 0, Period: 9, New State: [ 8.   68.8   1.   41.3   2.    0.   -1.    0.    0.   20.   10.92  0.
#   2.  ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 9, New State: [ 9.   76.1   1.   26.    2.    0.   -1.    0.    0.   20.   10.92  0.
#   2.  ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 9, New State: [10.   83.8   1.   27.6   2.    0.   -1.    0.    0.   20.   10.92  0.
#   2.  ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 9, New State: [11.   90.6   0.   40.3   2.    0.   -1.    0.    0.   20.   10.92  0.
#   2.  ], Action:[0.9], Reward: 0.0, Period End: False
# Rnd: 0, Period: 9, New State: [12.   75.7   1.   32.9   2.    0.   -1.    0.    0.   20.   10.92  0.
#   2.  ], Action:[0.1], Reward: 0.0, Period End: True
# Rnd: 0, Period: 10, New State: [  1.    18.4    2.    67.1    1.     1.    42.75   1.     1.   103.9
#   10.92   0.     0.  ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 10, New State: [  2.     44.      0.     82.37    0.      1.     63.185   1.      1.
#  103.9    40.715   1.      1.   ], Action:[0.8], Reward: 40.7, Period End: False
# Rnd: 0, Period: 10, New State: [ 3.    45.6    1.    59.8    2.     1.    52.7    1.     1.    71.6
#  40.715  1.     1.   ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 10, New State: [ 4.    63.7    0.    73.     1.     1.    68.35   1.     1.    71.6
#  40.715  1.     1.   ], Action:[0.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 10, New State: [ 5.    59.6    1.    70.67   0.     1.    65.135  1.     1.    71.6
#   6.465  1.     2.   ], Action:[1.], Reward: 6.5, Period End: False
# Rnd: 0, Period: 10, New State: [ 6.    73.4    1.    36.1    2.     0.    -1.     0.     0.    20.
#   6.465  1.     2.   ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 10, New State: [ 7.    68.3    1.    27.1    2.     0.    -1.     0.     0.    20.
#   6.465  1.     2.   ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 10, New State: [ 8.    94.6    1.    47.1    2.     0.    -1.     0.     0.    20.
#   6.465  1.     2.   ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 10, New State: [ 9.    68.6    1.    43.     2.     0.    -1.     0.     0.    20.
#   6.465  1.     2.   ], Action:[0.9], Reward: 0.0, Period End: False
# Rnd: 0, Period: 10, New State: [10.    87.2    0.    31.     2.     0.    -1.     0.     0.    20.
#   6.465  1.     2.   ], Action:[0.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 10, New State: [11.    80.7    1.    39.8    2.     0.    -1.     0.     0.    20.
#   6.465  1.     2.   ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 10, New State: [12.    77.3    1.    40.3    2.     0.    -1.     0.     0.    20.
#   6.465  1.     2.   ], Action:[1.], Reward: 0.0, Period End: True

# %%
db.step_data.head(1000).groupby('current_bid_idx').sum()
# Out:
#                  rnd  period  step  \
# current_bid_idx
# 0                  0     117    93
# 1                  0     110    24
# 2                  0     433   609
#
#                                                               bids  \
# current_bid_idx
# 0                [90.76, 20.3, 48.4, 36.58, 22.7, 34.0, 92.62, ...
# 1                [5.67, 93.7, 40.7, 71.64, 71.8, 64.0, 48.6, 69...
# 2                [52.68, 22.9, 67.2, 22.43, 13.8, 34.0, 37.71, ...
#
#                                                               asks  \
# current_bid_idx
# 0                [59.5, 66.0, 81.2, 93.2, 71.0, 81.2, 50.4, 47....
# 1                [38.9, 47.6, 18.1, 53.2, 49.8, 92.7, 54.0, 43....
# 2                [54.3, 67.7, 117.0, 56.5, 54.2, 104.2, 60.1, 7...
#
#                  current_bid  current_ask  current_ask_idx  buy  sell  \
# current_bid_idx
# 0                    1638.09       1396.2               16   20    19
# 1                    1638.40        848.7               23   22    22
# 2                    3333.00       6465.7               81   11     6
#
#                    price  sale  bprofit  sprofit
# current_bid_idx
# 0                1417.32    22   513.18   401.42
# 1                1243.55    22   745.25   563.85
# 2                 599.15    11   140.05   135.45

# %%
# Define your environment and parameters (replace with your actual environment setup)
rnd = 0
period = 0
num_states = nsteps
min_frac = 0.01
max_frac = 1.5
eval_steps = 1000
training_step = 50000

# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO, A2C, DQN, SAC
from stable_baselines3.ppo.policies import MlpPolicy
from stable_baselines3.common.base_class import BaseAlgorithm
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env.db.round_data.redemption_values
# Out:
# 0    [[93.4, 75.3, 72.4, 64.0, 60.9, 59.6, 48.7, 24...
# Name: redemption_values, dtype: object

# %% [markdown]
# ### Continous Action Space

# %%
from stable_baselines3 import SAC, DDPG, TD3, A2C, PPO
db = Database(game_metadata, buyer_strategies, seller_strategies)
db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
db.round_data.token_costs = [np.array([
    [48.7, 62.4, 64.4, 69.7, 73.9, 88.0, 89.9, 100.2],
    [48.7, 62.4, 64.4, 69.7, 73.9, 88.0, 89.9, 100.2],
    [48.7, 62.4, 64.4, 69.7, 73.9, 88.0, 89.9, 100.2]])]
db.round_data.redemption_values = [np.array([
    [93.4, 75.3, 72.4, 64.0, 60.9, 59.6, 48.7, 24.6],
    [93.4, 75.3, 72.4, 64.0, 60.9, 59.6, 48.7, 24.6],
    [93.4, 75.3, 72.4, 64.0, 60.9, 59.6, 48.7, 24.6]])]
env = TradingEnv(db, nsteps)
policy_kwargs = dict(net_arch=dict(pi=[128, 128], qf=[128, 128]))
model = SAC("MlpPolicy", env, policy_kwargs=policy_kwargs, verbose=1,)
model.learn(50000, progress_bar = False)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | -3.11    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 480      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 48       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 6.12     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 498      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 96       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | -1.36    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 204      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 144      |
# | train/             |          |
# |    actor_loss      | 2.82     |
# |    critic_loss     | 44.5     |
# |    ent_coef        | 0.998    |
# |    ent_coef_loss   | -0.00312 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 3.29     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 151      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 192      |
# | train/             |          |
# |    actor_loss      | 2.27     |
# |    critic_loss     | 68.3     |
# |    ent_coef        | 0.983    |
# |    ent_coef_loss   | -0.028   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 91       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 2.95     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 133      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 240      |
# | train/             |          |
# |    actor_loss      | 2.51     |
# |    critic_loss     | 38.6     |
# |    ent_coef        | 0.969    |
# |    ent_coef_loss   | -0.052   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 139      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 3.42     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 125      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 288      |
# | train/             |          |
# |    actor_loss      | 1.97     |
# |    critic_loss     | 39.1     |
# |    ent_coef        | 0.955    |
# |    ent_coef_loss   | -0.0768  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 187      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 3.62     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 120      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 336      |
# | train/             |          |
# |    actor_loss      | 2.08     |
# |    critic_loss     | 37.2     |
# |    ent_coef        | 0.941    |
# |    ent_coef_loss   | -0.101   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 235      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 3.34     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 117      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 384      |
# | train/             |          |
# |    actor_loss      | 2.31     |
# |    critic_loss     | 30       |
# |    ent_coef        | 0.927    |
# |    ent_coef_loss   | -0.125   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 283      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 4.6      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 114      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 432      |
# | train/             |          |
# |    actor_loss      | 1.49     |
# |    critic_loss     | 48.5     |
# |    ent_coef        | 0.914    |
# |    ent_coef_loss   | -0.136   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 331      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 5.04     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 112      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 480      |
# | train/             |          |
# |    actor_loss      | 1.98     |
# |    critic_loss     | 27.4     |
# |    ent_coef        | 0.901    |
# |    ent_coef_loss   | -0.175   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 379      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 5.51     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 110      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 528      |
# | train/             |          |
# |    actor_loss      | 1.68     |
# |    critic_loss     | 29.6     |
# |    ent_coef        | 0.888    |
# |    ent_coef_loss   | -0.193   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 427      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 5.99     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 109      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 576      |
# | train/             |          |
# |    actor_loss      | 1.54     |
# |    critic_loss     | 39.7     |
# |    ent_coef        | 0.875    |
# |    ent_coef_loss   | -0.219   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 475      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 7.15     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 107      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 624      |
# | train/             |          |
# |    actor_loss      | 0.484    |
# |    critic_loss     | 36.6     |
# |    ent_coef        | 0.863    |
# |    ent_coef_loss   | -0.241   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 523      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 7.13     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 107      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 672      |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 35.9     |
# |    ent_coef        | 0.851    |
# |    ent_coef_loss   | -0.257   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 571      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 7.72     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 106      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 720      |
# | train/             |          |
# |    actor_loss      | 0.403    |
# |    critic_loss     | 43.4     |
# |    ent_coef        | 0.839    |
# |    ent_coef_loss   | -0.269   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 619      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 7.71     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 105      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 768      |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 24.4     |
# |    ent_coef        | 0.828    |
# |    ent_coef_loss   | -0.285   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 667      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 7.63     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 105      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 816      |
# | train/             |          |
# |    actor_loss      | 0.42     |
# |    critic_loss     | 44.5     |
# |    ent_coef        | 0.817    |
# |    ent_coef_loss   | -0.311   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 715      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 7.07     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 104      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 864      |
# | train/             |          |
# |    actor_loss      | 1.59     |
# |    critic_loss     | 35.6     |
# |    ent_coef        | 0.806    |
# |    ent_coef_loss   | -0.302   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 763      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 7.14     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 104      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 912      |
# | train/             |          |
# |    actor_loss      | 1.35     |
# |    critic_loss     | 23.6     |
# |    ent_coef        | 0.795    |
# |    ent_coef_loss   | -0.322   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 811      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 7.55     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 103      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 960      |
# | train/             |          |
# |    actor_loss      | 0.703    |
# |    critic_loss     | 24       |
# |    ent_coef        | 0.785    |
# |    ent_coef_loss   | -0.371   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 859      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 8.04     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 103      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1008     |
# | train/             |          |
# |    actor_loss      | 0.859    |
# |    critic_loss     | 27.6     |
# |    ent_coef        | 0.775    |
# |    ent_coef_loss   | -0.375   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 907      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 8.11     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 102      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1056     |
# | train/             |          |
# |    actor_loss      | 0.909    |
# |    critic_loss     | 30.6     |
# |    ent_coef        | 0.765    |
# |    ent_coef_loss   | -0.332   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 955      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 8.38     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 101      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1104     |
# | train/             |          |
# |    actor_loss      | 1.61     |
# |    critic_loss     | 25.1     |
# |    ent_coef        | 0.756    |
# |    ent_coef_loss   | -0.387   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1003     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 9.12     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 100      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1152     |
# | train/             |          |
# |    actor_loss      | 0.572    |
# |    critic_loss     | 19.5     |
# |    ent_coef        | 0.746    |
# |    ent_coef_loss   | -0.335   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1051     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 9.66     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 99       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | 0.525    |
# |    critic_loss     | 24.3     |
# |    ent_coef        | 0.737    |
# |    ent_coef_loss   | -0.315   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 10.9     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 98       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1248     |
# | train/             |          |
# |    actor_loss      | 1.45     |
# |    critic_loss     | 18.9     |
# |    ent_coef        | 0.728    |
# |    ent_coef_loss   | -0.347   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1147     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 11.2     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 98       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1296     |
# | train/             |          |
# |    actor_loss      | -0.368   |
# |    critic_loss     | 18.1     |
# |    ent_coef        | 0.72     |
# |    ent_coef_loss   | -0.353   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1195     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 12.6     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 97       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1344     |
# | train/             |          |
# |    actor_loss      | 0.462    |
# |    critic_loss     | 21.6     |
# |    ent_coef        | 0.712    |
# |    ent_coef_loss   | -0.369   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1243     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 12.9     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 97       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1392     |
# | train/             |          |
# |    actor_loss      | -1.33    |
# |    critic_loss     | 27.9     |
# |    ent_coef        | 0.703    |
# |    ent_coef_loss   | -0.357   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1291     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 13.9     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 96       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1440     |
# | train/             |          |
# |    actor_loss      | -0.131   |
# |    critic_loss     | 23       |
# |    ent_coef        | 0.695    |
# |    ent_coef_loss   | -0.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1339     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 14.3     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 96       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1488     |
# | train/             |          |
# |    actor_loss      | -0.521   |
# |    critic_loss     | 24.3     |
# |    ent_coef        | 0.688    |
# |    ent_coef_loss   | -0.437   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1387     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 15       |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 95       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1536     |
# | train/             |          |
# |    actor_loss      | -0.27    |
# |    critic_loss     | 20.5     |
# |    ent_coef        | 0.68     |
# |    ent_coef_loss   | -0.399   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1435     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 15.9     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 95       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1584     |
# | train/             |          |
# |    actor_loss      | -1.28    |
# |    critic_loss     | 27       |
# |    ent_coef        | 0.673    |
# |    ent_coef_loss   | -0.431   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1483     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 16.5     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 94       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1632     |
# | train/             |          |
# |    actor_loss      | -1.29    |
# |    critic_loss     | 32.2     |
# |    ent_coef        | 0.666    |
# |    ent_coef_loss   | -0.459   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1531     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 17.1     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 94       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1680     |
# | train/             |          |
# |    actor_loss      | -2.04    |
# |    critic_loss     | 26.8     |
# |    ent_coef        | 0.659    |
# |    ent_coef_loss   | -0.367   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1579     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 17.4     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 94       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1728     |
# | train/             |          |
# |    actor_loss      | -1.2     |
# |    critic_loss     | 30.1     |
# |    ent_coef        | 0.652    |
# |    ent_coef_loss   | -0.291   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1627     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 17.7     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 94       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1776     |
# | train/             |          |
# |    actor_loss      | -2.63    |
# |    critic_loss     | 27.4     |
# |    ent_coef        | 0.645    |
# |    ent_coef_loss   | -0.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1675     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 17.5     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 93       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1824     |
# | train/             |          |
# |    actor_loss      | -2.05    |
# |    critic_loss     | 21.8     |
# |    ent_coef        | 0.638    |
# |    ent_coef_loss   | -0.46    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1723     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 18.1     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 93       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 1872     |
# | train/             |          |
# |    actor_loss      | -1.32    |
# |    critic_loss     | 23.1     |
# |    ent_coef        | 0.632    |
# |    ent_coef_loss   | -0.392   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1771     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 18.2     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 93       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 1920     |
# | train/             |          |
# |    actor_loss      | -2.59    |
# |    critic_loss     | 13.1     |
# |    ent_coef        | 0.625    |
# |    ent_coef_loss   | -0.424   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1819     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 19.1     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 92       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1968     |
# | train/             |          |
# |    actor_loss      | -2.71    |
# |    critic_loss     | 23.9     |
# |    ent_coef        | 0.619    |
# |    ent_coef_loss   | -0.305   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1867     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 20.4     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 92       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2016     |
# | train/             |          |
# |    actor_loss      | -3.7     |
# |    critic_loss     | 21.1     |
# |    ent_coef        | 0.613    |
# |    ent_coef_loss   | -0.53    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1915     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 21.8     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 92       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 2064     |
# | train/             |          |
# |    actor_loss      | -2.63    |
# |    critic_loss     | 22.4     |
# |    ent_coef        | 0.607    |
# |    ent_coef_loss   | -0.358   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1963     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 22.2     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 92       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 2112     |
# | train/             |          |
# |    actor_loss      | -2.91    |
# |    critic_loss     | 22.6     |
# |    ent_coef        | 0.601    |
# |    ent_coef_loss   | -0.548   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2011     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 22.9     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 92       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 2160     |
# | train/             |          |
# |    actor_loss      | -2.84    |
# |    critic_loss     | 24.5     |
# |    ent_coef        | 0.596    |
# |    ent_coef_loss   | -0.213   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2059     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 91       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 2208     |
# | train/             |          |
# |    actor_loss      | -3.45    |
# |    critic_loss     | 17.7     |
# |    ent_coef        | 0.59     |
# |    ent_coef_loss   | -0.402   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2107     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 23.7     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 91       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 2256     |
# | train/             |          |
# |    actor_loss      | -4.24    |
# |    critic_loss     | 16.4     |
# |    ent_coef        | 0.585    |
# |    ent_coef_loss   | -0.447   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2155     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 24.3     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 91       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 2304     |
# | train/             |          |
# |    actor_loss      | -3.85    |
# |    critic_loss     | 17.4     |
# |    ent_coef        | 0.579    |
# |    ent_coef_loss   | -0.486   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2203     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 24.7     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 91       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 2352     |
# | train/             |          |
# |    actor_loss      | -4.13    |
# |    critic_loss     | 18.3     |
# |    ent_coef        | 0.574    |
# |    ent_coef_loss   | -0.483   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2251     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 24.6     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 91       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | -4.07    |
# |    critic_loss     | 16.7     |
# |    ent_coef        | 0.568    |
# |    ent_coef_loss   | -0.311   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 24.5     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 91       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 2448     |
# | train/             |          |
# |    actor_loss      | -4.07    |
# |    critic_loss     | 16.9     |
# |    ent_coef        | 0.563    |
# |    ent_coef_loss   | -0.436   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2347     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 24.4     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 90       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 2496     |
# | train/             |          |
# |    actor_loss      | -5.07    |
# |    critic_loss     | 24.1     |
# |    ent_coef        | 0.558    |
# |    ent_coef_loss   | -0.42    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2395     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 24.8     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 90       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 2544     |
# | train/             |          |
# |    actor_loss      | -4.44    |
# |    critic_loss     | 16.5     |
# |    ent_coef        | 0.553    |
# |    ent_coef_loss   | -0.357   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2443     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 25.3     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 90       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 2592     |
# | train/             |          |
# |    actor_loss      | -5.77    |
# |    critic_loss     | 17.1     |
# |    ent_coef        | 0.547    |
# |    ent_coef_loss   | -0.343   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2491     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 25.1     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 89       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 2640     |
# | train/             |          |
# |    actor_loss      | -6.24    |
# |    critic_loss     | 12.1     |
# |    ent_coef        | 0.542    |
# |    ent_coef_loss   | -0.345   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2539     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 25.8     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 88       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 2688     |
# | train/             |          |
# |    actor_loss      | -5.49    |
# |    critic_loss     | 21       |
# |    ent_coef        | 0.538    |
# |    ent_coef_loss   | -0.51    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2587     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 25.8     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 88       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 2736     |
# | train/             |          |
# |    actor_loss      | -6.56    |
# |    critic_loss     | 18.5     |
# |    ent_coef        | 0.533    |
# |    ent_coef_loss   | -0.299   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2635     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 26.1     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 89       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 2784     |
# | train/             |          |
# |    actor_loss      | -5.79    |
# |    critic_loss     | 16.1     |
# |    ent_coef        | 0.528    |
# |    ent_coef_loss   | -0.261   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2683     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 26.3     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 88       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 2832     |
# | train/             |          |
# |    actor_loss      | -6.46    |
# |    critic_loss     | 16.7     |
# |    ent_coef        | 0.523    |
# |    ent_coef_loss   | -0.257   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2731     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 26.6     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 88       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 2880     |
# | train/             |          |
# |    actor_loss      | -7.47    |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.519    |
# |    ent_coef_loss   | -0.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2779     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 26.8     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 88       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 2928     |
# | train/             |          |
# |    actor_loss      | -6.21    |
# |    critic_loss     | 17.7     |
# |    ent_coef        | 0.514    |
# |    ent_coef_loss   | -0.378   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2827     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.2     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 88       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 2976     |
# | train/             |          |
# |    actor_loss      | -7.26    |
# |    critic_loss     | 16.8     |
# |    ent_coef        | 0.509    |
# |    ent_coef_loss   | -0.452   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2875     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.4     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 88       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 3024     |
# | train/             |          |
# |    actor_loss      | -7.42    |
# |    critic_loss     | 19.7     |
# |    ent_coef        | 0.505    |
# |    ent_coef_loss   | -0.282   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2923     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.8     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 89       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 3072     |
# | train/             |          |
# |    actor_loss      | -5.45    |
# |    critic_loss     | 9.96     |
# |    ent_coef        | 0.5      |
# |    ent_coef_loss   | -0.487   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2971     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 28.2     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 89       |
# |    time_elapsed    | 35       |
# |    total_timesteps | 3120     |
# | train/             |          |
# |    actor_loss      | -7       |
# |    critic_loss     | 15       |
# |    ent_coef        | 0.496    |
# |    ent_coef_loss   | -0.221   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3019     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 28.2     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 89       |
# |    time_elapsed    | 35       |
# |    total_timesteps | 3168     |
# | train/             |          |
# |    actor_loss      | -7.55    |
# |    critic_loss     | 12       |
# |    ent_coef        | 0.492    |
# |    ent_coef_loss   | -0.476   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3067     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.4     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 89       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 3216     |
# | train/             |          |
# |    actor_loss      | -7.29    |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.488    |
# |    ent_coef_loss   | -0.232   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3115     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.1     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 89       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 3264     |
# | train/             |          |
# |    actor_loss      | -7.84    |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.484    |
# |    ent_coef_loss   | -0.338   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3163     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.4     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 89       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 3312     |
# | train/             |          |
# |    actor_loss      | -8.54    |
# |    critic_loss     | 20.1     |
# |    ent_coef        | 0.48     |
# |    ent_coef_loss   | -0.378   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3211     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.4     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 89       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 3360     |
# | train/             |          |
# |    actor_loss      | -7.98    |
# |    critic_loss     | 8.11     |
# |    ent_coef        | 0.475    |
# |    ent_coef_loss   | -0.238   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3259     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.5     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 89       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 3408     |
# | train/             |          |
# |    actor_loss      | -8.28    |
# |    critic_loss     | 11.2     |
# |    ent_coef        | 0.471    |
# |    ent_coef_loss   | -0.323   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3307     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.4     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 89       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 3456     |
# | train/             |          |
# |    actor_loss      | -8.62    |
# |    critic_loss     | 12.2     |
# |    ent_coef        | 0.467    |
# |    ent_coef_loss   | -0.264   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3355     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.5     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 89       |
# |    time_elapsed    | 39       |
# |    total_timesteps | 3504     |
# | train/             |          |
# |    actor_loss      | -8.4     |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.463    |
# |    ent_coef_loss   | -0.477   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3403     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.4     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 89       |
# |    time_elapsed    | 39       |
# |    total_timesteps | 3552     |
# | train/             |          |
# |    actor_loss      | -9.38    |
# |    critic_loss     | 19.4     |
# |    ent_coef        | 0.46     |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3451     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.5     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 89       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | -8.15    |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.456    |
# |    ent_coef_loss   | -0.277   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.5     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 89       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 3648     |
# | train/             |          |
# |    actor_loss      | -9.06    |
# |    critic_loss     | 9.08     |
# |    ent_coef        | 0.452    |
# |    ent_coef_loss   | -0.513   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3547     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.7     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 89       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 3696     |
# | train/             |          |
# |    actor_loss      | -9.23    |
# |    critic_loss     | 15.9     |
# |    ent_coef        | 0.448    |
# |    ent_coef_loss   | -0.595   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3595     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.9     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 89       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 3744     |
# | train/             |          |
# |    actor_loss      | -9.3     |
# |    critic_loss     | 11.5     |
# |    ent_coef        | 0.444    |
# |    ent_coef_loss   | -0.189   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3643     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 27.7     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 89       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 3792     |
# | train/             |          |
# |    actor_loss      | -9.24    |
# |    critic_loss     | 11.1     |
# |    ent_coef        | 0.44     |
# |    ent_coef_loss   | -0.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3691     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 28.2     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 89       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 3840     |
# | train/             |          |
# |    actor_loss      | -8.5     |
# |    critic_loss     | 12.4     |
# |    ent_coef        | 0.437    |
# |    ent_coef_loss   | -0.439   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3739     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 28       |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 89       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 3888     |
# | train/             |          |
# |    actor_loss      | -10.4    |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.433    |
# |    ent_coef_loss   | -0.251   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3787     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 28.3     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 89       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 3936     |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 11.8     |
# |    ent_coef        | 0.429    |
# |    ent_coef_loss   | -0.184   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3835     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 28.3     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 89       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 3984     |
# | train/             |          |
# |    actor_loss      | -8.21    |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.426    |
# |    ent_coef_loss   | -0.155   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3883     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 28.4     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 88       |
# |    time_elapsed    | 45       |
# |    total_timesteps | 4032     |
# | train/             |          |
# |    actor_loss      | -9.6     |
# |    critic_loss     | 12.3     |
# ...
# | time/              |          |
# |    episodes        | 3084     |
# |    fps             | 71       |
# |    time_elapsed    | 519      |
# |    total_timesteps | 37008    |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 3.87     |
# |    ent_coef        | 0.095    |
# |    ent_coef_loss   | -0.00524 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36907    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.1     |
# | time/              |          |
# |    episodes        | 3088     |
# |    fps             | 71       |
# |    time_elapsed    | 520      |
# |    total_timesteps | 37056    |
# | train/             |          |
# |    actor_loss      | -10.6    |
# |    critic_loss     | 4.11     |
# |    ent_coef        | 0.0955   |
# |    ent_coef_loss   | -0.0413  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36955    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.4     |
# | time/              |          |
# |    episodes        | 3092     |
# |    fps             | 71       |
# |    time_elapsed    | 521      |
# |    total_timesteps | 37104    |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 5.72     |
# |    ent_coef        | 0.095    |
# |    ent_coef_loss   | -0.174   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37003    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.6     |
# | time/              |          |
# |    episodes        | 3096     |
# |    fps             | 71       |
# |    time_elapsed    | 522      |
# |    total_timesteps | 37152    |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 5.8      |
# |    ent_coef        | 0.0946   |
# |    ent_coef_loss   | 0.123    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37051    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.5     |
# | time/              |          |
# |    episodes        | 3100     |
# |    fps             | 71       |
# |    time_elapsed    | 523      |
# |    total_timesteps | 37200    |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 6.86     |
# |    ent_coef        | 0.0949   |
# |    ent_coef_loss   | 0.245    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.3     |
# | time/              |          |
# |    episodes        | 3104     |
# |    fps             | 71       |
# |    time_elapsed    | 524      |
# |    total_timesteps | 37248    |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 5.12     |
# |    ent_coef        | 0.0943   |
# |    ent_coef_loss   | -0.303   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37147    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.1     |
# | time/              |          |
# |    episodes        | 3108     |
# |    fps             | 71       |
# |    time_elapsed    | 525      |
# |    total_timesteps | 37296    |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 6.42     |
# |    ent_coef        | 0.0949   |
# |    ent_coef_loss   | 0.156    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37195    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39       |
# | time/              |          |
# |    episodes        | 3112     |
# |    fps             | 71       |
# |    time_elapsed    | 525      |
# |    total_timesteps | 37344    |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 5.17     |
# |    ent_coef        | 0.0956   |
# |    ent_coef_loss   | -0.0413  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37243    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.3     |
# | time/              |          |
# |    episodes        | 3116     |
# |    fps             | 70       |
# |    time_elapsed    | 526      |
# |    total_timesteps | 37392    |
# | train/             |          |
# |    actor_loss      | -10.8    |
# |    critic_loss     | 4.51     |
# |    ent_coef        | 0.0953   |
# |    ent_coef_loss   | -0.478   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37291    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.1     |
# | time/              |          |
# |    episodes        | 3120     |
# |    fps             | 70       |
# |    time_elapsed    | 527      |
# |    total_timesteps | 37440    |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 5.65     |
# |    ent_coef        | 0.0943   |
# |    ent_coef_loss   | -0.24    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37339    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.2     |
# | time/              |          |
# |    episodes        | 3124     |
# |    fps             | 70       |
# |    time_elapsed    | 528      |
# |    total_timesteps | 37488    |
# | train/             |          |
# |    actor_loss      | -12.3    |
# |    critic_loss     | 4.35     |
# |    ent_coef        | 0.0936   |
# |    ent_coef_loss   | -0.0267  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37387    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 38.9     |
# | time/              |          |
# |    episodes        | 3128     |
# |    fps             | 70       |
# |    time_elapsed    | 529      |
# |    total_timesteps | 37536    |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 5.65     |
# |    ent_coef        | 0.0928   |
# |    ent_coef_loss   | -0.097   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37435    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.2     |
# | time/              |          |
# |    episodes        | 3132     |
# |    fps             | 70       |
# |    time_elapsed    | 530      |
# |    total_timesteps | 37584    |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 5.27     |
# |    ent_coef        | 0.0922   |
# |    ent_coef_loss   | -0.0997  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37483    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.3     |
# | time/              |          |
# |    episodes        | 3136     |
# |    fps             | 70       |
# |    time_elapsed    | 531      |
# |    total_timesteps | 37632    |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 5.32     |
# |    ent_coef        | 0.0919   |
# |    ent_coef_loss   | 0.182    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37531    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.1     |
# | time/              |          |
# |    episodes        | 3140     |
# |    fps             | 70       |
# |    time_elapsed    | 531      |
# |    total_timesteps | 37680    |
# | train/             |          |
# |    actor_loss      | -13.6    |
# |    critic_loss     | 3.78     |
# |    ent_coef        | 0.0916   |
# |    ent_coef_loss   | 0.0434   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37579    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.3     |
# | time/              |          |
# |    episodes        | 3144     |
# |    fps             | 70       |
# |    time_elapsed    | 532      |
# |    total_timesteps | 37728    |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 4.56     |
# |    ent_coef        | 0.0921   |
# |    ent_coef_loss   | 0.324    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37627    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.4     |
# | time/              |          |
# |    episodes        | 3148     |
# |    fps             | 70       |
# |    time_elapsed    | 533      |
# |    total_timesteps | 37776    |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 4.97     |
# |    ent_coef        | 0.0927   |
# |    ent_coef_loss   | 0.146    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37675    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.2     |
# | time/              |          |
# |    episodes        | 3152     |
# |    fps             | 70       |
# |    time_elapsed    | 534      |
# |    total_timesteps | 37824    |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 5.31     |
# |    ent_coef        | 0.0933   |
# |    ent_coef_loss   | -0.0366  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37723    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.7     |
# | time/              |          |
# |    episodes        | 3156     |
# |    fps             | 70       |
# |    time_elapsed    | 535      |
# |    total_timesteps | 37872    |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 4.19     |
# |    ent_coef        | 0.0937   |
# |    ent_coef_loss   | -0.337   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37771    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.9     |
# | time/              |          |
# |    episodes        | 3160     |
# |    fps             | 70       |
# |    time_elapsed    | 536      |
# |    total_timesteps | 37920    |
# | train/             |          |
# |    actor_loss      | -10.7    |
# |    critic_loss     | 5.21     |
# |    ent_coef        | 0.0937   |
# |    ent_coef_loss   | 0.116    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37819    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 39.9     |
# | time/              |          |
# |    episodes        | 3164     |
# |    fps             | 70       |
# |    time_elapsed    | 537      |
# |    total_timesteps | 37968    |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 4.98     |
# |    ent_coef        | 0.0947   |
# |    ent_coef_loss   | 0.435    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37867    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | 40       |
# | time/              |          |
# |    episodes        | 3168     |
# |    fps             | 70       |
# |    time_elapsed    | 537      |
# |    total_timesteps | 38016    |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 5        |
# |    ent_coef        | 0.0955   |
# |    ent_coef_loss   | 0.177    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37915    |
# ---------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 15
#      13 policy_kwargs = dict(net_arch=dict(pi=[128, 128], qf=[128, 128]))
#      14 model = SAC("MlpPolicy", env, policy_kwargs=policy_kwargs, verbose=1,)
# ---> 15 model.learn(50000, progress_bar = False)
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/sac/sac.py:307, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     298 def learn(
#     299     self: SelfSAC,
#     300     total_timesteps: int,
#    (...)
#     305     progress_bar: bool = False,
#     306 ) -> SelfSAC:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/common/off_policy_algorithm.py:331, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     329         # Special case when the user passes `gradient_steps=0`
#     330         if gradient_steps > 0:
# --> 331             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     333 callback.on_training_end()
#     335 return self
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/stable_baselines3/sac/sac.py:267, in SAC.train(self, gradient_steps, batch_size)
#     265 # Optimize the critic
#     266 self.critic.optimizer.zero_grad()
# --> 267 critic_loss.backward()
#     268 self.critic.optimizer.step()
#     270 # Compute actor loss
#     271 # Alternative: actor_loss = th.mean(log_prob - qf1_pi)
#     272 # Min over all critic networks
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
model.save("trained_sac_model")

# %%
model.learn(50000, progress_bar = False)

# %%
db.step_data.head(60).groupby('current_bid_idx').sum()

# %%
db.step_data.tail(60).groupby('current_bid_idx').sum()

# %%
db.round_data.redemption_values.item()

# %%
db.step_data.tail(60)

# %%
graph_period(env.db, 0, 2236)

# %% [markdown]
# ### Play Game

# %%
### from stable_baselines3 import SAC
loaded_model = SAC.load("trained_sac_model")

# Assuming you have a trained agent loaded as 'loaded_model'
db2 = Database(game_metadata, buyer_strategies, seller_strategies)
db2.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
db2.round_data.token_costs = [np.array([
    [48.7, 62.4, 64.4, 69.7, 73.9, 88.0, 89.9, 100.2],
    [48.7, 62.4, 64.4, 69.7, 73.9, 88.0, 89.9, 100.2],
    [48.7, 62.4, 64.4, 69.7, 73.9, 88.0, 89.9, 100.2]])]
db2.round_data.redemption_values = [np.array([
    [93.4, 75.3, 72.4, 64.0, 60.9, 59.6, 48.7, 24.6],
    [93.4, 75.3, 72.4, 64.0, 60.9, 59.6, 48.7, 24.6],
    [93.4, 75.3, 72.4, 64.0, 60.9, 59.6, 48.7, 24.6]])]
env2 = TradingEnv2(db2, nsteps)

obs, _ = env2.reset()  # Reset the environment to start a new game
done = False
user_id = 0
if user_id == 0:
    print('You are seller')
else:
    print('You are buyer')
while not done:
    user_input = input("Your offer: ")
    user_input = float(user_input)
    action, _ = loaded_model.predict(obs, deterministic=True)  # Get the agent's action
    obs, reward, done, _, _ = env2.step(action, user_input, user_id)  # Take the action and observe the next state

    if user_id == 0:
        print(
    if db2.sellers[0].sale
# Out:
# Your bid:  50
# [0.51949584]
# Your bid:  50
# [0.6275569]
# Your bid:  50
# [0.61427706]
# Your bid:  50
# [0.62133455]
# Your bid:  50
# [0.5805974]
# Your bid:  50
# [0.43714607]
# Your bid:  50
# [0.46290636]
# Your bid:  50
# [0.5477744]
# Your bid:  50
# [0.47734815]
# Your bid:  50
# [0.424411]
# Your bid:  50
# [0.42635298]
# Your bid:  50
# [0.40141302]

# %%
env2 = TradingEnv2(db2, nsteps)
obs, _ = env2.reset()  # Reset the environment to start a new game

# %%
db2.sellers[0].value
# Out:
# nan

# %%
db2.step_data.groupby('current_bid_idx').sum()
# Out:
#                  rnd  period  step  \
# current_bid_idx
# 0                  0       0     5
# 1                  0       0    51
# 2                  0       0    10
#
#                                                               bids  \
# current_bid_idx
# 0                [73.23, 50.0, 68.0, 69.67, 50.0, 45.2, 67.75, ...
# 1                [nan, 50.0, nan, nan, 50.0, nan, nan, 50.0, na...
# 2                [71.16, 50.0, 72.5, nan, 50.0, 70.3, nan, 50.0...
#
#                                                               asks  \
# current_bid_idx
# 0                [71.5, 56.5, 50.2, 65.4, 87.1, 88.3, 77.2, 91....
# 1                [79.1, 80.2, nan, nan, 81.6, nan, nan, 76.5, n...
# 2                [67.1, 56.8, 82.5, 92.8, 84.5, 74.7, 90.5, 86....
#
#                  current_bid  current_ask  current_ask_idx  buy  sell   price  \
# current_bid_idx
# 0                     210.65        192.8                2    2     3  197.00
# 1                     300.00        475.5                5    2     0  143.70
# 2                     209.30        208.3                5    2     3  203.65
#
#                  sale  bprofit  sprofit
# current_bid_idx
# 0                   3    44.10    37.20
# 1                   2    25.00    16.90
# 2                   3    37.45    28.15

# %%
db2.step_data.groupby('current_ask_idx').sum()
# Out:
#                  rnd  period  step  \
# current_ask_idx
# 0                  0       0    11
# 1                  0       0    46
# 2                  0       0     9
#
#                                                               bids  \
# current_ask_idx
# 0                [69.67, 50.0, 45.2, 67.75, 50.0, 57.1, nan, 50...
# 1                [71.16, 50.0, 72.5, nan, 50.0, nan, nan, 50.0,...
# 2                [73.23, 50.0, 68.0, nan, 50.0, 70.3, nan, 50.0...
#
#                                                               asks  \
# current_ask_idx
# 0                [65.4, 87.1, 88.3, 77.2, 91.8, 87.2, 79.1, 80....
# 1                [67.1, 56.8, 82.5, nan, 81.6, nan, nan, 76.5, ...
# 2                [71.5, 56.5, 50.2, 92.8, 84.5, 74.7, 90.5, 86....
#
#                  current_bid  current_bid_idx  current_ask  buy  sell  \
# current_ask_idx
# 0                     187.42                1        221.7    2     2
# 1                     322.50                7        453.2    2     1
# 2                     210.03                4        201.7    2     3
#
#                    price  sale  bprofit  sprofit
# current_ask_idx
# 0                214.385     3   26.715   38.885
# 1                129.250     2   39.450   18.150
# 2                200.715     3   40.385   25.215

# %%
env2.db.step_data
# Out:
# Empty DataFrame
# Columns: [rnd, period, step, bids, asks, current_bid, current_bid_idx, current_ask, current_ask_idx, buy, sell, price, sale, bprofit, sprofit]
# Index: []

# %%
class TradingEnv2(gym.Env):
    def __init__(self, db, nsteps, render_mode = None):
        self.rnd = 0
        self.period = -1
        self.nperiods = nperiods
        self.db = db
        self.action_space = spaces.Box(0,1,(1,),dtype=np.float32)
        self.observation_space = spaces.Box(-1,200,(13,),dtype=np.float32)

    def reset(self,seed=None):
        [buyer.next_token() for buyer in self.db.buyers]
        [seller.next_token() for seller in self.db.sellers]
        #self.db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
        self.db.reset_period(self.rnd)
        self.timestep = 0
        self.period += 1
        self.db.buyers[0].next_token()
        agent = self.db.buyers[0]
        observation = np.array([0,-1,-1,-1,-1,-1,-1,-1,agent.value,-1,-1,-1,agent.num_tokens_traded], dtype = np.float32)
        return observation, {}

    def step(self, action, user_action, user_id, seed=None, options=None):
        [buyer.next_token() for buyer in self.db.buyers]
        [seller.next_token() for seller in self.db.sellers]
        bid_frac = action.item()
        # convert action to bid
        self.db.buyers[0].next_token()
        min_bid = self.db.buyers[0].value * min_frac
        max_bid = self.db.buyers[0].value * max_frac
        bid = np.round(max_bid * bid_frac + (1 - bid_frac) * min_bid, 2)

        # simulate market
        bids = [buyer.bid(self.db) for buyer in self.db.buyers]
        bids[0] = bid
        asks = [seller.ask(self.db) for seller in self.db.sellers]

        if user_id == 0:
            asks[0] = user_action
        elif user_id == 1:
            bids[1] = user_action
        else:
            pass
            
        current_ask, current_ask_idx, current_bid, current_bid_idx = current_bid_ask(bids, asks)
        sale, price, bprofit, sprofit, buy, sell = buy_sell(self.db, current_bid, current_bid_idx, current_ask, current_ask_idx)
        step_data = [self.rnd, self.period, self.timestep, bids, asks, current_bid, current_bid_idx, current_ask, current_ask_idx, buy, sell, price, sale, bprofit, sprofit]
        self.db.add_step(step_data)

        # compute reward, new state
        reward = 0.0
        if sale == 1 and current_bid_idx == 0:
            reward = bprofit
            
        agent = self.db.buyers[0]
        observation = np.array([self.timestep + 1, current_ask, current_ask_idx, current_bid, current_bid_idx,
                                sale, price, buy, sell, agent.value, agent.step_profit,
                                agent.sale, agent.num_tokens_traded],dtype = np.float32)
        idx = np.isnan(observation)
        observation[idx] = -1.0
        # check termination
        self.timestep += 1
        if self.timestep == nsteps:
            terminated = True
            self.timestep = 0
        else:
            terminated = False
        infos = {"TimeLimit.truncated":True}
        truncated = False
        return observation, reward, terminated, truncated, infos
