# %%
from utils import * 
from algorithms import *
from agents import *

# %%
import warnings
from copy import deepcopy
warnings.filterwarnings('ignore')
numRounds, numPeriods, numSteps = 1, 500, 9
numBuyers, numSellers, numTokens = 3, 3, 3
gameTypes, seed = '1001', 49
disclosure = []
#disclosure = ['currentBid', 'currentBidIdx','currentAsk', 'currentAskIdx','buy','sell','price','sale', 'bids', 'asks']
disclosure = ['currentBid','currentAsk']
depth = 1
gameData = [gameTypes, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed]
# ZeroIntelligence, TruthTeller
buyers = [
    ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0),
    ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0),
]
sellers = [
    ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
    ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
          ]
log = Log(gameData, disclosure)
verbose = 10
rnd = 0
startRounds(gameData, log, buyers, sellers, rnd)

for rnd in range(numRounds):
    startRounds(gameData, log, buyers, sellers, rnd)
    for period in range(numPeriods):
        startPeriods(buyers, sellers)
        profits = []
        bids_ = []
        for step in range(numSteps):
            startSteps(buyers, sellers)
            bids, asks = collectOffers(buyers, sellers)
            currentAsk, currentAskIdx, currentBid, currentBidIdx = bestOffers(bids, asks)
            price, buy, sell = trade(buyers, sellers, currentAsk, currentAskIdx, currentBid, currentBidIdx)
            bprofit, sprofit = 0, 0
            if price > 0:
                buyers[currentBidIdx].transact(price)
                sellers[currentAskIdx].transact(price)
                bprofit = buyers[currentBidIdx].stepProfits
                sprofit = sellers[currentAskIdx].stepProfits
            with torch.no_grad():
                profits.append([buyers[0].stepProfits,buyers[1].stepProfits])
                bids_.append([bids[0], bids[1]])
            log.addStep([rnd, period, step, bids, asks, currentBid, currentBidIdx, currentAsk, currentAskIdx, buy, sell, price, price>0, bprofit, sprofit])
            observe(buyers, sellers, log.disclose())
            updateStates(buyers, sellers)
            updatePolicy(buyers, sellers)
            endSteps(buyers, sellers)
            
        if period%(numPeriods/20)==0:
            #print(rnd, period, log.stepData[['currentBidIdx', 'bprofit']].tail(verbose).groupby('currentBidIdx').sum().values.reshape(-1,))
            with torch.no_grad():
                print(rnd, period, np.nanmean(bids_, axis = 0), np.sum(profits, axis = 0))
                display(log.getPeriod(0, period))
            pass
        endPeriods(buyers, sellers)
    endRounds(buyers, sellers)
# Out:
# 0 0 [12.02222222 33.33333333] [0.95 3.45]
#    rnd  period  step          bids           asks  currentBid  currentBidIdx  \
# 0    0       0     0  [25.7, 54.9]   [77.1, 57.6]        54.9              1
# 1    0       0     1  [78.0, 42.2]  [77.5, 118.7]        78.0              0
# 2    0       0     2   [0.9, 20.2]   [77.9, 86.9]        20.2              1
# 3    0       0     3   [0.7, 19.0]  [58.8, 117.2]        19.0              1
# 4    0       0     4   [0.8, 37.5]   [77.2, 65.3]        37.5              1
# 5    0       0     5   [0.9, 35.3]   [65.8, 66.5]        35.3              1
# 6    0       0     6   [0.2, 14.7]  [79.5, 113.5]        14.7              1
# 7    0       0     7   [0.1, 32.0]  [57.4, 119.1]        32.0              1
# 8    0       0     8   [0.9, 44.2]   [63.6, 99.6]        44.2              1
#
#    currentAsk  currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 0        57.6              1   True   True  56.25   True     3.45    19.65
# 1        77.5              0   True   True  77.75   True     0.95    33.95
# 2        77.9              0  False  False    NaN  False     0.00     0.00
# 3        58.8              0  False  False    NaN  False     0.00     0.00
# 4        65.3              1  False  False    NaN  False     0.00     0.00
# 5        65.8              0  False  False    NaN  False     0.00     0.00
# 6        79.5              0  False  False    NaN  False     0.00     0.00
# 7        57.4              0  False  False    NaN  False     0.00     0.00
# 8        63.6              0  False  False    NaN  False     0.00     0.00
# 0 25 [ 1.78888889 27.3       ] [13.   6.3]
#      rnd  period  step         bids           asks  currentBid  currentBidIdx  \
# 225    0      25     0  [11.5, 7.2]   [82.6, 65.7]        11.5              0
# 226    0      25     1  [1.0, 51.4]   [55.4, 98.3]        51.4              1
# 227    0      25     2  [0.1, 42.2]  [77.2, 106.7]        42.2              1
# 228    0      25     3  [1.0, 28.5]  [56.9, 118.6]        28.5              1
# 229    0      25     4  [0.5, 42.1]   [75.8, 80.1]        42.1              1
# 230    0      25     5  [0.3, 12.1]   [79.5, 75.5]        12.1              1
# 231    0      25     6  [0.3, 21.7]   [92.7, 95.6]        21.7              1
# 232    0      25     7  [1.2, 34.3]   [78.4, 67.9]        34.3              1
# 233    0      25     8   [0.2, 6.2]   [87.8, 95.4]         6.2              1
#
#      currentAsk  currentAskIdx    buy   sell  price   sale  bprofit  sprofit
# 225        65.7              1   True  False   65.7   True     13.0     29.1
# 226        55.4              0   True   True   53.4   True      6.3      9.6
# 227        77.2              0  False  False    NaN  False      0.0      0.0
# 228        56.9              0  False  False    NaN  False      0.0      0.0
# 229        75.8              0  False  False    NaN  False      0.0      0.0
# 230        75.5              1  False  False    NaN  False      0.0      0.0
# 231        92.7              0  False  False    NaN  False      0.0      0.0
# 232        67.9              1  False  False    NaN  False      0.0      0.0
# 233        87.8              0  False  False    NaN  False      0.0      0.0
# 0 50 [15.12222222 29.97777778] [6.   2.15]
#      rnd  period  step          bids           asks  currentBid  \
# 450    0      50     0  [49.1, 59.0]   [83.1, 56.1]        59.0
# 451    0      50     1  [17.6, 24.2]   [54.9, 89.5]        24.2
# 452    0      50     2  [28.7, 39.5]   [73.5, 76.1]        39.5
# 453    0      50     3  [15.5, 32.0]  [67.5, 123.3]        32.0
# 454    0      50     4   [22.3, 7.0]   [72.7, 76.9]        22.3
# 455    0      50     5   [0.1, 41.5]   [93.1, 75.0]        41.5
# 456    0      50     6   [0.9, 22.6]   [56.2, 77.2]        22.6
# 457    0      50     7   [1.2, 11.5]  [60.6, 116.1]        11.5
# 458    0      50     8   [0.7, 32.5]   [81.3, 91.8]        32.5
#
#      currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 450              1        56.1              1   True   True  57.55   True
# 451              1        54.9              0  False  False    NaN  False
# 452              1        73.5              0  False  False    NaN  False
# 453              1        67.5              0  False  False    NaN  False
# 454              0        72.7              0   True  False  72.70   True
# 455              1        75.0              1  False  False    NaN  False
# 456              1        56.2              0  False  False    NaN  False
# 457              1        60.6              0  False  False    NaN  False
# 458              1        81.3              0  False  False    NaN  False
#
#      bprofit  sprofit
# 450     2.15    20.95
# 451     0.00     0.00
# 452     0.00     0.00
# 453     0.00     0.00
# 454     6.00    28.90
# 455     0.00     0.00
# 456     0.00     0.00
# 457     0.00     0.00
# 458     0.00     0.00
# 0 75 [ 7.35555556 31.91111111] [18.65  1.1 ]
#      rnd  period  step          bids           asks  currentBid  \
# 675    0      75     0  [60.9, 42.0]   [77.4, 59.2]        60.9
# 676    0      75     1   [0.8, 58.6]  [61.4, 101.4]        58.6
# 677    0      75     2   [0.9, 30.9]   [94.3, 77.6]        30.9
# 678    0      75     3   [0.5, 24.2]  [94.8, 116.5]        24.2
# 679    0      75     4   [0.6, 16.1]  [60.2, 114.7]        16.1
# 680    0      75     5   [0.5, 29.6]   [81.2, 95.3]        29.6
# 681    0      75     6    [1.1, 9.6]   [60.4, 65.3]         9.6
# 682    0      75     7   [0.5, 34.3]  [62.3, 105.0]        34.3
# 683    0      75     8   [0.4, 41.9]   [51.5, 97.3]        41.9
#
#      currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 675              0        59.2              1   True   True  60.05   True
# 676              1        61.4              0  False   True  58.60   True
# 677              1        77.6              1  False  False    NaN  False
# 678              1        94.8              0  False  False    NaN  False
# 679              1        60.2              0  False  False    NaN  False
# 680              1        81.2              0  False  False    NaN  False
# 681              1        60.4              0  False  False    NaN  False
# 682              1        62.3              0  False  False    NaN  False
# 683              1        51.5              0  False  False    NaN  False
#
#      bprofit  sprofit
# 675    18.65    23.45
# 676     1.10    14.80
# 677     0.00     0.00
# 678     0.00     0.00
# 679     0.00     0.00
# 680     0.00     0.00
# 681     0.00     0.00
# 682     0.00     0.00
# 683     0.00     0.00
# 0 100 [ 7.25555556 24.46666667] [25.9  4.8]
#      rnd  period  step          bids           asks  currentBid  \
# 900    0     100     0  [58.5, 24.9]   [66.2, 47.1]        58.5
# 901    0     100     1   [0.9, 30.8]   [67.6, 69.0]        30.8
# 902    0     100     2   [1.1, 12.3]   [81.1, 89.9]        12.3
# 903    0     100     3   [0.5, 28.3]  [68.0, 120.3]        28.3
# 904    0     100     4   [0.4, 55.5]   [54.3, 89.0]        55.5
# 905    0     100     5   [0.9, 11.0]   [72.1, 80.4]        11.0
# 906    0     100     6   [1.2, 34.6]   [58.6, 68.5]        34.6
# 907    0     100     7   [0.8, 15.9]   [59.1, 90.0]        15.9
# 908    0     100     8    [1.0, 6.9]   [77.8, 68.4]         6.9
#
#      currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 900              0        47.1              1   True   True   52.8   True
# 901              1        67.6              0  False  False    NaN  False
# 902              1        81.1              0  False  False    NaN  False
# 903              1        68.0              0  False  False    NaN  False
# 904              1        54.3              0   True   True   54.9   True
# 905              1        72.1              0  False  False    NaN  False
# 906              1        58.6              0  False  False    NaN  False
# 907              1        59.1              0  False  False    NaN  False
# 908              1        68.4              1  False  False    NaN  False
#
#      bprofit  sprofit
# 900     25.9     16.2
# 901      0.0      0.0
# 902      0.0      0.0
# 903      0.0      0.0
# 904      4.8     11.1
# 905      0.0      0.0
# 906      0.0      0.0
# 907      0.0      0.0
# 908      0.0      0.0
# 0 125 [13.31111111 25.1       ] [25.05  6.35]
#       rnd  period  step          bids           asks  currentBid  \
# 1125    0     125     0  [43.3, 58.8]   [47.9, 66.2]        58.8
# 1126    0     125     1   [9.5, 31.3]   [83.4, 64.2]        31.3
# 1127    0     125     2  [12.5, 17.9]   [56.4, 50.6]        17.9
# 1128    0     125     3  [52.6, 10.9]   [56.3, 54.7]        52.6
# 1129    0     125     4   [0.2, 18.5]   [77.6, 88.0]        18.5
# 1130    0     125     5   [0.2, 24.9]  [91.7, 104.2]        24.9
# 1131    0     125     6    [0.8, 8.9]   [69.6, 93.4]         8.9
# 1132    0     125     7   [0.2, 36.8]   [63.2, 93.8]        36.8
# 1133    0     125     8   [0.5, 17.9]  [79.1, 122.3]        17.9
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 1125              1        47.9              0   True   True  53.35   True
# 1126              1        64.2              1  False  False    NaN  False
# 1127              1        50.6              1  False  False    NaN  False
# 1128              0        54.7              1   True   True  53.65   True
# 1129              1        77.6              0  False  False    NaN  False
# 1130              1        91.7              0  False  False    NaN  False
# 1131              1        69.6              0  False  False    NaN  False
# 1132              1        63.2              0  False  False    NaN  False
# 1133              1        79.1              0  False  False    NaN  False
#
#       bprofit  sprofit
# 1125     6.35     9.55
# 1126     0.00     0.00
# 1127     0.00     0.00
# 1128    25.05    17.05
# 1129     0.00     0.00
# 1130     0.00     0.00
# 1131     0.00     0.00
# 1132     0.00     0.00
# 1133     0.00     0.00
# 0 150 [ 4.28888889 25.05555556] [32.7 15.5]
#       rnd  period  step          bids           asks  currentBid  \
# 1350    0     150     0  [32.9, 12.5]   [46.0, 58.4]        32.9
# 1351    0     150     1   [0.6, 23.3]   [74.4, 44.2]        23.3
# 1352    0     150     2   [1.3, 27.1]   [92.5, 80.5]        27.1
# 1353    0     150     3   [0.9, 41.4]   [96.6, 95.0]        41.4
# 1354    0     150     4   [0.3, 42.4]  [90.4, 118.8]        42.4
# 1355    0     150     5   [0.8, 22.1]   [92.2, 85.9]        22.1
# 1356    0     150     6   [0.6, 29.1]   [78.4, 92.4]        29.1
# 1357    0     150     7   [0.9, 21.7]   [86.5, 74.6]        21.7
# 1358    0     150     8    [0.3, 5.9]   [80.0, 95.6]         5.9
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 1350              0        46.0              0   True  False   46.0   True
# 1351              1        44.2              1   True  False   44.2   True
# 1352              1        80.5              1  False  False    NaN  False
# 1353              1        95.0              1  False  False    NaN  False
# 1354              1        90.4              0  False  False    NaN  False
# 1355              1        85.9              1  False  False    NaN  False
# 1356              1        78.4              0  False  False    NaN  False
# 1357              1        74.6              1  False  False    NaN  False
# 1358              1        80.0              0  False  False    NaN  False
#
#       bprofit  sprofit
# 1350     32.7      2.2
# 1351     15.5      7.6
# 1352      0.0      0.0
# 1353      0.0      0.0
# 1354      0.0      0.0
# 1355      0.0      0.0
# 1356      0.0      0.0
# 1357      0.0      0.0
# 1358      0.0      0.0
# 0 175 [ 8.52222222 25.86666667] [ 4.3  12.55]
#       rnd  period  step          bids           asks  currentBid  \
# 1575    0     175     0  [51.1, 53.5]   [52.8, 41.4]        53.5
# 1576    0     175     1   [8.9, 38.4]   [72.9, 70.7]        38.4
# 1577    0     175     2   [13.1, 4.6]   [75.4, 74.4]        13.1
# 1578    0     175     3   [0.6, 42.2]  [79.9, 189.0]        42.2
# 1579    0     175     4   [0.4, 35.0]  [46.6, 158.9]        35.0
# 1580    0     175     5   [1.2, 10.0]  [56.6, 103.5]        10.0
# 1581    0     175     6   [0.4, 20.5]  [58.1, 140.6]        20.5
# 1582    0     175     7   [0.5, 19.2]  [44.3, 141.0]        19.2
# 1583    0     175     8    [0.5, 9.4]  [60.2, 109.4]         9.4
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 1575              1        41.4              1   True   True  47.45   True
# 1576              1        70.7              1  False  False    NaN  False
# 1577              0        74.4              1   True  False  74.40   True
# 1578              1        79.9              0  False  False    NaN  False
# 1579              1        46.6              0  False  False    NaN  False
# 1580              1        56.6              0  False  False    NaN  False
# 1581              1        58.1              0  False  False    NaN  False
# 1582              1        44.3              0   True  False  44.30   True
# 1583              1        60.2              0  False  False    NaN  False
#
#       bprofit  sprofit
# 1575    12.25    10.85
# 1576     0.00     0.00
# 1577     4.30     9.50
# 1578     0.00     0.00
# 1579     0.00     0.00
# 1580     0.00     0.00
# 1581     0.00     0.00
# 1582     0.30     0.50
# 1583     0.00     0.00
# 0 200 [ 6.67777778 27.55555556] [23.65 14.8 ]
#       rnd  period  step          bids           asks  currentBid  \
# 1800    0     200     0  [54.0, 40.5]   [56.1, 58.5]        54.0
# 1801    0     200     1   [0.9, 42.7]   [56.7, 47.1]        42.7
# 1802    0     200     2   [0.9, 30.1]   [59.5, 93.2]        30.1
# 1803    0     200     3    [0.6, 5.5]   [92.5, 67.8]         5.5
# 1804    0     200     4    [0.5, 6.4]   [52.9, 69.4]         6.4
# 1805    0     200     5   [0.3, 27.1]   [82.3, 92.3]        27.1
# 1806    0     200     6   [1.0, 23.4]   [58.7, 98.9]        23.4
# 1807    0     200     7   [1.2, 42.2]  [57.0, 105.5]        42.2
# 1808    0     200     8   [0.7, 30.1]  [88.5, 104.9]        30.1
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 1800              0        56.1              0   True   True  55.05   True
# 1801              1        47.1              1   True   True  44.90   True
# 1802              1        59.5              0  False  False    NaN  False
# 1803              1        67.8              1  False  False    NaN  False
# 1804              1        52.9              0  False  False    NaN  False
# 1805              1        82.3              0  False  False    NaN  False
# 1806              1        58.7              0  False  False    NaN  False
# 1807              1        57.0              0  False  False    NaN  False
# 1808              1        88.5              0  False  False    NaN  False
#
#       bprofit  sprofit
# 1800    23.65    11.25
# 1801    14.80     8.30
# 1802     0.00     0.00
# 1803     0.00     0.00
# 1804     0.00     0.00
# 1805     0.00     0.00
# 1806     0.00     0.00
# 1807     0.00     0.00
# 1808     0.00     0.00
# 0 225 [ 9.34444444 26.74444444] [15.35 17.3 ]
#       rnd  period  step          bids           asks  currentBid  \
# 2025    0     225     0  [77.8, 26.4]   [48.9, 66.9]        77.8
# 2026    0     225     1   [1.3, 42.4]   [89.9, 61.1]        42.4
# 2027    0     225     2   [0.8, 39.8]   [52.3, 73.9]        39.8
# 2028    0     225     3   [1.3, 23.5]   [67.0, 65.6]        23.5
# 2029    0     225     4   [0.2, 26.7]  [86.1, 111.7]        26.7
# 2030    0     225     5    [0.5, 5.5]   [80.6, 90.1]         5.5
# 2031    0     225     6   [1.0, 42.2]   [71.2, 87.2]        42.2
# 2032    0     225     7    [0.8, 9.7]   [77.1, 75.0]         9.7
# 2033    0     225     8   [0.4, 24.5]   [57.3, 76.3]        24.5
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 2025              0        48.9              0   True   True  63.35   True
# 2026              1        61.1              1  False   True  42.40   True
# 2027              1        52.3              0  False  False    NaN  False
# 2028              1        65.6              1  False  False    NaN  False
# 2029              1        86.1              0  False  False    NaN  False
# 2030              1        80.6              0  False  False    NaN  False
# 2031              1        71.2              0  False  False    NaN  False
# 2032              1        75.0              1  False  False    NaN  False
# 2033              1        57.3              0  False  False    NaN  False
#
#       bprofit  sprofit
# 2025    15.35    19.55
# 2026    17.30     5.80
# 2027     0.00     0.00
# 2028     0.00     0.00
# 2029     0.00     0.00
# 2030     0.00     0.00
# 2031     0.00     0.00
# 2032     0.00     0.00
# 2033     0.00     0.00
# 0 250 [ 5.41111111 28.11111111] [39.2  12.45]
#       rnd  period  step          bids           asks  currentBid  \
# 2250    0     250     0  [42.2, 31.1]   [77.0, 36.8]        42.2
# 2251    0     250     1   [0.8, 45.3]   [49.2, 92.2]        45.3
# 2252    0     250     2   [1.2, 27.8]   [86.9, 78.5]        27.8
# 2253    0     250     3   [0.4, 33.9]  [69.3, 115.7]        33.9
# 2254    0     250     4   [1.2, 25.4]   [64.7, 65.8]        25.4
# 2255    0     250     5   [0.4, 31.2]  [70.5, 107.4]        31.2
# 2256    0     250     6   [1.0, 15.5]   [87.0, 72.9]        15.5
# 2257    0     250     7   [1.1, 29.3]  [55.1, 108.5]        29.3
# 2258    0     250     8   [0.4, 13.5]   [62.3, 86.9]        13.5
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 2250              0        36.8              1   True   True  39.50   True
# 2251              1        49.2              0   True   True  47.25   True
# 2252              1        78.5              1  False  False    NaN  False
# 2253              1        69.3              0  False  False    NaN  False
# 2254              1        64.7              0  False  False    NaN  False
# 2255              1        70.5              0  False  False    NaN  False
# 2256              1        72.9              1  False  False    NaN  False
# 2257              1        55.1              0  False  False    NaN  False
# 2258              1        62.3              0  False  False    NaN  False
#
#       bprofit  sprofit
# 2250    39.20     2.90
# 2251    12.45     3.45
# 2252     0.00     0.00
# 2253     0.00     0.00
# 2254     0.00     0.00
# 2255     0.00     0.00
# 2256     0.00     0.00
# 2257     0.00     0.00
# 2258     0.00     0.00
# 0 275 [ 8.72222222 21.75555556] [20.55 15.1 ]
#       rnd  period  step          bids           asks  currentBid  \
# 2475    0     275     0  [10.6, 24.1]   [44.6, 68.8]        24.1
# 2476    0     275     1   [62.9, 9.4]   [89.7, 53.4]        62.9
# 2477    0     275     2   [1.2, 17.6]   [71.2, 69.3]        17.6
# 2478    0     275     3   [0.4, 37.0]  [51.2, 120.5]        37.0
# 2479    0     275     4   [0.9, 24.4]  [89.5, 112.1]        24.4
# 2480    0     275     5   [0.6, 28.4]   [64.0, 74.2]        28.4
# 2481    0     275     6   [1.1, 25.4]   [55.2, 87.5]        25.4
# 2482    0     275     7   [0.5, 17.1]   [51.1, 74.2]        17.1
# 2483    0     275     8   [0.3, 12.4]   [60.7, 72.1]        12.4
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 2475              1        44.6              0   True  False  44.60   True
# 2476              0        53.4              1   True   True  58.15   True
# 2477              1        69.3              1  False  False    NaN  False
# 2478              1        51.2              0  False  False    NaN  False
# 2479              1        89.5              0  False  False    NaN  False
# 2480              1        64.0              0  False  False    NaN  False
# 2481              1        55.2              0  False  False    NaN  False
# 2482              1        51.1              0  False  False    NaN  False
# 2483              1        60.7              0  False  False    NaN  False
#
#       bprofit  sprofit
# 2475    15.10     0.80
# 2476    20.55    21.55
# 2477     0.00     0.00
# 2478     0.00     0.00
# 2479     0.00     0.00
# 2480     0.00     0.00
# 2481     0.00     0.00
# 2482     0.00     0.00
# 2483     0.00     0.00
# 0 300 [10.14444444 23.97777778] [20.7  4.1]
#       rnd  period  step          bids           asks  currentBid  \
# 2700    0     300     0  [26.2, 54.3]   [57.1, 56.9]        54.3
# 2701    0     300     1  [58.0, 34.3]  [81.6, 112.0]        58.0
# 2702    0     300     2    [1.2, 5.3]   [53.4, 69.1]         5.3
# 2703    0     300     3   [0.9, 14.4]   [83.7, 99.3]        14.4
# 2704    0     300     4   [1.2, 10.7]  [60.8, 116.8]        10.7
# 2705    0     300     5   [0.8, 27.0]  [94.0, 116.1]        27.0
# 2706    0     300     6   [1.0, 30.8]  [88.4, 119.1]        30.8
# 2707    0     300     7   [1.2, 34.3]   [94.5, 91.0]        34.3
# 2708    0     300     8    [0.8, 4.7]  [86.6, 101.9]         4.7
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 2700              1        56.9              1   True   True   55.6   True
# 2701              0        81.6              0  False   True   58.0   True
# 2702              1        53.4              0  False  False    NaN  False
# 2703              1        83.7              0  False  False    NaN  False
# 2704              1        60.8              0  False  False    NaN  False
# 2705              1        94.0              0  False  False    NaN  False
# 2706              1        88.4              0  False  False    NaN  False
# 2707              1        91.0              1  False  False    NaN  False
# 2708              1        86.6              0  False  False    NaN  False
#
#       bprofit  sprofit
# 2700      4.1     19.0
# 2701     20.7     14.2
# 2702      0.0      0.0
# 2703      0.0      0.0
# 2704      0.0      0.0
# 2705      0.0      0.0
# 2706      0.0      0.0
# 2707      0.0      0.0
# 2708      0.0      0.0
# 0 325 [ 7.87777778 23.88888889] [18.7 11.4]
#       rnd  period  step          bids           asks  currentBid  \
# 2925    0     325     0  [64.2, 32.4]   [62.5, 55.8]        64.2
# 2926    0     325     1   [1.0, 11.9]  [48.3, 105.0]        11.9
# 2927    0     325     2   [1.3, 10.1]  [56.7, 112.4]        10.1
# 2928    0     325     3   [0.8, 39.6]   [73.5, 79.1]        39.6
# 2929    0     325     4    [0.2, 8.6]   [57.8, 96.0]         8.6
# 2930    0     325     5   [0.7, 29.5]   [92.0, 98.9]        29.5
# 2931    0     325     6   [0.9, 43.9]   [60.6, 98.3]        43.9
# 2932    0     325     7   [0.7, 33.4]  [72.9, 100.6]        33.4
# 2933    0     325     8    [1.1, 5.6]  [84.5, 113.9]         5.6
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 2925              0        55.8              1   True   True   60.0   True
# 2926              1        48.3              0   True  False   48.3   True
# 2927              1        56.7              0  False  False    NaN  False
# 2928              1        73.5              0  False  False    NaN  False
# 2929              1        57.8              0  False  False    NaN  False
# 2930              1        92.0              0  False  False    NaN  False
# 2931              1        60.6              0  False  False    NaN  False
# 2932              1        72.9              0  False  False    NaN  False
# 2933              1        84.5              0  False  False    NaN  False
#
#       bprofit  sprofit
# 2925     18.7     23.4
# 2926     11.4      4.5
# 2927      0.0      0.0
# 2928      0.0      0.0
# 2929      0.0      0.0
# 2930      0.0      0.0
# 2931      0.0      0.0
# 2932      0.0      0.0
# 2933      0.0      0.0
# 0 350 [ 6.1        25.58888889] [32.1  8.1]
#       rnd  period  step          bids           asks  currentBid  \
# 3150    0     350     0  [11.1, 20.4]   [51.6, 66.4]        20.4
# 3151    0     350     1  [38.6, 23.5]   [70.1, 54.6]        38.6
# 3152    0     350     2   [0.9, 20.0]   [69.2, 98.9]        20.0
# 3153    0     350     3   [1.2, 33.5]   [67.5, 66.0]        33.5
# 3154    0     350     4   [1.2, 15.8]   [59.9, 74.8]        15.8
# 3155    0     350     5   [0.9, 28.2]  [67.6, 119.0]        28.2
# 3156    0     350     6   [0.2, 37.7]   [58.5, 93.1]        37.7
# 3157    0     350     7   [0.3, 32.1]   [62.5, 92.4]        32.1
# 3158    0     350     8   [0.5, 19.1]   [89.6, 83.2]        19.1
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 3150              1        51.6              0   True  False   51.6   True
# 3151              0        54.6              1   True   True   46.6   True
# 3152              1        69.2              0  False  False    NaN  False
# 3153              1        66.0              1  False  False    NaN  False
# 3154              1        59.9              0  False  False    NaN  False
# 3155              1        67.6              0  False  False    NaN  False
# 3156              1        58.5              0  False  False    NaN  False
# 3157              1        62.5              0  False  False    NaN  False
# 3158              1        83.2              1  False  False    NaN  False
#
#       bprofit  sprofit
# 3150      8.1      7.8
# 3151     32.1     10.0
# 3152      0.0      0.0
# 3153      0.0      0.0
# 3154      0.0      0.0
# 3155      0.0      0.0
# 3156      0.0      0.0
# 3157      0.0      0.0
# 3158      0.0      0.0
# 0 375 [ 8.6        28.05555556] [15.3 13.9]
#       rnd  period  step          bids           asks  currentBid  \
# 3375    0     375     0  [70.7, 32.0]   [66.2, 56.1]        70.7
# 3376    0     375     1   [1.1, 13.0]   [81.2, 77.4]        13.0
# 3377    0     375     2   [1.2, 36.8]  [45.8, 115.8]        36.8
# 3378    0     375     3   [1.1, 28.4]   [72.8, 93.8]        28.4
# 3379    0     375     4    [0.7, 7.3]   [58.3, 88.6]         7.3
# 3380    0     375     5   [1.0, 36.0]   [93.2, 80.0]        36.0
# 3381    0     375     6   [0.2, 33.9]   [75.8, 67.0]        33.9
# 3382    0     375     7   [0.3, 23.6]   [61.7, 66.1]        23.6
# 3383    0     375     8   [1.1, 41.5]   [96.5, 66.6]        41.5
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 3375              0        56.1              1   True   True   63.4   True
# 3376              1        77.4              1  False  False    NaN  False
# 3377              1        45.8              0   True  False   45.8   True
# 3378              1        72.8              0  False  False    NaN  False
# 3379              1        58.3              0  False  False    NaN  False
# 3380              1        80.0              1  False  False    NaN  False
# 3381              1        67.0              1  False  False    NaN  False
# 3382              1        61.7              0  False  False    NaN  False
# 3383              1        66.6              1  False  False    NaN  False
#
#       bprofit  sprofit
# 3375     15.3     26.8
# 3376      0.0      0.0
# 3377     13.9      2.0
# 3378      0.0      0.0
# 3379      0.0      0.0
# 3380      0.0      0.0
# 3381      0.0      0.0
# 3382      0.0      0.0
# 3383      0.0      0.0
# 0 400 [ 4.62222222 22.54444444] [9.6 9.6]
#       rnd  period  step          bids           asks  currentBid  \
# 3600    0     400     0  [12.0, 34.0]   [80.8, 50.1]        34.0
# 3601    0     400     1  [25.2, 20.2]   [69.1, 82.7]        25.2
# 3602    0     400     2   [0.5, 27.4]   [51.5, 80.7]        27.4
# 3603    0     400     3    [0.5, 6.9]   [65.5, 72.3]         6.9
# 3604    0     400     4   [0.2, 17.3]  [95.2, 119.6]        17.3
# 3605    0     400     5   [1.2, 31.0]   [94.6, 87.3]        31.0
# 3606    0     400     6   [1.1, 28.5]   [85.1, 83.8]        28.5
# 3607    0     400     7   [0.6, 28.1]  [66.9, 120.7]        28.1
# 3608    0     400     8    [0.3, 9.5]  [68.8, 121.0]         9.5
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 3600              1        50.1              1   True  False   50.1   True
# 3601              0        69.1              0   True  False   69.1   True
# 3602              1        51.5              0  False  False    NaN  False
# 3603              1        65.5              0  False  False    NaN  False
# 3604              1        95.2              0  False  False    NaN  False
# 3605              1        87.3              1  False  False    NaN  False
# 3606              1        83.8              1  False  False    NaN  False
# 3607              1        66.9              0  False  False    NaN  False
# 3608              1        68.8              0  False  False    NaN  False
#
#       bprofit  sprofit
# 3600      9.6     13.5
# 3601      9.6     25.3
# 3602      0.0      0.0
# 3603      0.0      0.0
# 3604      0.0      0.0
# 3605      0.0      0.0
# 3606      0.0      0.0
# 3607      0.0      0.0
# 3608      0.0      0.0
# 0 425 [ 8.36666667 27.16666667] [33.8 11.9]
#       rnd  period  step          bids           asks  currentBid  \
# 3825    0     425     0  [23.9, 31.8]   [80.9, 67.3]        31.8
# 3826    0     425     1  [47.6, 18.7]   [63.6, 42.2]        47.6
# 3827    0     425     2   [0.3, 21.3]  [81.9, 112.5]        21.3
# 3828    0     425     3   [0.2, 47.8]  [62.7, 114.8]        47.8
# 3829    0     425     4    [0.7, 4.5]  [86.3, 108.1]         4.5
# 3830    0     425     5   [0.3, 30.0]   [63.2, 99.9]        30.0
# 3831    0     425     6   [0.8, 21.8]   [87.8, 71.7]        21.8
# 3832    0     425     7   [0.8, 27.0]   [72.2, 69.1]        27.0
# 3833    0     425     8   [0.7, 41.6]   [54.4, 80.5]        41.6
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 3825              1        67.3              1  False  False    NaN  False
# 3826              0        42.2              1   True   True   44.9   True
# 3827              1        81.9              0  False  False    NaN  False
# 3828              1        62.7              0  False   True   47.8   True
# 3829              1        86.3              0  False  False    NaN  False
# 3830              1        63.2              0  False  False    NaN  False
# 3831              1        71.7              1  False  False    NaN  False
# 3832              1        69.1              1  False  False    NaN  False
# 3833              1        54.4              0  False  False    NaN  False
#
#       bprofit  sprofit
# 3825      0.0      0.0
# 3826     33.8      8.3
# 3827      0.0      0.0
# 3828     11.9      4.0
# 3829      0.0      0.0
# 3830      0.0      0.0
# 3831      0.0      0.0
# 3832      0.0      0.0
# 3833      0.0      0.0
# 0 450 [ 7.54444444 24.36666667] [24.95 14.4 ]
#       rnd  period  step          bids           asks  currentBid  \
# 4050    0     450     0  [62.3, 12.3]   [73.2, 45.2]        62.3
# 4051    0     450     1    [1.3, 9.8]   [45.3, 73.8]         9.8
# 4052    0     450     2   [0.2, 35.7]  [86.1, 106.2]        35.7
# 4053    0     450     3   [0.9, 42.4]   [56.8, 69.8]        42.4
# 4054    0     450     4   [0.2, 28.6]  [53.4, 119.9]        28.6
# 4055    0     450     5   [0.7, 16.5]   [92.1, 79.7]        16.5
# 4056    0     450     6   [0.9, 35.9]  [80.2, 112.6]        35.9
# 4057    0     450     7   [0.5, 25.2]   [77.4, 98.3]        25.2
# 4058    0     450     8   [0.9, 12.9]  [52.4, 102.5]        12.9
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 4050              0        45.2              1   True   True  53.75   True
# 4051              1        45.3              0   True  False  45.30   True
# 4052              1        86.1              0  False  False    NaN  False
# 4053              1        56.8              0  False  False    NaN  False
# 4054              1        53.4              0  False  False    NaN  False
# 4055              1        79.7              1  False  False    NaN  False
# 4056              1        80.2              0  False  False    NaN  False
# 4057              1        77.4              0  False  False    NaN  False
# 4058              1        52.4              0  False  False    NaN  False
#
#       bprofit  sprofit
# 4050    24.95    17.15
# 4051    14.40     1.50
# 4052     0.00     0.00
# 4053     0.00     0.00
# 4054     0.00     0.00
# 4055     0.00     0.00
# 4056     0.00     0.00
# 4057     0.00     0.00
# 4058     0.00     0.00
# 0 475 [ 5.88888889 28.56666667] [30.1 15.1]
#       rnd  period  step          bids           asks  currentBid  \
# 4275    0     475     0  [47.0, 43.4]   [71.6, 50.2]        47.0
# 4276    0     475     1   [0.3, 27.1]   [71.8, 85.4]        27.1
# 4277    0     475     2   [0.6, 14.7]  [44.6, 112.5]        14.7
# 4278    0     475     3   [1.2, 12.4]  [71.2, 122.1]        12.4
# 4279    0     475     4    [0.7, 8.4]   [60.8, 84.7]         8.4
# 4280    0     475     5   [0.9, 35.5]  [55.6, 120.8]        35.5
# 4281    0     475     6   [0.3, 42.2]   [75.5, 93.3]        42.2
# 4282    0     475     7   [1.0, 33.7]  [75.5, 102.2]        33.7
# 4283    0     475     8   [1.0, 39.7]   [72.3, 71.9]        39.7
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 4275              0        50.2              1   True   True   48.6   True
# 4276              1        71.8              0  False  False    NaN  False
# 4277              1        44.6              0   True  False   44.6   True
# 4278              1        71.2              0  False  False    NaN  False
# 4279              1        60.8              0  False  False    NaN  False
# 4280              1        55.6              0  False  False    NaN  False
# 4281              1        75.5              0  False  False    NaN  False
# 4282              1        75.5              0  False  False    NaN  False
# 4283              1        71.9              1  False  False    NaN  False
#
#       bprofit  sprofit
# 4275     30.1     12.0
# 4276      0.0      0.0
# 4277     15.1      0.8
# 4278      0.0      0.0
# 4279      0.0      0.0
# 4280      0.0      0.0
# 4281      0.0      0.0
# 4282      0.0      0.0
# 4283      0.0      0.0

# %%
log.getPeriod(0, period-1)
# Out:
#       rnd  period  step          bids           asks  currentBid  \
# 4482    0     498     0  [37.8, 38.4]   [73.4, 44.4]        38.4
# 4483    0     498     1  [21.7, 28.7]  [76.7, 109.3]        28.7
# 4484    0     498     2  [69.6, 21.4]  [61.7, 102.6]        69.6
# 4485    0     498     3   [0.7, 24.2]   [56.1, 78.9]        24.2
# 4486    0     498     4   [0.4, 37.1]  [63.7, 122.2]        37.1
# 4487    0     498     5   [1.1, 23.4]  [62.6, 110.7]        23.4
# 4488    0     498     6   [1.0, 41.7]  [51.6, 123.0]        41.7
# 4489    0     498     7   [0.3, 25.6]   [76.3, 97.6]        25.6
# 4490    0     498     8   [0.9, 30.9]  [86.1, 108.0]        30.9
#
#       currentBidIdx  currentAsk  currentAskIdx    buy   sell  price   sale  \
# 4482              1        44.4              1   True   True  41.40   True
# 4483              1        76.7              0  False  False    NaN  False
# 4484              0        61.7              0   True   True  65.65   True
# 4485              1        56.1              0  False  False    NaN  False
# 4486              1        63.7              0  False  False    NaN  False
# 4487              1        62.6              0  False  False    NaN  False
# 4488              1        51.6              0  False  False    NaN  False
# 4489              1        76.3              0  False  False    NaN  False
# 4490              1        86.1              0  False  False    NaN  False
#
#       bprofit  sprofit
# 4482    18.30     4.80
# 4483     0.00     0.00
# 4484    13.05    21.85
# 4485     0.00     0.00
# 4486     0.00     0.00
# 4487     0.00     0.00
# 4488     0.00     0.00
# 4489     0.00     0.00
# 4490     0.00     0.00

# %%
log.graphLearning(trackBuyersIdx = [0], trackSellersIdx = [], rolling_window=100, type = 'period')

# %%
log.graphOffers(0, 100, [0], [])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 log.graphOffers(0, 100, [0], [])
#
# Cell In[8], line 79, in Log.graphOffers(self, rnd, period, trackBuyersIdx, trackSellersIdx)
#      77 notTrackBuyers = [i for i in range(self.numBuyers) if i not in trackBuyersIdx]
#      78 notTrackSellers = [i for i in range(self.numBuyers) if i not in trackSellersIdx]
# ---> 79 ax.plot(periodBids[:,notTrackBuyers], c='red', linestyle='dotted', alpha = 0.3)
#      80 ax.plot(periodBids[:,trackBuyersIdx], c='red', linestyle='dotted', alpha = 1.0)
#      81 ax.scatter(range(self.numSteps), np.max(periodBids, axis = 1), c='red', label='Winning Bids', alpha = 0.5)
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
log.graphSales(0, 100, trackBuyersIdx=[0], trackSellersIdx=[])

# %%
log.stepData.tail(20)

# %%
class Log:
    def __init__(self, gameData,disclosure):
        self.gameData = gameData
        self.gameTypes, self.numBuyers, self.numSellers, self.numTokens, self.numRounds, self.numPeriods, self.numSteps, self.seed = gameData
        self.stepData = pd.DataFrame(columns=['rnd', 'period', 'step', 'bids','asks','currentBid','currentBidIdx','currentAsk',
                                             'currentAskIdx','buy','sell','price','sale', 'bprofit', 'sprofit'])
        self.roundData = pd.DataFrame(columns=['rnd', 'buyerValues', 'sellerCosts', 'demand', 'supply', 'prices', 'peq', 'qeq', 
                                              'buyerReservationPrices', 'sellerReservationPrices', 'buyerSurplus', 'sellerSurplus', 
                                              'totalSurplus', 'buyerSurplusFrac', 'sellerSurplusFrac'])
        self.disclosure = disclosure
        
    def addStep(self, stepData):
        self.stepData.loc[len(self.stepData.index)] = stepData

    def addRound(self, roundData):
        self.roundData.loc[len(self.roundData.index)] = roundData
    
    def disclose(self):
        return self.stepData[self.disclosure].iloc[-1]
        
    def getPeriod(self, rnd, period):
        return self.stepData[(self.stepData.rnd==rnd) & (self.stepData.period==period)]
        
    def getPeriodActivity(self, rnd, period):
        periodData = self.getPeriod(rnd, period)
        periodBids = list(periodData.bids)
        periodAsks = list(periodData.asks)
        periodPrices = list(periodData.price)
        periodSales = np.cumsum(np.where(periodData.price > 0,1,0))
        return np.array(periodBids), np.array(periodAsks), np.array(periodPrices), np.array(periodSales)

    def getRound(self, rnd):
        return self.roundData[(self.roundData.rnd==rnd)]

    def getRoundList(self, rnd):
        return self.getRound(rnd).values.tolist()[0][1:]


    def graphSales(self, rnd, period, trackBuyersIdx = [], trackSellersIdx = []):
        colors = customGraphSettings()
        fig, ax = graphMarket(*self.gameData, *self.getRoundList(rnd))
        periodBids, periodAsks, periodPrices, periodSales = self.getPeriodActivity(rnd,period)
        plt.plot(range(1,len(periodPrices)+1), periodPrices, color='black', linestyle='dashdot', label='Actual Prices')
        
        for j in range(self.numBuyers):
            y = [periodSales[i] for i in range(self.numSteps) if periodPrices[i] > 0]
            x = [periodBids[i][j] for i in range(self.numSteps) if periodPrices[i] > 0]
            if j in trackBuyersIdx:
                plt.plot(y, x, linestyle='dotted', color = 'red')
            else:
                plt.plot(y, x, linestyle='dotted', color = 'red', alpha = 0.2)
                
        for j in range(self.numSellers):
            y = [periodSales[i] for i in range(self.numSteps) if periodPrices[i] > 0]
            x = [periodAsks[i][j] for i in range(self.numSteps) if periodPrices[i] > 0]
            if j in trackSellersIdx:
                plt.plot(y, x, linestyle='dotted', color = 'blue')
            else:
                plt.plot(y, x, linestyle='dotted', color = 'blue', alpha = 0.2)
                
        for i in range(self.numSteps):
            if (periodPrices[i] > 0):
                ax.scatter([periodSales[i]] * len(periodBids[i]), periodBids[i], s=10, alpha=0.2, c='red')
                ax.scatter([periodSales[i]] * len(periodAsks[i]), periodAsks[i], s=10, alpha=0.2, c='blue')
                
        ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.15), ncol=5)
        ax.set_title('Dynamic Double Auction - Transactions', fontsize=16, fontweight='bold')
        plt.text(0.90, 0.10, f'Round: {rnd}', transform=plt.gca().transAxes, alpha=0.5)
        plt.text(0.90, 0.05, f'Period: {period}', transform=plt.gca().transAxes, alpha=0.5)
        plt.show()
    

    def graphOffers(self, rnd, period, trackBuyersIdx = [], trackSellersIdx = []):
        periodBids, periodAsks, periodPrices, periodSales = self.getPeriodActivity(rnd,period)
        fig, ax = plt.subplots()
        colors = customGraphSettings()
        notTrackBuyers = [i for i in range(self.numBuyers) if i not in trackBuyersIdx]
        notTrackSellers = [i for i in range(self.numBuyers) if i not in trackSellersIdx]
        print(notTrackBuyers, self.numBuyers, trackBuyersIdx)
        ax.plot(periodBids[:,notTrackBuyers], c='red', linestyle='dotted', alpha = 0.3)
        ax.plot(periodBids[:,trackBuyersIdx], c='red', linestyle='dotted', alpha = 1.0)
        ax.scatter(range(self.numSteps), np.max(periodBids, axis = 1), c='red', label='Winning Bids', alpha = 0.5)
        ax.plot(periodAsks[:,notTrackSellers], c='blue', linestyle='dotted', alpha = 0.3)
        ax.plot(periodAsks[:,trackSellersIdx], c='blue', linestyle='dotted', alpha = 1.0)
        ax.scatter(range(self.numSteps), np.min(periodAsks, axis = 1), c='blue', label='Winning Asks', alpha = 0.5)
        #ax.plot(periodBids, c='red', linestyle='dotted', label='Bids')
        #ax.plot(periodAsks, c='blue', linestyle='dotted', label='Asks')
        ax.plot(range(self.numSteps), periodPrices, c='black', label='Prices', linestyle='dashdot')
        #ax.scatter(range(self.numSteps), periodPrices, c='black', label='Prices')
        ax.set_title('Dynamic Double Auction - Offers', fontsize=16, fontweight='bold')
        ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.15), ncol=5)
        plt.xlabel('Price')
        plt.ylabel('Time Step')
        ax.yaxis.tick_left()
        ax.xaxis.tick_bottom()
        ax.xaxis.set_label_position('bottom')
        ax.set_yticks(np.arange(0, 100, 5))
        ax.set_xticks(np.arange(0, len(periodSales), 1))
        plt.text(0.90, 0.10, f'Round: {rnd}', transform=plt.gca().transAxes, alpha=0.5)
        plt.text(0.90, 0.05, f'Period: {period}', transform=plt.gca().transAxes, alpha=0.5)
        plt.show()


    def graphLearning(self, trackBuyersIdx = [], trackSellersIdx = [], rolling_window = 1, type = 'period'):
        df = self.stepData
        fig, ax = plt.subplots()
        colors = customGraphSettings()
        for j in range(self.numBuyers):
            rolling_mean = df[df.currentBidIdx == j][[type, 'bprofit']].groupby([type]).sum().rolling(rolling_window).mean()
            if j in trackBuyersIdx:
                ax.plot(rolling_mean, color = 'red', alpha = 1.0, linestyle = 'dotted', label = f'Bidder {j}')
            else:
                ax.plot(rolling_mean, color = 'red', alpha = 0.3, linestyle = 'dotted')
                
        for j in range(self.numSellers):
            rolling_mean = df[df.currentAskIdx == j][[type, 'sprofit']].groupby([type]).sum().rolling(rolling_window).mean()
            if j in trackSellersIdx:
                ax.plot(rolling_mean, color = 'blue', alpha = 1.0, linestyle = 'dotted', label = f'Asker {j}')
            else:
                ax.plot(rolling_mean, color = 'blue', alpha = 0.3, linestyle = 'dotted')
        
        ax.set_title('Learning Curves', fontsize=16, fontweight='bold')
        plt.xlabel('Period')
        plt.ylabel('Avg Profit')
        ax.yaxis.tick_left()
        ax.xaxis.tick_bottom()
        ax.xaxis.set_label_position('bottom')
        #ax.set_yticks(np.arange(0, 100, 5))
        #ax.set_xticks(np.arange(0, 100, 20))
        #ax.text(0.80, 0.10, f'Round: {rnd}', transform=plt.gca().transAxes, alpha=0.5)
        #ax.text(0.80, 0.05, f'Period: {period}', transform=plt.gca().transAxes, alpha=0.5)
        ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.15), ncol=5)
        plt.ylim(ymin=0)
        plt.show()
