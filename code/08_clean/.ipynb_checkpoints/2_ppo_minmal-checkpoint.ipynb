# %% [markdown]
# ### Test

# %%
from utils import * 
from algorithms import *
from agents import *
from env import *

# %%
# HYPERPARAMS
learning_rate  = 0.0003
gamma           = 0.9
lmbda           = 0.9
eps_clip        = 0.2
K_epoch         = 10
rollout_len    = 3
buffer_size    = 10
minibatch_size = 32
verbose = 1
num_states = 2

# %%
# ENVIRONMENT PARAMS
numRounds, numPeriods, numSteps = 1, 10000, 9
numBuyers, numSellers, numTokens = 3, 6, 4
gameTypes, seed = '1111', 42
disclosure = []

class GymEnv(gym.Env):
    def __init__(self, metaData, buyers, sellers, log):
        self.gameData = metaData[0:8]
        self.gameTypes, self.numBuyers, self.numSellers, self.numTokens, self.numRounds, self.numPeriods, self.numSteps, self.seed = self.gameData
        self.disclosure, self.buyers, self.sellers = metaData[8:]
        self.log = log
        self.rnd = 0
        self.period = 0
        self.Step = 0
        self.buyers = buyers
        self.sellers = sellers
        self.action_space = spaces.Box(-1,1,(1,),dtype=np.float32)
        self.numStates = len(generateState(self.buyers[0]))
        self.observation_space = spaces.Box(-1,9,(self.numStates,),dtype=np.float32)
        startRounds(self.gameData, self.log, self.buyers, self.sellers, self.rnd)
    
    def reset(self, seed = None):
        startPeriods(self.buyers, self.sellers)
        generateState(self.buyers[0])
        return self.buyers[0].state, {}

    def step(self, action):
        # start step -> reset step counts, update token values, generate state
        startSteps(self.buyers, self.sellers)
        print('\n',self.buyers[0].state, self.buyers[0].done)

        # trade: replace first bid with action
        bids, asks = collectOffers(self.buyers, self.sellers)
        min = self.buyers[0].stepTokenValue*0.01
        max = self.buyers[0].stepTokenValue*1.5
        frac = (action+1)/2
        bids[0] = min * (1-frac) + frac * max

        # transact
        currentAsk, currentAskIdx, currentBid, currentBidIdx = bestOffers(bids, asks)
        price, buy, sell = trade(self.buyers, self.sellers, currentAsk, currentAskIdx, currentBid, currentBidIdx)

        # obtain profits
        bprofit, sprofit = 0, 0
        if price > 0:
            self.buyers[currentBidIdx].transact(price)
            self.sellers[currentAskIdx].transact(price)
            bprofit = self.buyers[currentBidIdx].stepProfits
            sprofit = self.sellers[currentAskIdx].stepProfits

        # update log, disclose information and update states
        self.log.addStep([self.rnd, self.period, self.Step, bids, asks, currentBid, currentBidIdx, currentAsk, currentAskIdx, buy, sell, price, price>0, bprofit, sprofit])
        observe(self.buyers, self.sellers, self.log.disclose()) # add disclosure to personal data
        agentsObserve(self.buyers, self.sellers) # reinforcers update state and store data into algorithm
        print(self.buyers[0].state, self.buyers[0].done)

        # compute reward, newState, done
        newState = self.buyers[0].state
        done = self.buyers[0].done
        reward = 0.0
        if price > 0 and currentBidIdx == 0:
            reward = np.nan_to_num(bprofit,nan=0)

        # train agent
        agentsTrain(self.buyers, self.sellers)

        # end step: add to period counters
        endSteps(self.buyers, self.sellers)

        # if done with episode, end period
        self.Step += 1
        if done:
            endPeriods(self.buyers, self.sellers)
            self.period += 1
            self.Step = 0
        print(self.buyers[0].state, self.buyers[0].done)
        return newState, reward, done, False, {}
depth = 0
gameData = [gameTypes, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed]
numStates = num_states
log = Log(gameData, disclosure)

# ALGORITHM
algoArgs = [num_states, learning_rate, gamma, lmbda, eps_clip, K_epoch, rollout_len, buffer_size, minibatch_size, verbose]
model = PPO1(*algoArgs)
score = 0.0
print_interval = 100
rollout = []

# OTHER AGENTS
buyers = [Reinforcer(gameData, disclosure, index=0, buyer=1, reinforcer=1, depth = depth, verbose=verbose, numStates = num_states, algo = 'BASE', algoArgs=[numStates]),
          ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0),
          ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0)]
sellers = [ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0)]

# INITIALIZE
metaData = [gameTypes, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed, disclosure, buyers, sellers]
env = GymEnv(metaData, buyers, sellers, log)
print(log.roundData.iloc[0].buyerValues)
print(log.roundData.iloc[0].sellerCosts)
print(buyers[0].state)
# Out:
# [[ 99.25003886  82.45671643  77.66026229  65.21989865]
#  [100.          84.05672672  63.22103594  62.96150214]
#  [ 78.67729377  60.07550004  59.31575489  58.17739974]]
# [[11.47061757 16.75562681 39.29472894 54.31626246]
#  [22.83601084 29.76199996 33.6351073  56.56277446]
#  [22.02002285 45.1952035  52.5790546  78.76449945]
#  [27.9216024  38.27685302 51.64216474 57.74193037]
#  [36.9662783  38.72188629 43.40438254 87.08807828]
#  [24.4482233  26.90662066 47.53168931 66.02949848]]
# [0, 0]

# %%
# TRAINING LOOP
for n_epi in range(1000):
    s, _ = env.reset()
    done = False
    count = 0
    a_list = []
    while count < 200 and not done:
        for t in range(rollout_len):
            mu, std = model.pi(torch.from_numpy(np.array(s)).float())
            dist = Normal(mu, std)
            a = dist.sample()
            a_list.append(a.item())
            log_prob = dist.log_prob(a)
            s_prime, r, done, truncated, info = env.step(a.item())
            rollout.append((s, a, r, s_prime, log_prob.item(), done))
            print('\t', n_epi, s, a, r, s_prime, log_prob.item(), done)
            if len(rollout) == rollout_len:
                model.put_data(rollout)
                rollout = []
            s = s_prime
            score += r
            count += 1
        model.train()

    if n_epi%print_interval==0 and n_epi!=0:
        print("# of episode :{}, avg score : {:.1f}, optmization step: {}, mu:{:.3f}, std:{:.3f}, mean a:{:.3f}, std a:{:.3f}".format(n_epi,
                                                                                          score/print_interval,
                                                                                          model.optimization_step,
                                                                                          mu.item(), std.item(), 
                                                                                          np.mean(a_list), np.std(a_list)
                                                                                         ))
        score = 0.0
# Out:
#  [0, 0] False
# state:[0, 0], action:-0.8508987126404584, reward:40.217007446117435, newstate:[0, 1],done:False
# [0, 1] False
# [0, 1] False
# 	 0 [0, 0] tensor([0.4008]) 40.217007446117435 [0, 1] -0.6705466508865356 False
#
#  [1, 0] False
# state:[1, 0], action:-0.8519106965318193, reward:29.02425278165539, newstate:[1, 1],done:False
# [1, 1] False
# [1, 1] False
# 	 0 [0, 1] tensor([0.2606]) 29.02425278165539 [1, 1] -0.5982328057289124 False
#
#  [2, 0] False
# state:[2, 0], action:0.45921235667612814, reward:0, newstate:[2, 0],done:False
# [2, 0] False
# [2, 0] False
# 	 0 [1, 1] tensor([-0.6985]) 0.0 [2, 0] -0.7507069110870361 False
#
#  [3, 0] False
# state:[3, 0], action:-0.012408807271218514, reward:0, newstate:[3, 0],done:False
# [3, 0] False
# [3, 0] False
# 	 0 [2, 0] tensor([-1.6414]) 0.0 [3, 0] -3.044830799102783 False
#
#  [4, 0] False
# state:[4, 0], action:0.815132947852186, reward:19.74311305114852, newstate:[4, 1],done:False
# [4, 1] False
# [4, 1] False
# 	 0 [3, 0] tensor([0.3803]) 19.74311305114852 [4, 1] -0.9183309078216553 False
#
#  [5, 0] False
# state:[5, 0], action:0.6162407591288339, reward:0, newstate:[5, 0],done:False
# [5, 0] False
# [5, 0] False
# 	 0 [4, 1] tensor([-0.7615]) 0.0 [5, 0] -0.6102047562599182 False
#
#  [6, 0] False
# state:[6, 0], action:-0.36399305005627225, reward:2.060930554721523, newstate:[6, 1],done:False
# [6, 1] False
# [6, 1] False
# 	 0 [5, 0] tensor([0.8948]) 2.060930554721523 [6, 1] -2.108761787414551 False
#
#  [7, 0] False
# state:[7, 0], action:-0.5557843790585395, reward:0, newstate:[7, 0],done:False
# [7, 0] False
# [7, 0] False
# 	 0 [6, 1] tensor([0.0818]) 0.0 [7, 0] -1.0539695024490356 False
#
#  [8, 0] False
# state:[8, 0], action:0.9248945898842225, reward:0, newstate:[8, 0],done:False
# [8, 0] False
# [8, 0] False
# 	 0 [7, 0] tensor([-1.7066]) 0.0 [8, 0] -1.976657509803772 False
#
#  [9, 0] False
# state:[9, 0], action:-0.44270707152677713, reward:0, newstate:[9, 0],done:False
# [9, 0] False
# [9, 0] False
# 	 0 [8, 0] tensor([-1.5593]) 0.0 [9, 0] -1.5546590089797974 False
#
#  [10, 0] False
# state:[10, 0], action:-0.5247249120152007, reward:0, newstate:[10, 0],done:False
# [10, 0] False
# [10, 0] False
# 	 0 [9, 0] tensor([-1.8006]) 0.0 [10, 0] -1.8960912227630615 False
#
#  [11, 0] False
# state:[11, 0], action:-0.6269629792002915, reward:0, newstate:[11, 0],done:False
# [11, 0] False
# [11, 0] False
# 	 0 [10, 0] tensor([-0.1328]) 0.0 [11, 0] -0.8812710642814636 False
#
#  [12, 0] False
# state:[12, 0], action:-0.6512671419900171, reward:0, newstate:[12, 0],done:False
# [12, 0] False
# [12, 0] False
# 	 0 [11, 0] tensor([0.7411]) 0.0 [12, 0] -2.202969789505005 False
#
#  [13, 0] False
# state:[13, 0], action:0.8493872365571256, reward:0, newstate:[13, 0],done:False
# [13, 0] False
# [13, 0] False
# 	 0 [12, 0] tensor([-1.5410]) 0.0 [13, 0] -1.2444984912872314 False
#
#  [14, 0] False
# state:[14, 0], action:-0.5162954181990966, reward:0, newstate:[14, 0],done:False
# [14, 0] False
# [14, 0] False
# 	 0 [13, 0] tensor([-0.0245]) 0.0 [14, 0] -1.1051380634307861 False
#
#  [15, 0] False
# state:[15, 0], action:0.45191135774047875, reward:0, newstate:[15, 0],done:False
# [15, 0] False
# [15, 0] False
# 	 0 [14, 0] tensor([-1.0574]) 0.0 [15, 0] -0.8249744772911072 False
#
#  [16, 0] False
# state:[16, 0], action:0.7971083770541585, reward:0, newstate:[16, 0],done:False
# [16, 0] False
# [16, 0] False
# 	 0 [15, 0] tensor([-0.0053]) 0.0 [16, 0] -1.1952824592590332 False
#
#  [17, 0] False
# state:[17, 0], action:0.09746757873317224, reward:0, newstate:[17, 0],done:False
# [17, 0] False
# [17, 0] False
# 	 0 [16, 0] tensor([-0.4104]) 0.0 [17, 0] -0.9123445153236389 False
#
#  [18, 0] False
# state:[18, 0], action:0.4929828102360483, reward:0, newstate:[18, 0],done:False
# [18, 0] False
# [18, 0] False
# 	 0 [17, 0] tensor([0.0646]) 0.0 [18, 0] -1.3244521617889404 False
#
#  [19, 0] False
# state:[19, 0], action:-0.4695952646365491, reward:0, newstate:[19, 0],done:False
# [19, 0] False
# [19, 0] False
# 	 0 [18, 0] tensor([-0.6881]) 0.0 [19, 0] -0.860649824142456 False
#
#  [20, 0] False
# state:[20, 0], action:0.005274186210384224, reward:0, newstate:[20, 0],done:False
# [20, 0] False
# [20, 0] False
# 	 0 [19, 0] tensor([-1.1587]) 0.0 [20, 0] -0.9033476710319519 False
#
#  [21, 0] False
# state:[21, 0], action:0.29094459181433563, reward:0, newstate:[21, 0],done:False
# [21, 0] False
# [21, 0] False
# 	 0 [20, 0] tensor([-2.2891]) 0.0 [21, 0] -1.9275429248809814 False
#
#  [22, 0] False
# state:[22, 0], action:0.8566371251754508, reward:0, newstate:[22, 0],done:False
# [22, 0] False
# [22, 0] False
# 	 0 [21, 0] tensor([-2.6578]) 0.0 [22, 0] -2.491708993911743 False
#
#  [23, 0] False
# state:[23, 0], action:0.7022733430337138, reward:0, newstate:[23, 0],done:False
# [23, 0] False
# [23, 0] False
# 	 0 [22, 0] tensor([-0.3486]) 0.0 [23, 0] -1.080759048461914 False
#
#  [24, 0] False
# state:[24, 0], action:-0.8056470124584629, reward:0, newstate:[24, 0],done:False
# [24, 0] False
# [24, 0] False
# 	 0 [23, 0] tensor([-0.7886]) 0.0 [24, 0] -0.9419478178024292 False
#
#  [25, 0] False
# state:[25, 0], action:0.39403148199053595, reward:0, newstate:[25, 0],done:False
# [25, 0] False
# [25, 0] False
# 	 0 [24, 0] tensor([-0.2194]) 0.0 [25, 0] -1.1951825618743896 False
#
#  [26, 0] False
# state:[26, 0], action:0.8264811051129426, reward:0, newstate:[26, 0],done:False
# [26, 0] False
# [26, 0] False
# 	 0 [25, 0] tensor([0.5507]) 0.0 [26, 0] -1.990427017211914 False
#
#  [27, 0] False
# state:[27, 0], action:0.7800106836351326, reward:0, newstate:[27, 0],done:False
# [27, 0] False
# [27, 0] False
# 	 0 [26, 0] tensor([-0.7197]) 0.0 [27, 0] -1.0084508657455444 False
#
#  [28, 0] False
# state:[28, 0], action:0.08528926941515325, reward:0, newstate:[28, 0],done:False
# [28, 0] False
# [28, 0] False
# 	 0 [27, 0] tensor([-1.2707]) 0.0 [28, 0] -1.041118860244751 False
#
#  [29, 0] False
# state:[29, 0], action:-0.7458789746962304, reward:0, newstate:[29, 0],done:False
# [29, 0] False
# [29, 0] False
# 	 0 [28, 0] tensor([-3.4282]) 0.0 [29, 0] -3.501725196838379 False
#
#  [30, 0] False
# state:[30, 0], action:0.06270926313629599, reward:0, newstate:[30, 0],done:False
# [30, 0] False
# [30, 0] False
# 	 0 [29, 0] tensor([-1.0626]) 0.0 [30, 0] -1.0378848314285278 False
#
#  [31, 0] False
# state:[31, 0], action:0.5903723895374073, reward:0, newstate:[31, 0],done:False
# [31, 0] False
# [31, 0] False
# 	 0 [30, 0] tensor([-0.4610]) 0.0 [31, 0] -1.1530663967132568 False
#
#  [32, 0] False
# state:[32, 0], action:0.39194841218739596, reward:0, newstate:[32, 0],done:False
# [32, 0] False
# [32, 0] False
# 	 0 [31, 0] tensor([-0.5617]) 0.0 [32, 0] -1.132591962814331 False
#
#  [33, 0] False
# state:[33, 0], action:0.32039475343546253, reward:0, newstate:[33, 0],done:False
# [33, 0] False
# [33, 0] False
# 	 0 [32, 0] tensor([-0.1300]) 0.0 [33, 0] -1.3451189994812012 False
#
#  [34, 0] False
# state:[34, 0], action:-0.5045380209976851, reward:0, newstate:[34, 0],done:False
# [34, 0] False
# [34, 0] False
# 	 0 [33, 0] tensor([-1.3156]) 0.0 [34, 0] -1.138771414756775 False
#
#  [35, 0] False
# state:[35, 0], action:0.7109211680220144, reward:0, newstate:[35, 0],done:False
# [35, 0] False
# [35, 0] False
# 	 0 [34, 0] tensor([-1.1613]) 0.0 [35, 0] -1.1271171569824219 False
#
#  [36, 0] False
# state:[36, 0], action:-0.13229670152405393, reward:0, newstate:[36, 0],done:False
# [36, 0] False
# [36, 0] False
# 	 0 [35, 0] tensor([-0.8827]) 0.0 [36, 0] -1.13655686378479 False
#
#  [37, 0] False
# state:[37, 0], action:0.006272517160175406, reward:0, newstate:[37, 0],done:False
# [37, 0] False
# [37, 0] False
# 	 0 [36, 0] tensor([-0.1486]) 0.0 [37, 0] -1.372373342514038 False
#
#  [38, 0] False
# state:[38, 0], action:0.1715511625469266, reward:0, newstate:[38, 0],done:False
# [38, 0] False
# [38, 0] False
# 	 0 [37, 0] tensor([-1.8205]) 0.0 [38, 0] -1.3749330043792725 False
#
#  [39, 0] False
# state:[39, 0], action:0.8829296175530503, reward:0, newstate:[39, 0],done:False
# [39, 0] False
# [39, 0] False
# 	 0 [38, 0] tensor([-2.7966]) 0.0 [39, 0] -2.14510440826416 False
#
#  [40, 0] False
# state:[40, 0], action:-0.9635563486969005, reward:0, newstate:[40, 0],done:False
# [40, 0] False
# [40, 0] False
# 	 0 [39, 0] tensor([-3.5004]) 0.0 [40, 0] -3.0016417503356934 False
#
#  [41, 0] False
# state:[41, 0], action:0.6289369651778716, reward:0, newstate:[41, 0],done:False
# [41, 0] False
# [41, 0] False
# 	 0 [40, 0] tensor([-1.2666]) 0.0 [41, 0] -1.2319650650024414 False
#
#  [42, 0] False
# state:[42, 0], action:0.6069618607696972, reward:0, newstate:[42, 0],done:False
# [42, 0] False
# [42, 0] False
# 	 0 [41, 0] tensor([0.7943]) 0.0 [42, 0] -2.0920095443725586 False
#
#  [43, 0] False
# state:[43, 0], action:-0.25596382841443366, reward:0, newstate:[43, 0],done:False
# [43, 0] False
# [43, 0] False
# 	 0 [42, 0] tensor([-1.3427]) 0.0 [43, 0] -1.2733427286148071 False
#
#  [44, 0] False
# state:[44, 0], action:0.5090857481693647, reward:0, newstate:[44, 0],done:False
# [44, 0] False
# [44, 0] False
# 	 0 [43, 0] tensor([-0.8279]) 0.0 [44, 0] -1.2641156911849976 False
#
#  [45, 0] False
# state:[45, 0], action:-0.22159664253167377, reward:0, newstate:[45, 0],done:False
# [45, 0] False
# [45, 0] False
# 	 0 [44, 0] tensor([2.6355]) 0.0 [45, 0] -4.529150485992432 False
#
#  [46, 0] False
# state:[46, 0], action:0.14687577624657222, reward:0, newstate:[46, 0],done:False
# [46, 0] False
# [46, 0] False
# 	 0 [45, 0] tensor([-0.7916]) 0.0 [46, 0] -1.296797752380371 False
#
#  [47, 0] False
# state:[47, 0], action:0.5831580874516971, reward:0, newstate:[47, 0],done:False
# [47, 0] False
# [47, 0] False
# 	 0 [46, 0] tensor([0.2830]) 0.0 [47, 0] -1.6830735206604004 False
#
#  [48, 0] False
# state:[48, 0], action:0.7754083655165995, reward:0, newstate:[48, 0],done:False
# [48, 0] False
# [48, 0] False
# 	 0 [47, 0] tensor([-3.0890]) 0.0 [48, 0] -2.3040781021118164 False
#
#  [49, 0] False
# state:[49, 0], action:-0.8317863877700051, reward:0, newstate:[49, 0],done:False
# [49, 0] False
# [49, 0] False
# 	 0 [48, 0] tensor([0.6727]) 0.0 [49, 0] -1.9434913396835327 False
#
#  [50, 0] False
# state:[50, 0], action:0.9732791570023509, reward:0, newstate:[50, 0],done:False
# [50, 0] False
# [50, 0] False
# 	 0 [49, 0] tensor([-1.0313]) 0.0 [50, 0] -1.3449522256851196 False
#
#  [51, 0] False
# state:[51, 0], action:-0.24748082893816847, reward:0, newstate:[51, 0],done:False
# [51, 0] False
# [51, 0] False
# 	 0 [50, 0] tensor([-2.8892]) 0.0 [51, 0] -2.1000962257385254 False
#
#  [52, 0] False
# state:[52, 0], action:-0.0147497914182817, reward:0, newstate:[52, 0],done:False
# [52, 0] False
# [52, 0] False
# 	 0 [51, 0] tensor([-4.2524]) 0.0 [52, 0] -3.5071568489074707 False
#
#  [53, 0] False
# state:[53, 0], action:0.4920897585308466, reward:0, newstate:[53, 0],done:False
# [53, 0] False
# [53, 0] False
# 	 0 [52, 0] tensor([-3.0768]) 0.0 [53, 0] -2.2334365844726562 False
#
#  [54, 0] False
# state:[54, 0], action:0.9264450788812226, reward:0, newstate:[54, 0],done:False
# [54, 0] False
# [54, 0] False
# 	 0 [53, 0] tensor([-1.7513]) 0.0 [54, 0] -1.5087716579437256 False
#
#  [55, 0] False
# state:[55, 0], action:-0.8524068705292023, reward:0, newstate:[55, 0],done:False
# [55, 0] False
# [55, 0] False
# 	 0 [54, 0] tensor([-3.2154]) 0.0 [55, 0] -2.3257317543029785 False
#
#  [56, 0] False
# state:[56, 0], action:0.2551161601681269, reward:0, newstate:[56, 0],done:False
# [56, 0] False
# [56, 0] False
# 	 0 [55, 0] tensor([0.8702]) 0.0 [56, 0] -2.059338092803955 False
#
#  [57, 0] False
# state:[57, 0], action:-0.08868649442857413, reward:0, newstate:[57, 0],done:False
# [57, 0] False
# [57, 0] False
# 	 0 [56, 0] tensor([-1.0526]) 0.0 [57, 0] -1.4423538446426392 False
#
#  [58, 0] False
# state:[58, 0], action:-0.8445307260700303, reward:0, newstate:[58, 0],done:False
# [58, 0] False
# [58, 0] False
# 	 0 [57, 0] tensor([-2.8315]) 0.0 [58, 0] -2.0292906761169434 False
#
#  [59, 0] False
# state:[59, 0], action:0.36946234510775855, reward:0, newstate:[59, 0],done:False
# [59, 0] False
# [59, 0] False
# 	 0 [58, 0] tensor([1.6378]) 0.0 [59, 0] -2.627108573913574 False
#
#  [60, 0] False
# state:[60, 0], action:-0.16351392741876225, reward:0, newstate:[60, 0],done:False
# [60, 0] False
# [60, 0] False
# 	 0 [59, 0] tensor([-1.1763]) 0.0 [60, 0] -1.4868528842926025 False
#
#  [61, 0] False
# state:[61, 0], action:0.9745522586298889, reward:0, newstate:[61, 0],done:False
# [61, 0] False
# [61, 0] False
# 	 0 [60, 0] tensor([-1.5938]) 0.0 [61, 0] -1.5506503582000732 False
#
#  [62, 0] False
# state:[62, 0], action:-0.06261368041005944, reward:0, newstate:[62, 0],done:False
# [62, 0] False
# [62, 0] False
# 	 0 [61, 0] tensor([0.3011]) 0.0 [62, 0] -1.768428087234497 False
#
#  [63, 0] False
# state:[63, 0], action:0.9932736741478108, reward:0, newstate:[63, 0],done:False
# [63, 0] False
# [63, 0] False
# 	 0 [62, 0] tensor([-4.1464]) 0.0 [63, 0] -3.0064969062805176 False
#
#  [64, 0] False
# state:[64, 0], action:-0.74168116969701, reward:0, newstate:[64, 0],done:False
# [64, 0] False
# [64, 0] False
# 	 0 [63, 0] tensor([0.3382]) 0.0 [64, 0] -1.7953708171844482 False
#
#  [65, 0] False
# state:[65, 0], action:-0.772884815600742, reward:0, newstate:[65, 0],done:False
# [65, 0] False
# [65, 0] False
# 	 0 [64, 0] tensor([-1.9767]) 0.0 [65, 0] -1.682269811630249 False
#
#  [66, 0] False
# state:[66, 0], action:0.12187594307077254, reward:0, newstate:[66, 0],done:False
# [66, 0] False
# [66, 0] False
# 	 0 [65, 0] tensor([-1.6784]) 0.0 [66, 0] -1.6227551698684692 False
#
#  [67, 0] False
# state:[67, 0], action:0.40815953619844714, reward:0, newstate:[67, 0],done:False
# [67, 0] False
# [67, 0] False
# 	 0 [66, 0] tensor([3.4835]) 0.0 [67, 0] -4.297954082489014 False
#
#  [68, 0] False
# state:[68, 0], action:-0.12505015595254187, reward:0, newstate:[68, 0],done:False
# [68, 0] False
# [68, 0] False
# 	 0 [67, 0] tensor([-1.8801]) 0.0 [68, 0] -1.6860679388046265 False
#
#  [69, 0] False
# state:[69, 0], action:0.7247274174934903, reward:0, newstate:[69, 0],done:False
# [69, 0] False
# [69, 0] False
# 	 0 [68, 0] tensor([-0.2426]) 0.0 [69, 0] -1.6698395013809204 False
#
#  [70, 0] False
# state:[70, 0], action:0.9600651505709541, reward:0, newstate:[70, 0],done:False
# [70, 0] False
# [70, 0] False
# 	 0 [69, 0] tensor([-0.2623]) 0.0 [70, 0] -1.6765066385269165 False
#
#  [71, 0] False
# state:[71, 0], action:-0.7439083220844551, reward:0, newstate:[71, 0],done:False
# [71, 0] False
# [71, 0] False
# 	 0 [70, 0] tensor([1.5290]) 0.0 [71, 0] -2.4068899154663086 False
#
#  [72, 0] False
# state:[72, 0], action:-0.052076719474255295, reward:0, newstate:[72, 0],done:False
# [72, 0] False
# [72, 0] False
# 	 0 [71, 0] tensor([-1.6962]) 0.0 [72, 0] -1.6901614665985107 False
#
#  [73, 0] False
# state:[73, 0], action:-0.6459790314465064, reward:0, newstate:[73, 0],done:False
# [73, 0] False
# [73, 0] False
# 	 0 [72, 0] tensor([0.0496]) 0.0 [73, 0] -1.7729949951171875 False
#
#  [74, 0] False
# state:[74, 0], action:0.3807896572587306, reward:0, newstate:[74, 0],done:False
# [74, 0] False
# [74, 0] False
# 	 0 [73, 0] tensor([-3.5682]) 0.0 [74, 0] -2.4114060401916504 False
#
#  [75, 0] False
# state:[75, 0], action:-0.8778440802902725, reward:0, newstate:[75, 0],done:False
# [75, 0] False
# [75, 0] False
# 	 0 [74, 0] tensor([-0.6324]) 0.0 [75, 0] -1.6822975873947144 False
#
#  [76, 0] False
# state:[76, 0], action:-0.030954029617957346, reward:0, newstate:[76, 0],done:False
# [76, 0] False
# [76, 0] False
# 	 0 [75, 0] tensor([-0.3587]) 0.0 [76, 0] -1.7237157821655273 False
#
#  [77, 0] False
# state:[77, 0], action:0.4266991717691049, reward:0, newstate:[77, 0],done:False
# [77, 0] False
# [77, 0] False
# 	 0 [76, 0] tensor([-0.4620]) 0.0 [77, 0] -1.721138834953308 False
#
#  [78, 0] False
# state:[78, 0], action:-0.5150589927305407, reward:0, newstate:[78, 0],done:False
# [78, 0] False
# [78, 0] False
# 	 0 [77, 0] tensor([-3.4868]) 0.0 [78, 0] -2.3479442596435547 False
#
#  [79, 0] False
# state:[79, 0], action:-0.7604757363614976, reward:0, newstate:[79, 0],done:False
# [79, 0] False
# [79, 0] False
# 	 0 [78, 0] tensor([-2.5785]) 0.0 [79, 0] -1.9674667119979858 False
#
#  [80, 0] False
# state:[80, 0], action:0.07421308363709556, reward:0, newstate:[80, 0],done:False
# [80, 0] False
# [80, 0] False
# 	 0 [79, 0] tensor([-5.9858]) 0.0 [80, 0] -4.208010196685791 False
#
#  [81, 0] False
# state:[81, 0], action:0.29183448266320244, reward:0, newstate:[81, 0],done:False
# [81, 0] False
# [81, 0] False
# 	 0 [80, 0] tensor([3.1236]) 0.0 [81, 0] -3.397001266479492 False
#
#  [82, 0] False
# state:[82, 0], action:-0.694281721631336, reward:0, newstate:[82, 0],done:False
# [82, 0] False
# [82, 0] False
# 	 0 [81, 0] tensor([-0.7563]) 0.0 [82, 0] -1.7518033981323242 False
#
#  [83, 0] False
# state:[83, 0], action:-0.8395325086767156, reward:0, newstate:[83, 0],done:False
# [83, 0] False
# [83, 0] False
# 	 0 [82, 0] tensor([2.3891]) 0.0 [83, 0] -2.8314623832702637 False
#
#  [84, 0] False
# state:[84, 0], action:0.7310142517879605, reward:0, newstate:[84, 0],done:False
# [84, 0] False
# [84, 0] False
# 	 0 [83, 0] tensor([-2.5675]) 0.0 [84, 0] -1.9927713871002197 False
#
#  [85, 0] False
# state:[85, 0], action:0.1432253789397997, reward:0, newstate:[85, 0],done:False
# [85, 0] False
# [85, 0] False
# 	 0 [84, 0] tensor([-0.9734]) 0.0 [85, 0] -1.7786723375320435 False
#
#  [86, 0] False
# state:[86, 0], action:-0.5151805351698395, reward:0, newstate:[86, 0],done:False
# [86, 0] False
# [86, 0] False
# 	 0 [85, 0] tensor([-6.8319]) 0.0 [86, 0] -4.772192001342773 False
#
#  [87, 0] False
# state:[87, 0], action:0.06517886510317172, reward:0, newstate:[87, 0],done:False
# [87, 0] False
# [87, 0] False
# 	 0 [86, 0] tensor([3.9198]) 0.0 [87, 0] -3.8782267570495605 False
#
#  [88, 0] False
# state:[88, 0], action:0.6197488917092697, reward:0, newstate:[88, 0],done:False
# [88, 0] False
# [88, 0] False
# 	 0 [87, 0] tensor([-1.4354]) 0.0 [88, 0] -1.8262596130371094 False
#
#  [89, 0] False
# state:[89, 0], action:-0.3022634669140094, reward:0, newstate:[89, 0],done:False
# [89, 0] False
# [89, 0] False
# 	 0 [88, 0] tensor([-2.1784]) 0.0 [89, 0] -1.9350812435150146 False
#
#  [90, 0] False
# state:[90, 0], action:-0.6375338676686797, reward:0, newstate:[90, 0],done:False
# [90, 0] False
# [90, 0] False
# 	 0 [89, 0] tensor([-0.9788]) 0.0 [90, 0] -1.8310720920562744 False
#
#  [91, 0] False
# state:[91, 0], action:-0.5967453599045109, reward:0, newstate:[91, 0],done:False
# [91, 0] False
# [91, 0] False
# 	 0 [90, 0] tensor([-0.6030]) 0.0 [91, 0] -1.8537311553955078 False
#
#  [92, 0] False
# state:[92, 0], action:0.7544010816262166, reward:0, newstate:[92, 0],done:False
# [92, 0] False
# [92, 0] False
# 	 0 [91, 0] tensor([-1.8566]) 0.0 [92, 0] -1.9082616567611694 False
#
#  [93, 0] False
# state:[93, 0], action:0.49521876035250223, reward:0, newstate:[93, 0],done:False
# [93, 0] False
# [93, 0] False
# 	 0 [92, 0] tensor([-1.3147]) 0.0 [93, 0] -1.8690176010131836 False
#
#  [94, 0] False
# state:[94, 0], action:0.2484759918279842, reward:0, newstate:[94, 0],done:False
# [94, 0] False
# [94, 0] False
# 	 0 [93, 0] tensor([-5.2099]) 0.0 [94, 0] -3.1901626586914062 False
#
#  [95, 0] False
# state:[95, 0], action:0.24014551185702704, reward:0, newstate:[95, 0],done:False
# [95, 0] False
# [95, 0] False
# 	 0 [94, 0] tensor([2.1755]) 0.0 [95, 0] -2.6169300079345703 False
#
#  [96, 0] False
# state:[96, 0], action:0.48789258514535394, reward:0, newstate:[96, 0],done:False
# [96, 0] False
# [96, 0] False
# 	 0 [95, 0] tensor([2.5601]) 0.0 [96, 0] -2.7977232933044434 False
#
#  [97, 0] False
# state:[97, 0], action:-0.7787365260895855, reward:0, newstate:[97, 0],done:False
# [97, 0] False
# [97, 0] False
# 	 0 [96, 0] tensor([-0.4751]) 0.0 [97, 0] -1.920339822769165 False
#
#  [98, 0] False
# state:[98, 0], action:0.44450513678613257, reward:0, newstate:[98, 0],done:False
# [98, 0] False
# [98, 0] False
# 	 0 [97, 0] tensor([-0.9929]) 0.0 [98, 0] -1.9107108116149902 False
#
#  [99, 0] False
# state:[99, 0], action:-0.6368045663971487, reward:0, newstate:[99, 0],done:False
# [99, 0] False
# [99, 0] False
# 	 0 [98, 0] tensor([-2.1170]) 0.0 [99, 0] -2.0045199394226074 False
#
#  [100, 0] False
# state:[100, 0], action:0.17245966403359447, reward:0, newstate:[100, 0],done:False
# [100, 0] False
# [100, 0] False
# 	 0 [99, 0] tensor([-0.9498]) 0.0 [100, 0] -1.930025339126587 False
#
#  [101, 0] False
# state:[101, 0], action:0.3933016477537845, reward:0, newstate:[101, 0],done:False
# [101, 0] False
# [101, 0] False
# 	 0 [100, 0] tensor([1.6221]) 0.0 [101, 0] -2.3859901428222656 False
#
#  [102, 0] False
# state:[102, 0], action:0.47288847124944566, reward:0, newstate:[102, 0],done:False
# [102, 0] False
# [102, 0] False
# 	 0 [101, 0] tensor([2.3036]) 0.0 [102, 0] -2.64451003074646 False
#
#  [103, 0] False
# state:[103, 0], action:-0.7506746375934663, reward:0, newstate:[103, 0],done:False
# [103, 0] False
# [103, 0] False
# 	 0 [102, 0] tensor([2.2738]) 0.0 [103, 0] -2.6287283897399902 False
#
#  [104, 0] False
# state:[104, 0], action:-0.32960551670819815, reward:0, newstate:[104, 0],done:False
# [104, 0] False
# [104, 0] False
# 	 0 [103, 0] tensor([3.2557]) 0.0 [104, 0] -3.079848289489746 False
#
#  [105, 0] False
# state:[105, 0], action:-0.3073080112680775, reward:0, newstate:[105, 0],done:False
# [105, 0] False
# [105, 0] False
# 	 0 [104, 0] tensor([-0.3651]) 0.0 [105, 0] -2.000781774520874 False
#
#  [106, 0] False
# state:[106, 0], action:-0.6472260269875534, reward:0, newstate:[106, 0],done:False
# [106, 0] False
# [106, 0] False
# 	 0 [105, 0] tensor([2.0816]) 0.0 [106, 0] -2.5479869842529297 False
#
#  [107, 0] False
# state:[107, 0], action:-0.9738110868233327, reward:0, newstate:[107, 0],done:False
# [107, 0] False
# [107, 0] False
# 	 0 [106, 0] tensor([-2.0202]) 0.0 [107, 0] -2.055159091949463 False
#
#  [108, 0] False
# state:[108, 0], action:0.9937485036918947, reward:0, newstate:[108, 0],done:False
# [108, 0] False
# [108, 0] False
# 	 0 [107, 0] tensor([-0.6595]) 0.0 [108, 0] -2.010219097137451 False
#
#  [109, 0] False
# state:[109, 0], action:-0.5897207190359857, reward:0, newstate:[109, 0],done:False
# [109, 0] False
# [109, 0] False
# 	 0 [108, 0] tensor([-0.9874]) 0.0 [109, 0] -2.012512445449829 False
#
#  [110, 0] False
# state:[110, 0], action:-0.09342233050394477, reward:0, newstate:[110, 0],done:False
# [110, 0] False
# [110, 0] False
# 	 0 [109, 0] tensor([1.6433]) 0.0 [110, 0] -2.4065937995910645 False
#
#  [111, 0] False
# state:[111, 0], action:0.7235712420270346, reward:0, newstate:[111, 0],done:False
# [111, 0] False
# [111, 0] False
# 	 0 [110, 0] tensor([-4.2160]) 0.0 [111, 0] -2.590446949005127 False
#
#  [112, 0] False
# state:[112, 0], action:-0.6876948052676193, reward:0, newstate:[112, 0],done:False
# [112, 0] False
# [112, 0] False
# 	 0 [111, 0] tensor([-0.2242]) 0.0 [112, 0] -2.070871114730835 False
#
#  [113, 0] False
# state:[113, 0], action:-0.9605789244912717, reward:0, newstate:[113, 0],done:False
# [113, 0] False
# [113, 0] False
# 	 0 [112, 0] tensor([-1.3057]) 0.0 [113, 0] -2.052370071411133 False
#
#  [114, 0] False
# state:[114, 0], action:-0.5136556180010918, reward:0, newstate:[114, 0],done:False
# [114, 0] False
# [114, 0] False
# 	 0 [113, 0] tensor([-2.5283]) 0.0 [114, 0] -2.1761980056762695 False
#
#  [115, 0] False
# state:[115, 0], action:-0.4137045394779735, reward:0, newstate:[115, 0],done:False
# [115, 0] False
# [115, 0] False
# 	 0 [114, 0] tensor([-2.7709]) 0.0 [115, 0] -2.2231693267822266 False
#
#  [116, 0] False
# state:[116, 0], action:0.16608312193938435, reward:0, newstate:[116, 0],done:False
# [116, 0] False
# [116, 0] False
# 	 0 [115, 0] tensor([-5.0067]) 0.0 [116, 0] -2.8712210655212402 False
#
#  [117, 0] False
# state:[117, 0], action:0.18058988502961548, reward:0, newstate:[117, 0],done:False
# [117, 0] False
# [117, 0] False
# 	 0 [116, 0] tensor([-0.0641]) 0.0 [117, 0] -2.124263286590576 False
#
#  [118, 0] False
# state:[118, 0], action:0.8969066139243134, reward:0, newstate:[118, 0],done:False
# [118, 0] False
# [118, 0] False
# 	 0 [117, 0] tensor([-2.1065]) 0.0 [118, 0] -2.148653507232666 False
#
#  [119, 0] False
# state:[119, 0], action:-0.1495729910615331, reward:0, newstate:[119, 0],done:False
# [119, 0] False
# [119, 0] False
# 	 0 [118, 0] tensor([-4.1234]) 0.0 [119, 0] -2.5594234466552734 False
#
#  [120, 0] False
# state:[120, 0], action:0.6698604735985982, reward:0, newstate:[120, 0],done:False
# [120, 0] False
# [120, 0] False
# 	 0 [119, 0] tensor([-2.0290]) 0.0 [120, 0] -2.1555323600769043 False
#
#  [121, 0] False
# state:[121, 0], action:-0.7644978342197177, reward:0, newstate:[121, 0],done:False
# [121, 0] False
# [121, 0] False
# 	 0 [120, 0] tensor([3.4056]) 0.0 [121, 0] -3.0027689933776855 False
#
#  [122, 0] False
# state:[122, 0], action:-0.978008342683039, reward:0, newstate:[122, 0],done:False
# [122, 0] False
# [122, 0] False
# 	 0 [121, 0] tensor([1.9291]) 0.0 [122, 0] -2.5089192390441895 False
#
#  [123, 0] False
# state:[123, 0], action:-0.6492574427531008, reward:0, newstate:[123, 0],done:False
# [123, 0] False
# [123, 0] False
# 	 0 [122, 0] tensor([-2.2461]) 0.0 [123, 0] -2.199389934539795 False
#
#  [124, 0] False
# state:[124, 0], action:0.4760672328527409, reward:0, newstate:[124, 0],done:False
# [124, 0] False
# [124, 0] False
# 	 0 [123, 0] tensor([-2.8464]) 0.0 [124, 0] -2.287247657775879 False
#
#  [125, 0] False
# state:[125, 0], action:0.438091810368491, reward:0, newstate:[125, 0],done:False
# [125, 0] False
# [125, 0] False
# 	 0 [124, 0] tensor([1.8128]) 0.0 [125, 0] -2.486137628555298 False
#
#  [126, 0] False
# state:[126, 0], action:-0.5701192428184865, reward:0, newstate:[126, 0],done:False
# [126, 0] False
# [126, 0] False
# 	 0 [125, 0] tensor([-4.4514]) 0.0 [126, 0] -2.6577224731445312 False
#
#  [127, 0] False
# state:[127, 0], action:-0.33151221836607836, reward:0, newstate:[127, 0],done:False
# [127, 0] False
# [127, 0] False
# 	 0 [126, 0] tensor([-6.5281]) 0.0 [127, 0] -3.4334540367126465 False
#
#  [128, 0] False
# state:[128, 0], action:-0.13034532279250755, reward:0, newstate:[128, 0],done:False
# [128, 0] False
# [128, 0] False
# 	 0 [127, 0] tensor([-2.8188]) 0.0 [128, 0] -2.3054659366607666 False
#
#  [129, 0] False
# state:[129, 0], action:-0.2780522061199464, reward:0, newstate:[129, 0],done:False
# [129, 0] False
# [129, 0] False
# 	 0 [128, 0] tensor([-0.8113]) 0.0 [129, 0] -2.179126739501953 False
#
#  [130, 0] False
# state:[130, 0], action:0.08380189475671629, reward:0, newstate:[130, 0],done:False
# [130, 0] False
# [130, 0] False
# 	 0 [129, 0] tensor([1.9083]) 0.0 [130, 0] -2.5212912559509277 False
#
#  [131, 0] False
# state:[131, 0], action:-0.5006639822816281, reward:0, newstate:[131, 0],done:False
# [131, 0] False
# [131, 0] False
# 	 0 [130, 0] tensor([4.5040]) 0.0 [131, 0] -3.377964496612549 False
#
#  [132, 0] False
# state:[132, 0], action:0.8504966348313316, reward:0, newstate:[132, 0],done:False
# [132, 0] False
# [132, 0] False
# 	 0 [131, 0] tensor([-1.3478]) 0.0 [132, 0] -2.2051849365234375 False
#
#  [133, 0] False
# state:[133, 0], action:0.8487923907530608, reward:0, newstate:[133, 0],done:False
# [133, 0] False
# [133, 0] False
# 	 0 [132, 0] tensor([-2.7127]) 0.0 [133, 0] -2.31937313079834 False
#
#  [134, 0] False
# state:[134, 0], action:0.6578309483013547, reward:0, newstate:[134, 0],done:False
# [134, 0] False
# [134, 0] False
# 	 0 [133, 0] tensor([-5.7427]) 0.0 [134, 0] -3.056601047515869 False
#
#  [135, 0] False
# state:[135, 0], action:-0.3202500724638677, reward:0, newstate:[135, 0],done:False
# [135, 0] False
# [135, 0] False
# 	 0 [134, 0] tensor([1.0393]) 0.0 [135, 0] -2.3761210441589355 False
#
#  [136, 0] False
# state:[136, 0], action:0.2517827528740182, reward:0, newstate:[136, 0],done:False
# [136, 0] False
# [136, 0] False
# 	 0 [135, 0] tensor([-3.4447]) 0.0 [136, 0] -2.4472451210021973 False
#
#  [137, 0] False
# state:[137, 0], action:0.7494033453683988, reward:0, newstate:[137, 0],done:False
# [137, 0] False
# [137, 0] False
# 	 0 [136, 0] tensor([-0.8395]) 0.0 [137, 0] -2.238487720489502 False
#
#  [138, 0] False
# state:[138, 0], action:-0.19613817278151569, reward:0, newstate:[138, 0],done:False
# [138, 0] False
# [138, 0] False
# 	 0 [137, 0] tensor([-6.7905]) 0.0 [138, 0] -3.427175521850586 False
#
#  [139, 0] False
# state:[139, 0], action:-0.15728599544585964, reward:0, newstate:[139, 0],done:False
# [139, 0] False
# [139, 0] False
# 	 0 [138, 0] tensor([-6.7830]) 0.0 [139, 0] -3.4144349098205566 False
#
#  [140, 0] False
# state:[140, 0], action:-0.5327844979001801, reward:0, newstate:[140, 0],done:False
# [140, 0] False
# [140, 0] False
# 	 0 [139, 0] tensor([-0.6336]) 0.0 [140, 0] -2.263808250427246 False
#
#  [141, 0] False
# state:[141, 0], action:-0.5634922242698717, reward:0, newstate:[141, 0],done:False
# [141, 0] False
# [141, 0] False
# 	 0 [140, 0] tensor([-5.1557]) 0.0 [141, 0] -2.8496906757354736 False
#
#  [142, 0] False
# state:[142, 0], action:-0.06519697750026054, reward:0, newstate:[142, 0],done:False
# [142, 0] False
# [142, 0] False
# 	 0 [141, 0] tensor([2.2897]) 0.0 [142, 0] -2.63383150100708 False
#
#  [143, 0] False
# state:[143, 0], action:0.21547358975771824, reward:0, newstate:[143, 0],done:False
# [143, 0] False
# [143, 0] False
# 	 0 [142, 0] tensor([3.6146]) 0.0 [143, 0] -2.97971773147583 False
#
#  [144, 0] False
# state:[144, 0], action:-0.2997494816665398, reward:0, newstate:[144, 0],done:False
# [144, 0] False
# [144, 0] False
# 	 0 [143, 0] tensor([3.4872]) 0.0 [144, 0] -2.939464569091797 False
#
#  [145, 0] False
# state:[145, 0], action:-0.2075159621946825, reward:0, newstate:[145, 0],done:False
# [145, 0] False
# [145, 0] False
# 	 0 [144, 0] tensor([-1.6502]) 0.0 [145, 0] -2.307851791381836 False
#
#  [146, 0] False
# state:[146, 0], action:0.07394884578682714, reward:0, newstate:[146, 0],done:False
# [146, 0] False
# [146, 0] False
# 	 0 [145, 0] tensor([-6.2658]) 0.0 [146, 0] -3.1747145652770996 False
#
#  [147, 0] False
# state:[147, 0], action:0.7774961597379544, reward:0, newstate:[147, 0],done:False
# [147, 0] False
# [147, 0] False
# 	 0 [146, 0] tensor([4.6584]) 0.0 [147, 0] -3.3029398918151855 False
#
#  [148, 0] False
# state:[148, 0], action:-0.1830935738586026, reward:0, newstate:[148, 0],done:False
# [148, 0] False
# [148, 0] False
# 	 0 [147, 0] tensor([-6.4521]) 0.0 [148, 0] -3.226016044616699 False
#
#  [149, 0] False
# state:[149, 0], action:0.36651752731919185, reward:0, newstate:[149, 0],done:False
# [149, 0] False
# [149, 0] False
# 	 0 [148, 0] tensor([2.9654]) 0.0 [149, 0] -2.797154664993286 False
#
#  [150, 0] False
# state:[150, 0], action:-0.3043815841956139, reward:0, newstate:[150, 0],done:False
# [150, 0] False
# [150, 0] False
# 	 0 [149, 0] tensor([-1.8567]) 0.0 [150, 0] -2.350287914276123 False
#
#  [151, 0] False
# state:[151, 0], action:0.7011634581884838, reward:0, newstate:[151, 0],done:False
# [151, 0] False
# [151, 0] False
# 	 0 [150, 0] tensor([-2.7747]) 0.0 [151, 0] -2.4277896881103516 False
#
#  [152, 0] False
# state:[152, 0], action:0.5054332791152825, reward:0, newstate:[152, 0],done:False
# [152, 0] False
# [152, 0] False
# 	 0 [151, 0] tensor([-4.4862]) 0.0 [152, 0] -2.694790840148926 False
#
#  [153, 0] False
# state:[153, 0], action:-0.3297622914817162, reward:0, newstate:[153, 0],done:False
# [153, 0] False
# [153, 0] False
# 	 0 [152, 0] tensor([-6.9534]) 0.0 [153, 0] -3.3644633293151855 False
#
#  [154, 0] False
# state:[154, 0], action:-0.42592373365017444, reward:0, newstate:[154, 0],done:False
# [154, 0] False
# [154, 0] False
# 	 0 [153, 0] tensor([-3.4590]) 0.0 [154, 0] -2.525974750518799 False
#
#  [155, 0] False
# state:[155, 0], action:0.5596907903022872, reward:0, newstate:[155, 0],done:False
# [155, 0] False
# [155, 0] False
# 	 0 [154, 0] tensor([0.6300]) 0.0 [155, 0] -2.4355974197387695 False
#
#  [156, 0] False
# state:[156, 0], action:0.8640562110200349, reward:0, newstate:[156, 0],done:False
# [156, 0] False
# [156, 0] False
# 	 0 [155, 0] tensor([-1.6319]) 0.0 [156, 0] -2.3788723945617676 False
#
#  [157, 0] False
# state:[157, 0], action:-0.8652987970624566, reward:0, newstate:[157, 0],done:False
# [157, 0] False
# [157, 0] False
# 	 0 [156, 0] tensor([3.2247]) 0.0 [157, 0] -2.8600833415985107 False
#
#  [158, 0] False
# state:[158, 0], action:0.937755710571383, reward:0, newstate:[158, 0],done:False
# [158, 0] False
# [158, 0] False
# 	 0 [157, 0] tensor([-4.8889]) 0.0 [158, 0] -2.7870941162109375 False
#
#  [159, 0] False
# state:[159, 0], action:-0.0227136191906685, reward:0, newstate:[159, 0],done:False
# [159, 0] False
# [159, 0] False
# 	 0 [158, 0] tensor([2.4385]) 0.0 [159, 0] -2.700767993927002 False
#
#  [160, 0] False
# state:[160, 0], action:-0.09722595134064904, reward:0, newstate:[160, 0],done:False
# [160, 0] False
# [160, 0] False
# 	 0 [159, 0] tensor([-6.3560]) 0.0 [160, 0] -3.1449546813964844 False
#
#  [161, 0] False
# state:[161, 0], action:0.30902242856227047, reward:0, newstate:[161, 0],done:False
# [161, 0] False
# [161, 0] False
# 	 0 [160, 0] tensor([-3.6735]) 0.0 [161, 0] -2.5845999717712402 False
#
#  [162, 0] False
# state:[162, 0], action:0.2770518953281711, reward:0, newstate:[162, 0],done:False
# [162, 0] False
# [162, 0] False
# 	 0 [161, 0] tensor([-8.5692]) 0.0 [162, 0] -3.8697361946105957 False
#
#  [163, 0] False
# state:[163, 0], action:-0.5737905919498334, reward:0, newstate:[163, 0],done:False
# [163, 0] False
# [163, 0] False
# 	 0 [162, 0] tensor([4.6471]) 0.0 [163, 0] -3.2168540954589844 False
#
#  [164, 0] False
# state:[164, 0], action:-0.6289489685937577, reward:0, newstate:[164, 0],done:False
# [164, 0] False
# [164, 0] False
# 	 0 [163, 0] tensor([-0.0366]) 0.0 [164, 0] -2.4414491653442383 False
#
#  [165, 0] False
# state:[165, 0], action:-0.7375102446352249, reward:0, newstate:[165, 0],done:False
# [165, 0] False
# [165, 0] False
# 	 0 [164, 0] tensor([2.6920]) 0.0 [165, 0] -2.7600488662719727 False
#
#  [166, 0] False
# state:[166, 0], action:-0.7496284155948991, reward:0, newstate:[166, 0],done:False
# [166, 0] False
# [166, 0] False
# 	 0 [165, 0] tensor([-7.4248]) 0.0 [166, 0] -3.434520721435547 False
#
#  [167, 0] False
# state:[167, 0], action:-0.46201319112980466, reward:0, newstate:[167, 0],done:False
# [167, 0] False
# [167, 0] False
# 	 0 [166, 0] tensor([1.5171]) 0.0 [167, 0] -2.5888686180114746 False
#
#  [168, 0] False
# state:[168, 0], action:-0.040122330565752984, reward:0, newstate:[168, 0],done:False
# [168, 0] False
# [168, 0] False
# 	 0 [167, 0] tensor([1.0310]) 0.0 [168, 0] -2.540592908859253 False
#
#  [169, 0] False
# state:[169, 0], action:-0.038986105484342115, reward:0, newstate:[169, 0],done:False
# [169, 0] False
# [169, 0] False
# 	 0 [168, 0] tensor([0.1313]) 0.0 [169, 0] -2.478684186935425 False
#
#  [170, 0] False
# state:[170, 0], action:0.4049299410882079, reward:0, newstate:[170, 0],done:False
# [170, 0] False
# [170, 0] False
# 	 0 [169, 0] tensor([-4.5883]) 0.0 [170, 0] -2.753066062927246 False
#
#  [171, 0] False
# state:[171, 0], action:-0.9335937824172669, reward:0, newstate:[171, 0],done:False
# [171, 0] False
# [171, 0] False
# 	 0 [170, 0] tensor([-1.8679]) 0.0 [171, 0] -2.4778153896331787 False
#
#  [172, 0] False
# state:[172, 0], action:-0.5996995115103798, reward:0, newstate:[172, 0],done:False
# [172, 0] False
# [172, 0] False
# 	 0 [171, 0] tensor([-2.8219]) 0.0 [172, 0] -2.5416014194488525 False
#
#  [173, 0] False
# state:[173, 0], action:-0.8960574326970552, reward:0, newstate:[173, 0],done:False
# [173, 0] False
# [173, 0] False
# 	 0 [172, 0] tensor([-5.2184]) 0.0 [173, 0] -2.8704397678375244 False
#
#  [174, 0] False
# state:[174, 0], action:0.6296502274930245, reward:0, newstate:[174, 0],done:False
# [174, 0] False
# [174, 0] False
# 	 0 [173, 0] tensor([1.2937]) 0.0 [174, 0] -2.5945000648498535 False
#
#  [175, 0] False
# state:[175, 0], action:0.05280532187222642, reward:0, newstate:[175, 0],done:False
# [175, 0] False
# [175, 0] False
# 	 0 [174, 0] tensor([1.0520]) 0.0 [175, 0] -2.575995922088623 False
#
#  [176, 0] False
# state:[176, 0], action:-0.5615720252839114, reward:0, newstate:[176, 0],done:False
# [176, 0] False
# [176, 0] False
# 	 0 [175, 0] tensor([2.1453]) 0.0 [176, 0] -2.7034854888916016 False
#
#  [177, 0] False
# state:[177, 0], action:0.11072710187526247, reward:0, newstate:[177, 0],done:False
# [177, 0] False
# [177, 0] False
# 	 0 [176, 0] tensor([-7.1334]) 0.0 [177, 0] -3.2990236282348633 False
#
#  [178, 0] False
# state:[178, 0], action:0.36045648486258264, reward:0, newstate:[178, 0],done:False
# [178, 0] False
# [178, 0] False
# 	 0 [177, 0] tensor([2.4283]) 0.0 [178, 0] -2.749386787414551 False
#
#  [179, 0] False
# state:[179, 0], action:0.4854130423999621, reward:0, newstate:[179, 0],done:False
# [179, 0] False
# [179, 0] False
# 	 0 [178, 0] tensor([2.5409]) 0.0 [179, 0] -2.768632411956787 False
#
#  [180, 0] False
# state:[180, 0], action:0.15735081714478683, reward:0, newstate:[180, 0],done:False
# [180, 0] False
# [180, 0] False
# 	 0 [179, 0] tensor([12.4874]) 0.0 [180, 0] -6.2681355476379395 False
#
#  [181, 0] False
# state:[181, 0], action:-0.44634440552989685, reward:0, newstate:[181, 0],done:False
# [181, 0] False
# [181, 0] False
# 	 0 [180, 0] tensor([-3.8661]) 0.0 [181, 0] -2.685805320739746 False
#
#  [182, 0] False
# state:[182, 0], action:-0.7368646297454804, reward:0, newstate:[182, 0],done:False
# [182, 0] False
# [182, 0] False
# 	 0 [181, 0] tensor([-5.5056]) 0.0 [182, 0] -2.933525562286377 False
#
#  [183, 0] False
# state:[183, 0], action:0.7087701867391583, reward:0, newstate:[183, 0],done:False
# [183, 0] False
# [183, 0] False
# 	 0 [182, 0] tensor([-0.3937]) 0.0 [183, 0] -2.536574363708496 False
#
#  [184, 0] False
# state:[184, 0], action:0.18590170286985486, reward:0, newstate:[184, 0],done:False
# [184, 0] False
# [184, 0] False
# 	 0 [183, 0] tensor([-4.6944]) 0.0 [184, 0] -2.804272174835205 False
#
#  [185, 0] False
# state:[185, 0], action:0.5469462513732013, reward:0, newstate:[185, 0],done:False
# [185, 0] False
# [185, 0] False
# 	 0 [184, 0] tensor([-8.3955]) 0.0 [185, 0] -3.6084556579589844 False
#
#  [186, 0] False
# state:[186, 0], action:0.039547897112035324, reward:0, newstate:[186, 0],done:False
# [186, 0] False
# [186, 0] False
# 	 0 [185, 0] tensor([-5.7398]) 0.0 [186, 0] -2.9797158241271973 False
#
#  [187, 0] False
# state:[187, 0], action:-0.6659161841981003, reward:0, newstate:[187, 0],done:False
# [187, 0] False
# [187, 0] False
# 	 0 [186, 0] tensor([-0.9081]) 0.0 [187, 0] -2.551313877105713 False
#
#  [188, 0] False
# state:[188, 0], action:0.6113403059001064, reward:0, newstate:[188, 0],done:False
# [188, 0] False
# [188, 0] False
# 	 0 [187, 0] tensor([-4.2653]) 0.0 [188, 0] -2.758115768432617 False
#
#  [189, 0] False
# state:[189, 0], action:0.06233905600206402, reward:0, newstate:[189, 0],done:False
# [189, 0] False
# [189, 0] False
# 	 0 [188, 0] tensor([4.6946]) 0.0 [189, 0] -3.168397903442383 False
#
#  [190, 0] False
# state:[190, 0], action:0.014469617376784871, reward:0, newstate:[190, 0],done:False
# [190, 0] False
# [190, 0] False
# 	 0 [189, 0] tensor([0.9746]) 0.0 [190, 0] -2.63942813873291 False
#
#  [191, 0] False
# state:[191, 0], action:0.2782398756310007, reward:0, newstate:[191, 0],done:False
# [191, 0] False
# [191, 0] False
# 	 0 [190, 0] tensor([-9.8244]) 0.0 [191, 0] -3.998135566711426 False
#
#  [192, 0] False
# state:[192, 0], action:-0.9400528202546441, reward:0, newstate:[192, 0],done:False
# [192, 0] False
# [192, 0] False
# 	 0 [191, 0] tensor([-7.3758]) 0.0 [192, 0] -3.314234733581543 False
#
#  [193, 0] False
# state:[193, 0], action:0.34520423645025256, reward:0, newstate:[193, 0],done:False
# [193, 0] False
# [193, 0] False
# 	 0 [192, 0] tensor([-4.6636]) 0.0 [193, 0] -2.82374906539917 False
#
#  [194, 0] False
# state:[194, 0], action:0.36649605657929163, reward:0, newstate:[194, 0],done:False
# [194, 0] False
# [194, 0] False
# 	 0 [193, 0] tensor([2.0444]) 0.0 [194, 0] -2.752810001373291 False
#
#  [195, 0] False
# state:[195, 0], action:0.37905350206312227, reward:0, newstate:[195, 0],done:False
# [195, 0] False
# [195, 0] False
# 	 0 [194, 0] tensor([-2.0717]) 0.0 [195, 0] -2.6137945652008057 False
#
#  [196, 0] False
# state:[196, 0], action:0.31569060920607206, reward:0, newstate:[196, 0],done:False
# [196, 0] False
# [196, 0] False
# 	 0 [195, 0] tensor([4.7013]) 0.0 [196, 0] -3.1634793281555176 False
#
#  [197, 0] False
# state:[197, 0], action:0.1340325219733356, reward:0, newstate:[197, 0],done:False
# [197, 0] False
# [197, 0] False
# 	 0 [196, 0] tensor([-10.4729]) 0.0 [197, 0] -4.1468186378479 False
#
#  [198, 0] False
# state:[198, 0], action:0.5245702695532315, reward:0, newstate:[198, 0],done:False
# [198, 0] False
# [198, 0] False
# 	 0 [197, 0] tensor([-6.0031]) 0.0 [198, 0] -3.0350899696350098 False
#
#  [199, 0] False
# state:[199, 0], action:-0.3508283401994594, reward:0, newstate:[199, 0],done:False
# [199, 0] False
# [199, 0] False
# 	 0 [198, 0] tensor([-3.1736]) 0.0 [199, 0] -2.693819999694824 False
#
#  [200, 0] False
# state:[200, 0], action:-0.25349641674131984, reward:0, newstate:[200, 0],done:False
# [200, 0] False
# [200, 0] False
# 	 0 [199, 0] tensor([-2.1427]) 0.0 [200, 0] -2.6410937309265137 False
#
#  [0, 0] False
# state:[0, 0], action:-0.24042843964154037, reward:0, newstate:[0, 0],done:False
# [0, 0] False
# [0, 0] False
# 	 1 [0, 0] tensor([-0.2580]) 0.0 [0, 0] -0.5290727019309998 False
#
#  [1, 0] False
# state:[1, 0], action:0.06720509345375691, reward:4.7015958375669555, newstate:[1, 1],done:False
# [1, 1] False
# [1, 1] False
# 	 1 [0, 0] tensor([1.2113]) 4.7015958375669555 [1, 1] -2.3566627502441406 False
#
#  [2, 0] False
# state:[2, 0], action:0.294949428309206, reward:0, newstate:[2, 0],done:False
# [2, 0] False
# [2, 0] False
# 	 1 [1, 1] tensor([-0.5270]) 0.0 [2, 0] -0.5962018966674805 False
#
#  [3, 0] False
# state:[3, 0], action:-0.4864468645589841, reward:38.23727464217149, newstate:[3, 1],done:False
# [3, 1] False
# [3, 1] False
# 	 1 [2, 0] tensor([-0.0328]) 38.23727464217149 [3, 1] -0.5285626649856567 False
#
#  [4, 0] False
# state:[4, 0], action:-0.17290179694929697, reward:0, newstate:[4, 0],done:False
# [4, 0] False
# [4, 0] False
# 	 1 [3, 1] tensor([-0.9596]) 0.0 [4, 0] -0.8469237089157104 False
#
#  [5, 0] False
# state:[5, 0], action:-0.4868744325972725, reward:0, newstate:[5, 0],done:False
# [5, 0] False
# [5, 0] False
# 	 1 [4, 0] tensor([-1.3767]) 0.0 [5, 0] -1.7678569555282593 False
#
#  [6, 0] False
# state:[6, 0], action:0.6383777188535804, reward:0, newstate:[6, 0],done:False
# [6, 0] False
# [6, 0] False
# 	 1 [5, 0] tensor([-1.6087]) 0.0 [6, 0] -2.121387004852295 False
#
#  [7, 0] False
# state:[7, 0], action:-0.5262588820510359, reward:0, newstate:[7, 0],done:False
# [7, 0] False
# [7, 0] False
# 	 1 [6, 0] tensor([-0.1867]) 0.0 [7, 0] -0.6598060131072998 False
#
#  [8, 0] False
# state:[8, 0], action:-0.09646464252554177, reward:0, newstate:[8, 0],done:False
# [8, 0] False
# [8, 0] False
# 	 1 [7, 0] tensor([-2.0254]) 0.0 [8, 0] -2.76194429397583 False
#
#  [9, 0] False
# state:[9, 0], action:0.283943000886532, reward:0, newstate:[9, 0],done:False
# [9, 0] False
# [9, 0] False
# 	 1 [8, 0] tensor([-0.8881]) 0.0 [9, 0] -0.7649387717247009 False
#
#  [10, 0] False
# state:[10, 0], action:-0.7271204948865337, reward:15.060262291471965, newstate:[10, 1],done:False
# [10, 1] False
# [10, 1] False
# 	 1 [9, 0] tensor([-0.8084]) 15.060262291471965 [10, 1] -0.7186729907989502 False
#
#  [11, 0] False
# state:[11, 0], action:-0.7432114210917495, reward:23.71989864525854, newstate:[11, 1],done:False
# [11, 1] False
# [11, 1] False
# 	 1 [10, 1] tensor([-1.8581]) 23.71989864525854 [11, 1] -1.6381003856658936 False
#
#  [12, 0] False
# state:[12, 0], action:0.7883817493282366, reward:0, newstate:[12, 0],done:False
# [12, 0] False
# [12, 0] False
# 	 1 [11, 1] tensor([-1.6040]) 0.0 [12, 0] -1.2071058750152588 False
#
#  [13, 0] False
# state:[13, 0], action:-0.8647748728155702, reward:0, newstate:[13, 0],done:False
# [13, 0] False
# [13, 0] False
# 	 1 [12, 0] tensor([-1.2435]) 0.0 [13, 0] -0.9451788663864136 False
#
#  [14, 0] False
# state:[14, 0], action:-0.3513324937692488, reward:0, newstate:[14, 0],done:False
# [14, 0] False
# [14, 0] False
# 	 1 [13, 0] tensor([-1.2314]) 0.0 [14, 0] -0.9216431379318237 False
#
#  [15, 0] False
# state:[15, 0], action:-0.0695887754325637, reward:0, newstate:[15, 0],done:False
# [15, 0] False
# [15, 0] False
# 	 1 [14, 0] tensor([-1.3139]) 0.0 [15, 0] -0.9694644212722778 False
#
#  [16, 0] False
# state:[16, 0], action:0.07165536894616253, reward:0, newstate:[16, 0],done:False
# [16, 0] False
# [16, 0] False
# 	 1 [15, 0] tensor([-0.0391]) 0.0 [16, 0] -1.1611828804016113 False
#
#  [17, 0] False
# state:[17, 0], action:0.8543556389589053, reward:0, newstate:[17, 0],done:False
# [17, 0] False
# [17, 0] False
# 	 1 [16, 0] tensor([0.2456]) 0.0 [17, 0] -1.5212366580963135 False
#
#  [18, 0] False
# state:[18, 0], action:0.6840665887528425, reward:0, newstate:[18, 0],done:False
# [18, 0] False
# [18, 0] False
# 	 1 [17, 0] tensor([-0.2408]) 0.0 [18, 0] -1.0449185371398926 False
#
#  [19, 0] False
# state:[19, 0], action:0.5640561753407718, reward:0, newstate:[19, 0],done:False
# [19, 0] False
# [19, 0] False
# 	 1 [18, 0] tensor([-1.6684]) 0.0 [19, 0] -1.2183712720870972 False
#
#  [20, 0] False
# state:[20, 0], action:0.8739156460621256, reward:0, newstate:[20, 0],done:False
# [20, 0] False
# [20, 0] False
# 	 1 [19, 0] tensor([-0.0358]) 0.0 [20, 0] -1.2635302543640137 False
#
#  [21, 0] False
# state:[21, 0], action:0.8387839464288347, reward:0, newstate:[21, 0],done:False
# [21, 0] False
# [21, 0] False
# 	 1 [20, 0] tensor([-1.2051]) 0.0 [21, 0] -0.929635763168335 False
#
#  [22, 0] False
# state:[22, 0], action:0.6348994169823832, reward:0, newstate:[22, 0],done:False
# [22, 0] False
# [22, 0] False
# 	 1 [21, 0] tensor([-2.5828]) 0.0 [22, 0] -2.3576109409332275 False
#
#  [23, 0] False
# state:[23, 0], action:-0.8381614338974956, reward:0, newstate:[23, 0],done:False
# [23, 0] False
# [23, 0] False
# 	 1 [22, 0] tensor([0.9021]) 0.0 [23, 0] -2.5960683822631836 False
#
#  [24, 0] False
# state:[24, 0], action:0.6449611272687219, reward:0, newstate:[24, 0],done:False
# [24, 0] False
# [24, 0] False
# 	 1 [23, 0] tensor([-1.2983]) 0.0 [24, 0] -0.9966215491294861 False
#
#  [25, 0] False
# state:[25, 0], action:-0.6503227454791749, reward:0, newstate:[25, 0],done:False
# [25, 0] False
# [25, 0] False
# 	 1 [24, 0] tensor([0.9367]) 0.0 [25, 0] -2.6108503341674805 False
#
#  [26, 0] False
# state:[26, 0], action:-0.7296674216903545, reward:0, newstate:[26, 0],done:False
# [26, 0] False
# [26, 0] False
# 	 1 [25, 0] tensor([-0.4831]) 0.0 [26, 0] -1.0656964778900146 False
#
#  [27, 0] False
# state:[27, 0], action:-0.12097662273417975, reward:0, newstate:[27, 0],done:False
# [27, 0] False
# [27, 0] False
# 	 1 [26, 0] tensor([-0.9764]) 0.0 [27, 0] -0.983930766582489 False
#
#  [28, 0] False
# state:[28, 0], action:-0.8773007457786637, reward:0, newstate:[28, 0],done:False
# [28, 0] False
# [28, 0] False
# 	 1 [27, 0] tensor([0.1369]) 0.0 [28, 0] -1.5139703750610352 False
#
#  [29, 0] False
# state:[29, 0], action:0.9673578505268272, reward:0, newstate:[29, 0],done:False
# [29, 0] False
# [29, 0] False
# 	 1 [28, 0] tensor([-3.3142]) 0.0 [29, 0] -3.276782512664795 False
#
#  [30, 0] False
# state:[30, 0], action:-0.8754164037398746, reward:0, newstate:[30, 0],done:False
# [30, 0] False
# [30, 0] False
# 	 1 [29, 0] tensor([-1.1225]) 0.0 [30, 0] -1.0436080694198608 False
#
#  [31, 0] False
# state:[31, 0], action:0.05408292782330326, reward:0, newstate:[31, 0],done:False
# [31, 0] False
# [31, 0] False
# 	 1 [30, 0] tensor([-0.6852]) 0.0 [31, 0] -1.0837703943252563 False
#
#  [32, 0] False
# state:[32, 0], action:-0.17174049494214594, reward:0, newstate:[32, 0],done:False
# [32, 0] False
# [32, 0] False
# 	 1 [31, 0] tensor([-3.0893]) 0.0 [32, 0] -2.720637798309326 False
#
#  [33, 0] False
# state:[33, 0], action:-0.9616154463538866, reward:0, newstate:[33, 0],done:False
# [33, 0] False
# [33, 0] False
# 	 1 [32, 0] tensor([-1.5387]) 0.0 [33, 0] -1.195643424987793 False
#
#  [34, 0] False
# state:[34, 0], action:-0.517597084800917, reward:0, newstate:[34, 0],done:False
# [34, 0] False
# [34, 0] False
# 	 1 [33, 0] tensor([-2.0077]) 0.0 [34, 0] -1.464629888534546 False
#
#  [35, 0] False
# state:[35, 0], action:-0.09124533088007825, reward:0, newstate:[35, 0],done:False
# [35, 0] False
# [35, 0] False
# 	 1 [34, 0] tensor([-0.6725]) 0.0 [35, 0] -1.1500520706176758 False
#
#  [36, 0] False
# state:[36, 0], action:-0.04796374126246694, reward:0, newstate:[36, 0],done:False
# [36, 0] False
# [36, 0] False
# 	 1 [35, 0] tensor([-0.4096]) 0.0 [36, 0] -1.2421128749847412 False
#
#  [37, 0] False
# state:[37, 0], action:0.5738067725105902, reward:0, newstate:[37, 0],done:False
# [37, 0] False
# [37, 0] False
# 	 1 [36, 0] tensor([-2.8787]) 0.0 [37, 0] -2.2749838829040527 False
#
#  [38, 0] False
# state:[38, 0], action:0.803523984270847, reward:0, newstate:[38, 0],done:False
# [38, 0] False
# [38, 0] False
# 	 1 [37, 0] tensor([-0.1007]) 0.0 [38, 0] -1.407305359840393 False
#
#  [39, 0] False
# state:[39, 0], action:-0.8666959188786201, reward:0, newstate:[39, 0],done:False
# [39, 0] False
# [39, 0] False
# 	 1 [38, 0] tensor([1.9256]) 0.0 [39, 0] -3.7046642303466797 False
#
#  [40, 0] False
# state:[40, 0], action:-0.8304159679083936, reward:0, newstate:[40, 0],done:False
# [40, 0] False
# [40, 0] False
# 	 1 [39, 0] tensor([-2.0636]) 0.0 [40, 0] -1.5249004364013672 False
#
#  [41, 0] False
# state:[41, 0], action:-0.2934971829958717, reward:0, newstate:[41, 0],done:False
# [41, 0] False
# [41, 0] False
# 	 1 [40, 0] tensor([0.8171]) 0.0 [41, 0] -2.1257076263427734 False
#
#  [42, 0] False
# state:[42, 0], action:-0.8032087005732054, reward:0, newstate:[42, 0],done:False
# [42, 0] False
# [42, 0] False
# 	 1 [41, 0] tensor([-1.3423]) 0.0 [42, 0] -1.2591824531555176 False
#
#  [43, 0] False
# state:[43, 0], action:-0.4091104450451595, reward:0, newstate:[43, 0],done:False
# [43, 0] False
# [43, 0] False
# 	 1 [42, 0] tensor([-1.7323]) 0.0 [43, 0] -1.3839811086654663 False
#
#  [44, 0] False
# state:[44, 0], action:0.549267561275576, reward:0, newstate:[44, 0],done:False
# [44, 0] False
# ...
# [42, 0] False
# [42, 0] False
# 	 29 [41, 0] tensor([-1.1637]) 0.0 [42, 0] -1.4134751558303833 False
#
#  [43, 0] False
# state:[43, 0], action:-0.05553491446697967, reward:0, newstate:[43, 0],done:False
# [43, 0] False
# [43, 0] False
# 	 29 [42, 0] tensor([-0.1177]) 0.0 [43, 0] -1.5767003297805786 False
#
#  [44, 0] False
# state:[44, 0], action:-0.33610207177635587, reward:0, newstate:[44, 0],done:False
# [44, 0] False
# [44, 0] False
# 	 29 [43, 0] tensor([-1.9099]) 0.0 [44, 0] -1.6070443391799927 False
#
#  [45, 0] False
# state:[45, 0], action:0.9161381106762096, reward:0, newstate:[45, 0],done:False
# [45, 0] False
# [45, 0] False
# 	 29 [44, 0] tensor([-0.7450]) 0.0 [45, 0] -1.5091755390167236 False
#
#  [46, 0] False
# state:[46, 0], action:0.7794089035770242, reward:0, newstate:[46, 0],done:False
# [46, 0] False
# [46, 0] False
# 	 29 [45, 0] tensor([-4.2276]) 0.0 [46, 0] -3.0687947273254395 False
#
#  [47, 0] False
# state:[47, 0], action:0.68548417624436, reward:0, newstate:[47, 0],done:False
# [47, 0] False
# [47, 0] False
# 	 29 [46, 0] tensor([-2.2777]) 0.0 [47, 0] -1.7837998867034912 False
#
#  [48, 0] False
# state:[48, 0], action:-0.013837504350667995, reward:0, newstate:[48, 0],done:False
# [48, 0] False
# [48, 0] False
# 	 29 [47, 0] tensor([-1.1607]) 0.0 [48, 0] -1.5852806568145752 False
#
#  [49, 0] False
# state:[49, 0], action:0.885200546717364, reward:0, newstate:[49, 0],done:False
# [49, 0] False
# [49, 0] False
# 	 29 [48, 0] tensor([-1.1360]) 0.0 [49, 0] -1.6104352474212646 False
#
#  [50, 0] False
# state:[50, 0], action:-0.8946183488929069, reward:0, newstate:[50, 0],done:False
# [50, 0] False
# [50, 0] False
# 	 29 [49, 0] tensor([-3.1727]) 0.0 [50, 0] -2.198765754699707 False
#
#  [51, 0] False
# state:[51, 0], action:-0.23427172805485674, reward:0, newstate:[51, 0],done:False
# [51, 0] False
# [51, 0] False
# 	 29 [50, 0] tensor([-0.5198]) 0.0 [51, 0] -1.6854560375213623 False
#
#  [52, 0] False
# state:[52, 0], action:-0.2773791688418483, reward:0, newstate:[52, 0],done:False
# [52, 0] False
# [52, 0] False
# 	 29 [51, 0] tensor([-0.3044]) 0.0 [52, 0] -1.736480474472046 False
#
#  [53, 0] False
# state:[53, 0], action:-0.9095494138446216, reward:0, newstate:[53, 0],done:False
# [53, 0] False
# [53, 0] False
# 	 29 [52, 0] tensor([-0.0126]) 0.0 [53, 0] -1.8090386390686035 False
#
#  [54, 0] False
# state:[54, 0], action:0.12342477259553308, reward:0, newstate:[54, 0],done:False
# [54, 0] False
# [54, 0] False
# 	 29 [53, 0] tensor([-5.8736]) 0.0 [54, 0] -4.065781116485596 False
#
#  [55, 0] False
# state:[55, 0], action:0.14445996526786087, reward:0, newstate:[55, 0],done:False
# [55, 0] False
# [55, 0] False
# 	 29 [54, 0] tensor([1.0442]) 0.0 [55, 0] -2.1477553844451904 False
#
#  [56, 0] False
# state:[56, 0], action:0.27322795943121725, reward:0, newstate:[56, 0],done:False
# [56, 0] False
# [56, 0] False
# 	 29 [55, 0] tensor([-0.7904]) 0.0 [56, 0] -1.7833168506622314 False
#
#  [57, 0] False
# state:[57, 0], action:0.6759031465314889, reward:0, newstate:[57, 0],done:False
# [57, 0] False
# [57, 0] False
# 	 29 [56, 0] tensor([-3.5149]) 0.0 [57, 0] -2.342751979827881 False
#
#  [58, 0] False
# state:[58, 0], action:0.009233765280251216, reward:0, newstate:[58, 0],done:False
# [58, 0] False
# [58, 0] False
# 	 29 [57, 0] tensor([1.4800]) 0.0 [58, 0] -2.3272182941436768 False
#
#  [59, 0] False
# state:[59, 0], action:-0.47311679062617307, reward:0, newstate:[59, 0],done:False
# [59, 0] False
# [59, 0] False
# 	 29 [58, 0] tensor([0.6956]) 0.0 [59, 0] -2.0714588165283203 False
#
#  [60, 0] False
# state:[60, 0], action:-0.46562922176561683, reward:0, newstate:[60, 0],done:False
# [60, 0] False
# [60, 0] False
# 	 29 [59, 0] tensor([-0.7473]) 0.0 [60, 0] -1.8730612993240356 False
#
#  [61, 0] False
# state:[61, 0], action:-0.6970504635663473, reward:0, newstate:[61, 0],done:False
# [61, 0] False
# [61, 0] False
# 	 29 [60, 0] tensor([-0.1727]) 0.0 [61, 0] -1.9386883974075317 False
#
#  [62, 0] False
# state:[62, 0], action:0.47923633257394926, reward:0, newstate:[62, 0],done:False
# [62, 0] False
# [62, 0] False
# 	 29 [61, 0] tensor([0.0182]) 0.0 [62, 0] -1.9818565845489502 False
#
#  [63, 0] False
# state:[63, 0], action:0.3858813078042589, reward:0, newstate:[63, 0],done:False
# [63, 0] False
# [63, 0] False
# 	 29 [62, 0] tensor([-0.2936]) 0.0 [63, 0] -1.964055061340332 False
#
#  [64, 0] False
# state:[64, 0], action:0.24815857589965273, reward:0, newstate:[64, 0],done:False
# [64, 0] False
# [64, 0] False
# 	 29 [63, 0] tensor([-0.2927]) 0.0 [64, 0] -1.9830784797668457 False
#
#  [65, 0] False
# state:[65, 0], action:0.5015758499920222, reward:0, newstate:[65, 0],done:False
# [65, 0] False
# [65, 0] False
# 	 29 [64, 0] tensor([0.5191]) 0.0 [65, 0] -2.1119155883789062 False
#
#  [66, 0] False
# state:[66, 0], action:0.5337317284981877, reward:0, newstate:[66, 0],done:False
# [66, 0] False
# [66, 0] False
# 	 29 [65, 0] tensor([-0.0456]) 0.0 [66, 0] -2.0442447662353516 False
#
#  [67, 0] False
# state:[67, 0], action:-0.6460076172191094, reward:0, newstate:[67, 0],done:False
# [67, 0] False
# [67, 0] False
# 	 29 [66, 0] tensor([6.3661]) 0.0 [67, 0] -5.069486618041992 False
#
#  [68, 0] False
# state:[68, 0], action:0.9505795404315474, reward:0, newstate:[68, 0],done:False
# [68, 0] False
# [68, 0] False
# 	 29 [67, 0] tensor([1.1777]) 0.0 [68, 0] -2.2865614891052246 False
#
#  [69, 0] False
# state:[69, 0], action:0.31411770888416224, reward:0, newstate:[69, 0],done:False
# [69, 0] False
# [69, 0] False
# 	 29 [68, 0] tensor([-6.0378]) 0.0 [69, 0] -3.375009059906006 False
#
#  [70, 0] False
# state:[70, 0], action:0.23272912961500447, reward:0, newstate:[70, 0],done:False
# [70, 0] False
# [70, 0] False
# 	 29 [69, 0] tensor([-3.2902]) 0.0 [70, 0] -2.33056640625 False
#
#  [71, 0] False
# state:[71, 0], action:0.2065860558768975, reward:0, newstate:[71, 0],done:False
# [71, 0] False
# [71, 0] False
# 	 29 [70, 0] tensor([-2.2744]) 0.0 [71, 0] -2.1632304191589355 False
#
#  [72, 0] False
# state:[72, 0], action:-0.5268785960942626, reward:0, newstate:[72, 0],done:False
# [72, 0] False
# [72, 0] False
# 	 29 [71, 0] tensor([-2.0617]) 0.0 [72, 0] -2.154971122741699 False
#
#  [73, 0] False
# state:[73, 0], action:-0.34282917344929675, reward:0, newstate:[73, 0],done:False
# [73, 0] False
# [73, 0] False
# 	 29 [72, 0] tensor([1.7419]) 0.0 [73, 0] -2.460171699523926 False
#
#  [74, 0] False
# state:[74, 0], action:-0.8244815589613788, reward:0, newstate:[74, 0],done:False
# [74, 0] False
# [74, 0] False
# 	 29 [73, 0] tensor([-0.5908]) 0.0 [74, 0] -2.1442482471466064 False
#
#  [75, 0] False
# state:[75, 0], action:-0.24067996821337512, reward:0, newstate:[75, 0],done:False
# [75, 0] False
# [75, 0] False
# 	 29 [74, 0] tensor([6.1871]) 0.0 [75, 0] -4.3385138511657715 False
#
#  [76, 0] False
# state:[76, 0], action:0.4646177147481083, reward:0, newstate:[76, 0],done:False
# [76, 0] False
# [76, 0] False
# 	 29 [75, 0] tensor([-2.3477]) 0.0 [76, 0] -2.244990348815918 False
#
#  [77, 0] False
# state:[77, 0], action:0.09693810476701237, reward:0, newstate:[77, 0],done:False
# [77, 0] False
# [77, 0] False
# 	 29 [76, 0] tensor([0.3520]) 0.0 [77, 0] -2.259561061859131 False
#
#  [78, 0] False
# state:[78, 0], action:0.8473459839785946, reward:0, newstate:[78, 0],done:False
# [78, 0] False
# [78, 0] False
# 	 29 [77, 0] tensor([-2.3779]) 0.0 [78, 0] -2.2762269973754883 False
#
#  [79, 0] False
# state:[79, 0], action:-0.5338554138017708, reward:0, newstate:[79, 0],done:False
# [79, 0] False
# [79, 0] False
# 	 29 [78, 0] tensor([0.1000]) 0.0 [79, 0] -2.264437675476074 False
#
#  [80, 0] False
# state:[80, 0], action:0.15537268403445026, reward:0, newstate:[80, 0],done:False
# [80, 0] False
# [80, 0] False
# 	 29 [79, 0] tensor([0.7141]) 0.0 [80, 0] -2.340960741043091 False
#
#  [81, 0] False
# state:[81, 0], action:0.10131809274656556, reward:0, newstate:[81, 0],done:False
# [81, 0] False
# [81, 0] False
# 	 29 [80, 0] tensor([-0.6481]) 0.0 [81, 0] -2.2552778720855713 False
#
#  [82, 0] False
# state:[82, 0], action:-0.5243630032531901, reward:0, newstate:[82, 0],done:False
# [82, 0] False
# [82, 0] False
# 	 29 [81, 0] tensor([-2.1224]) 0.0 [82, 0] -2.3088881969451904 False
#
#  [83, 0] False
# state:[83, 0], action:0.8505796696201766, reward:0, newstate:[83, 0],done:False
# [83, 0] False
# [83, 0] False
# 	 29 [82, 0] tensor([-0.8649]) 0.0 [83, 0] -2.2820959091186523 False
#
#  [84, 0] False
# state:[84, 0], action:0.9889236954885054, reward:0, newstate:[84, 0],done:False
# [84, 0] False
# [84, 0] False
# 	 29 [83, 0] tensor([1.7100]) 0.0 [84, 0] -2.5300185680389404 False
#
#  [85, 0] False
# state:[85, 0], action:0.5666668669937251, reward:0, newstate:[85, 0],done:False
# [85, 0] False
# [85, 0] False
# 	 29 [84, 0] tensor([-0.9295]) 0.0 [85, 0] -2.311350107192993 False
#
#  [86, 0] False
# state:[86, 0], action:0.08953626415098292, reward:0, newstate:[86, 0],done:False
# [86, 0] False
# [86, 0] False
# 	 29 [85, 0] tensor([8.1868]) 0.0 [86, 0] -4.857145309448242 False
#
#  [87, 0] False
# state:[87, 0], action:-0.31183559615308387, reward:0, newstate:[87, 0],done:False
# [87, 0] False
# [87, 0] False
# 	 29 [86, 0] tensor([-2.3399]) 0.0 [87, 0] -2.3924245834350586 False
#
#  [88, 0] False
# state:[88, 0], action:-0.7532743106768991, reward:0, newstate:[88, 0],done:False
# [88, 0] False
# [88, 0] False
# 	 29 [87, 0] tensor([-6.8102]) 0.0 [88, 0] -3.3106799125671387 False
#
#  [89, 0] False
# state:[89, 0], action:-0.2746685649666427, reward:0, newstate:[89, 0],done:False
# [89, 0] False
# [89, 0] False
# 	 29 [88, 0] tensor([3.6556]) 0.0 [89, 0] -2.9653682708740234 False
#
#  [90, 0] False
# state:[90, 0], action:0.830643921108124, reward:0, newstate:[90, 0],done:False
# [90, 0] False
# [90, 0] False
# 	 29 [89, 0] tensor([-1.4664]) 0.0 [90, 0] -2.387873649597168 False
#
#  [91, 0] False
# state:[91, 0], action:0.9859678978162099, reward:0, newstate:[91, 0],done:False
# [91, 0] False
# [91, 0] False
# 	 29 [90, 0] tensor([-3.1997]) 0.0 [91, 0] -2.521857261657715 False
#
#  [92, 0] False
# state:[92, 0], action:-0.13598890536745856, reward:0, newstate:[92, 0],done:False
# [92, 0] False
# [92, 0] False
# 	 29 [91, 0] tensor([0.6944]) 0.0 [92, 0] -2.4819979667663574 False
#
#  [93, 0] False
# state:[93, 0], action:-0.9965923439178876, reward:0, newstate:[93, 0],done:False
# [93, 0] False
# [93, 0] False
# 	 29 [92, 0] tensor([0.8466]) 0.0 [93, 0] -2.506697177886963 False
#
#  [94, 0] False
# state:[94, 0], action:0.2166021372341984, reward:0, newstate:[94, 0],done:False
# [94, 0] False
# [94, 0] False
# 	 29 [93, 0] tensor([0.2066]) 0.0 [94, 0] -2.470569610595703 False
#
#  [95, 0] False
# state:[95, 0], action:0.2954128698380871, reward:0, newstate:[95, 0],done:False
# [95, 0] False
# [95, 0] False
# 	 29 [94, 0] tensor([-4.6219]) 0.0 [95, 0] -2.7563018798828125 False
#
#  [96, 0] False
# state:[96, 0], action:-0.7693297667798644, reward:0, newstate:[96, 0],done:False
# [96, 0] False
# [96, 0] False
# 	 29 [95, 0] tensor([-2.1653]) 0.0 [96, 0] -2.4923152923583984 False
#
#  [97, 0] False
# state:[97, 0], action:0.374009696177366, reward:0, newstate:[97, 0],done:False
# [97, 0] False
# [97, 0] False
# 	 29 [96, 0] tensor([2.2149]) 0.0 [97, 0] -2.7044031620025635 False
#
#  [98, 0] False
# state:[98, 0], action:-0.9598351386450046, reward:0, newstate:[98, 0],done:False
# [98, 0] False
# [98, 0] False
# 	 29 [97, 0] tensor([-5.1918]) 0.0 [98, 0] -2.868603467941284 False
#
#  [99, 0] False
# state:[99, 0], action:-0.05892859846260756, reward:0, newstate:[99, 0],done:False
# [99, 0] False
# [99, 0] False
# 	 29 [98, 0] tensor([-10.4487]) 0.0 [99, 0] -4.393365859985352 False
#
#  [100, 0] False
# state:[100, 0], action:0.46273186912163133, reward:0, newstate:[100, 0],done:False
# [100, 0] False
# [100, 0] False
# 	 29 [99, 0] tensor([-1.0156]) 0.0 [100, 0] -2.510922908782959 False
#
#  [101, 0] False
# state:[101, 0], action:0.36749012657568203, reward:0, newstate:[101, 0],done:False
# [101, 0] False
# [101, 0] False
# 	 29 [100, 0] tensor([-3.7031]) 0.0 [101, 0] -2.6706974506378174 False
#
#  [102, 0] False
# state:[102, 0], action:-0.8819388463246933, reward:0, newstate:[102, 0],done:False
# [102, 0] False
# [102, 0] False
# 	 29 [101, 0] tensor([-2.3505]) 0.0 [102, 0] -2.570892810821533 False
#
#  [103, 0] False
# state:[103, 0], action:-0.5585637847204228, reward:0, newstate:[103, 0],done:False
# [103, 0] False
# [103, 0] False
# 	 29 [102, 0] tensor([3.4083]) 0.0 [103, 0] -2.9213671684265137 False
#
#  [104, 0] False
# state:[104, 0], action:-0.2714152851692564, reward:0, newstate:[104, 0],done:False
# [104, 0] False
# [104, 0] False
# 	 29 [103, 0] tensor([-5.8684]) 0.0 [104, 0] -3.004791736602783 False
#
#  [105, 0] False
# state:[105, 0], action:0.8285814177350326, reward:0, newstate:[105, 0],done:False
# [105, 0] False
# [105, 0] False
# 	 29 [104, 0] tensor([-0.9820]) 0.0 [105, 0] -2.569836378097534 False
#
#  [106, 0] False
# state:[106, 0], action:0.4021916188764778, reward:0, newstate:[106, 0],done:False
# [106, 0] False
# [106, 0] False
# 	 29 [105, 0] tensor([-3.2780]) 0.0 [106, 0] -2.6745946407318115 False
#
#  [107, 0] False
# state:[107, 0], action:0.7742532250232572, reward:0, newstate:[107, 0],done:False
# [107, 0] False
# [107, 0] False
# 	 29 [106, 0] tensor([7.7146]) 0.0 [107, 0] -3.9285993576049805 False
#
#  [108, 0] False
# state:[108, 0], action:0.6782912509218217, reward:0, newstate:[108, 0],done:False
# [108, 0] False
# [108, 0] False
# 	 29 [107, 0] tensor([-1.3174]) 0.0 [108, 0] -2.6053595542907715 False
#
#  [109, 0] False
# state:[109, 0], action:-0.1962583959989057, reward:0, newstate:[109, 0],done:False
# [109, 0] False
# [109, 0] False
# 	 29 [108, 0] tensor([2.2623]) 0.0 [109, 0] -2.793771266937256 False
#
#  [110, 0] False
# state:[110, 0], action:0.19280127432572214, reward:0, newstate:[110, 0],done:False
# [110, 0] False
# [110, 0] False
# 	 29 [109, 0] tensor([6.1885]) 0.0 [110, 0] -3.4765048027038574 False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       7 while count < 200 and not done:
#       8     for t in range(rollout_len):
# ----> 9         mu, std = model.pi(torch.from_numpy(np.array(s)).float())
#      10         dist = Normal(mu, std)
#      11         a = dist.sample()
#
# File /econ_share/home/pp712/double-auctions/code/8_clean/algorithms.py:134, in PPO1.pi(self, x, softmax_dim)
#     133 def pi(self, x, softmax_dim = 0):
# --> 134     x = F.relu(self.fc1(x))
#     135     mu = torch.tanh(self.fc_mu(x))
#     136     std = F.softplus(self.fc_std(x))
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/nn/functional.py:1457, in relu(input, inplace)
#    1455     result = torch.relu_(input)
#    1456 else:
# -> 1457     result = torch.relu(input)
#    1458 return result
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/fx/traceback.py:41, in format_stack()
#      38     return [current_meta.get("stack_trace", "")]
#      39 else:
#      40     # fallback to traceback.format_stack()
# ---> 41     return traceback.format_list(traceback.extract_stack()[:-1])
#
# File /econ_share/apps/miniforge3/lib/python3.11/traceback.py:41, in format_list(extracted_list)
#      29 def format_list(extracted_list):
#      30     """Format a list of tuples or FrameSummary objects for printing.
#      31
#      32     Given a list of tuples or FrameSummary objects as returned by
#    (...)
#      39     whose source text line is not None.
#      40     """
# ---> 41     return StackSummary.from_list(extracted_list).format()
#
# File /econ_share/apps/miniforge3/lib/python3.11/traceback.py:531, in StackSummary.format(self)
#     529 count = 0
#     530 for frame_summary in self:
# --> 531     formatted_frame = self.format_frame_summary(frame_summary)
#     532     if formatted_frame is None:
#     533         continue
#
# File /econ_share/apps/miniforge3/lib/python3.11/traceback.py:471, in StackSummary.format_frame_summary(self, frame_summary)
#     468 stripped_line = frame_summary.line.strip()
#     469 row.append('    {}\n'.format(stripped_line))
# --> 471 orig_line_len = len(frame_summary._original_line)
#     472 frame_line_len = len(frame_summary.line.lstrip())
#     473 stripped_characters = orig_line_len - frame_line_len
#
# File /econ_share/apps/miniforge3/lib/python3.11/traceback.py:310, in FrameSummary._original_line(self)
#     307 def __len__(self):
#     308     return 4
# --> 310 @property
#     311 def _original_line(self):
#     312     # Returns the line as-is from the source, without modifying whitespace.
#     313     self.line
#     314     return self._line
#
# KeyboardInterrupt:

# %%
env.log.graphTraining(maxNumPeriods=3000, skip = 20, trackBuyersIdx = [0])

# %%
env.log.graphLearning(trackBuyersIdx = [0], trackSellersIdx = [], rolling_window=100, type = 'period')

# %%
env.log.stepData.tail(10)

# %%
env.log.graphSales(0, 4887, trackBuyersIdx=[0], trackSellersIdx=[])

# %%
env.log.graphOffers(0, 4888, trackBuyersIdx=[0], trackSellersIdx=[])
