# %%
from utils import * 
from algorithms import *
from agents import *

# %%
numRounds, numPeriods, numSteps = 1, 10000, 10
numBuyers, numSellers, numTokens = 2, 4, 4
gameTypes, seed = '1001', 42
disclosure = []
depth = 0
gameData = [gameTypes, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed]
verbose = -1
num_states = numStates = 2
buyers = [Reinforcer(gameData, disclosure, index=0, buyer=1, reinforcer=1, numStates = 2, algo='PPO1'),
          Reinforcer(gameData, disclosure, index=0, buyer=1, reinforcer=1, numStates = 2, algo='PPO1')]
          #ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0),
          #ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0)]

sellers = [ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0)]
log = Log(gameData, disclosure)
rnd = 0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 9
#       7 verbose = -1
#       8 num_states = numStates = 2
# ----> 9 buyers = [Reinforcer(gameData, disclosure, index=0, buyer=1, reinforcer=1, numStates = 2, algo='PPO1', algoArgs = [num_states, verbose]),
#      10           Reinforcer(gameData, disclosure, index=0, buyer=1, reinforcer=1, numStates = 2, algo='PPO1', algoArgs = [num_states, verbose])]
#      11           #ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0),
#      12           #ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0)]
#      14 sellers = [ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
#      15            ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
#      16            ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
#      17            ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0)]
#
# File /econ_share/home/pp712/double-auctions/code/9_final/agents.py:120, in Reinforcer.__init__(self, gameData, disclosure, index, buyer, reinforcer, numStates, numActions, algo, depth, verbose, algoArgs)
#     118 self.numActions = numActions
#     119 self.state = [0]*self.numStates
# --> 120 self.algo = loadAlgo(algo, algoArgs=algoArgs)
#     121 self.done = False
#     122 self.verbose = verbose
#
# File /econ_share/home/pp712/double-auctions/code/9_final/algorithms.py:28, in loadAlgo(algo, algoArgs)
#      26     return DQN(*algoArgs)
#      27 if algo=='PPO1':
# ---> 28     return PPO1(*algoArgs)
#      29 if algo=='PPO2':
#      30     return PPO2(*algoArgs)
#
# File /econ_share/home/pp712/double-auctions/code/9_final/algorithms.py:127, in PPO1.__init__(self, num_states, learning_rate, gamma, lmbda, eps_clip, K_epoch, rollout_len, buffer_size, minibatch_size, verbose)
#     125 self.fc_std  = nn.Linear(64,1)
#     126 self.fc_v = nn.Linear(64,1)
# --> 127 self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)
#     128 self.optimization_step = 0
#     129 self.score          = 0.0
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/optim/adam.py:19, in Adam.__init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused)
#      14 def __init__(self, params, lr=1e-3, betas=(0.9, 0.999), eps=1e-8,
#      15              weight_decay=0, amsgrad=False, *, foreach: Optional[bool] = None,
#      16              maximize: bool = False, capturable: bool = False,
#      17              differentiable: bool = False, fused: Optional[bool] = None):
#      18     if not 0.0 <= lr:
# ---> 19         raise ValueError("Invalid learning rate: {}".format(lr))
#      20     if not 0.0 <= eps:
#      21         raise ValueError("Invalid epsilon value: {}".format(eps))
#
# ValueError: Invalid learning rate: -1

# %%
for rnd in range(numRounds):
    startRounds(gameData, log, buyers, sellers, rnd)
    score1, score2 = 0.0, 0.0
    for period in range(numPeriods):
        startPeriods(buyers, sellers)
        for step in range(numSteps):
            # start
            startSteps(buyers, sellers)

            # set state
            buyers[0].state = [buyers[0].periodSteps, buyers[0].periodTrades]
            buyers[1].state = [buyers[1].periodSteps, buyers[1].periodTrades]

            # trade
            bids, asks = collectOffers(buyers, sellers)
            currentAsk, currentAskIdx, currentBid, currentBidIdx = bestOffers(bids, asks)
            price, buy, sell = trade(buyers, sellers, currentAsk, currentAskIdx, currentBid, currentBidIdx)
            bprofit, sprofit = 0, 0
            if price > 0:
                buyers[currentBidIdx].transact(price)
                sellers[currentAskIdx].transact(price)
                bprofit = buyers[currentBidIdx].stepProfits
                sprofit = sellers[currentAskIdx].stepProfits
            if currentBidIdx == 0:
                score1 += bprofit
            if currentBidIdx == 1:
                score2 += bprofit
                
            # log and end step
            log.addStep([rnd, period, step, bids, asks, currentBid, currentBidIdx, currentAsk, currentAskIdx, buy, sell, price, price>0, bprofit, sprofit])
            observe(buyers, sellers, log.disclose())
            endSteps(buyers, sellers) # updates period counters

            # new state and done
            buyers[0].newState = [step+1, buyers[0].periodTrades]
            buyers[1].newState = [step+1, buyers[1].periodTrades]
            if step == numSteps - 1:
                buyers[0].done = True
                buyers[1].done = True
            else:
                buyers[0].done = False
                buyers[1].done = False

            # load data and train
            agentsObserve(buyers, sellers)
            agentsTrain(buyers, sellers)

        endPeriods(buyers, sellers)
        if period%100==0:
            print(score1/100, score2/100)
            score1, score2 = 0.0, 0.0
    endRounds(buyers, sellers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 for rnd in range(numRounds):
# ----> 2     startRounds(gameData, log, buyers, sellers, rnd)
#       3     score1, score2 = 0.0, 0.0
#       4     for period in range(numPeriods):
#
# NameError: name 'log' is not defined

# %%
log.graphLearning(rolling_window = 100, trackBuyersIdx=[0,1], trackSellersIdx=[])

# %%
log.graphSales(0, period-1, trackBuyersIdx=[0,1], trackSellersIdx=[])

# %%
log.roundData.buyerValues.item()
# Out:
# array([[98.66747422, 81.34610326, 79.18073043, 65.91406304],
#        [99.69105289, 83.27003575, 64.27784395, 63.711074  ]])

# %%
log.stepData.tail(15)
# Out:
#       rnd  period  step          bids                                  asks  \
# 6818    0     757     5  [57.7, 54.8]  [63.6, 42.5, 23.8, 81.2, 70.4, 60.2]
# 6819    0     757     6   [nan, 58.8]  [73.5, 56.2, 44.2, 72.6, 67.1, 59.5]
# 6820    0     757     7    [nan, 7.7]  [71.8, 70.7, 59.4, 57.8, 75.5, 46.1]
# 6821    0     757     8    [nan, nan]  [52.4, 52.6, 53.4, 44.4, 69.2, 58.4]
# 6822    0     758     0  [29.0, 17.0]  [61.2, 16.8, 34.2, 25.4, 31.0, 45.6]
# 6823    0     758     1  [11.1, 26.5]  [71.6, 14.2, 22.5, 21.4, 35.2, 49.5]
# 6824    0     758     2  [21.2, 16.6]  [76.0, 67.8, 36.7, 23.6, 33.0, 60.8]
# 6825    0     758     3  [28.7, 48.1]  [65.4, 54.6, 29.7, 57.4, 43.4, 63.4]
# 6826    0     758     4  [57.5, 28.1]  [70.0, 69.3, 49.7, 59.7, 43.8, 58.9]
# 6827    0     758     5  [58.7, 47.7]  [69.8, 59.6, 33.2, 62.8, 40.5, 53.4]
# 6828    0     758     6   [nan, 47.9]  [56.8, 37.3, 42.5, 46.4, 65.6, 64.9]
# 6829    0     758     7   [nan, 52.6]  [42.3, 55.9, 57.9, 48.6, 61.8, 65.3]
# 6830    0     758     8    [nan, nan]  [58.1, 81.1, 38.5, 80.0, 49.0, 45.5]
# 6831    0     759     0  [56.5, 27.1]  [66.7, 15.6, 24.5, 20.4, 28.7, 42.7]
# 6832    0     759     1  [31.0, 84.7]  [43.3, 15.8, 27.6, 28.8, 43.1, 69.6]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy   sell  \
# 6818        57.7            0.0        23.8              2  True   True
# 6819        58.8            1.0        44.2              2  True   True
# 6820         7.7            1.0        46.1              5  True  False
# 6821         NaN            NaN        44.4              3   NaN    NaN
# 6822        29.0            0.0        16.8              1  True   True
# 6823        26.5            1.0        14.2              1  True   True
# 6824        21.2            0.0        23.6              3  True   True
# 6825        48.1            1.0        29.7              2  True   True
# 6826        57.5            0.0        43.8              4  True   True
# 6827        58.7            0.0        33.2              2  True   True
# 6828        47.9            1.0        37.3              1  True   True
# 6829        52.6            1.0        42.3              0  True   True
# 6830         NaN            NaN        38.5              2   NaN    NaN
# 6831        56.5            0.0        15.6              1  True   True
# 6832        84.7            1.0        15.8              1  True   True
#
#       price   sale    bprofit    sprofit
# 6818  40.75   True  25.164063  19.088314
# 6819  51.50   True  12.777844  20.809292
# 6820  46.10   True  17.611074   8.052919
# 6821    NaN  False   0.000000   0.000000
# 6822  22.90   True  75.767474  12.215080
# 6823  20.35   True  79.341053   6.184849
# 6824  22.40   True  58.946103   3.155738
# 6825  38.90   True  44.370036  17.238314
# 6826  50.65   True  28.530730  25.113706
# 6827  45.95   True  19.964063  15.259292
# 6828  42.60   True  21.677844   5.367698
# 6829  47.45   True  16.261074   6.243154
# 6830    NaN  False   0.000000   0.000000
# 6831  36.05   True  62.617474  25.365080
# 6832  50.25   True  49.441053  36.084849

# %%
log.graphOffers(0, period-1, trackBuyersIdx=[0], trackSellersIdx=[0])

# %%
log.graphTraining(maxNumPeriods=period-1, skip = int((period-1)/50), trackBuyersIdx = [0])
