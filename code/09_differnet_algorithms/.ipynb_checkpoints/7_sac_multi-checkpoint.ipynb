# %%
from utils import * 
from algorithms import *
from agents import *

# %%
numRounds, numPeriods, numSteps = 1, 10000, 9
numBuyers, numSellers, numTokens = 2, 6, 4
gameTypes, seed = '1001', 42
disclosure = []
depth = 0
gameData = [gameTypes, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed]
verbose = 1
numStates = 2
buyers = [Reinforcer(gameData, disclosure, index=0, buyer=1, reinforcer=1, numStates = 2, algo='PPO1'),
          Reinforcer(gameData, disclosure, index=0, buyer=1, reinforcer=1, numStates = 2, algo='PPO1')]
          #ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0)]
sellers = [ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0)]
log = Log(gameData, disclosure)
rnd = 0

# %%
for rnd in range(numRounds):
    startRounds(gameData, log, buyers, sellers, rnd)
    score1, score2 = 0.0, 0.0
    for period in range(numPeriods):
        startPeriods(buyers, sellers)
        for step in range(numSteps):
            # start
            startSteps(buyers, sellers)

            # set state
            buyers[0].state = [buyers[0].periodSteps, buyers[0].periodTrades]
            buyers[1].state = [buyers[1].periodSteps, buyers[1].periodTrades]

            # trade
            bids, asks = collectOffers(buyers, sellers)
            currentAsk, currentAskIdx, currentBid, currentBidIdx = bestOffers(bids, asks)
            price, buy, sell = trade(buyers, sellers, currentAsk, currentAskIdx, currentBid, currentBidIdx)
            bprofit, sprofit = 0, 0
            if price > 0:
                buyers[currentBidIdx].transact(price)
                sellers[currentAskIdx].transact(price)
                bprofit = buyers[currentBidIdx].stepProfits
                sprofit = sellers[currentAskIdx].stepProfits
            if currentBidIdx == 0:
                score1 += bprofit
            if currentBidIdx == 1:
                score2 += bprofit
                
            # log and end step
            log.addStep([rnd, period, step, bids, asks, currentBid, currentBidIdx, currentAsk, currentAskIdx, buy, sell, price, price>0, bprofit, sprofit])
            observe(buyers, sellers, log.disclose())
            endSteps(buyers, sellers) # updates period counters

            # new state and done
            buyers[0].newState = [step+1, buyers[0].periodTrades]
            buyers[1].newState = [step+1, buyers[1].periodTrades]
            if step == numSteps - 1:
                buyers[0].done = True
                buyers[1].done = True
            else:
                buyers[0].done = False
                buyers[1].done = False

            # load data and train
            agentsObserve(buyers, sellers)
            agentsTrain(buyers, sellers)

        endPeriods(buyers, sellers)
        if period%100==0:
            print(score1/100, score2/100)
            score1, score2 = 0.0, 0.0
    endRounds(buyers, sellers)
# Out:
# 0.7783424286545089 0.9964262788974403
# 95.9337940797021 112.36311077773534
# 89.2947031679996 116.89158195536662
# 85.53360421199751 119.200903593454
# 82.00669684286008 119.40571371406577
# 81.38937856722829 119.94155032471595
# 78.33554379446264 119.49119448248834
# 83.58691623454607 121.12885541046049
# 85.79858278626978 122.7654363355584
# 91.21728763789704 124.87824844988914
# 91.52214136825575 124.51888517039559
# 90.03194223305235 124.05259118506658
# 96.22212368970321 127.77113507573382
# 105.10577274897652 129.27606399111602
# 107.2548964007538 130.65652360315914
# 107.69870972437162 125.94085081577404
# 110.31602580433058 120.40841690859477
# 118.06788441611238 118.36265323812825
# 117.81280113961904 115.35993182551101
# 120.4346370254835 112.9659911781605
# 125.60775715581822 109.47421238655951
# 128.76949796399455 107.4166356494721
# 128.0656685861041 105.84393918862037
# 136.80621700163854 103.8568058279935
# 139.43394032335925 101.1577288219509
# 141.1995899847571 101.4497555986295
# 142.39172412939936 99.78712522703286
# 139.779429572691 96.27773902194019
# 142.59066820881105 97.55377021621948
# 146.3514893348351 97.11896574059273
# 142.82758620725514 97.67417477262792
# 144.67937930263577 97.68968410493906
# 148.64649506832006 96.67552288031187
# 149.15967481331 96.82263310725851
# 144.63525908818357 97.73146516965986
# 147.47244409345544 97.45643893684934
# 154.23202393497584 99.42372463974631
# 148.55110367676673 98.51415973588227
# 153.37596622145608 98.58334392199997
# 150.8182551137871 101.38868989941338
# 147.68265989986403 98.81925026224177
# 149.69966811441253 100.20923088019336
# 151.3163293700728 101.16735505506215
# 155.00541326105775 101.46847649598156
# 146.84545916140823 103.99082875164186
# 149.3079775639492 104.07441972547389
# 149.13930929969578 105.02211346344828
# 152.0200246492475 104.6453299569517
# 150.8714646880651 104.07223077497228
# 151.41057416798694 105.25747706984686
# 147.5989056148959 104.9215826818148
# 146.64831150831805 104.60940053901324
# 149.53671477211273 104.99026463497486
# 152.25309373499897 105.79980174680469
# 150.16280560744622 106.47501659791688
# 153.50039920649525 106.90061942510194
# 152.17155290554035 107.41704228399894
# 149.95890768846107 106.96324052202408
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 15
#      12 buyers[1].state = [buyers[1].periodSteps, buyers[1].periodTrades]
#      14 # trade
# ---> 15 bids, asks = collectOffers(buyers, sellers)
#      16 currentAsk, currentAskIdx, currentBid, currentBidIdx = bestOffers(bids, asks)
#      17 price, buy, sell = trade(buyers, sellers, currentAsk, currentAskIdx, currentBid, currentBidIdx)
#
# File /econ_share/home/pp712/double-auctions/code/9_final/utils.py:148, in collectOffers(buyers, sellers)
#     146 bids, asks = [], []
#     147 for i, buyer in enumerate(buyers):
# --> 148     bids.append(buyer.bid())
#     149 for i, seller in enumerate(sellers):
#     150     asks.append(seller.ask())
#
# File /econ_share/home/pp712/double-auctions/code/9_final/agents.py:135, in Reinforcer.bid(self)
#     133 def bid(self):
#     134     self.stepBid = np.nan
# --> 135     self.action = self.algo.act(self.state)
#     136     if self.stepTokenValue >= 0:
#     137         min = self.stepTokenValue * 0.01
#
# File /econ_share/home/pp712/double-auctions/code/9_final/algorithms.py:138, in PPO1.act(self, s)
#     137 def act(self, s):
# --> 138     mu, std = self.pi(torch.from_numpy(np.array(s)).float())
#     139     std = torch.clamp(std, self.min_std, self.max_std)
#     140     dist = Normal(mu, std)
#
# File /econ_share/home/pp712/double-auctions/code/9_final/algorithms.py:159, in PPO1.pi(self, x, softmax_dim)
#     157 def pi(self, x, softmax_dim = 0):
#     158     mu = F.leaky_relu(self.fc1(x))
# --> 159     mu = torch.tanh(self.fc_mu(mu))
#     160     std = F.leaky_relu(self.fc2(x))
#     161     std = F.softplus(self.fc_std(std))
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/fx/traceback.py:41, in format_stack()
#      38     return [current_meta.get("stack_trace", "")]
#      39 else:
#      40     # fallback to traceback.format_stack()
# ---> 41     return traceback.format_list(traceback.extract_stack()[:-1])
#
# File /econ_share/apps/miniforge3/lib/python3.11/traceback.py:231, in extract_stack(f, limit)
#     229 if f is None:
#     230     f = sys._getframe().f_back
# --> 231 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     232 stack.reverse()
#     233 return stack
#
# File /econ_share/apps/miniforge3/lib/python3.11/traceback.py:393, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     390     for f, lineno in frame_gen:
#     391         yield f, (lineno, None, None, None)
# --> 393 return klass._extract_from_extended_frame_gen(
#     394     extended_frame_gen(), limit=limit, lookup_lines=lookup_lines,
#     395     capture_locals=capture_locals)
#
# File /econ_share/apps/miniforge3/lib/python3.11/traceback.py:432, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     428     result.append(FrameSummary(
#     429         filename, lineno, name, lookup_line=False, locals=f_locals,
#     430         end_lineno=end_lineno, colno=colno, end_colno=end_colno))
#     431 for filename in fnames:
# --> 432     linecache.checkcache(filename)
#     433 # If immediate lookup was desired, trigger lookups now.
#     434 if lookup_lines:
#
# File /econ_share/apps/miniforge3/lib/python3.11/linecache.py:72, in checkcache(filename)
#      70     continue   # no-op for files loaded via a __loader__
#      71 try:
# ---> 72     stat = os.stat(fullname)
#      73 except OSError:
#      74     cache.pop(filename, None)
#
# KeyboardInterrupt:

# %%
log.graphLearning(rolling_window = 100, trackBuyersIdx=[0,1], trackSellersIdx=[])

# %%
log.graphSales(0, period-1, trackBuyersIdx=[0,1], trackSellersIdx=[])

# %%
log.roundData.buyerValues.item()
# Out:
# array([[98.66747422, 81.34610326, 79.18073043, 65.91406304],
#        [99.69105289, 83.27003575, 64.27784395, 63.711074  ]])

# %%
log.stepData.tail(15)
# Out:
#        rnd  period  step                                     bids  \
# 51582    0    5731     3  [7.535138580930584, 36.886502395667165]
# 51583    0    5731     4                [1.9440226210407237, nan]
# 51584    0    5731     5                 [8.907299240755576, nan]
# 51585    0    5731     6                [10.518704150245114, nan]
# 51586    0    5731     7                [55.098308318773356, nan]
# 51587    0    5731     8                               [nan, nan]
# 51588    0    5732     0   [84.87555870317021, 131.4744696088758]
# 51589    0    5732     1  [70.21679228473666, 102.08771909817075]
# 51590    0    5732     2  [26.022826338565032, 46.29546252270053]
# 51591    0    5732     3   [42.88604278364926, 33.17675994659463]
# 51592    0    5732     4  [5.158076907550774, 31.564202813320254]
# 51593    0    5732     5                [14.162325980742546, nan]
# 51594    0    5732     6                [48.711505318084825, nan]
# 51595    0    5732     7                [4.8176992068167515, nan]
# 51596    0    5732     8                               [nan, nan]
#
#                                        asks  currentBid  currentBidIdx  \
# 51582  [62.4, 58.4, 22.7, 70.7, 43.3, 56.4]   36.886502            1.0
# 51583  [57.1, 70.5, 31.1, 69.1, 30.8, 52.7]    1.944023            0.0
# 51584  [75.9, 55.7, 54.7, 66.5, 68.4, 43.4]    8.907299            0.0
# 51585  [54.7, 49.6, 48.7, 67.4, 47.6, 41.0]   10.518704            0.0
# 51586  [61.6, 63.2, 46.9, 53.7, 56.8, 79.2]   55.098308            0.0
# 51587  [74.7, 45.1, 51.6, 58.5, 71.1, 66.4]         NaN            NaN
# 51588  [65.1, 12.0, 31.4, 30.5, 42.8, 64.7]  131.474470            1.0
# 51589  [48.1, 19.2, 30.9, 29.3, 43.9, 67.5]  102.087719            1.0
# 51590  [76.3, 57.8, 40.8, 36.4, 36.7, 49.5]   46.295463            1.0
# 51591  [57.9, 60.4, 25.7, 65.0, 30.3, 65.1]   42.886043            0.0
# 51592  [62.3, 44.7, 45.2, 58.9, 42.3, 70.9]   31.564203            1.0
# 51593  [44.9, 44.3, 54.9, 49.6, 40.0, 44.1]   14.162326            0.0
# 51594  [62.9, 53.8, 56.6, 71.1, 70.2, 57.0]   48.711505            0.0
# 51595  [51.0, 58.6, 54.0, 68.7, 67.5, 71.8]    4.817699            0.0
# 51596  [59.8, 94.2, 32.9, 74.6, 83.8, 68.3]         NaN            NaN
#
#        currentAsk  currentAskIdx   buy   sell      price   sale    bprofit  \
# 51582        22.7              2  True   True  29.793251   True  33.917823
# 51583        30.8              4  True  False  30.800000   True  67.867474
# 51584        43.4              5  True  False  43.400000   True  37.946103
# 51585        41.0              5  True  False  41.000000   True  38.180730
# 51586        46.9              2  True   True  50.999154   True  14.914909
# 51587        45.1              1   NaN    NaN        NaN  False   0.000000
# 51588        12.0              1  True   True  71.737235   True  27.953818
# 51589        19.2              1  True   True  60.643860   True  22.626176
# 51590        36.4              3  True   True  41.347731   True  22.930113
# 51591        25.7              2  True   True  34.293021   True  64.374453
# 51592        42.3              4  True   True  36.932101   True  26.778973
# 51593        40.0              4  True  False  40.000000   True  41.346103
# 51594        53.8              1  True   True  51.255753   True  27.924978
# 51595        51.0              0  True  False  51.000000   True  14.914063
# 51596        32.9              2   NaN    NaN        NaN  False   0.000000
#
#          sprofit
# 51582   8.131565
# 51583   5.263706
# 51584   5.352919
# 51585   2.077446
# 51586  20.308446
# 51587   0.000000
# 51588  61.052315
# 51589  46.478708
# 51590  22.103469
# 51591  12.631336
# 51592  11.395807
# 51593   1.477374
# 51594  14.023451
# 51595   9.793154
# 51596   0.000000

# %%
log.graphOffers(0, period-1, trackBuyersIdx=[0], trackSellersIdx=[0])

# %%
log.graphTraining(maxNumPeriods=period-1, skip = int((period-1)/50), trackBuyersIdx = [0])
