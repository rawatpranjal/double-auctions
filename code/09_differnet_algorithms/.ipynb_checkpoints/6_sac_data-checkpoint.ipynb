# %%
from utils import * 
from algorithms import *
from agents import *

# %%
numRounds, numPeriods, numSteps = 1, 10000, 9
numBuyers, numSellers, numTokens = 3, 6, 4
gameTypes, seed = '1001', 42
disclosure = []
depth = 0
gameData = [gameTypes, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed]
verbose = 1
num_states = numStates = 2
buyers = [Reinforcer(gameData, disclosure, index=0, buyer=1, reinforcer=1, numStates = 2, algo='SAC', algoArgs = [num_states]),
          ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0),
          ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0)]
sellers = [ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0)]
log = Log(gameData, disclosure)
rnd = 0

# %%
print_interval = 10
for rnd in range(numRounds):
    startRounds(gameData, log, buyers, sellers, rnd)
    score = 0.0
    for period in range(numPeriods):
        startPeriods(buyers, sellers)
        currentAsk, currentAskIdx, currentBid, currentBidIdx, price, buy, sell = -1, -1, -1, -1, -1, -1, -1
        for step in range(numSteps):
            # start
            startSteps(buyers, sellers)

            # set state
            state = [buyers[0].periodSteps, buyers[0].periodTrades, currentAsk, currentAskIdx, currentBid, currentBidIdx, price, buy, sell]
            nonNan = []
            for i in state:
                if i >=0 :
                    nonNan.append(i)
                else:
                    nonNan.append(-1)
            buyers[0].state = nonNan

            # trade
            bids, asks = collectOffers(buyers, sellers)
            currentAsk, currentAskIdx, currentBid, currentBidIdx = bestOffers(bids, asks)
            price, buy, sell = trade(buyers, sellers, currentAsk, currentAskIdx, currentBid, currentBidIdx)
            bprofit, sprofit = 0, 0
            if price > 0:
                buyers[currentBidIdx].transact(price)
                sellers[currentAskIdx].transact(price)
                bprofit = buyers[currentBidIdx].stepProfits
                sprofit = sellers[currentAskIdx].stepProfits
            if currentBidIdx == 0:
                score += bprofit
                
            # log and end step
            log.addStep([rnd, period, step, bids, asks, currentBid, currentBidIdx, currentAsk, currentAskIdx, buy, sell, price, price>0, bprofit, sprofit])
            observe(buyers, sellers, log.disclose())
            endSteps(buyers, sellers) # updates period counters

            # new state and done
            state = [step+1, buyers[0].periodTrades, currentAsk, currentAskIdx, currentBid, currentBidIdx, price, buy, sell]
            nonNan = []
            for i in state:
                if i >=0 :
                    nonNan.append(i)
                else:
                    nonNan.append(-1)
            buyers[0].newState = nonNan


            # load data and train
            agentsObserve(buyers, sellers)
            agentsTrain(buyers, sellers)

        endPeriods(buyers, sellers)
        if period%print_interval==0:
            print(score/print_interval)
            score = 0.0
    endRounds(buyers, sellers)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 23
#      20 buyers[0].state = nonNan
#      22 # trade
# ---> 23 bids, asks = collectOffers(buyers, sellers)
#      24 currentAsk, currentAskIdx, currentBid, currentBidIdx = bestOffers(bids, asks)
#      25 price, buy, sell = trade(buyers, sellers, currentAsk, currentAskIdx, currentBid, currentBidIdx)
#
# File /econ_share/home/pp712/double-auctions/code/9_final/utils.py:148, in collectOffers(buyers, sellers)
#     146 bids, asks = [], []
#     147 for i, buyer in enumerate(buyers):
# --> 148     bids.append(buyer.bid())
#     149 for i, seller in enumerate(sellers):
#     150     asks.append(seller.ask())
#
# File /econ_share/home/pp712/double-auctions/code/9_final/agents.py:135, in Reinforcer.bid(self)
#     133 def bid(self):
#     134     self.stepBid = np.nan
# --> 135     self.action = self.algo.act(self.state)
#     136     if self.stepTokenValue >= 0:
#     137         #min = self.stepTokenValue * 0.01
#     138         min = self.stepTokenValue * 0.1
#
# File /econ_share/home/pp712/double-auctions/code/9_final/algorithms.py:530, in SAC.act(self, s)
#     529 def act(self, s):
# --> 530     self.a, self.log_prob = self.pi(torch.from_numpy(np.array(s)).float())
#     531     return self.a.item()
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /econ_share/home/pp712/double-auctions/code/9_final/algorithms.py:435, in PolicyNet.forward(self, x)
#     434 def forward(self, x):
# --> 435     x = F.relu(self.fc1(x))
#     436     mu = self.fc_mu(x)
#     437     std = F.softplus(self.fc_std(x))
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /econ_share/home/pp712/myenv/lib/python3.11/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x9 and 2x128)

# %%
log.graphLearning(rolling_window = 100, trackBuyersIdx=[0], trackSellersIdx=[0])

# %%
log.graphSales(0, period-1, trackBuyersIdx=[0], trackSellersIdx=[0])

# %%
log.roundData.buyerValues.item()
# Out:
# array([[ 99.25003886,  82.45671643,  77.66026229,  65.21989865],
#        [100.        ,  84.05672672,  63.22103594,  62.96150214],
#        [ 78.67729377,  60.07550004,  59.31575489,  58.17739974]])

# %%
log.stepData.tail(15)
# Out:
#       rnd  period  step                              bids  \
# 3508    0     389     7  [49.478772040321786, 55.7, 44.9]
# 3509    0     389     8   [42.966949693750436, nan, 25.2]
# 3510    0     390     0   [58.26642542823319, 74.1, 53.3]
# 3511    0     390     1   [61.10346305007719, 61.0, 48.5]
# 3512    0     390     2   [51.56052266377239, 10.4, 31.0]
# 3513    0     390     3  [50.028270625771334, 83.3, 68.9]
# 3514    0     390     4   [45.12280472060983, 42.5, 74.2]
# 3515    0     390     5  [36.934800592874176, 34.7, 44.3]
# 3516    0     390     6   [54.51398022096394, 23.4, 39.8]
# 3517    0     390     7   [53.85894169068088, 17.3, 11.6]
# 3518    0     390     8                 [nan, 41.8, 49.9]
# 3519    0     391     0  [57.418606219593805, 72.0, 68.1]
# 3520    0     391     1   [61.19802793158192, 30.0, 41.2]
# 3521    0     391     2   [50.53605507855954, 13.9, 61.4]
# 3522    0     391     3   [55.30549974573417, 77.2, 45.5]
#
#                                       asks  currentBid  currentBidIdx  \
# 3508  [40.1, 38.9, 73.0, 42.7, 63.6, 86.7]   55.700000              1
# 3509  [64.3, 38.1, 73.3, 39.0, 42.0, 77.9]   42.966950              0
# 3510  [16.4, 36.7, 37.4, 52.2, 66.5, 41.9]   74.100000              1
# 3511  [18.6, 26.2, 38.3, 48.1, 57.4, 34.1]   61.103463              0
# 3512  [54.2, 32.8, 40.4, 30.7, 54.2, 32.5]   51.560523              0
# 3513  [54.8, 43.4, 32.2, 44.0, 55.5, 29.4]   83.300000              1
# 3514  [67.1, 28.5, 27.9, 40.7, 46.5, 29.1]   74.200000              2
# 3515  [65.9, 24.1, 59.0, 48.2, 40.4, 35.7]   44.300000              2
# 3516  [70.5, 41.9, 75.6, 43.3, 66.7, 30.6]   54.513980              0
# 3517  [50.2, 44.6, 85.4, 65.6, 49.6, 72.2]   53.858942              0
# 3518  [65.3, 50.9, 72.4, 64.0, 41.4, 56.1]   49.900000              2
# 3519  [15.7, 43.0, 26.3, 38.4, 49.6, 44.9]   72.000000              1
# 3520  [19.6, 33.5, 39.0, 35.6, 63.9, 44.5]   61.198028              0
# 3521  [48.3, 26.4, 33.9, 45.7, 50.1, 25.3]   61.400000              2
# 3522  [48.9, 33.0, 22.6, 36.4, 54.4, 39.4]   77.200000              1
#
#       currentAsk  currentAskIdx   buy  sell      price  sale    bprofit  \
# 3508        38.9              1  True  True  47.300000  True  15.661502
# 3509        38.1              1  True  True  40.533475  True  24.686424
# 3510        16.4              0  True  True  45.250000  True  54.750000
# 3511        18.6              0  True  True  39.851732  True  59.398307
# 3512        30.7              3  True  True  41.130261  True  41.326455
# 3513        29.4              5  True  True  56.350000  True  27.706727
# 3514        27.9              2  True  True  51.050000  True  27.627294
# 3515        24.1              1  True  True  34.200000  True  25.875500
# 3516        30.6              5  True  True  42.556990  True  35.103272
# 3517        44.6              1  True  True  49.229471  True  15.990428
# 3518        41.4              4  True  True  45.650000  True  13.665755
# 3519        15.7              0  True  True  43.850000  True  56.150000
# 3520        19.6              0  True  True  40.399014  True  58.851025
# 3521        25.3              5  True  True  43.350000  True  35.327294
# 3522        22.6              2  True  True  49.900000  True  34.156727
#
#         sprofit
# 3508  17.538000
# 3509   6.898368
# 3510  33.779382
# 3511  23.096105
# 3512  13.208659
# 3513  31.901777
# 3514  29.029977
# 3515  11.363989
# 3516  15.650369
# 3517  19.467471
# 3518   8.683722
# 3519  32.379382
# 3520  23.643387
# 3521  18.901777
# 3522  27.879977

# %%
log.graphOffers(0, period-1, trackBuyersIdx=[0], trackSellersIdx=[0])

# %%
log.graphTraining(maxNumPeriods=period-1, skip = int((period-1)/50), trackBuyersIdx = [0])
