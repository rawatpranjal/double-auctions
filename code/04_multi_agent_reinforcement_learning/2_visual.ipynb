# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
from functions import *
from itertools import count
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO, A2C, DQN, SAC
from stable_baselines3.ppo.policies import MlpPolicy
from stable_baselines3.common.base_class import BaseAlgorithm
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.noise import OrnsteinUhlenbeckActionNoise

# %%
# Game Setup
buyer_strategies = ['Honest', 'Random', 'Random']
seller_strategies = ['Random', 'Random', 'Random']
nbuyers, nsellers = len(buyer_strategies), len(seller_strategies)
nrounds, nperiods, ntokens, nsteps, gametype, nbuyers, nsellers = 2, 2, 10, 30, '1236', len(buyer_strategies), len(seller_strategies)
R1, R2, R3, R4 = gametype_to_ran(gametype)
game_metadata = [nrounds, nperiods, ntokens, nbuyers, nsellers, nsteps, R1, R2, R3, R4]
db = Database(game_metadata, buyer_strategies, seller_strategies)
rnd = 0
period = 0
db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
num_actions = 51 # discrete
num_states = nsteps
min_frac = 0.01
max_frac = 1.5

# %%
# Create environment
class TradingEnv(gym.Env):
    def __init__(self, db, nsteps, render_mode = None):
        self.rnd = 0
        self.period = -1
        self.nperiods = nperiods
        self.db = db
        self.action_space = spaces.Box(0,1,(1,),dtype=np.float)
        self.observation_space = spaces.Box(-1,200,(13,),dtype=np.float32)

    def reset(self,seed=None):
        #self.db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
        self.db.reset_period(self.rnd)
        self.timestep = 0
        self.period += 1
        self.db.buyers[0].next_token()
        agent = self.db.buyers[0]
        observation = np.array([0,-1,-1,-1,-1,-1,-1,-1,agent.value,-1,-1,-1,agent.num_tokens_traded], dtype = np.float32)
        return observation, {}

    def step(self, action, seed=None, options=None):
        [buyer.next_token() for buyer in self.db.buyers]
        [seller.next_token() for seller in self.db.sellers]
        bid_frac = action.item()
        # convert action to bid
        self.db.buyers[0].next_token()
        min_bid = self.db.buyers[0].value * min_frac
        max_bid = self.db.buyers[0].value * max_frac
        bid = np.round(max_bid * bid_frac + (1 - bid_frac) * min_bid, 2)

        # simulate market
        bids = [buyer.bid(self.db) for buyer in self.db.buyers]
        bids[0] = bid
        asks = [seller.ask(self.db) for seller in self.db.sellers]
        current_ask, current_ask_idx, current_bid, current_bid_idx = current_bid_ask(bids, asks)
        sale, price, bprofit, sprofit, buy, sell = buy_sell(self.db, current_bid, current_bid_idx, current_ask, current_ask_idx)
        step_data = [self.rnd, self.period, self.timestep, bids, asks, current_bid, current_bid_idx, current_ask, current_ask_idx, buy, sell, price, sale, bprofit, sprofit]
        self.db.add_step(step_data)

        # compute reward, new state
        reward = 0.0
        if sale == 1 and current_bid_idx == 0:
            reward = bprofit
            
        agent = self.db.buyers[0]
        observation = np.array([self.timestep + 1, current_ask, current_ask_idx, current_bid, current_bid_idx,
                                sale, price, buy, sell, agent.value, agent.step_profit,
                                agent.sale, agent.num_tokens_traded],dtype = np.float32)
        idx = np.isnan(observation)
        observation[idx] = -1.0
        # check termination
        self.timestep += 1
        if self.timestep == nsteps:
            terminated = True
            self.timestep = 0
        else:
            terminated = False
        infos = {"TimeLimit.truncated":True}
        truncated = False
        return observation, reward, terminated, truncated, infos

# %%
# Check environment
from stable_baselines3.common.env_checker import check_env
db = Database(game_metadata, buyer_strategies, seller_strategies)
db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
env = TradingEnv(db, nsteps)
check_env(env)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [32], line 6
#       4 db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
#       5 env = TradingEnv(db, nsteps)
# ----> 6 check_env(env)
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:444, in check_env(env, warn, skip_render_check)
#     439         warnings.warn(
#     440             f"Your action space has dtype {action_space.dtype}, we recommend using np.float32 to avoid cast errors."
#     441         )
#     443 # ============ Check the returned values ===============
# --> 444 _check_returned_values(env, observation_space, action_space)
#     446 # ==== Check the render method and the declared render modes ====
#     447 if not skip_render_check:
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:281, in _check_returned_values(env, observation_space, action_space)
#     279             raise AssertionError(f"Error while checking key={key}: " + str(e)) from e
#     280 else:
# --> 281     _check_obs(obs, observation_space, "reset")
#     283 # Sample a random action
#     284 action = action_space.sample()
#
# File /usr/local/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:223, in _check_obs(obs, observation_space, method_name)
#     217                 index_str = ",".join(map(str, index))
#     218                 message += (
#     219                     f"Expected: {lower_bounds[index]} <= obs[{index_str}] <= {upper_bounds[index]}, "
#     220                     f"actual value: {obs[index]} \n"
#     221                 )
# --> 223             raise AssertionError(message)
#     225 assert observation_space.contains(obs), (
#     226     f"The observation returned by the `{method_name}()` method "
#     227     f"does not match the given observation space {observation_space}"
#     228 )
#
# AssertionError: The observation returned by the `reset()` method does not match the bounds of the given observation space Box(-1.0, 200.0, (13,), float32).
# 1 invalid indices:
# Expected: -1.0 <= obs[8] <= 200.0, actual value: 670.7999877929688

# %%
# Random play
rnd = 0
db = Database(game_metadata, buyer_strategies, seller_strategies)
db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
env = TradingEnv(db, nsteps)
observation, info = env.reset()
for period in count():
    for timestep in count(): 
        action = env.action_space.sample()
        observation, reward, done, info, _ = env.step(action)
        print(f"Rnd: {rnd}, Period: {period}, New State: {observation}, Action:{np.round(action,1)}, Reward: {np.round(reward,1)}, Period End: {done}")
        if done:
            # If the episode is done, reset the environment
            #print('done')
            observation, info = env.reset()
            break
    if period == nperiods:
        period = 0
        break
env.close()
# Out:
# Rnd: 0, Period: 0, New State: [  1.    18.4    1.   481.5    1.     1.   249.95   1.     1.   510.8
#    0.     1.     0.  ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  2.    60.1    1.   435.2    2.     1.   247.65   1.     1.   510.8
#    0.     1.     0.  ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  3.     47.      0.    694.09    0.      1.    370.545   1.      1.
#  510.8   140.255   1.      1.   ], Action:[0.9], Reward: 140.3, Period End: False
# Rnd: 0, Period: 0, New State: [  4.     77.      0.    442.6     2.      1.    259.8     1.      1.
#  232.4   140.255   1.      1.   ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  5.    105.9     0.    623.1     1.      1.    364.5     1.      1.
#  232.4   140.255   1.      1.   ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  6.    115.4     0.    345.      1.      1.    230.2     1.      1.
#  232.4   140.255   1.      1.   ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  7.    146.3     1.    416.2     1.      1.    281.25    1.      1.
#  232.4   140.255   1.      1.   ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  8.    173.2     2.    407.7     1.      1.    290.45    1.      1.
#  232.4   140.255   1.      1.   ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [  9.    172.1     1.    447.7     2.      1.    309.9     1.      1.
#  232.4   140.255   1.      1.   ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 10.    224.6     2.    452.      2.      1.    338.3     1.      1.
#  232.4   140.255   1.      1.   ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 11.    286.1     0.    391.6     2.      1.    338.85    1.      1.
#  232.4   140.255   1.      1.   ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 12.    393.1     2.    293.4     1.      1.    293.4     0.      1.
#  232.4   140.255   1.      1.   ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 13.    361.1     2.    246.8     2.      0.     -1.      0.      0.
#  232.4   140.255   1.      1.   ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 14.    356.8     2.    224.5     2.      0.     -1.      0.      0.
#  232.4   140.255   1.      1.   ], Action:[0.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 15.    311.3     0.    239.9     2.      0.     -1.      0.      0.
#  232.4   140.255   1.      1.   ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 16.    414.1     2.    244.6     1.      0.     -1.      0.      0.
#  232.4   140.255   1.      1.   ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 17.    302.7     2.    251.42    0.      0.     -1.      0.      0.
#  232.4   140.255   0.      1.   ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 18.    376.7     2.    239.8     1.      0.     -1.      0.      0.
#  232.4   140.255   0.      1.   ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 19.    375.3     2.    207.1     1.      0.     -1.      0.      0.
#  232.4   140.255   0.      1.   ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 20.    310.7     2.    199.1     2.      0.     -1.      0.      0.
#  232.4   140.255   0.      1.   ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 21.    320.5     2.    240.8     2.      0.     -1.      0.      0.
#  232.4   140.255   0.      1.   ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 22.    319.      0.    276.3     2.      0.     -1.      0.      0.
#  232.4   140.255   0.      1.   ], Action:[0.6], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 23.    295.5     2.    240.2     1.      0.     -1.      0.      0.
#  232.4   140.255   0.      1.   ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 24.    406.2     0.    241.97    0.      0.     -1.      0.      0.
#  232.4   140.255   0.      1.   ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 25.   327.1    0.   309.13   0.     1.   309.13   0.     1.   232.4
#  -76.73   0.     2.  ], Action:[0.9], Reward: -76.7, Period End: False
# Rnd: 0, Period: 0, New State: [ 26.   388.3    2.   284.44   0.     0.    -1.     0.     0.   201.
#  -76.73   0.     2.  ], Action:[0.9], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 27.   322.4    2.   272.8    2.     0.    -1.     0.     0.   201.
#  -76.73   0.     2.  ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 28.   332.2    1.   261.6    2.     0.    -1.     0.     0.   201.
#  -76.73   0.     2.  ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 29.   353.3    2.   289.9    2.     1.   289.9    0.     1.   201.
#  -76.73   0.     2.  ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 0, New State: [ 30.   351.5    1.   268.7    2.     0.    -1.     0.     0.   201.
#  -76.73   0.     2.  ], Action:[0.3], Reward: 0.0, Period End: True
# Rnd: 0, Period: 1, New State: [  1.    16.8    1.   646.     1.     1.   331.4    1.     1.   510.8
#  -76.73   0.     0.  ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [  2.    49.7    0.   687.1    2.     1.   368.4    1.     1.   510.8
#  -76.73   0.     0.  ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [  3.    66.     0.   619.4    1.     1.   342.7    1.     1.   510.8
#  -76.73   0.     0.  ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [  4.     77.9     1.    642.79    0.      1.    360.345   1.      1.
#  510.8   150.455   1.      1.   ], Action:[0.8], Reward: 150.5, Period End: False
# Rnd: 0, Period: 1, New State: [  5.    104.3     0.    532.4     1.      1.    318.35    1.      1.
#  232.4   150.455   1.      1.   ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [  6.    131.2     2.    470.6     2.      1.    300.9     1.      1.
#  232.4   150.455   1.      1.   ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [  7.    137.2     0.    408.      2.      1.    272.6     1.      1.
#  232.4   150.455   1.      1.   ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [  8.    151.6     1.    543.5     1.      1.    347.55    1.      1.
#  232.4   150.455   1.      1.   ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [  9.    172.6     1.    337.8     2.      1.    255.2     1.      1.
#  232.4   150.455   1.      1.   ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 10.    272.4     2.    321.5     2.      1.    296.95    1.      1.
#  232.4   150.455   1.      1.   ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 11.    327.5     0.    437.1     1.      1.    382.3     1.      1.
#  232.4   150.455   1.      1.   ], Action:[0.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 12.    358.4     0.    249.      1.      0.     -1.      0.      0.
#  232.4   150.455   1.      1.   ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 13.    315.9     2.    225.7     2.      0.     -1.      0.      0.
#  232.4   150.455   1.      1.   ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 14.    345.4     2.    278.27    0.      0.     -1.      0.      0.
#  232.4   150.455   0.      1.   ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 15.    286.8     2.    278.      1.      1.    286.8     1.      0.
#  232.4   150.455   0.      1.   ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 16.   309.6    0.   301.42   0.     1.   301.42   0.     1.   232.4
#  -69.02   0.     2.  ], Action:[0.9], Reward: -69.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 17.   303.1    2.   267.46   0.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.9], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 18.   322.3    2.   227.19   0.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 19.   317.     2.   271.1    2.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 20.   391.8    0.   267.67   0.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.9], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 21.   319.8    2.   268.4    2.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 22.   390.2    1.   266.51   0.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.9], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 23.   331.4    1.   238.7    1.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 24.   343.9    2.   228.1    2.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 25.   356.6    2.   222.6    2.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 26.   353.2    1.   245.36   0.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 27.   330.9    2.   261.4    2.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 28.   329.5    1.   227.1    2.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 29.   315.2    2.   285.     2.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 1, New State: [ 30.   323.5    1.   279.5    2.     0.    -1.     0.     0.   201.
#  -69.02   0.     2.  ], Action:[0.1], Reward: 0.0, Period End: True
# Rnd: 0, Period: 2, New State: [  1.    18.5    1.   707.2    2.     1.   362.85   1.     1.   510.8
#  -69.02   0.     0.  ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  2.    58.4    0.   671.9    1.     1.   365.15   1.     1.   510.8
#  -69.02   0.     0.  ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  3.     82.8     1.    444.49    0.      1.    263.645   1.      1.
#  510.8   247.155   1.      1.   ], Action:[0.6], Reward: 247.2, Period End: False
# Rnd: 0, Period: 2, New State: [  4.     77.2     0.    509.3     1.      1.    293.25    1.      1.
#  232.4   247.155   1.      1.   ], Action:[0.3], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  5.     76.5     0.    570.2     1.      1.    323.35    1.      1.
#  232.4   247.155   1.      1.   ], Action:[0.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  6.    114.7     0.    465.9     1.      1.    290.3     1.      1.
#  232.4   247.155   1.      1.   ], Action:[1.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  7.    130.7     1.    433.7     2.      1.    282.2     1.      1.
#  232.4   247.155   1.      1.   ], Action:[0.9], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  8.    141.1     2.    350.4     1.      1.    245.75    1.      1.
#  232.4   247.155   1.      1.   ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  9.    187.6     1.    278.9     2.      1.    233.25    1.      1.
#  232.4   247.155   1.      1.   ], Action:[0.6], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 10.    259.4     2.    270.8     2.      1.    265.1     1.      1.
#  232.4   247.155   1.      1.   ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 11.    325.8     0.    231.6     2.      1.    325.8     1.      0.
#  232.4   247.155   1.      1.   ], Action:[0.6], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 12.    287.2     2.    242.91    0.      0.     -1.      0.      0.
#  232.4   247.155   0.      1.   ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 13.    379.4     0.    203.5     2.      0.     -1.      0.      0.
#  232.4   247.155   0.      1.   ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 14.    338.8     0.    223.2     1.      0.     -1.      0.      0.
#  232.4   247.155   0.      1.   ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 15.    364.7     1.    220.7     1.      0.     -1.      0.      0.
#  232.4   247.155   0.      1.   ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 16.    323.7     2.    219.9     2.      0.     -1.      0.      0.
#  232.4   247.155   0.      1.   ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 17.    396.3     2.    262.2     2.      0.     -1.      0.      0.
#  232.4   247.155   0.      1.   ], Action:[0.4], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 18.    398.7     2.    287.2     1.      1.    287.2     0.      1.
#  232.4   247.155   0.      1.   ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [ 19.    337.7     2.    234.1     2.      0.     -1.      0.      0.
#  232.4   247.155   0.      1.   ], Action:[0.6], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  20.    303.2     0.    341.66    0.      1.    341.66    0.      1.
#   232.4  -109.26    0.      2.  ], Action:[1.], Reward: -109.3, Period End: False
# Rnd: 0, Period: 2, New State: [  21.    341.      2.    274.6     1.      0.     -1.      0.      0.
#   201.   -109.26    0.      2.  ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  22.    305.2     2.    222.5     2.      0.     -1.      0.      0.
#   201.   -109.26    0.      2.  ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  23.    311.2     2.    222.1     1.      0.     -1.      0.      0.
#   201.   -109.26    0.      2.  ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  24.    334.5     2.    265.2     2.      0.     -1.      0.      0.
#   201.   -109.26    0.      2.  ], Action:[0.7], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  25.    343.4     1.    235.7     2.      0.     -1.      0.      0.
#   201.   -109.26    0.      2.  ], Action:[0.1], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  26.    398.4     1.    259.5     1.      0.     -1.      0.      0.
#   201.   -109.26    0.      2.  ], Action:[0.2], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  27.    327.5     1.    299.85    0.      0.     -1.      0.      0.
#   201.   -109.26    0.      2.  ], Action:[1.], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  28.    290.3     2.    255.42    0.      0.     -1.      0.      0.
#   201.   -109.26    0.      2.  ], Action:[0.8], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  29.    387.4     1.    248.1     2.      0.     -1.      0.      0.
#   201.   -109.26    0.      2.  ], Action:[0.5], Reward: 0.0, Period End: False
# Rnd: 0, Period: 2, New State: [  30.    305.4     2.    215.7     2.      0.     -1.      0.      0.
#   201.   -109.26    0.      2.  ], Action:[0.2], Reward: 0.0, Period End: True

# %%
rnd, period = 0,0
def graph_period(db, rnd, period):
    period_bids = list(db.get_period(rnd, period).bids)
    period_asks = list(db.get_period(rnd, period).asks)
    period_prices = list(db.get_period(rnd, period).price)
    period_sales = np.cumsum(np.where(db.get_period(rnd, period).price > 0,1,0))
    [_, demand_schedule, supply_schedule, P_grid, redemption_values, token_costs, p_eqbm, q_eqbm] = db.get_round(rnd).iloc[0].tolist()
    graph(demand_schedule, supply_schedule, P_grid, p_eqbm, q_eqbm, period_bids, period_asks, period_prices, period_sales, redemption_values, token_costs, db.ntokens, db.nbuyers, db.nsellers, db.nsteps)
    
def compute_demand_supply(redemption_values,token_costs,nbuyers,ntokens,granularity=100):
    max_price = np.max(redemption_values)
    min_price = np.min(token_costs)
    P_grid = np.linspace(min_price,max_price,granularity)
    demand_schedule = np.zeros((granularity),dtype = 'int')
    supply_schedule = np.zeros((granularity), dtype = 'int')
    for i, p in enumerate(P_grid):
        demand_schedule[i] = np.sum(p<=redemption_values)  
        supply_schedule[i] = np.sum(p>=token_costs) 
    return demand_schedule, supply_schedule, P_grid, min_price, max_price

def equilibrium(demand_schedule,supply_schedule,P_grid):
    p_eqbm, q_eqbm = [], np.nan
    for i, p in enumerate(P_grid):
        if demand_schedule[i] == supply_schedule[i]: # when sellers are ready to sell
            p_eqbm.append(p)
            q_eqbm = demand_schedule[i] 
    return np.nanmean(p_eqbm), q_eqbm


def graph(demand_schedule, supply_schedule, P_grid, p_eqbm, q_eqbm, 
                        period_bids, period_asks, period_prices, period_sales, 
                        redemption_values, token_costs, ntokens, nbuyers, nsellers, nsteps):
    minprc, maxprc = np.array(period_bids).max(), np.array(period_bids).min()
    plt.plot(demand_schedule, P_grid, label = 'Demand Curve', color = 'black', linestyle='--')
    plt.plot(supply_schedule, P_grid, label = 'Supply Curve', color = 'black', linestyle='--')
    #plt.scatter(period_prices, color='green', linestyle='--', label='Mean Real Prices')
    plt.axhline(y=np.nanmean(p_eqbm), color='black', linestyle='--', label='Mean Eqbm Prices')
    prices = []
    for i in range(nsteps):
        if (period_prices[i] > 0):
            plt.scatter([period_sales[i]]*len(period_bids[i]), period_bids[i], s = 10, marker = 'x', c = 'red')
            plt.scatter([period_sales[i]]*len(period_asks[i]), period_asks[i], s = 10, marker = 'o', c = 'blue')
        else:
            pass  
    plt.legend()
    text_content = f'q*={q_eqbm}, mean(q)={np.round(np.nanmax(period_sales),1)},p*={np.round(p_eqbm,1)}, mean(p)={np.round(np.nanmean(period_prices),1)}'
    plt.title(text_content)
    plt.xlim(0,q_eqbm+2)
    plt.ylim(minprc, maxprc)
    plt.show()
    
    plt.plot(np.array(period_bids)[:,0], c = 'o', linestyle='--')
    plt.plot(np.array(period_bids)[:,1:], c = 'r', linestyle='--')
    plt.plot(np.array(period_asks), c = 'b', linestyle='--')
    plt.scatter(range(nsteps), period_prices, c = 'g')
    plt.title('Bids (red), Asks (blue) and Prices (green) over trading steps')
    plt.show()

# %%
graph_period(db, rnd, period)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook 

def graph(demand_schedule, supply_schedule, P_grid, p_eqbm, q_eqbm,
          period_bids, period_asks, period_prices, period_sales,
          redemption_values, token_costs, ntokens, nbuyers, nsellers, nsteps):
    
    minprc, maxprc = np.array(period_bids).max(), np.array(period_bids).min()
    
    
    plt.plot(demand_schedule, P_grid, label='Demand Curve', color='black', linestyle='--')
    plt.plot(supply_schedule, P_grid, label='Supply Curve', color='black', linestyle='--')
    plt.axhline(y=np.nanmean(p_eqbm), color='black', linestyle='--', label='Mean Eqbm Prices')
    
    prices = []
    for i in range(nsteps):
        if (period_prices[i] > 0):
            # Clear the previous plot
            plt.clf()
            
            # Plot the demand and supply curves
            plt.plot(demand_schedule, P_grid, label='Demand Curve', color='black', linestyle='--')
            plt.plot(supply_schedule, P_grid, label='Supply Curve', color='black', linestyle='--')
            plt.axhline(y=np.nanmean(p_eqbm), color='black', linestyle='--', label='Mean Eqbm Prices')
            
            # Overlay the bids and asks for the current period
            plt.scatter([period_sales[i]] * len(period_bids[i]), period_bids[i], s=10, marker='x', c='red', label='Bids')
            plt.scatter([period_sales[i]] * len(period_asks[i]), period_asks[i], s=10, marker='o', c='blue', label='Asks')
            
            plt.xlabel('Quantity')
            plt.ylabel('Price')
            plt.legend()
            text_content = f'q*={q_eqbm}, mean(q)={np.round(np.nanmax(period_sales), 1)},p*={np.round(p_eqbm, 1)}, mean(p)={np.round(np.nanmean(period_prices), 1)}'
            plt.title(text_content)
            plt.xlim(0, q_eqbm + 2)
            plt.ylim(minprc, maxprc)
            plt.grid(True)
            
            plt.show()  # Show the updated plot
        else:
            pass
    plt.show()

# %%
graph_period(db, rnd, period)
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">

# %%
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact, widgets

def plot_order_book(demand_schedule, supply_schedule, P_grid, p_eqbm, q_eqbm,
                    period_bids, period_asks, period_prices, period_sales,
                    redemption_values, token_costs, ntokens, nbuyers, nsellers, nsteps, step):
    minprc, maxprc = np.array(period_bids).max(), np.array(period_bids).min()
    
    plt.figure(figsize=(10, 6))
    
    plt.plot(demand_schedule, P_grid, label='Demand Curve', color='black', linestyle='--')
    plt.plot(supply_schedule, P_grid, label='Supply Curve', color='black', linestyle='--')
    plt.axhline(y=np.nanmean(p_eqbm), color='black', linestyle='--', label='Mean Eqbm Prices')
    
    i = step - 1
    if (period_prices[i] > 0):
        # Plot the demand and supply curves
        plt.plot(demand_schedule, P_grid, label='Demand Curve', color='black', linestyle='--')
        plt.plot(supply_schedule, P_grid, label='Supply Curve', color='black', linestyle='--')
        plt.axhline(y=np.nanmean(p_eqbm), color='black', linestyle='--', label='Mean Eqbm Prices')
        
        # Overlay the bids and asks for the current period
        plt.scatter([period_sales[i]] * len(period_bids[i]), period_bids[i], s=10, marker='x', c='red', label='Bids')
        plt.scatter([period_sales[i]] * len(period_asks[i]), period_asks[i], s=10, marker='o', c='blue', label='Asks')
        
        plt.xlabel('Quantity')
        plt.ylabel('Price')
        plt.legend()
        text_content = f'q*={q_eqbm}, mean(q)={np.round(np.nanmax(period_sales), 1)},p*={np.round(p_eqbm, 1)}, mean(p)={np.round(np.nanmean(period_prices), 1)}'
        plt.title(text_content)
        plt.xlim(0, q_eqbm + 2)
        plt.ylim(minprc, maxprc)
        plt.grid(True)
        plt.show()

def interactive_order_book(demand_schedule, supply_schedule, P_grid, p_eqbm, q_eqbm,
                           period_bids, period_asks, period_prices, period_sales,
                           redemption_values, token_costs, ntokens, nbuyers, nsellers, nsteps):
    step_slider = widgets.IntSlider(min=1, max=nsteps, step=1, value=1, description='Step:')
    interact(plot_order_book,
             demand_schedule=widgets.fixed(demand_schedule),
             supply_schedule=widgets.fixed(supply_schedule),
             P_grid=widgets.fixed(P_grid),
             p_eqbm=widgets.fixed(p_eqbm),
             q_eqbm=widgets.fixed(q_eqbm),
             period_bids=widgets.fixed(period_bids),
             period_asks=widgets.fixed(period_asks),
             period_prices=widgets.fixed(period_prices),
             period_sales=widgets.fixed(period_sales),
             redemption_values=widgets.fixed(redemption_values),
             token_costs=widgets.fixed(token_costs),
             ntokens=widgets.fixed(ntokens),
             nbuyers=widgets.fixed(nbuyers),
             nsellers=widgets.fixed(nsellers),
             nsteps=widgets.fixed(nsteps),
             step=step_slider)

# Example data
demand_schedule = [100, 90, 80, 70, 60]
supply_schedule = [40, 50, 60, 70, 80]
P_grid = [10, 20, 30, 40, 50]
p_eqbm = 25
q_eqbm = 45
period_bids = [[10, 9, 8, 7, 6], [11, 10, 9, 8, 7]]
period_asks = [[12, 13, 14, 15, 16], [11, 12, 13, 14, 15]]
period_prices = [22, 28]
period_sales = [45, 45]
redemption_values = [5, 5]
token_costs = [2, 2]
ntokens = 100
nbuyers = 20
nsellers = 20
nsteps = 2

interactive_order_book(demand_schedule, supply_schedule, P_grid, p_eqbm, q_eqbm,
                       period_bids, period_asks, period_prices, period_sales,
                       redemption_values, token_costs, ntokens, nbuyers, nsellers, nsteps)
# Out:
# interactive(children=(IntSlider(value=1, description='Step:', max=2, min=1), Output()), _dom_classes=('widget-…

# %%
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

def graph(demand_schedule, supply_schedule, P_grid, p_eqbm, q_eqbm,
          period_bids, period_asks, period_prices, period_sales,
          redemption_values, token_costs, ntokens, nbuyers, nsellers, nsteps):
    
    # Create a figure for order book visualization
    fig_order_book = go.Figure()
    
    # Plot demand and supply curves
    fig_order_book.add_trace(go.Scatter(x=demand_schedule, y=P_grid, mode='lines', name='Demand Curve', line=dict(dash='dash')))
    fig_order_book.add_trace(go.Scatter(x=supply_schedule, y=P_grid, mode='lines', name='Supply Curve', line=dict(dash='dash')))
    fig_order_book.add_shape(dict(type='line', x0=0, x1=q_eqbm, y0=p_eqbm, y1=p_eqbm, line=dict(dash='dash'), name='Mean Eqbm Prices'))

    for i in range(nsteps):
        if (period_prices[i] > 0):
            # Overlay bids and asks for the current period
            fig_order_book.add_trace(go.Scatter(x=[period_sales[i]] * len(period_bids[i]), y=period_bids[i], 
                                                mode='markers', marker=dict(symbol='x', size=8, color='red'), name='Bids'))
            fig_order_book.add_trace(go.Scatter(x=[period_sales[i]] * len(period_asks[i]), y=period_asks[i], 
                                                mode='markers', marker=dict(symbol='circle', size=8, color='blue'), name='Asks'))
    
    # Configure layout for the order book visualization
    fig_order_book.update_layout(
        title=f'q*={q_eqbm}, mean(q)={np.round(np.nanmax(period_sales), 1)}, p*={np.round(p_eqbm, 1)}, mean(p)={np.round(np.nanmean(period_prices), 1)}',
        xaxis_title='Quantity',
        yaxis_title='Price',
        xaxis=dict(range=[0, q_eqbm + 2]),
        yaxis=dict(range=[min(P_grid), max(P_grid)]),
        legend=dict(x=0.02, y=0.95),
        showlegend=True
    )
    
    # Create a figure for trading steps visualization
    fig_trading_steps = go.Figure()

    fig_trading_steps.add_trace(go.Scatter(x=list(range(nsteps)), y=period_bids, mode='lines', name='Bids', line=dict(dash='dash')))
    fig_trading_steps.add_trace(go.Scatter(x=list(range(nsteps)), y=period_asks, mode='lines', name='Asks', line=dict(dash='dash')))
    fig_trading_steps.add_trace(go.Scatter(x=list(range(nsteps)), y=period_prices, mode='markers', name='Prices', marker=dict(size=8, color='green')))

    # Configure layout for the trading steps visualization
    fig_trading_steps.update_layout(
        title='Bids (red), Asks (blue), and Prices (green) over Trading Steps',
        xaxis_title='Trading Steps',
        yaxis_title='Price',
        xaxis=dict(tickvals=list(range(nsteps))),
        legend=dict(x=0.02, y=0.95),
        showlegend=True,
        grid=True
    )
    
    # Show the order book and trading steps figures
    fig_order_book.show()
    fig_trading_steps.show()

# Example data
demand_schedule = [100, 90, 80, 70, 60]
supply_schedule = [40, 50, 60, 70, 80]
P_grid = [10, 20, 30, 40, 50]
p_eqbm = 25
q_eqbm = 45
period_bids = [[10, 9, 8, 7, 6], [11, 10, 9, 8, 7]]
period_asks = [[12, 13, 14, 15, 16], [11, 12, 13, 14, 15]]
period_prices = [22, 28]
period_sales = [45, 45]
redemption_values = [5, 5]
token_costs = [2, 2]
ntokens = 100
nbuyers = 20
nsellers = 20
nsteps = 2

graph(demand_schedule, supply_schedule, P_grid, p_eqbm, q_eqbm,
      period_bids, period_asks, period_prices, period_sales,
      redemption_values, token_costs, ntokens, nbuyers, nsellers, nsteps)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [129], line 75
#      72 nsellers = 20
#      73 nsteps = 2
# ---> 75 graph(demand_schedule, supply_schedule, P_grid, p_eqbm, q_eqbm,
#      76       period_bids, period_asks, period_prices, period_sales,
#      77       redemption_values, token_costs, ntokens, nbuyers, nsellers, nsteps)
#
# Cell In [129], line 44, in graph(demand_schedule, supply_schedule, P_grid, p_eqbm, q_eqbm, period_bids, period_asks, period_prices, period_sales, redemption_values, token_costs, ntokens, nbuyers, nsellers, nsteps)
#      41 fig_trading_steps.add_trace(go.Scatter(x=list(range(nsteps)), y=period_prices, mode='markers', name='Prices', marker=dict(size=8, color='green')))
#      43 # Configure layout for the trading steps visualization
# ---> 44 fig_trading_steps.update_layout(
#      45     title='Bids (red), Asks (blue), and Prices (green) over Trading Steps',
#      46     xaxis_title='Trading Steps',
#      47     yaxis_title='Price',
#      48     xaxis=dict(tickvals=list(range(nsteps))),
#      49     legend=dict(x=0.02, y=0.95),
#      50     showlegend=True,
#      51     grid=True
#      52 )
#      54 # Show the order book and trading steps figures
#      55 fig_order_book.show()
#
# File /usr/local/lib/python3.10/site-packages/plotly/graph_objs/_figure.py:762, in Figure.update_layout(self, dict1, overwrite, **kwargs)
#     736 def update_layout(self, dict1=None, overwrite=False, **kwargs) -> "Figure":
#     737     """
#     738
#     739     Update the properties of the figure's layout with a dict and/or with
#    (...)
#     760
#     761     """
# --> 762     return super(Figure, self).update_layout(dict1, overwrite, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/plotly/basedatatypes.py:1401, in BaseFigure.update_layout(self, dict1, overwrite, **kwargs)
#    1377 def update_layout(self, dict1=None, overwrite=False, **kwargs):
#    1378     """
#    1379     Update the properties of the figure's layout with a dict and/or with
#    1380     keyword arguments.
#    (...)
#    1399         The Figure object that the update_layout method was called on
#    1400     """
# -> 1401     self.layout.update(dict1, overwrite=overwrite, **kwargs)
#    1402     return self
#
# File /usr/local/lib/python3.10/site-packages/plotly/basedatatypes.py:5122, in BasePlotlyType.update(self, dict1, overwrite, **kwargs)
#    5120     with self.figure.batch_update():
#    5121         BaseFigure._perform_update(self, dict1, overwrite=overwrite)
# -> 5122         BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5123 else:
#    5124     BaseFigure._perform_update(self, dict1, overwrite=overwrite)
#
# File /usr/local/lib/python3.10/site-packages/plotly/basedatatypes.py:3929, in BaseFigure._perform_update(plotly_obj, update_obj, overwrite)
#    3926                 plotly_obj[key] = val
#    3927         else:
#    3928             # Assign non-compound value
# -> 3929             plotly_obj[key] = val
#    3931 elif isinstance(plotly_obj, tuple):
#    3933     if len(update_obj) == 0:
#    3934         # Nothing to do
#
# File /usr/local/lib/python3.10/site-packages/plotly/basedatatypes.py:5861, in BaseLayoutType.__setitem__(self, prop, value)
#    5858 match = self._subplot_re_match(prop)
#    5859 if match is None:
#    5860     # Set as ordinary property
# -> 5861     super(BaseLayoutHierarchyType, self).__setitem__(prop, value)
#    5862 else:
#    5863     # Set as subplotid property
#    5864     self._set_subplotid_prop(prop, value)
#
# File /usr/local/lib/python3.10/site-packages/plotly/basedatatypes.py:4851, in BasePlotlyType.__setitem__(self, prop, value)
#    4849 # ### Handle compound property ###
#    4850 if isinstance(validator, CompoundValidator):
# -> 4851     self._set_compound_prop(prop, value)
#    4853 # ### Handle compound array property ###
#    4854 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File /usr/local/lib/python3.10/site-packages/plotly/basedatatypes.py:5262, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5259 # Import value
#    5260 # ------------
#    5261 validator = self._get_validator(prop)
# -> 5262 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5264 # Save deep copies of current and new states
#    5265 # ------------------------------------------
#    5266 curr_val = self._compound_props.get(prop, None)
#
# File /usr/local/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:2464, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2462         v = self.data_class()
#    2463     else:
# -> 2464         self.raise_invalid_val(v)
#    2466 v._plotly_name = self.plotly_name
#    2467 return v
#
# File /usr/local/lib/python3.10/site-packages/_plotly_utils/basevalidators.py:288, in BaseValidator.raise_invalid_val(self, v, inds)
#     285             for i in inds:
#     286                 name += "[" + str(i) + "]"
# --> 288         raise ValueError(
#     289             """
#     290     Invalid value of type {typ} received for the '{name}' property of {pname}
#     291         Received value: {v}
#     292
#     293 {valid_clr_desc}""".format(
#     294                 name=name,
#     295                 pname=self.parent_name,
#     296                 typ=type_str(v),
#     297                 v=repr(v),
#     298                 valid_clr_desc=self.description(),
#     299             )
#     300         )
#
# ValueError:
#     Invalid value of type 'builtins.bool' received for the 'grid' property of layout
#         Received value: True
#
#     The 'grid' property is an instance of Grid
#     that may be specified as:
#       - An instance of :class:`plotly.graph_objs.layout.Grid`
#       - A dict of string/value properties that will be passed
#         to the Grid constructor
#
#         Supported dict properties:
#
#             columns
#                 The number of columns in the grid. If you
#                 provide a 2D `subplots` array, the length of
#                 its longest row is used as the default. If you
#                 give an `xaxes` array, its length is used as
#                 the default. But it's also possible to have a
#                 different length, if you want to leave a row at
#                 the end for non-cartesian subplots.
#             domain
#                 :class:`plotly.graph_objects.layout.grid.Domain
#                 ` instance or dict with compatible properties
#             pattern
#                 If no `subplots`, `xaxes`, or `yaxes` are given
#                 but we do have `rows` and `columns`, we can
#                 generate defaults using consecutive axis IDs,
#                 in two ways: "coupled" gives one x axis per
#                 column and one y axis per row. "independent"
#                 uses a new xy pair for each cell, left-to-right
#                 across each row then iterating rows according
#                 to `roworder`.
#             roworder
#                 Is the first row the top or the bottom? Note
#                 that columns are always enumerated from left to
#                 right.
#             rows
#                 The number of rows in the grid. If you provide
#                 a 2D `subplots` array or a `yaxes` array, its
#                 length is used as the default. But it's also
#                 possible to have a different length, if you
#                 want to leave a row at the end for non-
#                 cartesian subplots.
#             subplots
#                 Used for freeform grids, where some axes may be
#                 shared across subplots but others are not. Each
#                 entry should be a cartesian subplot id, like
#                 "xy" or "x3y2", or "" to leave that cell empty.
#                 You may reuse x axes within the same column,
#                 and y axes within the same row. Non-cartesian
#                 subplots and traces that support `domain` can
#                 place themselves in this grid separately using
#                 the `gridcell` attribute.
#             xaxes
#                 Used with `yaxes` when the x and y axes are
#                 shared across columns and rows. Each entry
#                 should be an x axis id like "x", "x2", etc., or
#                 "" to not put an x axis in that column. Entries
#                 other than "" must be unique. Ignored if
#                 `subplots` is present. If missing but `yaxes`
#                 is present, will generate consecutive IDs.
#             xgap
#                 Horizontal space between grid cells, expressed
#                 as a fraction of the total width available to
#                 one cell. Defaults to 0.1 for coupled-axes
#                 grids and 0.2 for independent grids.
#             xside
#                 Sets where the x axis labels and titles go.
#                 "bottom" means the very bottom of the grid.
#                 "bottom plot" is the lowest plot that each x
#                 axis is used in. "top" and "top plot" are
#                 similar.
#             yaxes
#                 Used with `yaxes` when the x and y axes are
#                 shared across columns and rows. Each entry
#                 should be an y axis id like "y", "y2", etc., or
#                 "" to not put a y axis in that row. Entries
#                 other than "" must be unique. Ignored if
#                 `subplots` is present. If missing but `xaxes`
#                 is present, will generate consecutive IDs.
#             ygap
#                 Vertical space between grid cells, expressed as
#                 a fraction of the total height available to one
#                 cell. Defaults to 0.1 for coupled-axes grids
#                 and 0.3 for independent grids.
#             yside
#                 Sets where the y axis labels and titles go.
#                 "left" means the very left edge of the grid.
#                 *left plot* is the leftmost plot that each y
#                 axis is used in. "right" and *right plot* are
#                 similar.

# %%
import itertools

import matplotlib.pyplot as plt
import numpy as np

import matplotlib.animation as animation


def data_gen():
    for cnt in itertools.count():
        t = cnt / 10
        yield t, np.sin(2*np.pi*t) * np.exp(-t/10.)


def init():
    ax.set_ylim(-1.1, 1.1)
    ax.set_xlim(0, 1)
    del xdata[:]
    del ydata[:]
    line.set_data(xdata, ydata)
    return line,

fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.grid()
xdata, ydata = [], []


def run(data):
    # update the data
    t, y = data
    xdata.append(t)
    ydata.append(y)
    xmin, xmax = ax.get_xlim()

    if t >= xmax:
        ax.set_xlim(xmin, 2*xmax)
        ax.figure.canvas.draw()
    line.set_data(xdata, ydata)

    return line,

# Only save last 100 frames, but run forever
ani = animation.FuncAnimation(fig, run, data_gen, interval=100, init_func=init,
                              save_count=100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">

# %%
# Training parameters
rnd = 0
period = 0
num_states = nsteps
min_frac = 0.01
max_frac = 1.5
eval_steps = 1000
training_step = 50000

# %% [markdown]
# ### Continous Action Space

# %%
from stable_baselines3 import SAC, DDPG, TD3, A2C, PPO
db = Database(game_metadata, buyer_strategies, seller_strategies)
db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
env = TradingEnv(db, nsteps)
n_actions = env.action_space.shape[-1]
param_noise = None
action_noise = OrnsteinUhlenbeckActionNoise(mean=np.zeros(n_actions), sigma=float(0.5) * np.ones(n_actions))
policy_kwargs = dict(net_arch=dict(pi=[128, 128], qf=[128, 128]))
model = SAC("Ln MlpPolicy", env, policy_kwargs=policy_kwargs, verbose=1, batch_size=128, action_noise = action_noise)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(50000, progress_bar = True)
# Out:
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 80       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | -4.91    |
# |    critic_loss     | 51.7     |
# |    ent_coef        | 0.991    |
# |    ent_coef_loss   | -0.0147  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 166      |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 63       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | -8.31    |
# |    critic_loss     | 39.7     |
# |    ent_coef        | 0.941    |
# |    ent_coef_loss   | -0.0992  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 162      |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 59       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 600      |
# | train/             |          |
# |    actor_loss      | -9.98    |
# |    critic_loss     | 40.3     |
# |    ent_coef        | 0.891    |
# |    ent_coef_loss   | -0.182   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 57       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | -12.3    |
# |    critic_loss     | 52.5     |
# |    ent_coef        | 0.844    |
# |    ent_coef_loss   | -0.238   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 699      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 156      |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 56       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 45.2     |
# |    ent_coef        | 0.802    |
# |    ent_coef_loss   | -0.286   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 899      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 146      |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 55       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 27.4     |
# |    ent_coef        | 0.763    |
# |    ent_coef_loss   | -0.264   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 53       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 1400     |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 40       |
# |    ent_coef        | 0.725    |
# |    ent_coef_loss   | -0.365   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 52       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 30.8     |
# |    ent_coef        | 0.687    |
# |    ent_coef_loss   | -0.516   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 52       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | -17.3    |
# |    critic_loss     | 42.3     |
# |    ent_coef        | 0.649    |
# |    ent_coef_loss   | -0.589   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 52       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 32.6     |
# |    ent_coef        | 0.613    |
# |    ent_coef_loss   | -0.686   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 137      |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 52       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 2200     |
# | train/             |          |
# |    actor_loss      | -19.3    |
# |    critic_loss     | 88.3     |
# |    ent_coef        | 0.578    |
# |    ent_coef_loss   | -0.692   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 137      |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 50       |
# |    time_elapsed    | 47       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 15.4     |
# |    ent_coef        | 0.545    |
# |    ent_coef_loss   | -0.838   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 50       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 2600     |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 49.7     |
# |    ent_coef        | 0.514    |
# |    ent_coef_loss   | -0.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 50       |
# |    time_elapsed    | 55       |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 24.1     |
# |    ent_coef        | 0.485    |
# |    ent_coef_loss   | -0.923   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 50       |
# |    time_elapsed    | 59       |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | -14.4    |
# |    critic_loss     | 24.8     |
# |    ent_coef        | 0.458    |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 50       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | -22.8    |
# |    critic_loss     | 47.2     |
# |    ent_coef        | 0.433    |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 145      |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 50       |
# |    time_elapsed    | 67       |
# |    total_timesteps | 3400     |
# | train/             |          |
# |    actor_loss      | -14.3    |
# |    critic_loss     | 15.7     |
# |    ent_coef        | 0.409    |
# |    ent_coef_loss   | -1.24    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 146      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 50       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 22.4     |
# |    ent_coef        | 0.385    |
# |    ent_coef_loss   | -0.997   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 50       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 3800     |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 22.5     |
# |    ent_coef        | 0.362    |
# |    ent_coef_loss   | -1.41    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 146      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 49       |
# |    time_elapsed    | 80       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -17      |
# |    critic_loss     | 22.4     |
# |    ent_coef        | 0.34     |
# |    ent_coef_loss   | -1.62    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 50       |
# |    time_elapsed    | 83       |
# |    total_timesteps | 4200     |
# | train/             |          |
# |    actor_loss      | -13.6    |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.319    |
# |    ent_coef_loss   | -1.58    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 50       |
# |    time_elapsed    | 87       |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | -15.8    |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.3      |
# |    ent_coef_loss   | -1.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 50       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 4600     |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.283    |
# |    ent_coef_loss   | -1.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 50       |
# |    time_elapsed    | 95       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -20.6    |
# |    critic_loss     | 16.8     |
# |    ent_coef        | 0.267    |
# |    ent_coef_loss   | -1.52    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 50       |
# |    time_elapsed    | 98       |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -17.8    |
# |    critic_loss     | 8.17     |
# |    ent_coef        | 0.251    |
# |    ent_coef_loss   | -1.92    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 50       |
# |    time_elapsed    | 102      |
# |    total_timesteps | 5200     |
# | train/             |          |
# |    actor_loss      | -17.1    |
# |    critic_loss     | 8.76     |
# |    ent_coef        | 0.237    |
# |    ent_coef_loss   | -1.83    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 51       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 5400     |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 28       |
# |    ent_coef        | 0.223    |
# |    ent_coef_loss   | -1.91    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 51       |
# |    time_elapsed    | 108      |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 14.6     |
# |    ent_coef        | 0.211    |
# |    ent_coef_loss   | -1.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 51       |
# |    time_elapsed    | 112      |
# |    total_timesteps | 5800     |
# | train/             |          |
# |    actor_loss      | -16      |
# |    critic_loss     | 9.55     |
# |    ent_coef        | 0.199    |
# |    ent_coef_loss   | -2.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 51       |
# |    time_elapsed    | 115      |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -25.6    |
# |    critic_loss     | 25.6     |
# |    ent_coef        | 0.188    |
# |    ent_coef_loss   | -2.07    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 51       |
# |    time_elapsed    | 119      |
# |    total_timesteps | 6200     |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 16.1     |
# |    ent_coef        | 0.178    |
# |    ent_coef_loss   | -2.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 51       |
# |    time_elapsed    | 123      |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | -19      |
# |    critic_loss     | 19.1     |
# |    ent_coef        | 0.168    |
# |    ent_coef_loss   | -2.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 154      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 51       |
# |    time_elapsed    | 127      |
# |    total_timesteps | 6600     |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 16       |
# |    ent_coef        | 0.159    |
# |    ent_coef_loss   | -2.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 51       |
# |    time_elapsed    | 130      |
# |    total_timesteps | 6800     |
# | train/             |          |
# |    actor_loss      | -22.2    |
# |    critic_loss     | 19.1     |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -2.31    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 159      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 52       |
# |    time_elapsed    | 134      |
# |    total_timesteps | 7000     |
# | train/             |          |
# |    actor_loss      | -16.6    |
# |    critic_loss     | 10.7     |
# |    ent_coef        | 0.144    |
# |    ent_coef_loss   | -1.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 161      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 51       |
# |    time_elapsed    | 139      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | -20.7    |
# |    critic_loss     | 9.25     |
# |    ent_coef        | 0.137    |
# |    ent_coef_loss   | -1.31    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 51       |
# |    time_elapsed    | 143      |
# |    total_timesteps | 7400     |
# | train/             |          |
# |    actor_loss      | -18.6    |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.13     |
# |    ent_coef_loss   | -2.16    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 51       |
# |    time_elapsed    | 148      |
# |    total_timesteps | 7600     |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 12.1     |
# |    ent_coef        | 0.124    |
# |    ent_coef_loss   | -1.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 165      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 51       |
# |    time_elapsed    | 152      |
# |    total_timesteps | 7800     |
# | train/             |          |
# |    actor_loss      | -20.1    |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.118    |
# |    ent_coef_loss   | -1.83    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 165      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 50       |
# |    time_elapsed    | 157      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -16.9    |
# |    critic_loss     | 9.96     |
# |    ent_coef        | 0.112    |
# |    ent_coef_loss   | -2.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 164      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 50       |
# |    time_elapsed    | 161      |
# |    total_timesteps | 8200     |
# | train/             |          |
# |    actor_loss      | -27.8    |
# |    critic_loss     | 16.6     |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -1.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 164      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 50       |
# |    time_elapsed    | 165      |
# |    total_timesteps | 8400     |
# | train/             |          |
# |    actor_loss      | -26.2    |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 166      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 50       |
# |    time_elapsed    | 170      |
# |    total_timesteps | 8600     |
# | train/             |          |
# |    actor_loss      | -23.1    |
# |    critic_loss     | 10.1     |
# |    ent_coef        | 0.0984   |
# |    ent_coef_loss   | -1.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 167      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 50       |
# |    time_elapsed    | 174      |
# |    total_timesteps | 8800     |
# | train/             |          |
# |    actor_loss      | -19.3    |
# |    critic_loss     | 15.8     |
# |    ent_coef        | 0.0938   |
# |    ent_coef_loss   | -1.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 50       |
# |    time_elapsed    | 178      |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 7.85     |
# |    ent_coef        | 0.0893   |
# |    ent_coef_loss   | -1.35    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 50       |
# |    time_elapsed    | 183      |
# |    total_timesteps | 9200     |
# | train/             |          |
# |    actor_loss      | -24.9    |
# |    critic_loss     | 19.1     |
# |    ent_coef        | 0.0855   |
# |    ent_coef_loss   | -1.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 50       |
# |    time_elapsed    | 187      |
# |    total_timesteps | 9400     |
# | train/             |          |
# |    actor_loss      | -29.1    |
# |    critic_loss     | 15.7     |
# |    ent_coef        | 0.0817   |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 171      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 49       |
# |    time_elapsed    | 192      |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | -26.7    |
# |    critic_loss     | 8.35     |
# |    ent_coef        | 0.0783   |
# |    ent_coef_loss   | -1.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 49       |
# |    time_elapsed    | 196      |
# |    total_timesteps | 9800     |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 17.4     |
# |    ent_coef        | 0.0747   |
# |    ent_coef_loss   | -1.06    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 173      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 49       |
# |    time_elapsed    | 201      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -27.4    |
# |    critic_loss     | 15.6     |
# |    ent_coef        | 0.0706   |
# |    ent_coef_loss   | -1.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 173      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 49       |
# |    time_elapsed    | 205      |
# |    total_timesteps | 10200    |
# | train/             |          |
# |    actor_loss      | -24.3    |
# |    critic_loss     | 12.1     |
# |    ent_coef        | 0.0674   |
# |    ent_coef_loss   | -1.91    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 49       |
# |    time_elapsed    | 210      |
# |    total_timesteps | 10400    |
# | train/             |          |
# |    actor_loss      | -21.7    |
# |    critic_loss     | 10.1     |
# |    ent_coef        | 0.0642   |
# |    ent_coef_loss   | -2.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 49       |
# |    time_elapsed    | 214      |
# |    total_timesteps | 10600    |
# | train/             |          |
# |    actor_loss      | -27      |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.0612   |
# |    ent_coef_loss   | -2.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 177      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 49       |
# |    time_elapsed    | 218      |
# |    total_timesteps | 10800    |
# | train/             |          |
# |    actor_loss      | -30.4    |
# |    critic_loss     | 19       |
# |    ent_coef        | 0.0587   |
# |    ent_coef_loss   | -1.64    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 176      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 49       |
# |    time_elapsed    | 222      |
# |    total_timesteps | 11000    |
# | train/             |          |
# |    actor_loss      | -26      |
# |    critic_loss     | 16.1     |
# |    ent_coef        | 0.0565   |
# |    ent_coef_loss   | -0.767   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 178      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 49       |
# |    time_elapsed    | 227      |
# |    total_timesteps | 11200    |
# | train/             |          |
# |    actor_loss      | -28.9    |
# |    critic_loss     | 15       |
# |    ent_coef        | 0.0546   |
# |    ent_coef_loss   | -1.55    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 49       |
# |    time_elapsed    | 232      |
# |    total_timesteps | 11400    |
# | train/             |          |
# |    actor_loss      | -28.2    |
# |    critic_loss     | 20.9     |
# |    ent_coef        | 0.0527   |
# |    ent_coef_loss   | -0.104   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 180      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 48       |
# |    time_elapsed    | 238      |
# |    total_timesteps | 11600    |
# | train/             |          |
# |    actor_loss      | -28.9    |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.0509   |
# |    ent_coef_loss   | -1.75    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 181      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 48       |
# |    time_elapsed    | 243      |
# |    total_timesteps | 11800    |
# | train/             |          |
# |    actor_loss      | -31.6    |
# |    critic_loss     | 12.9     |
# |    ent_coef        | 0.0493   |
# |    ent_coef_loss   | -1.59    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 182      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 48       |
# |    time_elapsed    | 249      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -31.9    |
# |    critic_loss     | 20       |
# |    ent_coef        | 0.0477   |
# |    ent_coef_loss   | -0.584   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 182      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 48       |
# |    time_elapsed    | 254      |
# |    total_timesteps | 12200    |
# | train/             |          |
# |    actor_loss      | -35.9    |
# |    critic_loss     | 15       |
# |    ent_coef        | 0.0458   |
# |    ent_coef_loss   | -1.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 47       |
# |    time_elapsed    | 262      |
# |    total_timesteps | 12400    |
# | train/             |          |
# |    actor_loss      | -35.8    |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0449   |
# |    ent_coef_loss   | -1.31    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 46       |
# |    time_elapsed    | 268      |
# |    total_timesteps | 12600    |
# | train/             |          |
# |    actor_loss      | -32.5    |
# |    critic_loss     | 8.61     |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | -0.221   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 186      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 46       |
# |    time_elapsed    | 274      |
# |    total_timesteps | 12800    |
# | train/             |          |
# |    actor_loss      | -42.4    |
# |    critic_loss     | 20.6     |
# |    ent_coef        | 0.0433   |
# |    ent_coef_loss   | -0.165   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 187      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 46       |
# |    time_elapsed    | 280      |
# |    total_timesteps | 13000    |
# | train/             |          |
# |    actor_loss      | -32.6    |
# |    critic_loss     | 23.9     |
# |    ent_coef        | 0.0425   |
# |    ent_coef_loss   | -0.781   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 46       |
# |    time_elapsed    | 284      |
# |    total_timesteps | 13200    |
# | train/             |          |
# |    actor_loss      | -33.3    |
# |    critic_loss     | 16.8     |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | -0.119   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 46       |
# |    time_elapsed    | 288      |
# |    total_timesteps | 13400    |
# | train/             |          |
# |    actor_loss      | -34.1    |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | -0.404   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 46       |
# |    time_elapsed    | 293      |
# |    total_timesteps | 13600    |
# | train/             |          |
# |    actor_loss      | -37.2    |
# |    critic_loss     | 16.1     |
# |    ent_coef        | 0.0395   |
# |    ent_coef_loss   | -0.855   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 46       |
# |    time_elapsed    | 297      |
# |    total_timesteps | 13800    |
# | train/             |          |
# |    actor_loss      | -26.2    |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.0388   |
# |    ent_coef_loss   | -0.121   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 46       |
# |    time_elapsed    | 301      |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | -29.4    |
# |    critic_loss     | 9.95     |
# |    ent_coef        | 0.038    |
# |    ent_coef_loss   | 0.63     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 46       |
# |    time_elapsed    | 306      |
# |    total_timesteps | 14200    |
# | train/             |          |
# |    actor_loss      | -26.1    |
# |    critic_loss     | 5.78     |
# |    ent_coef        | 0.0373   |
# |    ent_coef_loss   | 0.271    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 192      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 46       |
# |    time_elapsed    | 310      |
# |    total_timesteps | 14400    |
# | train/             |          |
# |    actor_loss      | -36.3    |
# |    critic_loss     | 15.5     |
# |    ent_coef        | 0.0367   |
# |    ent_coef_loss   | 0.0228   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 192      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 46       |
# |    time_elapsed    | 320      |
# |    total_timesteps | 14800    |
# | train/             |          |
# |    actor_loss      | -46.3    |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.0361   |
# |    ent_coef_loss   | 0.241    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 45       |
# |    time_elapsed    | 327      |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | -39.9    |
# |    critic_loss     | 15.9     |
# |    ent_coef        | 0.0365   |
# |    ent_coef_loss   | 0.00638  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 197      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 45       |
# |    time_elapsed    | 332      |
# |    total_timesteps | 15200    |
# | train/             |          |
# |    actor_loss      | -38.8    |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.0359   |
# |    ent_coef_loss   | -0.112   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 199      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 45       |
# |    time_elapsed    | 337      |
# |    total_timesteps | 15400    |
# | train/             |          |
# |    actor_loss      | -35.6    |
# |    critic_loss     | 16.9     |
# |    ent_coef        | 0.0357   |
# |    ent_coef_loss   | -0.297   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 201      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 45       |
# |    time_elapsed    | 342      |
# |    total_timesteps | 15600    |
# | train/             |          |
# |    actor_loss      | -43      |
# |    critic_loss     | 14.8     |
# |    ent_coef        | 0.0357   |
# |    ent_coef_loss   | -0.193   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 203      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 45       |
# |    time_elapsed    | 347      |
# |    total_timesteps | 15800    |
# | train/             |          |
# |    actor_loss      | -40.2    |
# |    critic_loss     | 18.7     |
# |    ent_coef        | 0.0361   |
# |    ent_coef_loss   | 0.665    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 205      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 45       |
# |    time_elapsed    | 351      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -43.5    |
# |    critic_loss     | 17.4     |
# |    ent_coef        | 0.037    |
# |    ent_coef_loss   | 1.04     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 206      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 45       |
# |    time_elapsed    | 356      |
# |    total_timesteps | 16200    |
# | train/             |          |
# |    actor_loss      | -43      |
# |    critic_loss     | 13       |
# |    ent_coef        | 0.0374   |
# |    ent_coef_loss   | 0.703    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 45       |
# |    time_elapsed    | 361      |
# |    total_timesteps | 16400    |
# | train/             |          |
# |    actor_loss      | -36      |
# |    critic_loss     | 14.9     |
# |    ent_coef        | 0.0383   |
# |    ent_coef_loss   | 0.377    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 210      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 45       |
# |    time_elapsed    | 366      |
# |    total_timesteps | 16600    |
# | train/             |          |
# |    actor_loss      | -39      |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0387   |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 210      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 45       |
# |    time_elapsed    | 371      |
# |    total_timesteps | 16800    |
# | train/             |          |
# |    actor_loss      | -40.8    |
# |    critic_loss     | 9.1      |
# |    ent_coef        | 0.0382   |
# |    ent_coef_loss   | -0.614   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16699    |
# ---------------------------------
# ...
# |    fps             | 41       |
# |    time_elapsed    | 887      |
# |    total_timesteps | 37200    |
# | train/             |          |
# |    actor_loss      | -85      |
# |    critic_loss     | 6.02     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | 0.371    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 748      |
# |    fps             | 41       |
# |    time_elapsed    | 893      |
# |    total_timesteps | 37400    |
# | train/             |          |
# |    actor_loss      | -79.8    |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -0.0901  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 752      |
# |    fps             | 41       |
# |    time_elapsed    | 898      |
# |    total_timesteps | 37600    |
# | train/             |          |
# |    actor_loss      | -86.2    |
# |    critic_loss     | 30.7     |
# |    ent_coef        | 0.107    |
# |    ent_coef_loss   | -0.506   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 756      |
# |    fps             | 41       |
# |    time_elapsed    | 903      |
# |    total_timesteps | 37800    |
# | train/             |          |
# |    actor_loss      | -91.6    |
# |    critic_loss     | 5.6      |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | 0.24     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 41       |
# |    time_elapsed    | 908      |
# |    total_timesteps | 38000    |
# | train/             |          |
# |    actor_loss      | -82.7    |
# |    critic_loss     | 20.8     |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -0.0233  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    episodes        | 764      |
# |    fps             | 41       |
# |    time_elapsed    | 914      |
# |    total_timesteps | 38200    |
# | train/             |          |
# |    actor_loss      | -77      |
# |    critic_loss     | 5.39     |
# |    ent_coef        | 0.105    |
# |    ent_coef_loss   | -0.273   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 768      |
# |    fps             | 41       |
# |    time_elapsed    | 921      |
# |    total_timesteps | 38400    |
# | train/             |          |
# |    actor_loss      | -90.1    |
# |    critic_loss     | 5.21     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | -0.0492  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 280      |
# | time/              |          |
# |    episodes        | 772      |
# |    fps             | 41       |
# |    time_elapsed    | 929      |
# |    total_timesteps | 38600    |
# | train/             |          |
# |    actor_loss      | -89.3    |
# |    critic_loss     | 4.17     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | -0.285   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 776      |
# |    fps             | 41       |
# |    time_elapsed    | 935      |
# |    total_timesteps | 38800    |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 5.67     |
# |    ent_coef        | 0.104    |
# |    ent_coef_loss   | 0.29     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 41       |
# |    time_elapsed    | 944      |
# |    total_timesteps | 39000    |
# | train/             |          |
# |    actor_loss      | -84.1    |
# |    critic_loss     | 6.83     |
# |    ent_coef        | 0.105    |
# |    ent_coef_loss   | 0.119    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 784      |
# |    fps             | 40       |
# |    time_elapsed    | 961      |
# |    total_timesteps | 39200    |
# | train/             |          |
# |    actor_loss      | -88.9    |
# |    critic_loss     | 46.5     |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | 0.226    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 788      |
# |    fps             | 40       |
# |    time_elapsed    | 969      |
# |    total_timesteps | 39400    |
# | train/             |          |
# |    actor_loss      | -97.2    |
# |    critic_loss     | 10.4     |
# |    ent_coef        | 0.108    |
# |    ent_coef_loss   | 0.095    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 792      |
# |    fps             | 40       |
# |    time_elapsed    | 974      |
# |    total_timesteps | 39600    |
# | train/             |          |
# |    actor_loss      | -91.7    |
# |    critic_loss     | 10.1     |
# |    ent_coef        | 0.109    |
# |    ent_coef_loss   | 0.254    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 796      |
# |    fps             | 40       |
# |    time_elapsed    | 988      |
# |    total_timesteps | 39800    |
# | train/             |          |
# |    actor_loss      | -92.8    |
# |    critic_loss     | 5.78     |
# |    ent_coef        | 0.109    |
# |    ent_coef_loss   | 0.239    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 40       |
# |    time_elapsed    | 999      |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -90.8    |
# |    critic_loss     | 5.73     |
# |    ent_coef        | 0.111    |
# |    ent_coef_loss   | 0.05     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 804      |
# |    fps             | 39       |
# |    time_elapsed    | 1008     |
# |    total_timesteps | 40200    |
# | train/             |          |
# |    actor_loss      | -85.5    |
# |    critic_loss     | 6.79     |
# |    ent_coef        | 0.112    |
# |    ent_coef_loss   | 0.225    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 808      |
# |    fps             | 39       |
# |    time_elapsed    | 1014     |
# |    total_timesteps | 40400    |
# | train/             |          |
# |    actor_loss      | -96      |
# |    critic_loss     | 10.3     |
# |    ent_coef        | 0.113    |
# |    ent_coef_loss   | 0.00232  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 275      |
# | time/              |          |
# |    episodes        | 812      |
# |    fps             | 39       |
# |    time_elapsed    | 1021     |
# |    total_timesteps | 40600    |
# | train/             |          |
# |    actor_loss      | -98.2    |
# |    critic_loss     | 5.31     |
# |    ent_coef        | 0.116    |
# |    ent_coef_loss   | 0.232    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 816      |
# |    fps             | 39       |
# |    time_elapsed    | 1030     |
# |    total_timesteps | 40800    |
# | train/             |          |
# |    actor_loss      | -89.1    |
# |    critic_loss     | 7.52     |
# |    ent_coef        | 0.116    |
# |    ent_coef_loss   | -0.0819  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 820      |
# |    fps             | 39       |
# |    time_elapsed    | 1039     |
# |    total_timesteps | 41000    |
# | train/             |          |
# |    actor_loss      | -85.6    |
# |    critic_loss     | 9.72     |
# |    ent_coef        | 0.117    |
# |    ent_coef_loss   | -0.379   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 824      |
# |    fps             | 39       |
# |    time_elapsed    | 1046     |
# |    total_timesteps | 41200    |
# | train/             |          |
# |    actor_loss      | -85.8    |
# |    critic_loss     | 3.85     |
# |    ent_coef        | 0.117    |
# |    ent_coef_loss   | -0.281   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    episodes        | 828      |
# |    fps             | 39       |
# |    time_elapsed    | 1053     |
# |    total_timesteps | 41400    |
# | train/             |          |
# |    actor_loss      | -95.1    |
# |    critic_loss     | 11       |
# |    ent_coef        | 0.117    |
# |    ent_coef_loss   | 0.166    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 832      |
# |    fps             | 39       |
# |    time_elapsed    | 1061     |
# |    total_timesteps | 41600    |
# | train/             |          |
# |    actor_loss      | -88.2    |
# |    critic_loss     | 46.9     |
# |    ent_coef        | 0.117    |
# |    ent_coef_loss   | 0.457    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 836      |
# |    fps             | 39       |
# |    time_elapsed    | 1067     |
# |    total_timesteps | 41800    |
# | train/             |          |
# |    actor_loss      | -78      |
# |    critic_loss     | 5.78     |
# |    ent_coef        | 0.117    |
# |    ent_coef_loss   | -0.672   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 840      |
# |    fps             | 39       |
# |    time_elapsed    | 1074     |
# |    total_timesteps | 42000    |
# | train/             |          |
# |    actor_loss      | -88      |
# |    critic_loss     | 3.96     |
# |    ent_coef        | 0.116    |
# |    ent_coef_loss   | 0.406    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 844      |
# |    fps             | 38       |
# |    time_elapsed    | 1082     |
# |    total_timesteps | 42200    |
# | train/             |          |
# |    actor_loss      | -98.4    |
# |    critic_loss     | 8.21     |
# |    ent_coef        | 0.119    |
# |    ent_coef_loss   | 0.469    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 848      |
# |    fps             | 38       |
# |    time_elapsed    | 1087     |
# |    total_timesteps | 42400    |
# | train/             |          |
# |    actor_loss      | -86.7    |
# |    critic_loss     | 9.67     |
# |    ent_coef        | 0.121    |
# |    ent_coef_loss   | -0.0404  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    episodes        | 852      |
# |    fps             | 38       |
# |    time_elapsed    | 1094     |
# |    total_timesteps | 42600    |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 16.3     |
# |    ent_coef        | 0.122    |
# |    ent_coef_loss   | 0.152    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42499    |
# ---------------------------------

# %%
db.step_data.head(500).groupby('current_bid_idx').sum()
# Out:
#                  rnd  period  step  current_bid  current_ask  current_ask_idx  \
# current_bid_idx
# 0                  0     490  2668      7168.89       4443.3              589
# 1                  0     329  1176      4361.80       2628.6              339
# 2                  0     607  4170      5947.30       5853.7              669
# 3                  0     435  2171      5084.70       3547.3              521
# 4                  0     389  2065      4796.40       3285.7              430
#
#                  buy  sell    price  sale  bprofit  sprofit
# current_bid_idx
# 0                 60    90  4857.39    91    92.41  1807.99
# 1                 69    67  3417.30    70  1511.70  1133.10
# 2                 39    41  2094.10    44   903.10   705.40
# 3                 60    57  2934.50    60  1529.50  1237.20
# 4                 47    47  2458.35    49  1449.05  1144.75

# %%
db.step_data.tail(500).groupby('current_bid_idx').sum()
# Out:
#                  rnd  period  step  current_bid  current_ask  current_ask_idx  \
# current_bid_idx
# 0                  0   56744  1313      2922.51       2446.3              313
# 1                  0   67593  1092      4623.70       2564.2              337
# 2                  0  133295  4630      6540.90       6400.7              795
# 3                  0   98225  2616      5727.20       4157.8              621
# 4                  0   94603  2599      5276.10       4033.6              545
#
#                  buy  sell     price  sale   bprofit   sprofit
# current_bid_idx
# 0                 52    42  2238.795    52  1106.005   489.295
# 1                 70    70  3403.800    70  1525.200  1352.400
# 2                 48    45  2342.500    50   921.000   787.300
# 3                 60    60  2964.950    60  1499.050  1282.950
# 4                 48    46  2438.500    50  1513.500  1165.600

# %%
db.round_data.redemption_values.item()

# %%
db.step_data.tail(60)

# %%
graph_period(env.db, 0, 2236)

# %%
from stable_baselines3 import DQN
db = Database(game_metadata, buyer_strategies, seller_strategies)
db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
env = TradingEnv(db, nsteps)
env.action_space = spaces.Discrete(51)
#policy_kwargs = dict(net_arch=dict(pi=[64, 64], qf=[64, 64]))
model = DQN("MlpPolicy", env, verbose=1,)
model.learn(50000, progress_bar = False)

# %%
db.step_data.head(100).groupby('current_bid_idx').sum()

# %%
db.step_data.tail(100).groupby('current_bid_idx').sum()

# %% [markdown]
# ## ON POLICY

# %% [markdown]
# ### DDPG - Deterministic Deep Policy Gradient

# %%
from stable_baselines3 import DDPG
db = Database(game_metadata, buyer_strategies, seller_strategies)
db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
env = TradingEnv(db, nsteps)
policy_kwargs = dict(net_arch=dict(pi=[64, 64], qf=[64, 64]))
model = DDPG("MlpPolicy", env, policy_kwargs=policy_kwargs, verbose=1,)
model.learn(50000, progress_bar = True)

# %%
db.step_data.head(100).groupby('current_bid_idx').sum()
# Out:
#                  rnd  period  step  current_bid  current_ask  current_ask_idx  \
# current_bid_idx
# 0                  0      11   562      1433.54        914.6              109
# 1                  0       7   214       874.80        478.2               68
# 2                  0      12   855      1262.00       1241.7              159
# 3                  0      13   492      1080.60        774.7              118
# 4                  0       7   327       839.20        572.6               67
#
#                  buy  sell     price  sale  bprofit  sprofit
# current_bid_idx
# 0                 12    19  1014.965    19    2.835  352.065
# 1                 14    14   676.500    14  309.300  251.200
# 2                  8     8   429.400     9  178.600  159.800
# 3                 12    11   600.700    12  292.100  257.900
# 4                 10    10   498.950    10  291.450  195.850

# %%
db.step_data.tail(100).groupby('current_bid_idx').sum()
# Out:
#                  rnd  period  step  current_bid  current_ask  current_ask_idx  \
# current_bid_idx
# 0                  0   10857   269       506.15        514.1               73
# 1                  0   13579   239       946.20        548.3               44
# 2                  0   26237   899      1291.80       1228.7              169
# 3                  0   22625   586      1247.20        936.0              142
# 4                  0   17194   457      1009.10        693.3              105
#
#                  buy  sell    price  sale  bprofit  sprofit
# current_bid_idx
# 0                 10     6  432.865    10  162.835   56.565
# 1                 14    14  709.250    14  276.550  278.950
# 2                 11     9  505.900    11  197.900  146.000
# 3                 13    13  609.450    13  335.850  278.750
# 4                  9    10  488.600    10  301.800  258.100

# %% [markdown]
# ### PPO - Proximal Policy Optimization

# %%
from stable_baselines3 import PPO
db = Database(game_metadata, buyer_strategies, seller_strategies)
db.reset_round(rnd, ntokens, nbuyers, nsellers, R1, R2, R3, R4)
env = TradingEnv(db, nsteps)
policy_kwargs = dict(net_arch=dict(pi=[64, 64], qf=[64, 64]))
model = PPO("MlpPolicy", env, policy_kwargs=policy_kwargs, verbose=1)
model.learn(50000, progress_bar = False)

# %% [markdown]
# ### A2C - Advantage Actor-Critic

# %%
# Create A2C model
from stable_baselines3.ppo.policies import MlpPolicy
a2c_model = A2C(MlpPolicy, env, verbose=0)

# Train the A2C agent for 10000 steps
a2c_model.learn(total_timesteps=training_step, progress_bar = True)

# Evaluate the trained A2C agent
mean_reward_a2c, std_reward_a2c = evaluate_policy(a2c_model, env, n_eval_episodes=eval_steps)
print(f"A2C mean_reward: {mean_reward_a2c:.2f} +/- {std_reward_a2c:.2f}")
