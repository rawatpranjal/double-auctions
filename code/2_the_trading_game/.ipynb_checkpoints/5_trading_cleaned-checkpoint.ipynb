# %%
from packages import *
from game import *

# %%
list_of_strategies = ['Honest', 'Random', 'Creeper', 'Markup', 'Sniper', 'Foresight']
honest_only = ['Honest']*5
random_only = ['Random']*5
buyer_strategies = honest_only
seller_strategies = honest_only
db = TradingGame(buyer_strategies, seller_strategies, verbose = 1)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In [2], line 6
#       4 buyer_strategies = honest_only
#       5 seller_strategies = list_of_strategies
# ----> 6 db = TradingGame(buyer_strategies, seller_strategies, verbose = 1)
#
# File ~/Desktop/AI_Double_Auctions/code/trading_game/game.py:41, in TradingGame(buyer_strategies, seller_strategies, verbose)
#      37 for step in range(nsteps):
#      38
#      39     # bid/ask step
#      40     bids = [buyer.bid(db) for buyer in db.buyers]
# ---> 41     asks = [seller.ask(db) for seller in db.sellers]
#      43     if np.all(np.isnan(bids)) == False:
#      44         current_bid_idx = np.nanargmax(bids)
#
# File ~/Desktop/AI_Double_Auctions/code/trading_game/game.py:41, in <listcomp>(.0)
#      37 for step in range(nsteps):
#      38
#      39     # bid/ask step
#      40     bids = [buyer.bid(db) for buyer in db.buyers]
# ---> 41     asks = [seller.ask(db) for seller in db.sellers]
#      43     if np.all(np.isnan(bids)) == False:
#      44         current_bid_idx = np.nanargmax(bids)
#
# File ~/Desktop/AI_Double_Auctions/code/trading_game/traders.py:98, in Random.ask(self, db)
#      96 self.next_token()
#      97 if self.value != np.nan:
# ---> 98     self.ask_amount = np.round(np.random.uniform(self.value, self.value*1.2, 1).item(),1)
#      99 else:
#     100     self.ask_amount = np.nan
#
# File mtrand.pyx:1119, in numpy.random.mtrand.RandomState.uniform()
#
# OverflowError: Range exceeds valid bounds

# %%
db.buyers

# %%
rnd, period = np.random.randint(0,db.nrounds), np.random.randint(0,db.nperiods)
db.get_token_values(rnd).item()

# %%
db.get_period(rnd, period)

# %%
db.graph_period(rnd, period)
# Out:
# Rounds:1, Periods1, Tokens:4, Buyers:5, Sellers6, R1 to R4:(10, 10, 10, 10)

# %%
individual_outcomes(db)
# Out:
#                  mean_bids  mean_price  mean_profit  total_sales  total_profit
# current_bid_idx
# 0                20.714815   19.225000     1.757407           22         47.45
# 1                20.342857   17.709615     3.272857           26        114.55
# 2                20.848800   17.460714     0.554000           14         69.25
# 3                19.235593   18.528571     2.015254           21        118.90
# 4                21.758491   20.792857     0.995283            8         52.75
# 5                17.121053   14.830769     0.772368           55         58.70

# %%
winners_buyers = list(individual_outcomes(db).sort_values(by='total_profit', ascending=False).index)

for i in winners_buyers:
    print(list_of_strategies[i])
# Out:
# Markup
# Random
# Creeper
# Foresight
# Sniper
# Honest

# %%
winners_sellers = list(individual_outcomes(db, buyers=False).sort_values(by='total_profit', ascending=False).index)
list_of_strategies = ['Honest', 'Random', 'Creeper', 'Markup', 'Sniper']

for i in winners_sellers:
    print(list_of_strategies[i])
# Out:
# Random
# Sniper
# Creeper
# Honest

# %%
individual_outcomes(db, buyers = False)
# Out:
#                  mean_asks  mean_price  mean_profit  total_sales  total_profit
# current_ask_idx
# 1                 6.500000       12.50     6.000000            2         12.00
# 2                13.305263       11.95     0.056579            1          2.15
# 3                 8.040000       12.28     4.240000            5         21.20
# 4                 9.600000       11.97     2.370000            5         11.85

# %%
market_outcomes(db)
# Out:
#             mean_market_price     p_eqbm  q_eqbm  total_sales
# rnd period
# 0   0               12.169231  11.697998    14.0           13
