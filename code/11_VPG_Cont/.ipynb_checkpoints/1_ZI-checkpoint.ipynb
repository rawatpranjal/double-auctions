# %%
from utils import * 
from algorithms import *
from agents import *

# %%
numRounds, numPeriods, numSteps = 1, 5000, 10
numBuyers, numSellers, numTokens = 4, 4, 4
gameTypes, seed = '1111', 42
gameData = [gameTypes, numBuyers, numSellers, numTokens, numRounds, numPeriods, numSteps, seed]
disclosure = ['bids', 'asks', 'currentBid', 'currentBidIdx','currentAsk', 'currentAskIdx', 'buy', 'sell', 'price', 'sale']
depth = 1
buyers = [ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0),
          ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0),
          ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0),
          ZeroIntelligence(gameData, disclosure, index=0, buyer=1, reinforcer=0)]
sellers = [ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0),
           ZeroIntelligence(gameData, disclosure, index=0, buyer=0, reinforcer=0)]
log = Log(gameData, disclosure)
rnd = 0
state_record = []
reward_record = []

# %%
for rnd in range(numRounds):
    startRounds(gameData, log, buyers, sellers, rnd)
    print(log.roundData.buyerValues.item())
    print(log.roundData.sellerCosts.item())
    for period in range(numPeriods):
        startPeriods(buyers, sellers)
        for step in range(numSteps):
            startSteps(buyers, sellers)
            buyers[0].state = generateState(buyers[0], disclosure, depth)
            state_record.append(buyers[0].state)
            bids, asks = collectOffers(buyers, sellers)
            currentAsk, currentAskIdx, currentBid, currentBidIdx = bestOffers(bids, asks)
            price, buy, sell = trade(buyers, sellers, currentAsk, currentAskIdx, currentBid, currentBidIdx)
            bprofit, sprofit = 0, 0
            if price > 0:
                buyers[currentBidIdx].transact(price)
                sellers[currentAskIdx].transact(price)
                bprofit = buyers[currentBidIdx].stepProfits
                sprofit = sellers[currentAskIdx].stepProfits
            reward_record.append(buyers[0].stepProfits)
            log.addStep([rnd, period, step, bids, asks, currentBid, currentBidIdx, currentAsk, currentAskIdx, buy, sell, price, price>0, bprofit, sprofit])
            observe(buyers, sellers, log.disclose())
            agentsObserve(buyers, sellers)
            agentsTrain(buyers, sellers)
            endSteps(buyers, sellers)
        endPeriods(buyers, sellers)
    endRounds(buyers, sellers)
# Out:
# [[85.82202637 81.73001813 81.63077519 77.98802756]
#  [86.00286066 81.75851481 77.79014457 77.22312836]
#  [83.24607464 78.75300079 77.92916939 77.73215368]
#  [81.78455651 76.72373723 71.09604113 70.44124563]]
# [[42.84624139 45.55309494 45.88317457 51.95146854]
#  [40.61548525 47.08281665 48.26232262 56.1070403 ]
#  [42.80119778 46.68836691 49.39779518 50.24920035]
#  [47.07267989 47.93213437 48.90976077 59.15714846]]

# %%
states = np.array(state_record)
rewards = np.array(reward_record)
x = np.r_[np.mean(rewards), np.std(rewards)]

np.savetxt('mean.csv', np.mean(states,axis=0), delimiter=',')
np.savetxt('std.csv', np.std(states,axis=0), delimiter=',')
np.savetxt('mean_rewards.csv', x, delimiter=',')

# %%
states = pd.DataFrame(state_record, columns = disclosure)

# %%
mean, std = np.loadtxt('mean_rewards.csv', delimiter=',')
mean
# Out:
# 5.973607515719246

# %%
log.stepData.tail(1000)[['currentBidIdx', 'bprofit']].groupby('currentBidIdx').sum()/log.stepData.tail(1000).period.nunique()
# Out:
#                  bprofit
# currentBidIdx
# 0              58.655204
# 1              54.109045
# 2              48.269351
# 3              30.547908

# %%
log.stepData.tail(1000)[['currentAskIdx', 'bprofit']].groupby('currentAskIdx').sum()/log.stepData.tail(1000).period.nunique()
# Out:
#                  bprofit
# currentAskIdx
# 0              55.187007
# 1              51.927322
# 2              49.707444
# 3              34.759736

# %%
log.getPeriod(0, period-1)
# Out:
#       rnd  period  step                      bids                      asks  \
# 9980    0     998     0  [76.8, 54.6, 81.5, 41.6]  [51.0, 42.7, 51.0, 48.4]
# 9981    0     998     1  [70.6, 45.7, 63.6, 50.5]  [46.7, 55.3, 56.5, 60.7]
# 9982    0     998     2  [68.7, 82.5, 47.4, 57.8]  [51.6, 60.9, 48.9, 60.2]
# 9983    0     998     3  [74.5, 63.4, 72.4, 65.9]  [65.4, 69.0, 58.5, 65.7]
# 9984    0     998     4  [60.0, 69.7, 40.9, 80.4]  [65.9, 68.1, 56.3, 53.7]
# 9985    0     998     5  [57.2, 76.9, 73.2, 49.5]  [57.9, 58.3, 65.5, 53.1]
# 9986    0     998     6  [44.3, 40.0, 54.4, 74.7]  [61.2, 64.7, 72.7, 59.2]
# 9987    0     998     7  [60.2, 52.9, 46.5, 62.8]  [66.2, 66.2, 50.6, 68.0]
# 9988    0     998     8  [65.0, 51.6, 45.3, 54.2]  [57.4, 63.8, 75.4, 78.3]
# 9989    0     998     9  [51.4, 76.1, 61.9, 58.0]  [54.1, 57.7, 60.8, 86.8]
#
#       currentBid  currentBidIdx  currentAsk  currentAskIdx   buy  sell  price  \
# 9980        81.5              2        42.7              1  True  True  62.10
# 9981        70.6              0        46.7              0  True  True  58.65
# 9982        82.5              1        48.9              2  True  True  65.70
# 9983        74.5              0        58.5              2  True  True  66.50
# 9984        80.4              3        53.7              3  True  True  67.05
# 9985        76.9              1        53.1              3  True  True  65.00
# 9986        74.7              3        59.2              3  True  True  66.95
# 9987        62.8              3        50.6              2  True  True  56.70
# 9988        65.0              0        57.4              0  True  True  61.20
# 9989        76.1              1        54.1              0  True  True  65.10
#
#       sale    bprofit    sprofit
# 9980  True  21.146075  21.484515
# 9981  True  27.172026  15.803759
# 9982  True  20.302861  22.898802
# 9983  True  15.230018  19.811633
# 9984  True  14.734557  19.977320
# 9985  True  16.758515  17.067866
# 9986  True   9.773737  18.040239
# 9987  True  14.396041   7.302205
# 9988  True  20.430775  15.646905
# 9989  True  12.690145  19.216825

# %%
log.graphLearning(rolling_window = 500, trackBuyersIdx=[0], trackSellersIdx=[0])

# %%
log.graphSales(0, period-1, trackBuyersIdx=[0], trackSellersIdx=[0])

# %%
log.stepData.tail(15)
# Out:
#        rnd  period  step                      bids                      asks  \
# 15985    0     999     1  [76.3, 45.6, 73.9, 59.1]  [59.5, 50.4, 52.0, 63.1]
# 15986    0     999     2  [50.1, 63.9, 75.2, 47.2]  [47.7, 61.3, 63.4, 57.2]
# 15987    0     999     3  [74.1, 63.2, 48.6, 60.7]  [56.0, 53.0, 50.4, 56.3]
# 15988    0     999     4  [72.5, 56.2, 75.8, 41.4]  [48.8, 47.7, 64.6, 50.0]
# 15989    0     999     5  [61.4, 76.5, 58.0, 44.9]  [65.1, 53.2, 48.9, 65.1]
# 15990    0     999     6  [40.1, 66.1, 55.3, 58.7]  [64.3, 49.4, 67.7, 63.7]
# 15991    0     999     7  [73.7, 61.3, 45.2, 42.8]  [56.0, 76.3, 50.4, 52.9]
# 15992    0     999     8   [nan, 68.9, 47.9, 56.5]  [63.0, 68.2, 69.6, 53.4]
# 15993    0     999     9   [nan, 75.6, 42.6, 71.6]  [47.6, 79.8, 53.7, 62.0]
# 15994    0     999    10    [nan, nan, 52.0, 65.6]  [53.2, 80.8, 68.2, 56.2]
# 15995    0     999    11    [nan, nan, 57.3, 62.4]   [nan, 73.4, 66.3, 51.6]
# 15996    0     999    12    [nan, nan, 69.9, 51.9]   [nan, 78.6, 73.6, 51.4]
# 15997    0     999    13    [nan, nan, 52.7, 54.4]   [nan, 59.9, 56.8, 60.6]
# 15998    0     999    14    [nan, nan, 65.3, 52.7]    [nan, 57.0, nan, 68.1]
# 15999    0     999    15     [nan, nan, nan, 49.6]     [nan, nan, nan, 69.3]
#
#        currentBid  currentBidIdx  currentAsk  currentAskIdx   buy   sell  \
# 15985        76.3              0        50.4              1  True   True
# 15986        75.2              2        47.7              0  True   True
# 15987        74.1              0        50.4              2  True   True
# 15988        75.8              2        47.7              1  True   True
# 15989        76.5              1        48.9              2  True   True
# 15990        66.1              1        49.4              1  True   True
# 15991        73.7              0        50.4              2  True   True
# 15992        68.9              1        53.4              3  True   True
# 15993        75.6              1        47.6              0  True   True
# 15994        65.6              3        53.2              0  True   True
# 15995        62.4              3        51.6              3  True   True
# 15996        69.9              2        51.4              3  True   True
# 15997        54.4              3        56.8              2  True   True
# 15998        65.3              2        57.0              1  True   True
# 15999        49.6              3        69.3              3  True  False
#
#        price  sale    bprofit    sprofit
# 15985  63.35  True  18.380018  22.734515
# 15986  61.45  True  21.796075  15.896905
# 15987  62.25  True  19.380775  19.448802
# 15988  61.75  True  17.003001  14.667183
# 15989  62.70  True  23.302861  16.011633
# 15990  57.75  True  24.008515   9.487677
# 15991  62.05  True  15.938028  12.652205
# 15992  61.15  True  16.640145  14.077320
# 15993  61.60  True  15.623128  15.716825
# 15994  59.40  True  22.384557   7.448531
# 15995  57.00  True  19.723737   9.067866
# 15996  60.65  True  17.279169  11.740239
# 15997  55.60  True  15.496041   5.350800
# 15998  61.15  True  16.582154   5.042960
# 15999  69.30  True   1.141246  10.142852

# %%
log.getPeriod(0, period-1).sum()
# Out:
# rnd                                                              0
# period                                                       15968
# step                                                           120
# bids             [82.1, 60.3, 74.1, 56.3, 77.9, 83.4, 60.4, 41....
# asks             [48.0, 58.7, 53.2, 56.3, 46.3, 53.0, 61.0, 67....
# currentBid                                                  1105.0
# currentBidIdx                                                   24
# currentAsk                                                   872.2
# currentAskIdx                                                   24
# buy                                                             15
# sell                                                            13
# price                                                       1001.9
# sale                                                            16
# bprofit                                                 265.751475
# sprofit                                                 231.390072
# dtype: object

# %%
log.graphOffers(0, period-1, trackBuyersIdx=[0], trackSellersIdx=[0])

# %%
log.graphTraining(maxNumPeriods=period-1, skip = int((period-1)/20), trackBuyersIdx = [0])
